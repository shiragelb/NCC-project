# %%
###getting the reports local url's:###
##extracting folders id from shared memory

from google.colab import auth
from googleapiclient.discovery import build
import pandas as pd

# Authenticate
auth.authenticate_user()
drive_service = build('drive', 'v3')

folder_id = "1e0eA-AIsz_BSwVHOppJMXECX42hBfG4J"

def list_all_files_in_folder_recursive(parent_id, parent_path=""):
    """Recursively list all files in a folder and subfolders"""
    all_files = []

    query = f"'{parent_id}' in parents and trashed=false"
    page_token = None

    while True:
        response = drive_service.files().list(
            q=query,
            spaces='drive',
            fields='nextPageToken, files(id, name, mimeType)',
            pageToken=page_token
        ).execute()

        for item in response.get('files', []):
            item_path = f"{parent_path}/{item['name']}" if parent_path else item['name']

            if item['mimeType'] == 'application/vnd.google-apps.folder':
                # Recurse into subfolder
                all_files.extend(list_all_files_in_folder_recursive(item['id'], item_path))
            else:
                all_files.append({
                    "file_name": item['name'],
                    "file_path": item_path,
                    "file_id": item['id'],
                    "file_url": f"https://drive.google.com/file/d/{item['id']}/view?usp=sharing"
                })

        page_token = response.get('nextPageToken', None)
        if page_token is None:
            break

    return all_files

# Run the recursive function
files_list = list_all_files_in_folder_recursive(folder_id)

# Convert to DataFrame
df_files = pd.DataFrame(files_list)
##df_files.head()


##getting local id of the file
# !pip install python-docx
import os
from googleapiclient.http import MediaIoBaseDownload
import io

def get_chapter_file(chapter_num: int, year: str, download_dir="/content") -> str:
    """
    Download a chapter file for a given year from Google Drive and return its local path.

    Args:
        chapter_num (int): The chapter number (e.g., 1, 2, ..., 14).
        year (str): The year folder name.
        download_dir (str): Local folder to save the file. Defaults to /content in Colab.

    Returns:
        str: Local path to the downloaded file, or None if not found.
    """
    # Normalize chapter filename (01, 02, ...)
    chapter_str = f"{chapter_num:02}"

    # Find matching file in df_files
    match = df_files[
        (df_files["file_name"].str.contains(chapter_str)) &
        (df_files["file_path"].str.contains(f"{year}/"))
    ]

    if match.empty:
        print(f"❌ No file found for chapter {chapter_str} in year {year}")
        return None

    file_id = match.iloc[0]["file_id"]
    file_name = match.iloc[0]["file_name"]
    local_path = os.path.join(download_dir, year, file_name)

    # Ensure year directory exists locally
    os.makedirs(os.path.dirname(local_path), exist_ok=True)

    # Download the file from Google Drive
    request = drive_service.files().get_media(fileId=file_id)
    fh = io.FileIO(local_path, "wb")
    downloader = MediaIoBaseDownload(fh, request)

    done = False
    while not done:
        status, done = downloader.next_chunk()
        if status:
            print(f"⬇️ Download {int(status.progress() * 100)}%.")

    print(f"✅ Saved to {local_path}")
    return local_path
# Out:
# Collecting python-docx
#   Downloading python_docx-1.2.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from python-docx) (5.4.0)
# Requirement already satisfied: typing_extensions>=4.9.0 in /usr/local/lib/python3.12/dist-packages (from python-docx) (4.15.0)
# Downloading python_docx-1.2.0-py3-none-any.whl (252 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 9.2 MB/s eta 0:00:00
# Installing collected packages: python-docx
# Successfully installed python-docx-1.2.0

# %%
#a code that downloads the files to a directory called content/reports ####

import os
import io
from googleapiclient.http import MediaIoBaseDownload

def download_all_chapters(download_dir="/content/reports", years=range(2001, 2016), chapters=range(1, 16)):
    """
    Downloads all chapters for all years to local environment.

    Returns:
        dict: {year: {chapter_number: local_path}}
    """
    all_paths = {}

    for year in years:
        year_str = str(year)
        all_paths[year_str] = {}

        for chapter in chapters:
            chapter_str = f"{chapter:02}"

            # Find matching file in df_files
            # Find matching .docx file in df_files
            match = df_files[
                (df_files["file_name"].str.endswith(".docx")) &   # only docx
                (df_files["file_name"].str.contains(chapter_str)) &
                (df_files["file_path"].str.contains(f"{year_str}/"))
            ]

            if match.empty:
                print(f"⚠️ Chapter {chapter_str} not found for year {year_str}")
                continue

            file_id = match.iloc[0]["file_id"]
            file_name = match.iloc[0]["file_name"]
            local_path = os.path.join(download_dir, year_str, f"{chapter_str}_{file_name}")

            # Ensure folder exists
            os.makedirs(os.path.dirname(local_path), exist_ok=True)

            # Download file
            request = drive_service.files().get_media(fileId=file_id)
            fh = io.FileIO(local_path, "wb")
            downloader = MediaIoBaseDownload(fh, request)

            done = False
            while not done:
                status, done = downloader.next_chunk()
                if status:
                    print(f"⬇️ Download {int(status.progress() * 100)}% for {file_name}")

            print(f"✅ Saved {file_name} to {local_path}")
            all_paths[year_str][chapter] = local_path

    return all_paths
download_all_chapters()
# Out:
# ⬇️ Download 100% for 01.docx
# ✅ Saved 01.docx to /content/reports/2001/01_01.docx
# ⬇️ Download 100% for 02.docx
# ✅ Saved 02.docx to /content/reports/2001/02_02.docx
# ⬇️ Download 100% for 03.docx
# ✅ Saved 03.docx to /content/reports/2001/03_03.docx
# ⬇️ Download 100% for 04.docx
# ✅ Saved 04.docx to /content/reports/2001/04_04.docx
# ⬇️ Download 100% for 05.docx
# ✅ Saved 05.docx to /content/reports/2001/05_05.docx
# ⬇️ Download 100% for 06.docx
# ✅ Saved 06.docx to /content/reports/2001/06_06.docx
# ⬇️ Download 100% for 07.docx
# ✅ Saved 07.docx to /content/reports/2001/07_07.docx
# ⬇️ Download 100% for 08.docx
# ✅ Saved 08.docx to /content/reports/2001/08_08.docx
# ⬇️ Download 100% for 09.docx
# ✅ Saved 09.docx to /content/reports/2001/09_09.docx
# ⬇️ Download 100% for 10.docx
# ✅ Saved 10.docx to /content/reports/2001/10_10.docx
# ⬇️ Download 100% for 11.docx
# ✅ Saved 11.docx to /content/reports/2001/11_11.docx
# ⬇️ Download 100% for 12.docx
# ✅ Saved 12.docx to /content/reports/2001/12_12.docx
# ⬇️ Download 100% for 13.docx
# ✅ Saved 13.docx to /content/reports/2001/13_13.docx
# ⬇️ Download 100% for 14.docx
# ✅ Saved 14.docx to /content/reports/2001/14_14.docx
# ⬇️ Download 100% for 15.docx
# ✅ Saved 15.docx to /content/reports/2001/15_15.docx
# ⬇️ Download 100% for 01.docx
# ✅ Saved 01.docx to /content/reports/2002/01_01.docx
# ⬇️ Download 100% for 02.docx
# ✅ Saved 02.docx to /content/reports/2002/02_02.docx
# ⬇️ Download 100% for 03.docx
# ✅ Saved 03.docx to /content/reports/2002/03_03.docx
# ⬇️ Download 100% for 04.docx
# ✅ Saved 04.docx to /content/reports/2002/04_04.docx
# ⬇️ Download 100% for 05.docx
# ✅ Saved 05.docx to /content/reports/2002/05_05.docx
# ⬇️ Download 100% for 06.docx
# ✅ Saved 06.docx to /content/reports/2002/06_06.docx
# ⬇️ Download 100% for 07.docx
# ✅ Saved 07.docx to /content/reports/2002/07_07.docx
# ⬇️ Download 100% for 08.docx
# ✅ Saved 08.docx to /content/reports/2002/08_08.docx
# ⬇️ Download 100% for 09.docx
# ✅ Saved 09.docx to /content/reports/2002/09_09.docx
# ⬇️ Download 100% for 10.docx
# ✅ Saved 10.docx to /content/reports/2002/10_10.docx
# ⬇️ Download 100% for 11.docx
# ✅ Saved 11.docx to /content/reports/2002/11_11.docx
# ⬇️ Download 100% for 12.docx
# ✅ Saved 12.docx to /content/reports/2002/12_12.docx
# ⬇️ Download 100% for 13.docx
# ✅ Saved 13.docx to /content/reports/2002/13_13.docx
# ⬇️ Download 100% for 14.docx
# ✅ Saved 14.docx to /content/reports/2002/14_14.docx
# ⬇️ Download 100% for 15.docx
# ✅ Saved 15.docx to /content/reports/2002/15_15.docx
# ⬇️ Download 100% for 01.docx
# ✅ Saved 01.docx to /content/reports/2003/01_01.docx
# ⬇️ Download 100% for 02.docx
# ✅ Saved 02.docx to /content/reports/2003/02_02.docx
# ⬇️ Download 100% for 03.docx
# ✅ Saved 03.docx to /content/reports/2003/03_03.docx
# ⬇️ Download 100% for 04.docx
# ✅ Saved 04.docx to /content/reports/2003/04_04.docx
# ⬇️ Download 100% for 05.docx
# ✅ Saved 05.docx to /content/reports/2003/05_05.docx
# ⬇️ Download 100% for 06.docx
# ✅ Saved 06.docx to /content/reports/2003/06_06.docx
# ⬇️ Download 100% for 07.docx
# ✅ Saved 07.docx to /content/reports/2003/07_07.docx
# ⬇️ Download 100% for 08.docx
# ✅ Saved 08.docx to /content/reports/2003/08_08.docx
# ⬇️ Download 100% for 09.docx
# ✅ Saved 09.docx to /content/reports/2003/09_09.docx
# ⬇️ Download 100% for 10.docx
# ✅ Saved 10.docx to /content/reports/2003/10_10.docx
# ⬇️ Download 100% for 11.docx
# ✅ Saved 11.docx to /content/reports/2003/11_11.docx
# ⬇️ Download 100% for 12.docx
# ✅ Saved 12.docx to /content/reports/2003/12_12.docx
# ⬇️ Download 100% for 13.docx
# ✅ Saved 13.docx to /content/reports/2003/13_13.docx
# ⬇️ Download 100% for 14.docx
# ✅ Saved 14.docx to /content/reports/2003/14_14.docx
# ⬇️ Download 100% for 15.docx
# ✅ Saved 15.docx to /content/reports/2003/15_15.docx
# ⬇️ Download 100% for 01.docx
# ✅ Saved 01.docx to /content/reports/2004/01_01.docx
# ⬇️ Download 100% for 02.docx
# ✅ Saved 02.docx to /content/reports/2004/02_02.docx
# ⬇️ Download 100% for 03.docx
# ✅ Saved 03.docx to /content/reports/2004/03_03.docx
# ⬇️ Download 100% for 04.docx
# ✅ Saved 04.docx to /content/reports/2004/04_04.docx
# ⬇️ Download 100% for 05.docx
# ✅ Saved 05.docx to /content/reports/2004/05_05.docx
# ⬇️ Download 100% for 06.docx
# ✅ Saved 06.docx to /content/reports/2004/06_06.docx
# ⬇️ Download 100% for 07.docx
# ✅ Saved 07.docx to /content/reports/2004/07_07.docx
# ⬇️ Download 100% for 08.docx
# ✅ Saved 08.docx to /content/reports/2004/08_08.docx
# ⚠️ Chapter 09 not found for year 2004
# ⬇️ Download 100% for 10.docx
# ✅ Saved 10.docx to /content/reports/2004/10_10.docx
# ⚠️ Chapter 11 not found for year 2004
# ⬇️ Download 100% for 12.docx
# ✅ Saved 12.docx to /content/reports/2004/12_12.docx
# ⬇️ Download 100% for 13.docx
# ✅ Saved 13.docx to /content/reports/2004/13_13.docx
# ⬇️ Download 100% for 14.docx
# ✅ Saved 14.docx to /content/reports/2004/14_14.docx
# ⬇️ Download 100% for 15.docx
# ✅ Saved 15.docx to /content/reports/2004/15_15.docx
# ⬇️ Download 100% for 01.docx
# ✅ Saved 01.docx to /content/reports/2005/01_01.docx
# ⬇️ Download 100% for 02.docx
# ✅ Saved 02.docx to /content/reports/2005/02_02.docx
# ⬇️ Download 100% for 03.docx
# ✅ Saved 03.docx to /content/reports/2005/03_03.docx
# ⬇️ Download 100% for 04.docx
# ✅ Saved 04.docx to /content/reports/2005/04_04.docx
# ⬇️ Download 100% for 05_content2005.docx
# ✅ Saved 05_content2005.docx to /content/reports/2005/05_05_content2005.docx
# ⬇️ Download 100% for 06.docx
# ✅ Saved 06.docx to /content/reports/2005/06_06.docx
# ⬇️ Download 100% for 07.docx
# ✅ Saved 07.docx to /content/reports/2005/07_07.docx
# ⬇️ Download 100% for 08.docx
# ✅ Saved 08.docx to /content/reports/2005/08_08.docx
# ⬇️ Download 100% for 09.docx
# ✅ Saved 09.docx to /content/reports/2005/09_09.docx
# ⬇️ Download 100% for 10.docx
# ✅ Saved 10.docx to /content/reports/2005/10_10.docx
# ⬇️ Download 100% for 11.docx
# ✅ Saved 11.docx to /content/reports/2005/11_11.docx
# ⬇️ Download 100% for 12.docx
# ✅ Saved 12.docx to /content/reports/2005/12_12.docx
# ⬇️ Download 100% for 13.docx
# ✅ Saved 13.docx to /content/reports/2005/13_13.docx
# ⬇️ Download 100% for 14.docx
# ✅ Saved 14.docx to /content/reports/2005/14_14.docx
# ⬇️ Download 100% for 15.docx
# ✅ Saved 15.docx to /content/reports/2005/15_15.docx
# ⬇️ Download 100% for 01.docx
# ✅ Saved 01.docx to /content/reports/2006/01_01.docx
# ⬇️ Download 100% for 02.docx
# ✅ Saved 02.docx to /content/reports/2006/02_02.docx
# ⬇️ Download 100% for 03.docx
# ✅ Saved 03.docx to /content/reports/2006/03_03.docx
# ⬇️ Download 100% for 04.docx
# ✅ Saved 04.docx to /content/reports/2006/04_04.docx
# ⬇️ Download 100% for 05.docx
# ✅ Saved 05.docx to /content/reports/2006/05_05.docx
# ⬇️ Download 100% for 06.docx
# ✅ Saved 06.docx to /content/reports/2006/06_06.docx
# ⬇️ Download 100% for 07.docx
# ✅ Saved 07.docx to /content/reports/2006/07_07.docx
# ⬇️ Download 100% for 08.docx
# ✅ Saved 08.docx to /content/reports/2006/08_08.docx
# ⬇️ Download 100% for 09.docx
# ✅ Saved 09.docx to /content/reports/2006/09_09.docx
# ⬇️ Download 100% for 10.docx
# ✅ Saved 10.docx to /content/reports/2006/10_10.docx
# ⬇️ Download 100% for 11.docx
# ✅ Saved 11.docx to /content/reports/2006/11_11.docx
# ⬇️ Download 100% for 12.docx
# ✅ Saved 12.docx to /content/reports/2006/12_12.docx
# ⬇️ Download 100% for 13.docx
# ✅ Saved 13.docx to /content/reports/2006/13_13.docx
# ⬇️ Download 100% for 14.docx
# ✅ Saved 14.docx to /content/reports/2006/14_14.docx
# ⬇️ Download 100% for 15.docx
# ✅ Saved 15.docx to /content/reports/2006/15_15.docx
# ⬇️ Download 100% for 01.docx
# ✅ Saved 01.docx to /content/reports/2007/01_01.docx
# ⬇️ Download 100% for 02.docx
# ✅ Saved 02.docx to /content/reports/2007/02_02.docx
# ⬇️ Download 100% for 03.docx
# ✅ Saved 03.docx to /content/reports/2007/03_03.docx
# ⬇️ Download 100% for 04.docx
# ✅ Saved 04.docx to /content/reports/2007/04_04.docx
# ⬇️ Download 100% for 05.docx
# ✅ Saved 05.docx to /content/reports/2007/05_05.docx
# ⬇️ Download 100% for 06.docx
# ✅ Saved 06.docx to /content/reports/2007/06_06.docx
# ⬇️ Download 100% for 07.docx
# ✅ Saved 07.docx to /content/reports/2007/07_07.docx
# ⬇️ Download 100% for 08.docx
# ✅ Saved 08.docx to /content/reports/2007/08_08.docx
# ⬇️ Download 100% for 09.docx
# ✅ Saved 09.docx to /content/reports/2007/09_09.docx
# ⬇️ Download 100% for 10.docx
# ✅ Saved 10.docx to /content/reports/2007/10_10.docx
# ⬇️ Download 100% for 11.docx
# ✅ Saved 11.docx to /content/reports/2007/11_11.docx
# ⬇️ Download 100% for 12.docx
# ✅ Saved 12.docx to /content/reports/2007/12_12.docx
# ⬇️ Download 100% for 13.docx
# ✅ Saved 13.docx to /content/reports/2007/13_13.docx
# ⬇️ Download 100% for 14.docx
# ✅ Saved 14.docx to /content/reports/2007/14_14.docx
# ⬇️ Download 100% for 15.docx
# ✅ Saved 15.docx to /content/reports/2007/15_15.docx
# ⬇️ Download 100% for 01.docx
# ✅ Saved 01.docx to /content/reports/2008/01_01.docx
# ⬇️ Download 100% for 02.docx
# ✅ Saved 02.docx to /content/reports/2008/02_02.docx
# ⬇️ Download 100% for 03.docx
# ✅ Saved 03.docx to /content/reports/2008/03_03.docx
# ⬇️ Download 100% for 04.docx
# ✅ Saved 04.docx to /content/reports/2008/04_04.docx
# ⬇️ Download 100% for 05.docx
# ✅ Saved 05.docx to /content/reports/2008/05_05.docx
# ⬇️ Download 100% for 06.docx
# ✅ Saved 06.docx to /content/reports/2008/06_06.docx
# ⬇️ Download 100% for 07.docx
# ✅ Saved 07.docx to /content/reports/2008/07_07.docx
# ⬇️ Download 100% for 08.docx
# ✅ Saved 08.docx to /content/reports/2008/08_08.docx
# ⬇️ Download 100% for 09.docx
# ✅ Saved 09.docx to /content/reports/2008/09_09.docx
# ⬇️ Download 100% for 10.docx
# ✅ Saved 10.docx to /content/reports/2008/10_10.docx
# ⬇️ Download 100% for 11.docx
# ✅ Saved 11.docx to /content/reports/2008/11_11.docx
# ⬇️ Download 100% for 12.docx
# ✅ Saved 12.docx to /content/reports/2008/12_12.docx
# ⬇️ Download 100% for 13.docx
# ✅ Saved 13.docx to /content/reports/2008/13_13.docx
# ⬇️ Download 100% for 14.docx
# ✅ Saved 14.docx to /content/reports/2008/14_14.docx
# ⬇️ Download 100% for 15.docx
# ✅ Saved 15.docx to /content/reports/2008/15_15.docx
# ⬇️ Download 100% for 01.docx
# ✅ Saved 01.docx to /content/reports/2009/01_01.docx
# ⬇️ Download 100% for 02.docx
# ✅ Saved 02.docx to /content/reports/2009/02_02.docx
# ⬇️ Download 100% for 03.docx
# ✅ Saved 03.docx to /content/reports/2009/03_03.docx
# ⬇️ Download 100% for 04.docx
# ✅ Saved 04.docx to /content/reports/2009/04_04.docx
# ⬇️ Download 100% for 05.docx
# ✅ Saved 05.docx to /content/reports/2009/05_05.docx
# ⚠️ Chapter 06 not found for year 2009
# ⬇️ Download 100% for 07.docx
# ✅ Saved 07.docx to /content/reports/2009/07_07.docx
# ⬇️ Download 100% for 08.docx
# ✅ Saved 08.docx to /content/reports/2009/08_08.docx
# ⬇️ Download 100% for 09.docx
# ✅ Saved 09.docx to /content/reports/2009/09_09.docx
# ⬇️ Download 100% for 10.docx
# ✅ Saved 10.docx to /content/reports/2009/10_10.docx
# ⬇️ Download 100% for 11.docx
# ✅ Saved 11.docx to /content/reports/2009/11_11.docx
# ⬇️ Download 100% for 12.docx
# ✅ Saved 12.docx to /content/reports/2009/12_12.docx
# ⬇️ Download 100% for 13.docx
# ✅ Saved 13.docx to /content/reports/2009/13_13.docx
# ⬇️ Download 100% for 14.docx
# ✅ Saved 14.docx to /content/reports/2009/14_14.docx
# ⬇️ Download 100% for 15.docx
# ✅ Saved 15.docx to /content/reports/2009/15_15.docx
# ⬇️ Download 100% for 01.docx
# ✅ Saved 01.docx to /content/reports/2010/01_01.docx
# ⬇️ Download 100% for 02.docx
# ✅ Saved 02.docx to /content/reports/2010/02_02.docx
# ⬇️ Download 100% for 03.docx
# ✅ Saved 03.docx to /content/reports/2010/03_03.docx
# ⬇️ Download 100% for 04.docx
# ✅ Saved 04.docx to /content/reports/2010/04_04.docx
# ⬇️ Download 100% for 05.docx
# ✅ Saved 05.docx to /content/reports/2010/05_05.docx
# ⬇️ Download 100% for 06.docx
# ✅ Saved 06.docx to /content/reports/2010/06_06.docx
# ⬇️ Download 100% for 07.docx
# ✅ Saved 07.docx to /content/reports/2010/07_07.docx
# ⬇️ Download 100% for 08.docx
# ✅ Saved 08.docx to /content/reports/2010/08_08.docx
# ⬇️ Download 100% for 09.docx
# ✅ Saved 09.docx to /content/reports/2010/09_09.docx
# ⬇️ Download 100% for 10.docx
# ✅ Saved 10.docx to /content/reports/2010/10_10.docx
# ⬇️ Download 100% for 11.docx
# ✅ Saved 11.docx to /content/reports/2010/11_11.docx
# ⬇️ Download 100% for 12.docx
# ✅ Saved 12.docx to /content/reports/2010/12_12.docx
# ⬇️ Download 100% for 13.docx
# ✅ Saved 13.docx to /content/reports/2010/13_13.docx
# ⬇️ Download 100% for 14.docx
# ✅ Saved 14.docx to /content/reports/2010/14_14.docx
# ⬇️ Download 100% for 15.docx
# ✅ Saved 15.docx to /content/reports/2010/15_15.docx
# ⬇️ Download 100% for 01.docx
# ✅ Saved 01.docx to /content/reports/2011/01_01.docx
# ⬇️ Download 100% for 02.docx
# ✅ Saved 02.docx to /content/reports/2011/02_02.docx
# ⬇️ Download 100% for 03.docx
# ✅ Saved 03.docx to /content/reports/2011/03_03.docx
# ⬇️ Download 100% for 04.docx
# ✅ Saved 04.docx to /content/reports/2011/04_04.docx
# ⬇️ Download 100% for 05.docx
# ✅ Saved 05.docx to /content/reports/2011/05_05.docx
# ⬇️ Download 100% for 06.docx
# ✅ Saved 06.docx to /content/reports/2011/06_06.docx
# ⬇️ Download 100% for 07.docx
# ✅ Saved 07.docx to /content/reports/2011/07_07.docx
# ⬇️ Download 100% for 08.docx
# ✅ Saved 08.docx to /content/reports/2011/08_08.docx
# ⬇️ Download 100% for 09.docx
# ✅ Saved 09.docx to /content/reports/2011/09_09.docx
# ⬇️ Download 100% for 10.docx
# ✅ Saved 10.docx to /content/reports/2011/10_10.docx
# ⬇️ Download 100% for 11.docx
# ✅ Saved 11.docx to /content/reports/2011/11_11.docx
# ⬇️ Download 100% for 12.docx
# ✅ Saved 12.docx to /content/reports/2011/12_12.docx
# ⬇️ Download 100% for 13.docx
# ✅ Saved 13.docx to /content/reports/2011/13_13.docx
# ⬇️ Download 100% for 14.docx
# ✅ Saved 14.docx to /content/reports/2011/14_14.docx
# ⬇️ Download 100% for 15.docx
# ✅ Saved 15.docx to /content/reports/2011/15_15.docx
# ⬇️ Download 100% for 01.docx
# ✅ Saved 01.docx to /content/reports/2012/01_01.docx
# ⬇️ Download 100% for 02.docx
# ✅ Saved 02.docx to /content/reports/2012/02_02.docx
# ⬇️ Download 100% for 03.docx
# ✅ Saved 03.docx to /content/reports/2012/03_03.docx
# ⬇️ Download 100% for 04.docx
# ✅ Saved 04.docx to /content/reports/2012/04_04.docx
# ⬇️ Download 100% for 05.docx
# ✅ Saved 05.docx to /content/reports/2012/05_05.docx
# ⬇️ Download 100% for 06.docx
# ✅ Saved 06.docx to /content/reports/2012/06_06.docx
# ⬇️ Download 100% for 07.docx
# ✅ Saved 07.docx to /content/reports/2012/07_07.docx
# ⬇️ Download 100% for 08.docx
# ✅ Saved 08.docx to /content/reports/2012/08_08.docx
# ⬇️ Download 100% for 09.docx
# ✅ Saved 09.docx to /content/reports/2012/09_09.docx
# ⬇️ Download 100% for 10.docx
# ✅ Saved 10.docx to /content/reports/2012/10_10.docx
# ⬇️ Download 100% for 11.docx
# ✅ Saved 11.docx to /content/reports/2012/11_11.docx
# ⬇️ Download 100% for 12.docx
# ✅ Saved 12.docx to /content/reports/2012/12_12.docx
# ⬇️ Download 100% for 13.docx
# ✅ Saved 13.docx to /content/reports/2012/13_13.docx
# ⬇️ Download 100% for 14.docx
# ✅ Saved 14.docx to /content/reports/2012/14_14.docx
# ⬇️ Download 100% for 15.docx
# ✅ Saved 15.docx to /content/reports/2012/15_15.docx
# ⚠️ Chapter 01 not found for year 2013
# ⬇️ Download 100% for 02.docx
# ✅ Saved 02.docx to /content/reports/2013/02_02.docx
# ⬇️ Download 100% for 03.docx
# ✅ Saved 03.docx to /content/reports/2013/03_03.docx
# ⬇️ Download 100% for 04.docx
# ✅ Saved 04.docx to /content/reports/2013/04_04.docx
# ⬇️ Download 100% for 05.docx
# ✅ Saved 05.docx to /content/reports/2013/05_05.docx
# ⬇️ Download 100% for 06.docx
# ✅ Saved 06.docx to /content/reports/2013/06_06.docx
# ⬇️ Download 100% for 07.docx
# ✅ Saved 07.docx to /content/reports/2013/07_07.docx
# ⬇️ Download 100% for 08.docx
# ✅ Saved 08.docx to /content/reports/2013/08_08.docx
# ⬇️ Download 100% for 09.docx
# ✅ Saved 09.docx to /content/reports/2013/09_09.docx
# ⬇️ Download 100% for 10.docx
# ✅ Saved 10.docx to /content/reports/2013/10_10.docx
# ⬇️ Download 100% for 11.docx
# ✅ Saved 11.docx to /content/reports/2013/11_11.docx
# ⬇️ Download 100% for 12.docx
# ✅ Saved 12.docx to /content/reports/2013/12_12.docx
# ⬇️ Download 100% for 13.docx
# ✅ Saved 13.docx to /content/reports/2013/13_13.docx
# ⬇️ Download 100% for 14.docx
# ✅ Saved 14.docx to /content/reports/2013/14_14.docx
# ⬇️ Download 100% for 15.docx
# ✅ Saved 15.docx to /content/reports/2013/15_15.docx
# ⬇️ Download 100% for 01.docx
# ✅ Saved 01.docx to /content/reports/2014/01_01.docx
# ⬇️ Download 100% for 02.docx
# ✅ Saved 02.docx to /content/reports/2014/02_02.docx
# ⬇️ Download 100% for 03.docx
# ✅ Saved 03.docx to /content/reports/2014/03_03.docx
# ⬇️ Download 100% for 04.docx
# ✅ Saved 04.docx to /content/reports/2014/04_04.docx
# ⬇️ Download 100% for 05.docx
# ✅ Saved 05.docx to /content/reports/2014/05_05.docx
# ⬇️ Download 100% for 06.docx
# ✅ Saved 06.docx to /content/reports/2014/06_06.docx
# ⬇️ Download 100% for 07.docx
# ✅ Saved 07.docx to /content/reports/2014/07_07.docx
# ⬇️ Download 100% for 08.docx
# ✅ Saved 08.docx to /content/reports/2014/08_08.docx
# ⬇️ Download 100% for 09.docx
# ✅ Saved 09.docx to /content/reports/2014/09_09.docx
# ⬇️ Download 100% for 10.docx
# ✅ Saved 10.docx to /content/reports/2014/10_10.docx
# ⬇️ Download 100% for 11.docx
# ✅ Saved 11.docx to /content/reports/2014/11_11.docx
# ⬇️ Download 100% for 12.docx
# ✅ Saved 12.docx to /content/reports/2014/12_12.docx
# ⬇️ Download 100% for 13.docx
# ✅ Saved 13.docx to /content/reports/2014/13_13.docx
# ⬇️ Download 100% for 14.docx
# ✅ Saved 14.docx to /content/reports/2014/14_14.docx
# ⚠️ Chapter 15 not found for year 2014
# ⬇️ Download 100% for 01.docx
# ✅ Saved 01.docx to /content/reports/2015/01_01.docx
# ⬇️ Download 100% for 02.docx
# ✅ Saved 02.docx to /content/reports/2015/02_02.docx
# ⬇️ Download 100% for 03.docx
# ✅ Saved 03.docx to /content/reports/2015/03_03.docx
# ⬇️ Download 100% for 04.docx
# ✅ Saved 04.docx to /content/reports/2015/04_04.docx
# ⬇️ Download 100% for 05.docx
# ✅ Saved 05.docx to /content/reports/2015/05_05.docx
# ⬇️ Download 100% for 06.docx
# ✅ Saved 06.docx to /content/reports/2015/06_06.docx
# ⬇️ Download 100% for 07.docx
# ✅ Saved 07.docx to /content/reports/2015/07_07.docx
# ⬇️ Download 100% for 08.docx
# ✅ Saved 08.docx to /content/reports/2015/08_08.docx
# ⬇️ Download 100% for 09.docx
# ✅ Saved 09.docx to /content/reports/2015/09_09.docx
# ⬇️ Download 100% for 10.docx
# ✅ Saved 10.docx to /content/reports/2015/10_10.docx
# ⬇️ Download 100% for 11.docx
# ✅ Saved 11.docx to /content/reports/2015/11_11.docx
# ⬇️ Download 100% for 12.docx
# ✅ Saved 12.docx to /content/reports/2015/12_12.docx
# ⬇️ Download 100% for 13.docx
# ✅ Saved 13.docx to /content/reports/2015/13_13.docx
# ⬇️ Download 100% for 14.docx
# ✅ Saved 14.docx to /content/reports/2015/14_14.docx
# ⬇️ Download 100% for 15.docx
# ✅ Saved 15.docx to /content/reports/2015/15_15.docx
# {'2001': {1: '/content/reports/2001/01_01.docx',
#   2: '/content/reports/2001/02_02.docx',
#   3: '/content/reports/2001/03_03.docx',
#   4: '/content/reports/2001/04_04.docx',
#   5: '/content/reports/2001/05_05.docx',
#   6: '/content/reports/2001/06_06.docx',
#   7: '/content/reports/2001/07_07.docx',
#   8: '/content/reports/2001/08_08.docx',
#   9: '/content/reports/2001/09_09.docx',
#   10: '/content/reports/2001/10_10.docx',
#   11: '/content/reports/2001/11_11.docx',
#   12: '/content/reports/2001/12_12.docx',
#   13: '/content/reports/2001/13_13.docx',
#   14: '/content/reports/2001/14_14.docx',
#   15: '/content/reports/2001/15_15.docx'},
#  '2002': {1: '/content/reports/2002/01_01.docx',
#   2: '/content/reports/2002/02_02.docx',
#   3: '/content/reports/2002/03_03.docx',
#   4: '/content/reports/2002/04_04.docx',
#   5: '/content/reports/2002/05_05.docx',
#   6: '/content/reports/2002/06_06.docx',
#   7: '/content/reports/2002/07_07.docx',
#   8: '/content/reports/2002/08_08.docx',
#   9: '/content/reports/2002/09_09.docx',
#   10: '/content/reports/2002/10_10.docx',
#   11: '/content/reports/2002/11_11.docx',
#   12: '/content/reports/2002/12_12.docx',
#   13: '/content/reports/2002/13_13.docx',
#   14: '/content/reports/2002/14_14.docx',
#   15: '/content/reports/2002/15_15.docx'},
#  '2003': {1: '/content/reports/2003/01_01.docx',
#   2: '/content/reports/2003/02_02.docx',
#   3: '/content/reports/2003/03_03.docx',
#   4: '/content/reports/2003/04_04.docx',
#   5: '/content/reports/2003/05_05.docx',
#   6: '/content/reports/2003/06_06.docx',
#   7: '/content/reports/2003/07_07.docx',
#   8: '/content/reports/2003/08_08.docx',
#   9: '/content/reports/2003/09_09.docx',
#   10: '/content/reports/2003/10_10.docx',
#   11: '/content/reports/2003/11_11.docx',
#   12: '/content/reports/2003/12_12.docx',
#   13: '/content/reports/2003/13_13.docx',
#   14: '/content/reports/2003/14_14.docx',
#   15: '/content/reports/2003/15_15.docx'},
#  '2004': {1: '/content/reports/2004/01_01.docx',
#   2: '/content/reports/2004/02_02.docx',
#   3: '/content/reports/2004/03_03.docx',
#   4: '/content/reports/2004/04_04.docx',
#   5: '/content/reports/2004/05_05.docx',
#   6: '/content/reports/2004/06_06.docx',
#   7: '/content/reports/2004/07_07.docx',
#   8: '/content/reports/2004/08_08.docx',
#   10: '/content/reports/2004/10_10.docx',
#   12: '/content/reports/2004/12_12.docx',
#   13: '/content/reports/2004/13_13.docx',
#   14: '/content/reports/2004/14_14.docx',
#   15: '/content/reports/2004/15_15.docx'},
#  '2005': {1: '/content/reports/2005/01_01.docx',
#   2: '/content/reports/2005/02_02.docx',
#   3: '/content/reports/2005/03_03.docx',
#   4: '/content/reports/2005/04_04.docx',
#   5: '/content/reports/2005/05_05_content2005.docx',
#   6: '/content/reports/2005/06_06.docx',
#   7: '/content/reports/2005/07_07.docx',
#   8: '/content/reports/2005/08_08.docx',
#   9: '/content/reports/2005/09_09.docx',
#   10: '/content/reports/2005/10_10.docx',
#   11: '/content/reports/2005/11_11.docx',
#   12: '/content/reports/2005/12_12.docx',
#   13: '/content/reports/2005/13_13.docx',
#   14: '/content/reports/2005/14_14.docx',
#   15: '/content/reports/2005/15_15.docx'},
#  '2006': {1: '/content/reports/2006/01_01.docx',
#   2: '/content/reports/2006/02_02.docx',
#   3: '/content/reports/2006/03_03.docx',
#   4: '/content/reports/2006/04_04.docx',
#   5: '/content/reports/2006/05_05.docx',
#   6: '/content/reports/2006/06_06.docx',
#   7: '/content/reports/2006/07_07.docx',
#   8: '/content/reports/2006/08_08.docx',
#   9: '/content/reports/2006/09_09.docx',
#   10: '/content/reports/2006/10_10.docx',
#   11: '/content/reports/2006/11_11.docx',
#   12: '/content/reports/2006/12_12.docx',
#   13: '/content/reports/2006/13_13.docx',
#   14: '/content/reports/2006/14_14.docx',
#   15: '/content/reports/2006/15_15.docx'},
#  '2007': {1: '/content/reports/2007/01_01.docx',
#   2: '/content/reports/2007/02_02.docx',
#   3: '/content/reports/2007/03_03.docx',
#   4: '/content/reports/2007/04_04.docx',
#   5: '/content/reports/2007/05_05.docx',
#   6: '/content/reports/2007/06_06.docx',
#   7: '/content/reports/2007/07_07.docx',
#   8: '/content/reports/2007/08_08.docx',
#   9: '/content/reports/2007/09_09.docx',
#   10: '/content/reports/2007/10_10.docx',
#   11: '/content/reports/2007/11_11.docx',
#   12: '/content/reports/2007/12_12.docx',
#   13: '/content/reports/2007/13_13.docx',
#   14: '/content/reports/2007/14_14.docx',
#   15: '/content/reports/2007/15_15.docx'},
#  '2008': {1: '/content/reports/2008/01_01.docx',
#   2: '/content/reports/2008/02_02.docx',
#   3: '/content/reports/2008/03_03.docx',
#   4: '/content/reports/2008/04_04.docx',
#   5: '/content/reports/2008/05_05.docx',
#   6: '/content/reports/2008/06_06.docx',
#   7: '/content/reports/2008/07_07.docx',
#   8: '/content/reports/2008/08_08.docx',
#   9: '/content/reports/2008/09_09.docx',
#   10: '/content/reports/2008/10_10.docx',
#   11: '/content/reports/2008/11_11.docx',
#   12: '/content/reports/2008/12_12.docx',
#   13: '/content/reports/2008/13_13.docx',
#   14: '/content/reports/2008/14_14.docx',
#   15: '/content/reports/2008/15_15.docx'},
#  '2009': {1: '/content/reports/2009/01_01.docx',
#   2: '/content/reports/2009/02_02.docx',
#   3: '/content/reports/2009/03_03.docx',
#   4: '/content/reports/2009/04_04.docx',
#   5: '/content/reports/2009/05_05.docx',
#   7: '/content/reports/2009/07_07.docx',
#   8: '/content/reports/2009/08_08.docx',
#   9: '/content/reports/2009/09_09.docx',
#   10: '/content/reports/2009/10_10.docx',
#   11: '/content/reports/2009/11_11.docx',
#   12: '/content/reports/2009/12_12.docx',
#   13: '/content/reports/2009/13_13.docx',
#   14: '/content/reports/2009/14_14.docx',
#   15: '/content/reports/2009/15_15.docx'},
#  '2010': {1: '/content/reports/2010/01_01.docx',
#   2: '/content/reports/2010/02_02.docx',
#   3: '/content/reports/2010/03_03.docx',
#   4: '/content/reports/2010/04_04.docx',
#   5: '/content/reports/2010/05_05.docx',
#   6: '/content/reports/2010/06_06.docx',
#   7: '/content/reports/2010/07_07.docx',
#   8: '/content/reports/2010/08_08.docx',
#   9: '/content/reports/2010/09_09.docx',
#   10: '/content/reports/2010/10_10.docx',
#   11: '/content/reports/2010/11_11.docx',
#   12: '/content/reports/2010/12_12.docx',
#   13: '/content/reports/2010/13_13.docx',
#   14: '/content/reports/2010/14_14.docx',
#   15: '/content/reports/2010/15_15.docx'},
#  '2011': {1: '/content/reports/2011/01_01.docx',
#   2: '/content/reports/2011/02_02.docx',
#   3: '/content/reports/2011/03_03.docx',
#   4: '/content/reports/2011/04_04.docx',
#   5: '/content/reports/2011/05_05.docx',
#   6: '/content/reports/2011/06_06.docx',
#   7: '/content/reports/2011/07_07.docx',
#   8: '/content/reports/2011/08_08.docx',
#   9: '/content/reports/2011/09_09.docx',
#   10: '/content/reports/2011/10_10.docx',
#   11: '/content/reports/2011/11_11.docx',
#   12: '/content/reports/2011/12_12.docx',
#   13: '/content/reports/2011/13_13.docx',
#   14: '/content/reports/2011/14_14.docx',
#   15: '/content/reports/2011/15_15.docx'},
#  '2012': {1: '/content/reports/2012/01_01.docx',
#   2: '/content/reports/2012/02_02.docx',
#   3: '/content/reports/2012/03_03.docx',
#   4: '/content/reports/2012/04_04.docx',
#   5: '/content/reports/2012/05_05.docx',
#   6: '/content/reports/2012/06_06.docx',
#   7: '/content/reports/2012/07_07.docx',
#   8: '/content/reports/2012/08_08.docx',
#   9: '/content/reports/2012/09_09.docx',
#   10: '/content/reports/2012/10_10.docx',
#   11: '/content/reports/2012/11_11.docx',
#   12: '/content/reports/2012/12_12.docx',
#   13: '/content/reports/2012/13_13.docx',
#   14: '/content/reports/2012/14_14.docx',
#   15: '/content/reports/2012/15_15.docx'},
#  '2013': {2: '/content/reports/2013/02_02.docx',
#   3: '/content/reports/2013/03_03.docx',
#   4: '/content/reports/2013/04_04.docx',
#   5: '/content/reports/2013/05_05.docx',
#   6: '/content/reports/2013/06_06.docx',
#   7: '/content/reports/2013/07_07.docx',
#   8: '/content/reports/2013/08_08.docx',
#   9: '/content/reports/2013/09_09.docx',
#   10: '/content/reports/2013/10_10.docx',
#   11: '/content/reports/2013/11_11.docx',
#   12: '/content/reports/2013/12_12.docx',
#   13: '/content/reports/2013/13_13.docx',
#   14: '/content/reports/2013/14_14.docx',
#   15: '/content/reports/2013/15_15.docx'},
#  '2014': {1: '/content/reports/2014/01_01.docx',
#   2: '/content/reports/2014/02_02.docx',
#   3: '/content/reports/2014/03_03.docx',
#   4: '/content/reports/2014/04_04.docx',
#   5: '/content/reports/2014/05_05.docx',
#   6: '/content/reports/2014/06_06.docx',
#   7: '/content/reports/2014/07_07.docx',
#   8: '/content/reports/2014/08_08.docx',
#   9: '/content/reports/2014/09_09.docx',
#   10: '/content/reports/2014/10_10.docx',
#   11: '/content/reports/2014/11_11.docx',
#   12: '/content/reports/2014/12_12.docx',
#   13: '/content/reports/2014/13_13.docx',
#   14: '/content/reports/2014/14_14.docx'},
#  '2015': {1: '/content/reports/2015/01_01.docx',
#   2: '/content/reports/2015/02_02.docx',
#   3: '/content/reports/2015/03_03.docx',
#   4: '/content/reports/2015/04_04.docx',
#   5: '/content/reports/2015/05_05.docx',
#   6: '/content/reports/2015/06_06.docx',
#   7: '/content/reports/2015/07_07.docx',
#   8: '/content/reports/2015/08_08.docx',
#   9: '/content/reports/2015/09_09.docx',
#   10: '/content/reports/2015/10_10.docx',
#   11: '/content/reports/2015/11_11.docx',
#   12: '/content/reports/2015/12_12.docx',
#   13: '/content/reports/2015/13_13.docx',
#   14: '/content/reports/2015/14_14.docx',
#   15: '/content/reports/2015/15_15.docx'}}

# %%
## code extracing 2001-2016 using libra - updated ###

ֵֵ!pip install python-docx
# %apt-get install -y libreoffice
import os
import zipfile
import subprocess
from docx import Document
from PIL import Image
import json

graph_summary = {}

def trim_whitespace(image_path, save_path):
    """Trim extra whitespace around the image."""
    with Image.open(image_path) as im:
        im = im.convert("RGBA")
        bbox = im.getbbox()
        if bbox:
            im = im.crop(bbox)
        im.save(save_path)

def save_image_libre(img_data, img_ext, output_dir, idx, chapter, year):
    """Save image data; convert WMF/EMF to PNG using LibreOffice, else save directly."""
    tmp_filename = f"tmp_{idx}{img_ext}"
    tmp_path = os.path.join(output_dir, tmp_filename)

    with open(tmp_path, "wb") as f:
        f.write(img_data)

    serial_name = f"{idx}_{chapter}_{year}.png"
    save_path = os.path.join(output_dir, serial_name)

    if img_ext in [".wmf", ".emf"]:
        # Convert WMF/EMF → PNG using LibreOffice
        subprocess.run([
            "soffice", "--headless", "--convert-to", "png", "--outdir", output_dir, tmp_path
        ], check=True)

        exported_png = os.path.splitext(tmp_path)[0] + ".png"
        # Trim whitespace
        trim_whitespace(exported_png, save_path)
        os.remove(exported_png)
        os.remove(tmp_path)
    else:
      # Raster formats: save as PNG
      with Image.open(tmp_path) as im:
          # Convert CMYK to RGB if needed
          if im.mode == "CMYK":
              im = im.convert("RGB")
          im.save(save_path, "PNG")
      os.remove(tmp_path)


    return save_path

def extract_images_from_docx_tables(docx_path, output_dir, chapter, year, base_name="image"):
    os.makedirs(output_dir, exist_ok=True)
    doc = Document(docx_path)
    count = 0

    for table in doc.tables:
        first_row_text = " | ".join(cell.text.strip() for cell in table.rows[0].cells)
        if "תרשים" not in first_row_text:
            continue
        found_image = False
        for row in table.rows:
            for cell in row.cells:
                for para in cell.paragraphs:
                    text_before = para.text.strip()
                    for run in para.runs:
                        for blip in run._element.xpath(".//a:blip"):
                            rId = blip.get("{http://schemas.openxmlformats.org/officeDocument/2006/relationships}embed")
                            img_part = doc.part.related_parts[rId]
                            img_data = img_part.blob
                            img_ext = os.path.splitext(img_part.partname)[1].lower()
                            count += 1
                            img_filename = save_image_libre(img_data, img_ext, output_dir, count, chapter, year)
                            graph_summary[f'{count}_{chapter}_{year}'] = first_row_text
                            found_image = True
                            break
                        if found_image: break
                    if found_image: break
                if found_image: break
            if found_image: break

base_dir = "/content/reports"
save_dir = "/content/images"

for year in range(2016, 2017):
    year_folder = os.path.join(base_dir, str(year))
    for chapter in range(2,3):
        chapter_str = f"{chapter:02}"
        docx_file = os.path.join(year_folder, f"{chapter_str}_{chapter_str}.docx")
        if not os.path.exists(docx_file):
            continue
        out_path = os.path.join(save_dir, str(year), chapter_str)
        os.makedirs(out_path, exist_ok=True)
        base_name = f"{year}_{chapter_str}_"

        extract_images_from_docx_tables(docx_file, out_path, chapter, year, base_name=base_name)
        print(f"Finish extracting for year: {year}, chapter: {chapter}")

# Save JSON mapping
with open(os.path.join(save_dir, "graphs_summary.json"), "w", encoding="utf-8") as f:
    json.dump(graph_summary, f, ensure_ascii=False, indent=2)

print(f"Done! Extracted images are saved in '{save_dir}'")
# Out:
# Requirement already satisfied: python-docx in /usr/local/lib/python3.12/dist-packages (1.2.0)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from python-docx) (5.4.0)
# Requirement already satisfied: typing_extensions>=4.9.0 in /usr/local/lib/python3.12/dist-packages (from python-docx) (4.15.0)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libreoffice is already the newest version (1:7.3.7-0ubuntu0.22.04.10).
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.
# Finish extracting for year: 2016, chapter: 2
# Done! Extracted images are saved in '/content/images'

# %%
## size sainty check ###
#3
from pathlib import Path
from PIL import Image

min_size = 200  # minimum acceptable width or height
problem_images = []

for img_path in Path(save_dir).rglob("*.png"):
    with Image.open(img_path) as im:

        w, h = im.size
        if w < min_size or h < min_size:
            problem_images.append((img_path, w, h))

print(f"Checked {len(list(Path(save_dir).rglob('*.png')))} images.")
if problem_images:
    print(f"⚠️ {len(problem_images)} images are smaller than {min_size}px:")
    for p, w, h in problem_images:
        print(f"  {p} → {w}x{h}")
else:
    print("✅ All images are larger than the threshold and should be readable.")
# Out:
# Checked 2119 images.
# ✅ All images are larger than the threshold and should be readable.

# %%
from google.colab import drive
import shutil
import os

# 1️⃣ Mount Google Drive
drive.mount('/content/drive')

# 2️⃣ Create a zip of your folder
zip_name = "graphs_2006-2008"  # will create graphs_2003-2005.zip
shutil.make_archive(zip_name, 'zip', "/content/graphs_to_csvs_2001-2016")

# 3️⃣ Move the zip into Google Drive
destination = "/content/drive/My Drive/graphs_2006-2008-csv.zip"
shutil.move(zip_name + ".zip", destination)

print(f"✅ File saved to Google Drive: {destination}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /usr/lib/python3.12/shutil.py in move(src, dst, copy_function)
#     846     try:
# --> 847         os.rename(src, real_dst)
#     848     except OSError:
#
# OSError: [Errno 18] Invalid cross-device link: '/content/graphs_to_csv_2001-2002.zip.zip' -> '/content/drive/My Drive/graphs_to_csv_2001-2002.zip'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1179221393.py in <cell line: 0>()
#      12 # 3️⃣ Move the zip into Google Drive
#      13 destination = "/content/drive/My Drive/graphs_to_csv_2001-2002.zip"
# ---> 14 shutil.move("/content/graphs_to_csv_2001-2002.zip" + ".zip", destination)
#      15
#      16 print(f"✅ File saved to Google Drive: {destination}")
#
# /usr/lib/python3.12/shutil.py in move(src, dst, copy_function)
#     865             rmtree(src)
#     866         else:
# --> 867             copy_function(src, real_dst)
#     868             os.unlink(src)
#     869     return real_dst
#
# /usr/lib/python3.12/shutil.py in copy2(src, dst, follow_symlinks)
#     473                 raise
#     474
# --> 475     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     476     copystat(src, dst, follow_symlinks=follow_symlinks)
#     477     return dst
#
# /usr/lib/python3.12/shutil.py in copyfile(src, dst, follow_symlinks)
#     258         os.symlink(os.readlink(src), dst)
#     259     else:
# --> 260         with open(src, 'rb') as fsrc:
#     261             try:
#     262                 with open(dst, 'wb') as fdst:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/graphs_to_csv_2001-2002.zip.zip'

# %%
## extracting xlsx files correctly 2019, 2021-2024 by chapters ###

import os
import zipfile

def extract_embedded_excels(docx_path, output_dir="/content/extracted_files"):
    """
    Extract embedded Excel files from a .docx into a local directory.

    Args:
        docx_path (str): Path to the .docx file
        output_dir (str): Directory where extracted .xlsx files will be saved
    """
    os.makedirs(output_dir, exist_ok=True)

    with zipfile.ZipFile(docx_path, "r") as docx:
        # All embedded objects are inside word/embeddings/
        for file_name in docx.namelist():
            if file_name.startswith("word/embeddings/") and file_name.endswith(".xlsx"):
                # Create a unique name using the docx file's base name
                base_name = os.path.splitext(os.path.basename(docx_path))[0]
                out_file = os.path.join(output_dir, f"{base_name}_{os.path.basename(file_name)}")

                with docx.open(file_name) as source, open(out_file, "wb") as target:
                    target.write(source.read())
                print(f"Extracted: {out_file}")


extract_embedded_excels("/content/reports/2023/01_01.docx")
# Out:
# Extracted: /content/extracted_files/01_01_Microsoft_Excel_Worksheet.xlsx
# Extracted: /content/extracted_files/01_01_Microsoft_Excel_Worksheet1.xlsx
# Extracted: /content/extracted_files/01_01_Microsoft_Excel_Worksheet2.xlsx
# Extracted: /content/extracted_files/01_01_Microsoft_Excel_Worksheet3.xlsx
# Extracted: /content/extracted_files/01_01_Microsoft_Excel_Worksheet4.xlsx

# %%
## extracting the names of the tables that it is in and naming the files correctly
# also extractingt the xlsx files into a diffrent counting pronting if it matched the counting ###
# for years 2019, 2021-2024

import os
import shutil
import zipfile
import pandas as pd
import json
from docx import Document

def extract_docx_tables_and_excels(docx_path, year, chapter, output_base="/content/extracted_files"):
    """
    Extract embedded Excel files from a DOCX, convert to CSV, and map table headers to them.

    Args:
        docx_path (str): Path to the .docx file
        year (str|int): Year to tag output files
        chapter (str|int): Chapter number to tag output files
        output_base (str): Base output directory
    """
    year, chapter = str(year), str(chapter)
    output_dir = os.path.join(output_base, year, chapter)

    # Reset output dir
    if os.path.exists(output_dir):
        shutil.rmtree(output_dir)
    os.makedirs(output_dir, exist_ok=True)

    # ---------- Pass 1: Collect names from tables ----------
    # doc = Document(docx_path)
    # table_headers = []

    # for table in doc.tables:
    #     # Skip tables with no rows or no first cell text
    #     if len(table.rows) < 2:
    #         continue

    #     # Get the header text from the first row (row 0) if needed
    #     header_text = table.rows[0].cells[0].text.strip()
    #     if "תרשים" not in header_text:
    #         continue

    #     # Check only the second row (index 1)
    #     second_row = table.rows[1]
    #     has_content = False
    #     for cell in second_row.cells:
    #         # Check if the cell has any content (text, image, object)
    #         if len(cell._element) > 0 or cell.text.strip():
    #             print(len(cell._element))
    #             has_content = True
    #             print("has content: ",header_text)
    #             break

    # if not has_content:
    #     continue  # skip tables with an empty second row
    #     print("does not has content but do has 2+ cols: ", header_text)

    # # If second row has content, add the header
    # table_headers.append(header_text)
    doc = Document(docx_path)
    table_headers = []
    for table in doc.tables:
        if table.rows and table.cell(0,0).text:  # header exists
            if len(table.rows)==1:
              continue
            header_text = table.rows[0].cells[0].text.strip()
            if "תרשים" in header_text:
                # Repeat header as many times as there are columns
                #for _ in range(len(table.columns)):
                table_headers.append(header_text)

    print("Relevant table headers:", table_headers)

    # ---------- Pass 2: Extract embedded Excels and save as CSV ----------
    serial = 0
    csv_files = []
    with zipfile.ZipFile(docx_path, "r") as docx:
        for file_name in docx.namelist():
            if file_name.startswith("word/embeddings/") and file_name.endswith(".xlsx"):
                serial += 1
                out_csv = os.path.join(output_dir, f"{serial}_{chapter}_{year}.csv")

                # Save Excel temp
                excel_temp = os.path.join(output_dir, f"temp_{serial}.xlsx")
                with docx.open(file_name) as source, open(excel_temp, "wb") as target:
                    target.write(source.read())

                # Convert Excel -> CSV
                try:
                    xls = pd.ExcelFile(excel_temp)
                    # if multiple sheets -> concatenate into one CSV
                    df_all = []
                    for sheet in xls.sheet_names:
                        df = pd.read_excel(excel_temp, sheet_name=sheet)
                        df_all.append(df)
                    df_full = pd.concat(df_all, ignore_index=True)
                    df_full.to_csv(out_csv, index=False)
                    csv_files.append(out_csv)
                    print(f"Extracted: {out_csv}")
                except Exception as e:
                    print(f"⚠️ Could not convert {excel_temp}: {e}")
                finally:
                    os.remove(excel_temp)

    # ---------- Pass 3: Build JSON mapping ----------
    mapping = {}
    for idx, (csv_path, header) in enumerate(zip(csv_files, table_headers), start=1):
        key = f"{idx}_{chapter}_{year}"
        mapping[key] = header

    json_path = os.path.join(output_dir, f"{chapter}_{year}.json")
    with open(json_path, "w", encoding="utf-8") as f:
        json.dump(mapping, f, ensure_ascii=False, indent=2)

    # ---------- Sanity check ----------
    print("\n--- Sanity Check ---")
    print(f"Headers found: {len(table_headers)}")
    print(f"CSVs extracted: {len(csv_files)}")
    if len(table_headers) == len(csv_files):
        print("✅ Counts match.")
    else:
        print("⚠️ Mismatch between headers and CSVs!")

    print(f"\nJSON mapping saved at: {json_path}")
    return mapping



years= [2019,2021,2022,2023]
for year in years:
  for ch in range(1,15):
    extract_docx_tables_and_excels(f"/content/reports/{year}/{ch:02}_{ch:02}.docx",year,ch)
# Out:
# Relevant table headers: ["תרשים 1א': התפלגות הילדים בישראל, לפי דת (אחוזים) / 2023", "תרשים 1ב': יישובים* בהם ילדים מנו כ-25% ופחות או כ-50% ויותר מאוכלוסיית היישוב* / 2023", "תרשים 1ג': מספר הילדים (17-0) שקיבלו במהלך השנה מעמד של תושב ארעי או תושב קבע / 2020-2018", "תרשים 1ד': שיעור הילדים (17-0) הזרים שקיבלו במהלך השנה מעמד של תושב ארעי, לפי ארץ מוצא / 2020-2018", "תרשים 2א': שיעור הילדים העולים* מכלל אוכלוסיית העולים**, לפי תקופת עלייה / 2023-1948", 'תרשים 2ב\': מספר הילדים העולים (0-17) ילידי חו"ל לפי שנים לפי שנת עלייה / 2010 -\n2023', "תרשים 2ג': גיל הילדים (0-17) שעלו במהלך שנת 2023 (אחוזים)", 'תרשים 2ד\': שיעור הילדים העולים, ילידי חו"ל, לפי ארץ מוצא / 2023', "תרשים 2ה': מספר הילדים העולים* וילדי עולים** בגילאי 17-0 / 2008-2023***", "תרשים 2ו': התפלגות ילדי העולים* (17-0) וחלקם מכלל הילדים בישראל /\n2023-2010**", "תרשים 2ז': שיעור ילדי עולים*, לפי מספר הילדים במשפחה / 2023-2017", "תרשים 2ח': מספר ילדים* ממוצע במשפחות עולים עם ילדים בהשוואה לכלל המשפחות בישראל / 2023-2010**", "תרשים 2ט': התפלגות ילדי עולים* לפי גיל ויבשת מוצא של האב (אחוזים) / 2023", "תרשים 2י': שיעור התינוקות והפעוטות של מהגרי עבודה וזרים שאינם בני הרחקה שטופלו בתחנות לבריאות המשפחה (טיפות חלב), לפי גיל / 2023", "תרשים 2יא': שיעור התינוקות והפעוטות של מהגרי עבודה וזרים שאינם בני הרחקה שטופלו בתחנות לבריאות המשפחה (טיפות חלב), לפי מחוז / 2023", "תרשים 2יב': מספר התינוקות והפעוטות של מהגרי עבודה וזרים שאינם בני הרחקה שטופלו בתחנות לבריאות המשפחה (טיפות חלב) בעיר תל-אביב-יפו / 2023-2010", "תרשים 2יג': מספר ילדי מהגרי עבודה וילדי זרים שאינם בני הרחקה (18-0) המקבלים שירותים מקופת חולים מאוחדת / 2023-2010", "תרשים 2יד': גיל ילדי מהגרי עבודה וילדי זרים שאינם בני הרחקה (18-0) המקבלים שירותים מקופת חולים מאוחדת / 2023-2010", 'תרשים 3א: התפלגות הילדים החיים במשפחות שבראשן הורה עצמאי, לפי מצבו המשפחתי של ההורה / 2023-2010', 'תרשים 3ב: שיעור המשפחות שבראשן הורה עצמאי מכלל המשפחות עם ילדים בישראל, לפי ותק (אחוזים בקבוצה המתאימה) / דצמבר 2023', 'תרשים 3ג: מספר הילדים החיים במשפחות המקבלות דמי מזונות מן המוסד לביטוח לאומי וחלקם מכלל הילדים בישראל / 2023-2000', "תרשים 3ד': התפלגות ילדים יתומים החיים במשפחות שמקבלות גמלה* מהמוסד לביטוח לאומי, לפי סוג גמלה וגיל / דצמבר 2023", "תרשים 3ה': התפלגות הילדים שאומצו בידי אזרחי ישראל, לפי סוג האימוץ (באחוזים) / 2023-2022", "תרשים 3ו': מספר הילדים הישראלים שנמסרו לאימוץ בידי השירות למען הילד* במשרד הרווחה / 2023-1995", "תרשים 3ז': נישואי קטינים לפי גיל* ושנה (אחוזים) / 2022-1991**", 'תרשים 4א\': התפלגות סוג משפחה* של ילדים בפנימיות של המינהל לחינוך התיישבותי פנימייתי ועליית הנוער / תשפ"ד (2023/24)', 'תרשים 4ב\': מספר הילדים שהושמו בידי משרד הרווחה במסגרות חוץ-ביתיות ושיעורים לאלף ילדים בישראל / תשע"ט (2018/19) – תשפ"ד (2023/24)', 'תרשים 4ג\':  התפלגות הילדים שהושמו בידי משרד הרווחה במסגרות חוץ-ביתיות* / תשפ"ג (2022/23) - תשפ"ד (2023/24)', 'תרשים 4ד\': התפלגות הילדים* שהושמו בידי שירותי הרווחה בפנימיות לילדים בסיכון, לפי סוג פנימייה / תשפ"ד (2023/2024)', 'תרשים 4ה\': התפלגות הסמנים* של ילדים שהושמו בידי משרד הרווחה בפנימיות לילדים בסיכון, לפי מגדר / תשפ"ג (2022/23)', "תרשים 4ו': התפלגות הילדים שהושמו באומנה בידי משרד הרווחה, לפי סוג אומנה /\n2023", "תרשים 4ז': התפלגות גיל הילדים שהושמו באומנה בידי משרד הרווחה / 2023", "תרשים 4ח': התפלגות האשפוזים של ילדים בגיל 17-5 שהיו מאושפזים מעל 21 יום בבתי חולים כלליים*, לפי גיל / 2023-2000**", 'תרשים 5א\': שיעור הלומדים במערכת החינוך*, לפי גיל ומגזר (אחוז מקבוצת הגיל באוכלוסייה) / תשפ"ג (2022/23)', 'תרשים 5ב\': שיעור תלמידי פטור* הלומדים בחינוך היסודי העברי מכלל התלמידים בחינוך היסודי הרגיל\xa0 / תשס"א (2001/02) - תשפ"ד (2023/24)', 'תרשים 5ג\': שיעור* התחושות החיוביות כלפי בית הספר, לפי כיתה / \nתשפ"ג (2022/23)', 'תרשים 5ד\': שיעור* התלמידים שהעידו על יחסים חיוביים בין חבריהם לכיתה, לפי כיתה / תשפ"ב (2021/22)', 'תרשים 5ה\': מספר התלמידים שהורחקו לצמיתות מבית הספר / תשע"ב (2011/12) – תשפ"ג (2022/23)', 'תרשים 5ו\': מספר הערעורים של תלמידים שהורחקו לצמיתות מבית הספר, והתפלגות הערעורים לפי קבלתם / תשע"ב (2011/12) - תשפ"ג (2022/23)', 'תרשים 5ז\': מספר התלמידים שהורחקו לאלתר מבית הספר ושיעורם מכ ...
# Extracted: /content/extracted_files/2024/1/1_1_2024.csv
# Extracted: /content/extracted_files/2024/1/2_1_2024.csv
# Extracted: /content/extracted_files/2024/1/3_1_2024.csv
# Extracted: /content/extracted_files/2024/1/4_1_2024.csv
# Extracted: /content/extracted_files/2024/1/5_1_2024.csv
# Extracted: /content/extracted_files/2024/1/6_1_2024.csv
# Extracted: /content/extracted_files/2024/1/7_1_2024.csv
# Extracted: /content/extracted_files/2024/1/8_1_2024.csv
# Extracted: /content/extracted_files/2024/1/9_1_2024.csv
# Extracted: /content/extracted_files/2024/1/10_1_2024.csv
# Extracted: /content/extracted_files/2024/1/11_1_2024.csv
# Extracted: /content/extracted_files/2024/1/12_1_2024.csv
# Extracted: /content/extracted_files/2024/1/13_1_2024.csv
# Extracted: /content/extracted_files/2024/1/14_1_2024.csv
# Extracted: /content/extracted_files/2024/1/15_1_2024.csv
# Extracted: /content/extracted_files/2024/1/16_1_2024.csv
# Extracted: /content/extracted_files/2024/1/17_1_2024.csv
# Extracted: /content/extracted_files/2024/1/18_1_2024.csv
# Extracted: /content/extracted_files/2024/1/19_1_2024.csv
# Extracted: /content/extracted_files/2024/1/20_1_2024.csv
# Extracted: /content/extracted_files/2024/1/21_1_2024.csv
# Extracted: /content/extracted_files/2024/1/22_1_2024.csv
# Extracted: /content/extracted_files/2024/1/23_1_2024.csv
# Extracted: /content/extracted_files/2024/1/24_1_2024.csv
# Extracted: /content/extracted_files/2024/1/25_1_2024.csv
# Extracted: /content/extracted_files/2024/1/26_1_2024.csv
# Extracted: /content/extracted_files/2024/1/27_1_2024.csv
# Extracted: /content/extracted_files/2024/1/28_1_2024.csv
# Extracted: /content/extracted_files/2024/1/29_1_2024.csv
# Extracted: /content/extracted_files/2024/1/30_1_2024.csv
# Extracted: /content/extracted_files/2024/1/31_1_2024.csv
# Extracted: /content/extracted_files/2024/1/32_1_2024.csv
# Extracted: /content/extracted_files/2024/1/33_1_2024.csv
# Extracted: /content/extracted_files/2024/1/34_1_2024.csv
# Extracted: /content/extracted_files/2024/1/35_1_2024.csv
# Extracted: /content/extracted_files/2024/1/36_1_2024.csv
# Extracted: /content/extracted_files/2024/1/37_1_2024.csv
# Extracted: /content/extracted_files/2024/1/38_1_2024.csv
# Extracted: /content/extracted_files/2024/1/39_1_2024.csv
# Extracted: /content/extracted_files/2024/1/40_1_2024.csv
# Extracted: /content/extracted_files/2024/1/41_1_2024.csv
# Extracted: /content/extracted_files/2024/1/42_1_2024.csv
# Extracted: /content/extracted_files/2024/1/43_1_2024.csv
# Extracted: /content/extracted_files/2024/1/44_1_2024.csv
# Extracted: /content/extracted_files/2024/1/45_1_2024.csv
# Extracted: /content/extracted_files/2024/1/46_1_2024.csv
# Extracted: /content/extracted_files/2024/1/47_1_2024.csv
# Extracted: /content/extracted_files/2024/1/48_1_2024.csv
# Extracted: /content/extracted_files/2024/1/49_1_2024.csv
# Extracted: /content/extracted_files/2024/1/50_1_2024.csv
# Extracted: /content/extracted_files/2024/1/51_1_2024.csv
# Extracted: /content/extracted_files/2024/1/52_1_2024.csv
# Extracted: /content/extracted_files/2024/1/53_1_2024.csv
# Extracted: /content/extracted_files/2024/1/54_1_2024.csv
# Extracted: /content/extracted_files/2024/1/55_1_2024.csv
# Extracted: /content/extracted_files/2024/1/56_1_2024.csv
# Extracted: /content/extracted_files/2024/1/57_1_2024.csv
# Extracted: /content/extracted_files/2024/1/58_1_2024.csv
# Extracted: /content/extracted_files/2024/1/59_1_2024.csv
# Extracted: /content/extracted_files/2024/1/60_1_2024.csv
# Extracted: /content/extracted_files/2024/1/61_1_2024.csv
# Extracted: /content/extracted_files/2024/1/62_1_2024.csv
# Extracted: /content/extracted_files/2024/1/63_1_2024.csv
# Extracted: /content/extracted_files/2024/1/64_1_2024.csv
# Extracted: /content/extracted_files/2024/1/65_1_2024.csv
# Extracted: /content/extracted_files/2024/1/66_1_2024.csv
# Extracted: /content/extracted_files/2024/1/67_1_2024.csv
# Extracted: /content/extracted_files/2024/1/68_1_2024.csv
# Extracted: /content/extracted_files/2024/1/69_1_2024.csv
# Extracted: /content/extracted_files/2024/1/70_1_2024.csv
# Extracted: /content/extracted_files/2024/1/71_1_2024.csv
# Extracted: /content/extracted_files/2024/1/72_1_2024.csv
# Extracted: /content/extracted_files/2024/1/73_1_2024.csv
# Extracted: /content/extracted_files/2024/1/74_1_2024.csv
# Extracted: /content/extracted_files/2024/1/75_1_2024.csv
# Extracted: /content/extracted_files/2024/1/76_1_2024.csv
# Extracted: /content/extracted_files/2024/1/77_1_2024.csv
# Extracted: /content/extracted_files/2024/1/78_1_2024.csv
# Extracted: /content/extracted_files/2024/1/79_1_2024.csv
# Extracted: /content/extracted_files/2024/1/80_1_2024.csv
# Extracted: /content/extracted_files/2024/1/81_1_2024.csv
# Extracted: /content/extracted_files/2024/1/82_1_2024.csv
# Extracted: /content/extracted_files/2024/1/83_1_2024.csv
# Extracted: /content/extracted_files/2024/1/84_1_2024.csv
# Extracted: /content/extracted_files/2024/1/85_1_2024.csv
# Extracted: /content/extracted_files/2024/1/86_1_2024.csv
# Extracted: /content/extracted_files/2024/1/87_1_2024.csv
# Extracted: /content/extracted_files/2024/1/88_1_2024.csv
# Extracted: /content/extracted_files/2024/1/89_1_2024.csv
# Extracted: /content/extracted_files/2024/1/90_1_2024.csv
# Extracted: /content/extracted_files/2024/1/91_1_2024.csv
# Extracted: /content/extracted_files/2024/1/92_1_2024.csv
# Extracted: /content/extracted_files/2024/1/93_1_2024.csv
# Extracted: /content/extracted_files/2024/1/94_1_2024.csv
# Extracted: /content/extracted_files/2024/1/95_1_2024.csv
# Extracted: /content/extracted_files/2024/1/96_1_2024.csv
# Extracted: /content/extracted_files/2024/1/97_1_2024.csv
# Extracted: /content/extracted_files/2024/1/98_1_2024.csv
# Extracted: /content/extracted_files/2024/1/99_1_2024.csv
# Extracted: /content/extracted_files/2024/1/100_1_2024.csv
# Extracted: /content/extracted_files/2024/1/101_1_2024.csv
# Extracted: /content/extracted_files/2024/1/102_1_2024.csv
# Extracted: /content/extracted_files/2024/1/103_1_2024.csv
# Extracted: /content/extracted_files/2024/1/104_1_2024.csv
# Extracted: /content/extracted_files/2024/1/105_1_2024.csv
# Extracted: /content/extracted_files/2024/1/106_1_2024.csv
# Extracted: /content/extracted_files/2024/1/107_1_2024.csv
# Extracted: /content/extracted_files/2024/1/108_1_2024.csv
# Extracted: /content/extracted_files/2024/1/109_1_2024.csv
# Extracted: /content/extracted_files/2024/1/110_1_2024.csv
# Extracted: /content/extracted_files/2024/1/111_1_2024.csv
# Extracted: /content/extracted_files/2024/1/112_1_2024.csv
# Extracted: /content/extracted_files/2024/1/113_1_2024.csv
# Extracted: /content/extracted_files/2024/1/114_1_2024.csv
# Extracted: /content/extracted_files/2024/1/115_1_2024.csv
# Extracted: /content/extracted_files/2024/1/116_1_2024.csv
# Extracted: /content/extracted_files/2024/1/117_1_2024.csv
# Extracted: /content/extracted_files/2024/1/118_1_2024.csv
# Extracted: /content/extracted_files/2024/1/119_1_2024.csv
# Extracted: /content/extracted_files/2024/1/120_1_2024.csv
# Extracted: /content/extracted_files/2024/1/121_1_2024.csv
# Extracted: /content/extracted_files/2024/1/122_1_2024.csv
# Extracted: /content/extracted_files/2024/1/123_1_2024.csv
# Extracted: /content/extracted_files/2024/1/124_1_2024.csv
# Extracted: /content/extracted_files/2024/1/125_1_2024.csv
# Extracted: /content/extracted_files/2024/1/126_1_2024.csv
# Extracted: /content/extracted_files/2024/1/127_1_2024.csv
# Extracted: /content/extracted_files/2024/1/128_1_2024.csv
# Extracted: /content/extracted_files/2024/1/129_1_2024.csv
# Extracted: /content/extracted_files/2024/1/130_1_2024.csv
# Extracted: /content/extracted_files/2024/1/131_1_2024.csv
# Extracted: /content/extracted_files/2024/1/132_1_2024.csv
# Extracted: /content/extracted_files/2024/1/133_1_2024.csv
# Extracted: /content/extracted_files/2024/1/134_1_2024.csv
# Extracted: /content/extracted_files/2024/1/135_1_2024.csv
# Extracted: /content/extracted_files/2024/1/136_1_2024.csv
# Extracted: /content/extracted_files/2024/1/137_1_2024.csv
# Extracted: /content/extracted_files/2024/1/138_1_2024.csv
# Extracted: /content/extracted_files/2024/1/139_1_2024.csv
# Extracted: /content/extracted_files/2024/1/140_1_2024.csv
# Extracted: /content/extracted_files/2024/1/141_1_2024.csv
# Extracted: /content/extracted_files/2024/1/142_1_2024.csv
# Extracted: /content/extracted_files/2024/1/143_1_2024.csv
# Extracted: /content/extracted_files/2024/1/144_1_2024.csv
# Extracted: /content/extracted_files/2024/1/145_1_2024.csv
# Extracted: /content/extracted_files/2024/1/146_1_2024.csv
# Extracted: /content/extracted_files/2024/1/147_1_2024.csv
# Extracted: /content/extracted_files/2024/1/148_1_2024.csv
# Extracted: /content/extracted_files/2024/1/149_1_2024.csv
# Extracted: /content/extracted_files/2024/1/150_1_2024.csv
# Extracted: /content/extracted_files/2024/1/151_1_2024.csv
# Extracted: /content/extracted_files/2024/1/152_1_2024.csv
# Extracted: /content/extracted_files/2024/1/153_1_2024.csv
# Extracted: /content/extracted_files/2024/1/154_1_2024.csv
# Extracted: /content/extracted_files/2024/1/155_1_2024.csv
# Extracted: /content/extracted_files/2024/1/156_1_2024.csv
# Extracted: /content/extracted_files/2024/1/157_1_2024.csv
# Extracted: /content/extracted_files/2024/1/158_1_2024.csv
# Extracted: /content/extracted_files/2024/1/159_1_2024.csv
# Extracted: /content/extracted_files/2024/1/160_1_2024.csv
# Extracted: /content/extracted_files/2024/1/161_1_2024.csv
# Extracted: /content/extracted_files/2024/1/162_1_2024.csv
# Extracted: /content/extracted_files/2024/1/163_1_2024.csv
# Extracted: /content/extracted_files/2024/1/164_1_2024.csv
# Extracted: /content/extracted_files/2024/1/165_1_2024.csv
# Extracted: /content/extracted_files/2024/1/166_1_2024.csv
# Extracted: /content/extracted_files/2024/1/167_1_2024.csv
# Extracted: /content/extracted_files/2024/1/168_1_2024.csv
# Extracted: /content/extracted_files/2024/1/169_1_2024.csv
# Extracted: /content/extracted_files/2024/1/170_1_2024.csv
# Extracted: /content/extracted_files/2024/1/171_1_2024.csv
# Extracted: /content/extracted_files/2024/1/172_1_2024.csv
# Extracted: /content/extracted_files/2024/1/173_1_2024.csv
# Extracted: /content/extracted_files/2024/1/174_1_2024.csv
# Extracted: /content/extracted_files/2024/1/175_1_2024.csv
# Extracted: /content/extracted_files/2024/1/176_1_2024.csv
# Extracted: /content/extracted_files/2024/1/177_1_2024.csv
# Extracted: /content/extracted_files/2024/1/178_1_2024.csv
# Extracted: /content/extracted_files/2024/1/179_1_2024.csv
# Extracted: /content/extracted_files/2024/1/180_1_2024.csv
# Extracted: /content/extracted_files/2024/1/181_1_2024.csv
# Extracted: /content/extracted_files/2024/1/182_1_2024.csv
# Extracted: /content/extracted_files/2024/1/183_1_2024.csv
# Extracted: /content/extracted_files/2024/1/184_1_2024.csv
# Extracted: /content/extracted_files/2024/1/185_1_2024.csv
# Extracted: /content/extracted_files/2024/1/186_1_2024.csv
# Extracted: /content/extracted_files/2024/1/187_1_2024.csv
# Extracted: /content/extracted_files/2024/1/188_1_2024.csv
# Extracted: /content/extracted_files/2024/1/189_1_2024.csv
# Extracted: /content/extracted_files/2024/1/190_1_2024.csv
# Extracted: /content/extracted_files/2024/1/191_1_2024.csv
#
# --- Sanity Check ---
# Headers found: 198
# CSVs extracted: 191
# ⚠️ Mismatch between headers and CSVs!
#
# JSON mapping saved at: /content/extracted_files/2024/1/1_2024.json
# {'1_1_2024': "תרשים 1א': התפלגות הילדים בישראל, לפי דת (אחוזים) / 2023",
#  '2_1_2024': "תרשים 1ב': יישובים* בהם ילדים מנו כ-25% ופחות או כ-50% ויותר מאוכלוסיית היישוב* / 2023",
#  '3_1_2024': "תרשים 1ג': מספר הילדים (17-0) שקיבלו במהלך השנה מעמד של תושב ארעי או תושב קבע / 2020-2018",
#  '4_1_2024': "תרשים 1ד': שיעור הילדים (17-0) הזרים שקיבלו במהלך השנה מעמד של תושב ארעי, לפי ארץ מוצא / 2020-2018",
#  '5_1_2024': "תרשים 2א': שיעור הילדים העולים* מכלל אוכלוסיית העולים**, לפי תקופת עלייה / 2023-1948",
#  '6_1_2024': 'תרשים 2ב\': מספר הילדים העולים (0-17) ילידי חו"ל לפי שנים לפי שנת עלייה / 2010 -\n2023',
#  '7_1_2024': "תרשים 2ג': גיל הילדים (0-17) שעלו במהלך שנת 2023 (אחוזים)",
#  '8_1_2024': 'תרשים 2ד\': שיעור הילדים העולים, ילידי חו"ל, לפי ארץ מוצא / 2023',
#  '9_1_2024': "תרשים 2ה': מספר הילדים העולים* וילדי עולים** בגילאי 17-0 / 2008-2023***",
#  '10_1_2024': "תרשים 2ו': התפלגות ילדי העולים* (17-0) וחלקם מכלל הילדים בישראל /\n2023-2010**",
#  '11_1_2024': "תרשים 2ז': שיעור ילדי עולים*, לפי מספר הילדים במשפחה / 2023-2017",
#  '12_1_2024': "תרשים 2ח': מספר ילדים* ממוצע במשפחות עולים עם ילדים בהשוואה לכלל המשפחות בישראל / 2023-2010**",
#  '13_1_2024': "תרשים 2ט': התפלגות ילדי עולים* לפי גיל ויבשת מוצא של האב (אחוזים) / 2023",
#  '14_1_2024': "תרשים 2י': שיעור התינוקות והפעוטות של מהגרי עבודה וזרים שאינם בני הרחקה שטופלו בתחנות לבריאות המשפחה (טיפות חלב), לפי גיל / 2023",
#  '15_1_2024': "תרשים 2יא': שיעור התינוקות והפעוטות של מהגרי עבודה וזרים שאינם בני הרחקה שטופלו בתחנות לבריאות המשפחה (טיפות חלב), לפי מחוז / 2023",
#  '16_1_2024': "תרשים 2יב': מספר התינוקות והפעוטות של מהגרי עבודה וזרים שאינם בני הרחקה שטופלו בתחנות לבריאות המשפחה (טיפות חלב) בעיר תל-אביב-יפו / 2023-2010",
#  '17_1_2024': "תרשים 2יג': מספר ילדי מהגרי עבודה וילדי זרים שאינם בני הרחקה (18-0) המקבלים שירותים מקופת חולים מאוחדת / 2023-2010",
#  '18_1_2024': "תרשים 2יד': גיל ילדי מהגרי עבודה וילדי זרים שאינם בני הרחקה (18-0) המקבלים שירותים מקופת חולים מאוחדת / 2023-2010",
#  '19_1_2024': 'תרשים 3א: התפלגות הילדים החיים במשפחות שבראשן הורה עצמאי, לפי מצבו המשפחתי של ההורה / 2023-2010',
#  '20_1_2024': 'תרשים 3ב: שיעור המשפחות שבראשן הורה עצמאי מכלל המשפחות עם ילדים בישראל, לפי ותק (אחוזים בקבוצה המתאימה) / דצמבר 2023',
#  '21_1_2024': 'תרשים 3ג: מספר הילדים החיים במשפחות המקבלות דמי מזונות מן המוסד לביטוח לאומי וחלקם מכלל הילדים בישראל / 2023-2000',
#  '22_1_2024': "תרשים 3ד': התפלגות ילדים יתומים החיים במשפחות שמקבלות גמלה* מהמוסד לביטוח לאומי, לפי סוג גמלה וגיל / דצמבר 2023",
#  '23_1_2024': "תרשים 3ה': התפלגות הילדים שאומצו בידי אזרחי ישראל, לפי סוג האימוץ (באחוזים) / 2023-2022",
#  '24_1_2024': "תרשים 3ו': מספר הילדים הישראלים שנמסרו לאימוץ בידי השירות למען הילד* במשרד הרווחה / 2023-1995",
#  '25_1_2024': "תרשים 3ז': נישואי קטינים לפי גיל* ושנה (אחוזים) / 2022-1991**",
#  '26_1_2024': 'תרשים 4א\': התפלגות סוג משפחה* של ילדים בפנימיות של המינהל לחינוך התיישבותי פנימייתי ועליית הנוער / תשפ"ד (2023/24)',
#  '27_1_2024': 'תרשים 4ב\': מספר הילדים שהושמו בידי משרד הרווחה במסגרות חוץ-ביתיות ושיעורים לאלף ילדים בישראל / תשע"ט (2018/19) – תשפ"ד (2023/24)',
#  '28_1_2024': 'תרשים 4ג\':  התפלגות הילדים שהושמו בידי משרד הרווחה במסגרות חוץ-ביתיות* / תשפ"ג (2022/23) - תשפ"ד (2023/24)',
#  '29_1_2024': 'תרשים 4ד\': התפלגות הילדים* שהושמו בידי שירותי הרווחה בפנימיות לילדים בסיכון, לפי סוג פנימייה / תשפ"ד (2023/2024)',
#  '30_1_2024': 'תרשים 4ה\': התפלגות הסמנים* של ילדים שהושמו בידי משרד הרווחה בפנימיות לילדים בסיכון, לפי מגדר / תשפ"ג (2022/23)',
#  '31_1_2024': "תרשים 4ו': התפלגות הילדים שהושמו באומנה בידי משרד הרווחה, לפי סוג אומנה /\n2023",
#  '32_1_2024': "תרשים 4ז': התפלגות גיל הילדים שהושמו באומנה בידי משרד הרווחה / 2023",
#  '33_1_2024': "תרשים 4ח': התפלגות האשפוזים של ילדים בגיל 17-5 שהיו מאושפזים מעל 21 יום בבתי חולים כלליים*, לפי גיל / 2023-2000**",
#  '34_1_2024': 'תרשים 5א\': שיעור הלומדים במערכת החינוך*, לפי גיל ומגזר (אחוז מקבוצת הגיל באוכלוסייה) / תשפ"ג (2022/23)',
#  '35_1_2024': 'תרשים 5ב\': שיעור תלמידי פטור* הלומדים בחינוך היסודי העברי מכלל התלמידים בחינוך היסודי הרגיל\xa0 / תשס"א (2001/02) - תשפ"ד (2023/24)',
#  '36_1_2024': 'תרשים 5ג\': שיעור* התחושות החיוביות כלפי בית הספר, לפי כיתה / \nתשפ"ג (2022/23)',
#  '37_1_2024': 'תרשים 5ד\': שיעור* התלמידים שהעידו על יחסים חיוביים בין חבריהם לכיתה, לפי כיתה / תשפ"ב (2021/22)',
#  '38_1_2024': 'תרשים 5ה\': מספר התלמידים שהורחקו לצמיתות מבית הספר / תשע"ב (2011/12) – תשפ"ג (2022/23)',
#  '39_1_2024': 'תרשים 5ו\': מספר הערעורים של תלמידים שהורחקו לצמיתות מבית הספר, והתפלגות הערעורים לפי קבלתם / תשע"ב (2011/12) - תשפ"ג (2022/23)',
#  '40_1_2024': 'תרשים 5ז\': מספר התלמידים שהורחקו לאלתר מבית הספר ושיעורם מכלל התלמידים שהורחקו לצמיתות, לפי שנה / תשע"ב (2011/12) - תשפ"ג (2022/23)',
#  '41_1_2024': 'תרשים 5ח\': התפלגות מצב התלמידים שהורחקו לצמיתות מבית הספר לאחר הרחקתם/ תשפ"ב-תשפ"ג (2021/22 – 2022/23)',
#  '42_1_2024': 'תרשים 5ט\': מספר התלמידים בטיפול קציני ביקור סדיר (קב"סים), לפי שנה /\n(מספר ואחוז מכלל התלמידים) / תשע"ח (2017/18) – תשפ"ד (2023/24)',
#  '43_1_2024': 'תרשים 5י\': שיעור (לאלף) של התלמידים שנשרו מבתי הספר בפיקוחו של משרד החינוך*, לפי גיל וזרם חינוכי במהלך שנת הלימודים תשפ"ג (2022/23) ובמעבר לשנת הלימודים תשפ"ד (2023/24)',
#  '44_1_2024': 'תרשים 5יא\': היישובים בהם אחוז הנשירה מבתי הספר בפיקוחו של משרד החינוך* במהלך שנת הלימודים תשפ"ג (2022/23) ובמעבר לשנת הלימודים תשפ"ד (2023/24) היה זהה לשיעור הארצי או גבוה ממנו, ושיעור הגידול לעומת השנה הקודמת',
#  '45_1_2024': 'תרשים 5יב\': שיעור הזכאים לתעודת בגרות מתלמידי י"ב ומבני ה-17* / תש"ע (2009/2010) – תשפ"ג (2022/2023)',
#  '46_1_2024': 'תרשים 5יג\': יישובים (בני 5,000 נפש ויותר) בהם אחוז הזכאים לתעודת בגרות מתלמידי י"ב* הלומדים ביישוב היה 95% ומעלה, ושיעור הגידול בנקודות אחוז לעומת תשפ"ב / תשפ"ג (2022/23)',
#  '47_1_2024': 'תרשים 5יד\': יישובים (בני 5,000 נפש ויותר) בהם אחוז הזכאים לתעודת בגרות מתלמידי י"ב* הלומדים ביישוב היה 50% ומטה, ואחוז השינוי לעומת תשפ"ב / תשפ"ג (2022/23)',
#  '48_1_2024': 'תרשים 5טו\': שיעור הזכאים לתעודת בגרות שנבחנו במתמטיקה ובאנגלית ב-5 יחידות לימוד / תשע"ג (2012/13) – תשפ"ג (2022/23)',
#  '49_1_2024': 'תרשים 5טז\': שיעור הזכאים לתעודת בגרות מצטיינת מתלמידי י"ב / תשע"ג (2012/13) – תשפ"ג (2022/23)',
#  '50_1_2024': 'תרשים 5יז\': שיעור הזכאים לתעודת בגרות ושיעור העומדים בדרישות הסף של האוניברסיטאות מתלמידי כיתות י"ב לפי קבוצת אוכלוסייה / 2022-2000',
#  '51_1_2024': 'תרשים 5יח\': היישובים עם הפער הגבוה ביותר בין שיעור הזכאים לתעודת בגרות לבין שיעור העומדים בדרישות הסף* של האוניברסיטאות/ תשפ"ב (2021-22)',
#  '52_1_2024': 'תרשים 5יט\': זכאות לבגרות לפי השכלת אם, לפי סוג חינוך / תשפ"ג (2022/23)',
#  '53_1_2024': 'תרשים 5כ\': התפלגות הנבחנים בבחינת בגרות שמחברת הבחינה שלהם נפסלה* עקב חשד לאי-קיום טוהר הבחינה (אחוז המחברות הפסולות מכלל הנבחנים) תשע"ג (2012/13) – תשפ"ג (2022/23)',
#  '54_1_2024': 'תרשים 5כא\': התפלגות הבקשות שהוגשו לפטור מחוק לימוד חובה במסגרת חינוך ביתי, לפי סטטוס קבלה / תש"ע (2009/10) – תשפ"ד (2023/24)',
#  '55_1_2024': 'תרשים 5כב\': שיעור בני הנוער הלומדים לתואר ראשון לפי סוג מוסד לימודים / תשפ"ד (2023/24)',
#  '56_1_2024': 'תרשים 5כג\': התפלגות בני נוער הלומדים לתואר ראשון, לפי גיל / תשפ"ד (2023/24)',
#  '57_1_2024': 'תרשים 5כד\': שיעור בני נוער הלומדים לתואר ראשון, לפי מין  / תשפ"ד (2023/24)',
#  '58_1_2024': 'תרשים 5כה\': שיעור בני נוער הלומדים לתואר ראשון, לפי קבוצת אוכלוסייה /\nתשפ"ד (2023/24)',
#  '59_1_2024': 'תרשים 5כו\': שיעור בני נוער הלומדים לתואר ראשון, לפי אשכול חברתי-כלכלי /\nתשפ"ד (2023/24)',
#  '60_1_2024': 'תרשים 5כז\': שיעור בני נוער הלומדים לתואר ראשון, לפי תחום לימוד  / תשפ"ד (2023/24)',
#  '61_1_2024': 'תרשים 5כח\': ילדים בדואים בגילי 3 עד 5 מחוץ למערכת החינוך, לפי שנה (מספר ואחוז מכלל הילדים בגילים האלה ביישובים / (תשע"ו (2015/16) – תשפ"ג (2022/23)',
#  '62_1_2024': 'תרשים  5כט\': שיעורי למידה ל-1,000 נפשות בגילאי 13 ו-17 לפי מגזר / תש"פ (2019\\2020)',
#  '63_1_2024': "תרשים 5ל': התראות* שהתקבלו באמצעות מנגנון פוש לגבי העסקת אנשי צוות בעלי רישום פלילי במערכת החינוך / 2023-2019",
#  '64_1_2024': "תרשים 5לא': התפלגות ההתראות* שהתקבלו באמצעות מנגנון פוש לגבי העסקת אנשי צוות בעלי רישום פלילי במערכת החינוך לפי סוג עבירה/ 2021-2023",
#  '65_1_2024': 'תרשים 5לב\': ציון ממוצע של תלמידים בכיתות ד\' בהבנת הנקרא בשפת אם עברית, לפי רקע כלכלי-חברתי, ומין / תשפ"ב (2021/22)– תשפ"ג (2022/23)',
#  '66_1_2024': 'תרשים 5לג\': התפלגות רמת הביצוע של תלמידים בכיתות ד\' במבחן הבנת הנקרא בשפת אם בעברית, לפי רקע כלכלי, מין וסוג פיקוח / תשפ"ג (דצמבר 2022)',
#  '67_1_2024': 'תרשים 5לד\': ציון ממוצע של תלמידים בכיתות ד\' בהבנת הנקרא בשפת אם ערבית, לפי רקע כלכלי-חברתי, מגזר ומגדר/ תשפ"ב (2021/22)– תשפ"ג (2022/23)',
#  '68_1_2024': 'תרשים 5לה\': התפלגות רמת הביצוע של תלמידים בכיתות ד\' במבחן הבנת הנקרא בשפת אם ערבית, לפי רקע כלכלי, מגדר וסוג פיקוח/ תשפ"ג (דצמבר 2022)',
#  '69_1_2024': 'תרשים 6א: פעילות של בני נוער (17-13) ברשתות חברתיות נבחרות (אחוזים)* /  2023-2019',
#  '70_1_2024': 'תרשים 6ב: התפלגות פעילות הורים בהגנה על ילדיהם ברשת (אחוזים) / 2022',
#  '71_1_2024': 'תרשים 6ג: רצון בני נוער (17-13) להגביל את זמן המסך (אחוזים) / 2023-2019',
#  '72_1_2024': 'תרשים 6ד: זמן שהייה ברשתות חברתיות נבחרות בקרב בני נוער (17-13) (אחוזים)* / 2022',
#  '73_1_2024': 'תרשים 6ה: תחושות בני נוער (17-13) בעקבות שימוש ברשתות (אחוזים) / 2023',
#  '74_1_2024': 'תרשים 6ו: אחוז ילדים בגיל 6-9 עם סמארטפון/ 2023-2015',
#  '75_1_2024': 'תרשים 6ז: גיל ממוצע לקבלת סמראטפון ראשון/ 2014-2023',
#  '76_1_2024': 'תרשים 6ח: שיעור בני הנוער המשחקים במשחקי רשת/ 2023-2017',
#  '77_1_2024': 'תרשים 6ט: שיעור בני הנוער המשתמשים בטכנולוגיית AI/ 2023',
#  '78_1_2024': 'תרשים 6י\':  שיעור הילדים ובני הנוער (17-7) העוסקים בספורט תחרותי*, לפי גיל / תשפ"ג )2022/23(',
#  '79_1_2024': 'תרשים 6יא\':  שיעור הילדים ובני הנוער (17-7) שעוסקים בספורט תחרותי*, לפי \nסוג ענף הספורט / תשפ"ג )2022/23(',
#  '80_1_2024': "תרשים 6יד': שיעור מורשים לנהוג עד גיל 18 מכלל בני גילם*, לפי מגדר / 2023",
#  '81_1_2024': "תרשים 6טו': שיעור הנהגים עד גיל 18* מכלל בני גילם*, לפי סוג רשיון  / 2023",
#  '82_1_2024': "תרשים 7א': שיעור ילדים עם מוגבלויות מכלל הילדים בישראל / 2023-2021",
#  '83_1_2024': "תרשים 7ב': התפלגות ילדים ובני נוער בני 17-0 עם מוגבלות,* לפי סוג מוגבלות /  2023-2022",
#  '84_1_2024': "תרשים 7ג': התפלגות ילדים ובני נוער בני 17-0 עם מוגבלות, לפי קבוצת אוכלוסייה וסוג מוגבלות / 2023",
#  '85_1_2024': "תרשים 7ד': התפלגות ילדים ובני נוער בני 17-0 עם מוגבלות, לפי מגדר וסוג מוגבלות /  2023",
#  '86_1_2024': 'תרשים 7ה\': מספר תלמידים זכאי שירותי חינוך מיוחד ושיעורם מכלל אוכלוסיית התלמידים / תשפ"א-תשפ"ד (2020/21-2023/24)',
#  '87_1_2024': 'תרשים 7ו\': התפלגות תלמידי זכאי שירותי חינוך מיוחדים בשילוב, במסגרות לחינוך מיוחד ובבתי ספר רגילים, לפי סוג מסגרת / תשפ"א-תשפ"ד (2020/21-2023/24)',
#  '88_1_2024': 'תרשים 7ז\': התפלגות התלמידים זכאי שירותי חינוך מיוחדים לפי סוג פיקוח והתפלגות כלל תלמידי מערכת החינוך לפי סוג פיקוח תשפ"ד  (2023/24)',
#  '89_1_2024': 'תרשים 7ח\': התפלגות התלמידים זכאי שירותי חינוך מיוחדים במערכת החינוך לפי סוג מוגבלות (אחוז מכלל התלמידים זכאי שירותי חנ"מ) / תשפ"א-תשפ"ד',
#  '90_1_2024': "תרשים 7ט': התפלגות ילדים המקבלים קצבת ילד נכה (מספרים ושיעור לאלף מכלל הילדים בישראל) / 2023-1995*",
#  '91_1_2024': "תרשים 7י': התפלגות ילדים המקבלים קצבת ילד נכה, לפי גיל* / 2023-2005**",
#  '92_1_2024': "תרשים 7יא': ילדים עולים וילדי עולים* המקבלים קצבת ילד נכה / 2023",
#  '93_1_2024': "תרשים 7יב': שיעור הבקשות למכשירי שיקום עבור ילדים ובני נוער שהוגשו ללשכות הבריאות של משרד הבריאות, לפי סוג מכשיר / 2023",
#  '94_1_2024': "תרשים 8א': ממוצע חמש שנתי של תוחלת החיים בלידה*  לפי קבוצת אוכלוסייה ומגדר / 1996/1999-2022",
#  '95_1_2024': "תרשים 8ב': סיבת הפנייה של ילדים לחדר מיון – שיעור מקבוצת הגיל / 2023",
#  '96_1_2024': 'תרשים 8ג\': התפלגות הבקשות שאושרו לסייעות רפואיות לתלמידים בחינוך הרגיל\nלצורך השגחה מונעת / תשפ"ד (2023/24)',
#  '97_1_2024': "תרשים 8ד': מספר תיקי הילדים שעניינם נדון בוועדות פסיכיאטריות מחוזיות לילדים ונוער* / 2023-2010",
#  '98_1_2024': "תרשים 8ה': ילדים (17-0) מאושפזים באשפוז פסיכיאטרי בסוף השנה* לפי סטטוס חוקי / 2021",
#  '99_1_2024': "תרשים 8ו': שיעור תמותת תינוקות מוסלמים ותינוקות בדווים בנגב* /\n(שיעור לאלף לידות חי) / 2023-2010\n+",
#  '100_1_2024': "תרשים 9א': שיעור פניות ילדים לחדרי מיון לפי סיבת הפנייה / 2023",
#  '101_1_2024': "תרשים 9ב': מספר ושיעור פניות ילדים לחדרי מיון עקב סיבות חיצוניות* מתוך כלל הפניות למיון, לפי גיל (באחוזים) / 2023-2021",
#  '102_1_2024': "תרשים 9ג': מספר ושיעור פניות ילדים לחדרי מיון עקב תאונת דרכים מתוך כלל הפניות עקב סיבות חיצוניות, לפי גיל  (באחוזים)  / 2023",
#  '103_1_2024': "תרשים 9ד': אחוז האשפוזים וימי אשפוז של ילדים עקב סיבה חיצונית (תאונה) מתוך מכלל האשפוזים וימי האשפוז של ילדים/ 2022-2015",
#  '104_1_2024': "תרשים 9ה': התפלגות הסיבה החיצונית (תאונה) שגרמה לאשפוז ילדים* / 2022",
#  '105_1_2024': "תרשים 9ו': שיעור תמותה מפגיעה לא מכוונת (תאונות) לכל 100,000 ילדים, לפי דירוג חברתי-כלכלי של יישוב מגוריהם / ממוצע השנים 2023-2019",
#  '106_1_2024': "תרשים 9ז': התפלגות מקרי תמותה עקב היפגעות בלתי מכוונת לפי קבוצות גיל (17-0), (אחוזים)/ 2023",
#  '107_1_2024': "תרשים 9ח': מספר הילדים (14-0) שנפגעו בתאונת דרכים / 2023-2010",
#  '108_1_2024': "תרשים 9ט': חלקם של ילדים (14-0) שנפגעו בתאונת דרכים מכלל הנפגעים, לפי חומרת הפגיעה / 2023",
#  '109_1_2024': "תרשים 9י': מספר הילדים (14-0) שנפצעו קשה או שנהרגו בתאונת דרכים /\n2018-2023",
#  '110_1_2024': "תרשים 9יב': שיעור רוכבי אופניים/קורקינט חשמליים בני 18-0 שאושפזו כתוצאה מהיפגעות בתאונת דרכים, לפי סוג כלי ממונע / 2023",
#  '111_1_2024': "תרשים 9יג': שיעור רוכבי אופניים / קורקינט חשמליים בני 18-0 שאושפזו כתוצאה מהיפגעות בתאונת דרכים, לפי גיל* / 2023",
#  '112_1_2024': "תרשים 9יד': מספר רוכבי האופניים והקורקינטים החשמליים שנפצעו ואושפזו כתוצאה מהיפגעות בתאונת דרכים וחלקם של הילדים (15-0) מכלל הרוכבים שנפגעו ואושפזו בתאונות אלה / 2023-2013",
#  '113_1_2024': "תרשים 9טו': התפלגות ילדים שהושארו או נלכדו לבד ברכב, לפי סוג רכב (באחוזים)/ 2023",
#  '114_1_2024': "תרשים 9טז': מספר הילדים שנהרגו במהלך חופשת הקיץ, לפי שנה / 2023-2005",
#  '115_1_2024': "תרשים 9יז': התפלגות הילדים שנהרגו בטביעה במהלך חופשת הקיץ, לפי נסיבות הטביעה (מספר ואחוז מכלל הילדים שנהרגו בטביעה) / 2023-2017",
#  '116_1_2024': "תרשים 9יט': התפלגות הפניות למכון הארצי למידע רפואי בהרעלות עקב חשיפה לרעלים לפי גיל / 2023-2016",
#  '117_1_2024': "תרשים 10א': התפלגות אוכלוסיית הילדים בישראל ביישובים הגדולים מ-10,000 נפש באשכול חברתי כלכלי/ 2023\nחברתי-כלכלי** / 2023",
#  '118_1_2024': "תרשים 10ב': שיעור הילדים מכלל אוכלוסיית היישוב, ביישובים מעל 10,000 נפש לפי אשכול חברתי-כלכלי*/ 2023",
#  '119_1_2024': "תרשים 10ג': תחולת העוני בקרב ילדים (אחוזים) / 2023-2022",
#  '120_1_2024': "תרשים 10ד': תחולת העוני בקרב ילדים לפי הכנסה נטו, לפי מגזרים (באחוזים) / 2023-2020",
#  '121_1_2024': "תרשים 10ה': שיעור הילדים במשפחות המקבלות גמלה להבטחת הכנסה \nמכלל הילדים / 2023-2005*",
#  '122_1_2024': "תרשים 10ו': שיעור הילדים החיים במשפחות המקבלות גמלה להבטחת הכנסה*, לפי עילות נבחרות/ 2023",
#  '123_1_2024': "תרשים 10ז': שיעור הילדים שחיו במשק בית ללא מועסקים, מכלל הילדים, \nלפי קבוצת אוכלוסיה / 2023-2019",
#  '124_1_2024': "תרשים 10ח': שיעור הילדים (וילדים עולים) שחיו במשפחות בהן לפחות הורה אחד מקבל דמי אבטלה בפועל* / 2023",
#  '125_1_2024': "תרשים 10ט': שיעור בני 17-15 שעובדים* מקבוצת בני גילם / 2023-1990",
#  '126_1_2024': "תרשים 10י': התפלגות הפניות להסתדרות הנוער העובד והלומד*, לפי סעיפי תלונה עיקריים / 2023-2019",
#  '127_1_2024': "תרשים 10יא': כתבי אישום בגין הפרת חוק הנוער שהגיש מינהל ההסדרה והאכיפה במשרד העבודה, הרווחה והשירותים החברתיים/ 2023-1998",
#  '128_1_2024': 'תרשים 10יב: משקי בית לפי עשירוני הכנסה נטו לנפש סטנדרטית ולפי מספר ילדים, באחוזים / 2022',
#  '129_1_2024': "תרשים 10יג': הוצאה חודשית ממוצעת של משקי בית עם ילדים על סעיפי חינוך נבחרים, לפי עשירוני הכנסה נטו לנפש סטנדרטית / 2022",
#  '130_1_2024': "תרשים 10יד': התפלגות ההוצאה החודשית לחינוך במשקי בית עם ילדים (אחוזים) / 2022",
#  '131_1_2024': "תרשים 11א': החלטות של בתי משפט שלום לנוער בעניין הכרזת קטין כנזקק* (אחוזים) / 2023",
#  '132_1_2024': "תרשים 11ב': מספר הבקשות לאישור נישואי קטינות שהוגשו לבית המשפט לענייני משפחה / 2023-1997",
#  '133_1_2024': "תרשים 12א': התפלגות קטינים חשודים ונילונים* / 2023-2010",
#  '134_1_2024': "תרשים 12ב': שיעור הקטינים החשודים* עם תיקים פליליים** מכלל החשודים*** / 2023-2005",
#  '135_1_2024': "תרשים 12ג': התפלגות תיקים פליליים ותיקי ט.מ. בעבירות שמעורבים בהם קטינים חשודים*, לפי סוג תיק / 2023-2005",
#  '136_1_2024': "תרשים 12ד': התפלגות תיקים שנפתחו לקטינים* החשודים בביצוע עבירות נגד קטינים, לפי שנה / 2023-2006",
#  '137_1_2024': "תרשים 12ה': שיעור הקטינים החשודים עם תיקים פליליים*, לפי סוג עבירה / 2023",
#  '138_1_2024': "תרשים 12ו': שיעור התיקים שנפתחו לקטינים שנחשדו בביצוע עבירות אלימות נבחרות במוסדות חינוך (שיעור ל-10,000 בקבוצת הגיל) / 2023-2010",
#  '139_1_2024': "תרשים 12ז': מספר הקטינים העצורים, לפי שנה וגיל / 2023-2011",
#  '140_1_2024': "תרשים 12ח': התפלגות גילאי הקטינים העצורים / 2023",
#  '141_1_2024': "תרשים 12ט': התפלגות קטינים המופנים בידי המשטרה לטיפול שירות המבחן לנוער \nלפי סוג תיק (מספרים ושיעור לאלף בקבוצת הגיל 17-12) / 2023-2010\n\n\n                               לדלל את הסקאלה",
#  '142_1_2024': "תרשים 12י': שיעור הקטינים בטיפול שירות המבחן לנוער, לפי גילם בעת ביצוע העבירה (אחוז מכלל הקטינים המופנים) / 2023-2010",
#  '143_1_2024': "תרשים 12יא': מספר ההליכים הפליליים שבהם קטינים יוצגו בידי הסניגוריה הציבורית*, לפי שנה** / 2023-2010",
#  '144_1_2024': 'תרשים 12.26: מספר ההליכים הפליליים שבהם קטינים יוצגו בידי הסניגוריה הציבורית*, לפי מחוז וערכאה / 2023',
#  '145_1_2024': "תרשים 12יב': יחס הרשעה/אי הרשעה* בקרב קטינים לפי קבוצת אוכלוסייה (אחוזים)/ 2022",
#  '146_1_2024': 'תרשים 12יג\': התפלגות מעצרים* של קטינים תושבי ישראל שנקלטו במהלך שנת 2023 במתקני השב"ס, לפי גיל (באחוזים) / 2320',
#  '147_1_2024': 'תרשים 12יד\': התפלגות הקליטות* של קטינים תושבי ישראל במתקני השב"ס במהלך שנת 2023, לפי סוג אסיר (באחוזים) / 2023',
#  '148_1_2024': "תרשים 12טו': התפלגות קליטת אסירים/עצירים בטחוניים קטינים, לפי גיל / 2023",
#  '149_1_2024': "תרשים 13א': מספר התיקים הפליליים ותיקי טיפול מותנה (ט.מ.) שנפתחו בגין עבירות כנגד ילדים במשפחה ומחוץ למשפחה / 2023-2011",
#  '150_1_2024': "תרשים 13ב': אחוז* התיקים הפליליים ותיקי ט.מ. שנפתחו בגין עבירות כנגד ילדים במשפחה , לפי מצב התיק / 2023-2015",
#  '151_1_2024': "תרשים 13ג': שיעור התיקים הפליליים ותיקי ט.מ. שנפתחו בגין עבירות כנגד ילדים מחוץ למשפחה, לפי מצב התיק / 2023-2015",
#  '152_1_2024': "תרשים 13ד': התפלגות התיקים שנפתחו בגין עבירות אלימות גופנית* של בגירים כנגד קטינים, לפי שנה (מספרים ושיעור ל-10,000 בקרב בגירים) / 2023-2008",
#  '153_1_2024': "תרשים 13ה': יישובים* שבהם שיעור התיקים הפליליים שנפתחו בגין עבירות אלימות** של בגירים כנגד קטינים היה כפול מהשיעור הארצי / 2023",
#  '154_1_2024': "תרשים 13ו': מספר הילדים שנרצחו בתוך המשפחה / 2023-2004",
#  '155_1_2024': "תרשים 13ז':התפלגות הילדים שנרצחו בתוך המשפחה, לפי גיל / 2023-2004",
#  '156_1_2024': "תרשים 13ח': התפלגות התיקים שנפתחו בגין רצח ילדים בתוך המשפחה, לפי זיקת הפוגע לקורבן / 2023-2004",
#  '157_1_2024': "תרשים 13ט': מספר התיקים והגשת כתבי אישום בעבירות מין כלפי קטינים* / 2010-2023",
#  '158_1_2024': "תרשים 13י': שיעור התיקים שנפתחו בגין עבירת מין כלפי קטינים, לפי מגדר הנפגעים / 2023-2008",
#  '159_1_2024': "תרשים 13יא': מספר התיקים שנפתחו לבגירים בגין מכירת אלכוהול לקטינים, לפי שנה / 2023-2011",
#  '160_1_2024': "תרשים 13יב': מספר התיקים שנפתחו לבגירים בגין מכירת אלכוהול לקטינים ומספר כתבי האישום שהוגשו, לפי שנה / 2023-2005",
#  '161_1_2024': "תרשים 13יג': מספר התיקים שנפתחו לבגירים בחשד לביצוע עבירות כנגד קטינים במוסדות חינוך, לפי שנה וגיל / 2023-2008",
#  '162_1_2024': 'תרשים 13יד\': מספר התיקים שנפתחו בגין עבירות על "חוק הסרטונים"* הקשורות לאינטרנט** כנגד קטינים / 2023-2018',
#  '163_1_2024': "תרשים 13טו': מספר הילדים עד גיל 14 שנחקרו בידי חוקרי ילדים, לפי דת*\n/ 2023-2000",
#  '164_1_2024': "תרשים 13טז': התפלגות מעמד הילדים עד גיל 14 שנחקרו בידי חוקרי ילדים / 2023",
#  '165_1_2024': "תרשים 13יז': התפלגות סוג העבירה עליה נחקרו ילדים עד גיל 14 בידי חוקרי ילדים / 2023",
#  '166_1_2024': "תרשים 13יח': התפלגות הילדים היהודים עד גיל 14 שנחקרו בידי חוקרי ילדים / 2023",
#  '167_1_2024': "תרשים 13יט': התפלגות הילדים הלא-יהודים עד גיל 14 שנחקרו בידי חוקרי ילדים, לפי דת וקבוצת אוכלוסייה / 2023",
#  '168_1_2024': "תרשים 13כ': התפלגות הילדים שחשפו בחקירתם דבר פגיעה, לפי זיקת החשוד לנפגע*/ 2019, 2023-2022",
#  '169_1_2024': "תרשים 14א': התפלגות הילדים המוכרים למחלקות לשירותים חברתיים החיים במשפחות שבראשן הורה עצמאי / 2023",
#  '170_1_2024': "תרשים 14ב': מספר הדיווחים* לעובדים סוציאליים לחוק הנוער, לפי שנה /\n2023-2015**",
#  '171_1_2024': "תרשים 14ג': התפלגות הילדים שדווח עליו לעובדים סוציאליים לחוק הנוער בשל חשד לפגיעה, לפי זיקת הפוגע/ 2023-2016 (אחוזים)*",
#  '172_1_2024': "תרשים 14ד': דיווחים לעובדים סוציאליים לחוק הנוער בגין קטינים עם מוגבלויות (מספרים ואחוז מסך כל הדיווחים) / 2023-2015*",
#  '173_1_2024': "תרשים 14ה': דיווחים לעובדים סוציאליים לחוק הנוער בגין קטינים עולים* (מספרים ואחוז מסך כל הדיווחים) / 2019-2015",
#  '174_1_2024': "תרשים 14ו': שיעור דיווחי שווא*/ שלא נדרש בהם המשך טיפול לעובדים סוציאליים לחוק הנוער על חשד להתעללות בילדים, הזנחה וסיכון/ 2023-2015**",
#  '175_1_2024': "תרשים 14ז': דיווחים על קטינים שבעניינם הוגשה בקשה לוועדת פטור מדיווח למשטרה (מספרים ואחוז מכלל הדיווחים) / 2023-2015*",
#  '176_1_2024': "תרשים 14ח': התפלגות הגורם המפנה ומדווח לעובדים סוציאליים לחוק נוער/ 2020-2023 (אחוזים)*",
#  '177_1_2024': "תרשים 14ט': שיעור הילדים בסיכון שהיו בטיפול במסגרת חירום אינטרנית, לפי הסיבה העיקרית להפניה /  2023",
#  '178_1_2024': "תרשים 14י': התפלגות* הילדים בסיכון שהיו בטיפול במרכז חירום אינטרני, לפי שנה / 2023-2000",
#  '179_1_2024': "תרשים 14יא': מספר הילדים השוהים במקלטים לנשים נפגעות אלימות, לפי שנה/2023-2001",
#  '180_1_2024': "תרשים 14יב': התפלגות הגילים של ילדים השוהים במקלטים לנשים נפגעות אלימות / 2023 (אחוזים)",
#  '181_1_2024': "תרשים 14יג': התפלגות משך השהות של ילדים במקלטים לנשים נפגעות אלימות/ \n2023 (אחוזים)",
#  '182_1_2024': "תרשים 14יד': מספר בני הנוער והצעירים בטיפולה של רשות חסות הנוער, לפי שנה/ \n2023-2002",
#  '183_1_2024': "תרשים 14טו': התפלגות גילם של בני נוער וצעירים בטיפולה של רשות חסות הנוער \n/ 2023-2014",
#  '184_1_2024': "תרשים 14טז': התפלגות בני נוער וצעירים בטיפולה של רשות חסות הנוער, \nלפי קבוצת אוכלוסייה / 2023",
#  '185_1_2024': "תרשים 14יז': מספר הקטינים הנעדרים, לפי מגדר / 2022",
#  '186_1_2024': "תרשים 14יח': שיעור ניסיונות התאבדות של ילדים ובני נוער שהתקבלו בחדרי מיון, \nלפי גיל ושנה / 2023-2006",
#  '187_1_2024': "תרשים 14יט': מספר הילדים בגיל 17-13* שניסו להתאבד באמצעות רעלים**/  \n2023-1993",
#  '188_1_2024': "תרשים 14כ': מספר ההתאבדויות של ילדים ובני נוער עד גיל 17, לפי שנה/\n2021-2000",
#  '189_1_2024': "תרשים 14כא': שיעור ההתאבדויות של ילדים ובני נוער עד גיל 17, לפי מגדר/\n2021-2000",
#  '190_1_2024': "תרשים 14כב': שיעור ההתאבדויות של ילדים ובני נוער עד גיל 17, לפי גיל/ \n2021-2000",
#  '191_1_2024': "תרשים 14כג': מספר הפניות למוקד 105 (המטה הלאומי להגנה על ילדים ברשת) \\ 2023-2019"}

# %%
## filtering the relevant graphs from 2001-2016 ###

import os
import json
import shutil

# Paths
graphs_dir = "/content/graphs_2001_2016"
redundant_json_path = "/content/redundant_graphs.json"
graphs_summary_path = "/content/graphs_2001_2016/graphs_summary.json"
relevant_dir = "/content/relevant_graphs"
relevant_summary_path = "/content/relevant_graphs_summary.json"

# Load JSONs
with open(redundant_json_path, "r", encoding="utf-8") as f:
    redundant_map = json.load(f)

with open(graphs_summary_path, "r", encoding="utf-8") as f:
    graphs_summary = json.load(f)

# Ensure relevant directory exists
os.makedirs(relevant_dir, exist_ok=True)

# ---------- Filter relevant graphs ----------
relevant_summary = {}

for year in os.listdir(graphs_dir):
    year_path = os.path.join(graphs_dir, year)
    if not os.path.isdir(year_path):
        continue

    for chapter in os.listdir(year_path):
        chapter_path = os.path.join(year_path, chapter)
        if not os.path.isdir(chapter_path):
            continue

        for fname in os.listdir(chapter_path):
            if not fname.lower().endswith((".png", ".jpg", ".jpeg", ".pdf")):
                continue

            key = os.path.splitext(fname)[0]  # remove extension, keep exact key

            if redundant_map.get(key, "NO") == "NO":  # only keep relevant
                # Copy to relevant directory
                new_year_dir = os.path.join(relevant_dir, year)
                new_chap_dir = os.path.join(new_year_dir, chapter)
                os.makedirs(new_chap_dir, exist_ok=True)
                shutil.copy2(os.path.join(chapter_path, fname), os.path.join(new_chap_dir, fname))

                # Add to relevant summary if exists
                if key in graphs_summary:
                    relevant_summary[key] = graphs_summary[key]

# Save relevant summary JSON
with open(relevant_summary_path, "w", encoding="utf-8") as f:
    json.dump(relevant_summary, f, ensure_ascii=False, indent=2)

print("✅ Filtering complete")
print(f"Relevant graphs saved under: {relevant_dir}")
print(f"Relevant summary saved as: {relevant_summary_path}")
# Out:
# ✅ Filtering complete
# Relevant graphs saved under: /content/relevant_graphs
# Relevant summary saved as: /content/relevant_graphs_summary.json

# %%
## extracting photos to csv's ###
## converting png to csv
# for years 2001-2016

# !pip install anthropic
import os
import json
from pathlib import Path
from PIL import Image
import anthropic
import csv
import io
import re

# ---------- Config ----------
MAX_DIM = 1200   # resize larger images down
MIN_PIXELS = 50000  # skip if too small (< e.g., 200x250)
OUTPUT_DIR = "tables_out"

# Claude client
client = anthropic.Anthropic(
        api_key="" # replace with your actual API key
    )

# ---------- Utils ----------
def check_and_resize(path, max_dim=MAX_DIM, min_pixels=MIN_PIXELS):
    """
    Check image size and resize if too large.
    Skip if image too small.
    Returns PIL Image object or None.
    """
    img = Image.open(path)
    w, h = img.size
    if w * h < min_pixels:
        return None  # too small → skip
    scale = max_dim / max(w, h)
    if scale < 1:  # downscale
        new_size = (int(w * scale), int(h * scale))
        img = img.resize(new_size, Image.LANCZOS)
    print("proccesed img")
    return img

import base64
from io import BytesIO

def pil_to_base64(img):
    buffered = BytesIO()
    img.save(buffered, format="PNG")
    return base64.b64encode(buffered.getvalue()).decode()

def send_to_claude(image, prompt):
    """
    Send single image and prompt to Claude Sonnet 2.7 and return text output.
    """
    img_b64 = pil_to_base64(image)



    message = client.messages.create(
    # model="claude-sonnet-4-20250514",
    model="claude-3-7-sonnet-20250219",
    # model= "claude-3-haiku-20240307",
    max_tokens=4096,
    temperature=1,
    system="data extraction ",
    messages=[
        {
            "role": "user",
            "content": [
                {
                    "type": "image",
                    "source": {
                        "type": "base64",
                        "media_type": "image/png",
                        "data": img_b64
                    }
                },
                {
                    "type": "text",
                    "text": prompt
                }
                ]
            }
        ]
    )
    print(message.content)
    print("after Api call")
    return message.content[0].text.strip()



# ---------- Main pipeline ----------
def process_images(img_dir, graphs_json_path, output_dir, chapter_num=None, year_num=None):
    Path(output_dir).mkdir(parents=True, exist_ok=True)

    # Load graph names JSON
    with open(graphs_json_path, "r", encoding="utf-8") as f:
        graphs_map = json.load(f)

    if not os.path.exists(img_dir):
        print(f"⚠️ Skipping missing directory: {img_dir}")
        return

    # Collect valid images
    valid_images = []
    for fname in sorted(os.listdir(img_dir)):

        if not fname.lower().endswith((".png", ".jpg", ".jpeg")):
            continue
        path = os.path.join(img_dir, fname)
        img = check_and_resize(path)
        if img is None:
            print(f"⚠️ Skipping too-small image: {fname}")
            continue
        img = Image.open(path)
        if img is None:
            print(f"Skipping could not open: {fname}")
            continue
        valid_images.append((fname, img))

    if not valid_images:
        print("No valid images found in the directory.")
        return

    # Process each image individually
    for fname, img in valid_images:
        key = os.path.splitext(fname)[0]  # -> "3_4_2004"
        graph_name = graphs_map.get(key)
        print(graph_name)
        print(key)
        prompt =(
                   "You are a data analyst expert.\nTask: Extract a table from the attached image into a CSV file.\n\nRules:\n-All images contain Hebrew text.\n- if there is a number seperate with commas (e.g. 110,000) change it to non comma (110000).\n-Do not translate or change any values. Preserve all Hebrew exactly as in the table.\n-If a cell cannot be parsed, leave it empty (do not invent values).\n- if you cant read the hebrew do not invent words. use the graph name for context.\n-Some tables have section headers (e.g. סך הכל, חינוך עברי, חינוך ערבי).\nIn those cases, add a new column at the beginning called קבוצה, and repeat the section name for each row under it.\n- section headers cant be a header- it either a section header or a first row header.\n-If there is an informative sentence below/under the graph, put it as a whole row in the end of the CSV,leave an empty row before.\n-The header of the table for context is: {graph_name}\n-Output format: strict CSV (comma-separated, UTF-8).\n-All rows in the CSV must have exactly the same number of columns as the header row. If there are totals, footnotes, or sentences under the graph, fit them into the same number of columns (by using empty cells).\n-Do not wrap in Markdown or code fences.\n-If you cannot parse the full table, return exactly: null.\n\nReturn only one of:\nA valid CSV table, or\nThe string: null\n!! Do not return any text that is not a CSV file or null !!"
                  )

        print(f"Processing image: {fname} (graph: {graph_name})")
        result = send_to_claude(img, prompt).strip()
        print(result)
        # Skip saving if result is null
        if result.lower() == "null":
            print(f"⚠️ Skipping {fname} — Claude returned null (unreadable table).")
            continue

        try:
            # while re.search(r'(\d+),(\d{3})(?!\d)', result):
            #   result = re.sub(r'(\d+),(\d{3})(?!\d)', r'\1\2', result)
            reader = csv.reader(io.StringIO(result))
            rows = list(reader)
            if not rows or all(len(row) <=1 for row in rows):
                print(f"⚠️ Skipping {fname} — result is not a valid CSV.")
                continue

            rows[0] = [re.sub(r'\*+$', '', col).strip() for col in rows[0]]
            max_cols = max(len(row) for row in rows)
            for i, row in enumerate(rows):
                if len(row) < max_cols:
                    rows[i] = row + [""] * (max_cols - len(row))
                    print(f"⚠️ Row {i} in {fname} padded with empty strings.")
            outname = fname.rsplit(".", 1)[0] + ".csv"
            outpath = os.path.join(output_dir, outname)
            with open(outpath, "w", encoding="utf-8", newline="") as f:
                 writer = csv.writer(f)
                 writer.writerows(rows)

            print(f"✅ Saved CSV: {outname}")
        except Exception as e:
            print(f"⚠️ Skipping {fname} — CSV parse error: {e}")
            continue



for year in range(2001,2016):
    print(f"Processing year: {year}")
    for chap in range(1,16):
        print(f"Processing chapter: {chap}")
        process_images(f"/content/relevant_graphs/{year}/{chap:02d}",
                      "/content/relevant_graphs_summary.json",
                      f"/content/graphs_to_csvs_2001-2016/{year}/{chap:02d}",chap,year)
# Out:
# Collecting anthropic
#   Downloading anthropic-0.68.1-py3-none-any.whl.metadata (28 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /usr/local/lib/python3.12/dist-packages (from anthropic) (0.17.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (0.11.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (2.11.9)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.12/dist-packages (from anthropic) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->anthropic) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->anthropic) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.1)
# Downloading anthropic-0.68.1-py3-none-any.whl (325 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.2/325.2 kB 26.1 MB/s eta 0:00:00
# Installing collected packages: anthropic
# Successfully installed anthropic-0.68.1
# Processing year: 2009
# Processing chapter: 1
# proccesed img
# proccesed img
# יישובים שבהם  הילדים מונים עד 25% או 55% ויותר
# מהאוכלוסייה
# דצמבר 2008 | תרשים 1ב'
# 2_1_2009
# Processing image: 2_1_2009.png (graph: יישובים שבהם  הילדים מונים עד 25% או 55% ויותר
# מהאוכלוסייה
# דצמבר 2008 | תרשים 1ב')
# [TextBlock(citations=None, text='ישוב,סוג\nכרמיאל - ק. מוצקין,●\nק. ביאליק,●\nנצרת עילית,●\nנהריה,●\nחיפה,●\nק. ים,●\nהרצליה - גבעתיים,●\nתל-אביב-יפו,●\nרמת גן,●\nבת ים,●\nחולון,●\nראשל"צ,●\nנתניה,●\nמודיעין - עילית,■\nבית"ר עילית,■\nרהט,■\nכסייפה,■\nתל שבע,■\nערערה - בנגב,■\nשגב שלום,■\nחורה,■\nאלעד,■\nביטחוני,33.0%', type='text')]
# after Api call
# ישוב,סוג
# כרמיאל - ק. מוצקין,●
# ק. ביאליק,●
# נצרת עילית,●
# נהריה,●
# חיפה,●
# ק. ים,●
# הרצליה - גבעתיים,●
# תל-אביב-יפו,●
# רמת גן,●
# בת ים,●
# חולון,●
# ראשל"צ,●
# נתניה,●
# מודיעין - עילית,■
# בית"ר עילית,■
# רהט,■
# כסייפה,■
# תל שבע,■
# ערערה - בנגב,■
# שגב שלום,■
# חורה,■
# אלעד,■
# ביטחוני,33.0%
# ✅ Saved CSV: 2_1_2009.csv
# תרשים 1ג' | ילדים* חסרי אזרחות** ישראלית
# (מספרים ואחוזים)
# אפריל 2009
# 3_1_2009
# Processing image: 3_1_2009.png (graph: תרשים 1ג' | ילדים* חסרי אזרחות** ישראלית
# (מספרים ואחוזים)
# אפריל 2009)
# [TextBlock(citations=None, text='קבוצה,אחוז\nתושבי מזרח ירושלים,74.0\nאחר,26.0\n\n,\n,סך כל הילדים בלא אזרחות: 145,855', type='text')]
# after Api call
# קבוצה,אחוז
# תושבי מזרח ירושלים,74.0
# אחר,26.0
#
# ,
# ,סך כל הילדים בלא אזרחות: 145,855
# ⚠️ Row 0 in 3_1_2009.png padded with empty strings.
# ⚠️ Row 1 in 3_1_2009.png padded with empty strings.
# ⚠️ Row 2 in 3_1_2009.png padded with empty strings.
# ⚠️ Row 3 in 3_1_2009.png padded with empty strings.
# ⚠️ Row 4 in 3_1_2009.png padded with empty strings.
# ✅ Saved CSV: 3_1_2009.csv
# Processing chapter: 2
# proccesed img
# proccesed img
# proccesed img
# proccesed img
# proccesed img
# proccesed img
# proccesed img
# proccesed img
# תרשים 2א' | ילדים עולים וילדי עולים בגיל 0-17
# (מספרים)
# ינואר 2007 - ינואר 2009
# 1_2_2009
# Processing image: 1_2_2009.png (graph: תרשים 2א' | ילדים עולים וילדי עולים בגיל 0-17
# (מספרים)
# ינואר 2007 - ינואר 2009)
# [TextBlock(citations=None, text='שנה,ילדי עולים,עולים\n2007,238151,89516\n2008,235567,89979\n2009,235709,93156', type='text')]
# after Api call
# שנה,ילדי עולים,עולים
# 2007,238151,89516
# 2008,235567,89979
# 2009,235709,93156
# ✅ Saved CSV: 1_2_2009.csv
# תרשים 2ב' | ילדי עולים (0-17) וחלקם בכלל הילדים בישראל
# (מספרים ואחוזים)
# *1990-2008
# 2_2_2009
# Processing image: 2_2_2009.png (graph: תרשים 2ב' | ילדי עולים (0-17) וחלקם בכלל הילדים בישראל
# (מספרים ואחוזים)
# *1990-2008)
# [TextBlock(citations=None, text='שנה,אחוז,מספר\n1990,3.1,**\n1995,8.0,195,800\n2000,11.5,245,275\n2005,10.6,240,937\n2006,10.3,238,151\n2007,10.0,235,567\n2008,9.8,235,709', type='text')]
# after Api call
# שנה,אחוז,מספר
# 1990,3.1,**
# 1995,8.0,195,800
# 2000,11.5,245,275
# 2005,10.6,240,937
# 2006,10.3,238,151
# 2007,10.0,235,567
# 2008,9.8,235,709
# ⚠️ Row 0 in 2_2_2009.png padded with empty strings.
# ⚠️ Row 1 in 2_2_2009.png padded with empty strings.
# ✅ Saved CSV: 2_2_2009.csv
# ילדים (0-17) במשפחות עולים*
# (אחוזים)
# דצמבר 2008 | תרשים 2ג'
# 3_2_2009
# Processing image: 3_2_2009.png (graph: ילדים (0-17) במשפחות עולים*
# (אחוזים)
# דצמבר 2008 | תרשים 2ג')
# [TextBlock(citations=None, text='מספר הילדים במשפחה,אחוז\nילד אחד,25.6%\n2 ילדים,33.9%\n3 ילדים,17.1%\n4 + ילדים,23.4%\n\nסך כל הילדים במשפחות עולים: 235709', type='text')]
# after Api call
# מספר הילדים במשפחה,אחוז
# ילד אחד,25.6%
# 2 ילדים,33.9%
# 3 ילדים,17.1%
# 4 + ילדים,23.4%
#
# סך כל הילדים במשפחות עולים: 235709
# ⚠️ Row 5 in 3_2_2009.png padded with empty strings.
# ⚠️ Row 6 in 3_2_2009.png padded with empty strings.
# ✅ Saved CSV: 3_2_2009.csv
# תרשים 2ה' | חלקם של הילדים* בכלל העולים**
# לפי שנת עלייה (אחוזים)
# 1948-2008
# 5_2_2009
# Processing image: 5_2_2009.png (graph: תרשים 2ה' | חלקם של הילדים* בכלל העולים**
# לפי שנת עלייה (אחוזים)
# 1948-2008)
# [TextBlock(citations=None, text='שנה,אחוז ילדי העולים מכלל ילדי ישראל\n1948-1960,35.8\n1961-1964,40.6\n1965-1971,31.6\n1972-1979,27.6\n1980-1989,27.6\n1990-2001,29.2\n2005,28.7\n2006,28.3\n2007,27.0\n2008,23.2', type='text')]
# after Api call
# שנה,אחוז ילדי העולים מכלל ילדי ישראל
# 1948-1960,35.8
# 1961-1964,40.6
# 1965-1971,31.6
# 1972-1979,27.6
# 1980-1989,27.6
# 1990-2001,29.2
# 2005,28.7
# 2006,28.3
# 2007,27.0
# 2008,23.2
# ✅ Saved CSV: 5_2_2009.csv
# ילדי  מהגרי עבודה* המקבלים שירותים מקופת חולים מאוחדת
# לפי ארץ מוצא (מספרים ואחוזים)
# 2008 | תרשים 2ו'
# 6_2_2009
# Processing image: 6_2_2009.png (graph: ילדי  מהגרי עבודה* המקבלים שירותים מקופת חולים מאוחדת
# לפי ארץ מוצא (מספרים ואחוזים)
# 2008 | תרשים 2ו')
# [TextBlock(citations=None, text='ארץ מוצא,אחוז,מספר\nמזרח אירופה,14,235.76\nדרום אמריקה,12,202.08\nמזרח אסיה,20,336.8\nאפריקה,54,909.36', type='text')]
# after Api call
# ארץ מוצא,אחוז,מספר
# מזרח אירופה,14,235.76
# דרום אמריקה,12,202.08
# מזרח אסיה,20,336.8
# אפריקה,54,909.36
# ✅ Saved CSV: 6_2_2009.csv
# תינוקות ופעוטות של מהגרי עבודה שטופלו בתחנות לבריאות
# המשפחה (טיפות חלב) בעיר תל-אביב-יפו (מספרים)
# יולי 1996-יולי 2009 | תרשים 2ז'
# 7_2_2009
# Processing image: 7_2_2009.png (graph: תינוקות ופעוטות של מהגרי עבודה שטופלו בתחנות לבריאות
# המשפחה (טיפות חלב) בעיר תל-אביב-יפו (מספרים)
# יולי 1996-יולי 2009 | תרשים 2ז')
# [TextBlock(citations=None, text='שנה,מיישמות (6+)*,מיישמות (1-5)\n1996,225,400\n2000,362,677\n2003,359,1003\n2004,228,615\n2005,201,527\n2006,182,613\n2007,254,718\n2008,278,892\n2009,357,929', type='text')]
# after Api call
# שנה,מיישמות (6+)*,מיישמות (1-5)
# 1996,225,400
# 2000,362,677
# 2003,359,1003
# 2004,228,615
# 2005,201,527
# 2006,182,613
# 2007,254,718
# 2008,278,892
# 2009,357,929
# ✅ Saved CSV: 7_2_2009.csv
# ילדים מבקשי מקלט שטופלו בתחנות לבריאות המשפחה
# (טיפת חלב) בתחנה המרכזית בתל-אביב (אחוזים)
# יולי 2009 | תרשים 2ח'
# 8_2_2009
# Processing image: 8_2_2009.png (graph: ילדים מבקשי מקלט שטופלו בתחנות לבריאות המשפחה
# (טיפת חלב) בתחנה המרכזית בתל-אביב (אחוזים)
# יולי 2009 | תרשים 2ח')
# [TextBlock(citations=None, text='category,value\nתינוקות (גיל 0),40.7%\nפעוטות (1-5),59.3%', type='text')]
# after Api call
# category,value
# תינוקות (גיל 0),40.7%
# פעוטות (1-5),59.3%
# ✅ Saved CSV: 8_2_2009.csv
# ילדים מבקשי מקלט שלמדו במערכת החינוך בעיר תל אביב-יפו (אחוזים)
# ספטמבר 2008 | תרשים 2ט'
# 9_2_2009
# Processing image: 9_2_2009.png (graph: ילדים מבקשי מקלט שלמדו במערכת החינוך בעיר תל אביב-יפו (אחוזים)
# ספטמבר 2008 | תרשים 2ט')
# [TextBlock(citations=None, text='גיל,אחוז\n0-2,29.4%\n3-5,17.6%\n6-11,19.9%\n12-15,3.7%\n16-17,', type='text')]
# after Api call
# גיל,אחוז
# 0-2,29.4%
# 3-5,17.6%
# 6-11,19.9%
# 12-15,3.7%
# 16-17,
# ✅ Saved CSV: 9_2_2009.csv
# Processing chapter: 3
# proccesed img
# proccesed img
# proccesed img
# proccesed img
# proccesed img
# proccesed img
# proccesed img
# proccesed img
# proccesed img
# תרשים 3א' | מספר הילדים החיים במשפחות חד-הוריות
# לפי מצבו המשפחתי של ההורה
# 1993-2008*
# 1_3_2009
# Processing image: 1_3_2009.png (graph: תרשים 3א' | מספר הילדים החיים במשפחות חד-הוריות
# לפי מצבו המשפחתי של ההורה
# 1993-2008*)
# [TextBlock(citations=None, text='שנה,יזמות/ה,גרוש/ה,אלמן/ה,סך הכל\n1993,13589,71191,29051,118014\n1995,21164,81721,29347,132332\n2000,25192,116682,30000,170874\n2005,31999,128023,29071,192452\n2006,35393,138158,28118,201649\n2007,36773,140689,27427,205041\n2008,38591,143376,26941,208908', type='text')]
# after Api call
# שנה,יזמות/ה,גרוש/ה,אלמן/ה,סך הכל
# 1993,13589,71191,29051,118014
# 1995,21164,81721,29347,132332
# 2000,25192,116682,30000,170874
# 2005,31999,128023,29071,192452
# 2006,35393,138158,28118,201649
# 2007,36773,140689,27427,205041
# 2008,38591,143376,26941,208908
# ✅ Saved CSV: 1_3_2009.csv
# תרשים 3ב' | אחוז המשפחות החד-הוריות
# מכלל משפחות העולים והוותיקים
# דצמבר 2008
# 2_3_2009
# Processing image: 2_3_2009.png (graph: תרשים 3ב' | אחוז המשפחות החד-הוריות
# מכלל משפחות העולים והוותיקים
# דצמבר 2008)
# [TextBlock(citations=None, text='משפחות חד-הוריות עם ילדים,מספר משפחות בעולם,מספר משפחות בישראל\nמשפחות חד הוריות עם ילדים,27.4%,10.2%\nמשפחות עם ילדים (לא חד-הוריות),72.6%,89.8%\n,124657,1003575', type='text')]
# after Api call
# משפחות חד-הוריות עם ילדים,מספר משפחות בעולם,מספר משפחות בישראל
# משפחות חד הוריות עם ילדים,27.4%,10.2%
# משפחות עם ילדים (לא חד-הוריות),72.6%,89.8%
# ,124657,1003575
# ✅ Saved CSV: 2_3_2009.csv
# תרשים 3ג' | יישובים שילדים החיים במשפחות חד-הוריות מנו בהם
# 15% ויותר מילדי היישוב*
# דצמבר 2008
# 3_3_2009
# Processing image: 3_3_2009.png (graph: תרשים 3ג' | יישובים שילדים החיים במשפחות חד-הוריות מנו בהם
# 15% ויותר מילדי היישוב*
# דצמבר 2008)
# [TextBlock(citations=None, text='שם עיר,סימון\nעיריית קרית ים,•\nקריית ביאליק,•\nחיפה,•\nנשר,•\nמוצקין,•\nעכו,•\nמעלות תרשיחא,•\nכרמיאל,•\nסידות הכרמל,•\nקריית אתא,•\nאור-עקיבא,•\nפרדס חנה-כרכור,•\nחדרה,•\nגבעתיים,•\nת"א-יפו,•\nבת ים,•\nבני עייש,•\nאשקלון,•\nשדרות,•\nאילת,•\n\n,שיעור ארצי: 8.5%', type='text')]
# after Api call
# שם עיר,סימון
# עיריית קרית ים,•
# קריית ביאליק,•
# חיפה,•
# נשר,•
# מוצקין,•
# עכו,•
# מעלות תרשיחא,•
# כרמיאל,•
# סידות הכרמל,•
# קריית אתא,•
# אור-עקיבא,•
# פרדס חנה-כרכור,•
# חדרה,•
# גבעתיים,•
# ת"א-יפו,•
# בת ים,•
# בני עייש,•
# אשקלון,•
# שדרות,•
# אילת,•
#
# ,שיעור ארצי: 8.5%
# ⚠️ Row 21 in 3_3_2009.png padded with empty strings.
# ✅ Saved CSV: 3_3_2009.csv
# תרשים 3ד' | יישובים שבהם שיעורם של הילדים היהודים עד גיל 17 שהוריהם התגרשו בבתי דין רבניים היה 12.0 לאלף ויותר
# 2008
# 4_3_2009
# Processing image: 4_3_2009.png (graph: תרשים 3ד' | יישובים שבהם שיעורם של הילדים היהודים עד גיל 17 שהוריהם התגרשו בבתי דין רבניים היה 12.0 לאלף ויותר
# 2008)
# [TextBlock(citations=None, text='מקום,\nאלפי מנשה,\nפרדסיה,\nקרני שומרון,\nתל מונד,\nאריאל,\nבני עי"ש,\nלהבים,\nקצרין,\nקריית אתא,\nקריית ים,\nקריות ביאליק,\n\n,\nשיעור לסלט ארצי: 5.5', type='text')]
# after Api call
# מקום,
# אלפי מנשה,
# פרדסיה,
# קרני שומרון,
# תל מונד,
# אריאל,
# בני עי"ש,
# להבים,
# קצרין,
# קריית אתא,
# קריית ים,
# קריות ביאליק,
#
# ,
# שיעור לסלט ארצי: 5.5
# ⚠️ Row 12 in 4_3_2009.png padded with empty strings.
# ⚠️ Row 14 in 4_3_2009.png padded with empty strings.
# ✅ Saved CSV: 4_3_2009.csv
# תרשים 3ה' | מספר הילדים החיים במשפחות המקבלות דמי מזונות
# מן המוסד לביטוח לאומי
# 1992-2008*
# 5_3_2009
# Processing image: 5_3_2009.png (graph: תרשים 3ה' | מספר הילדים החיים במשפחות המקבלות דמי מזונות
# מן המוסד לביטוח לאומי
# 1992-2008*)
# [TextBlock(citations=None, text='שנה,מספרים\n1992,28303\n1995,37145\n2000,48134\n2001,51636\n2002,55231\n2003,50266\n2004,42867\n2005,41234\n2006,40225\n2007,38955\n2008,37415', type='text')]
# after Api call
# שנה,מספרים
# 1992,28303
# 1995,37145
# 2000,48134
# 2001,51636
# 2002,55231
# 2003,50266
# 2004,42867
# 2005,41234
# 2006,40225
# 2007,38955
# 2008,37415
# ✅ Saved CSV: 5_3_2009.csv
# תרשים 3ו' | ילדים יתומים החיים במשפחות המקבלות קצבאות מהביטוח הלאומי*
# לפי סוג קצבה (אחוזים)
# דצמבר 2008
# 6_3_2009
# Processing image: 6_3_2009.png (graph: תרשים 3ו' | ילדים יתומים החיים במשפחות המקבלות קצבאות מהביטוח הלאומי*
# לפי סוג קצבה (אחוזים)
# דצמבר 2008)
# [TextBlock(citations=None, text='קטגוריה,אחוז\nשארים,91.5%\nמשפחות נפגעי עבודה,5.1%\nנפגשים ויתומים מקבלי הבטחת הכנסה,1.3%\nנפגעי פעולות איבה,1.5%\nאלימות במשפחה,0.6%\n\nסך הכל,32468', type='text')]
# after Api call
# קטגוריה,אחוז
# שארים,91.5%
# משפחות נפגעי עבודה,5.1%
# נפגשים ויתומים מקבלי הבטחת הכנסה,1.3%
# נפגעי פעולות איבה,1.5%
# אלימות במשפחה,0.6%
#
# סך הכל,32468
# ⚠️ Row 6 in 6_3_2009.png padded with empty strings.
# ✅ Saved CSV: 6_3_2009.csv
# תרשים 3ז' | ילדים שאומצו בידי אזרחי ישראל*
# (מספרים ואחוזים)
# 2008
# 7_3_2009
# Processing image: 7_3_2009.png (graph: תרשים 3ז' | ילדים שאומצו בידי אזרחי ישראל*
# (מספרים ואחוזים)
# 2008)
# [TextBlock(citations=None, text='סוג,ערך\nאימון בארץ,26.7%\nאימון בין-ארצי,41.5%\nאימון קרובים**,\nפונדקאות***,\n,\nסך הכל: 374', type='text')]
# after Api call
# סוג,ערך
# אימון בארץ,26.7%
# אימון בין-ארצי,41.5%
# אימון קרובים**,
# פונדקאות***,
# ,
# סך הכל: 374
# ⚠️ Row 6 in 7_3_2009.png padded with empty strings.
# ✅ Saved CSV: 7_3_2009.csv
# תרשים 3ח' | שיעור הגיוס לצה"ל
# (אחוזים)
# 1992-2008*
# 8_3_2009
# Processing image: 8_3_2009.png (graph: תרשים 3ח' | שיעור הגיוס לצה"ל
# (אחוזים)
# 1992-2008*)
# [TextBlock(citations=None, text='מין,ילידי 1971,ילידי 1974,ילידי 1979,ילידי 1984,ילידי 1986,ילידי 1987\nבנים,82.7,82.4,80.7,77.6,77.5,75.3\nבנות,67.4,69.2,63.9,59.7,63.2,58.5', type='text')]
# after Api call
# מין,ילידי 1971,ילידי 1974,ילידי 1979,ילידי 1984,ילידי 1986,ילידי 1987
# בנים,82.7,82.4,80.7,77.6,77.5,75.3
# בנות,67.4,69.2,63.9,59.7,63.2,58.5
# ✅ Saved CSV: 8_3_2009.csv
# תרשים 3ט' | שיעור הגיוס לצה"ל וסיבת אי הגיוס
# לפי מין (אחוזים)
# 1992-2008
# 9_3_2009
# Processing image: 9_3_2009.png (graph: תרשים 3ט' | שיעור הגיוס לצה"ל וסיבת אי הגיוס
# לפי מין (אחוזים)
# 1992-2008)
# [TextBlock(citations=None, text='מין,ילידי 1987,בנים,4.1,11.6,9.0,75.3\nמין,ילידי 1987,בנות,4.9,5.1,32.9,58.5\nמין,ילידי 1986,בנים,4.0,11.4,8.5,76.1\nמין,ילידי 1986,בנות,3.5,5.8,31.4,59.3\nמין,ילידי 1984,בנים,4.2,10.2,8.0,77.6\nמין,ילידי 1984,בנות,3.5,6.0,30.8,59.7\nמין,ילידי 1979,בנים,2.9,8.8,6.6,80.7\nמין,ילידי 1979,בנות,3.2,6.3,26.6,63.9\nמין,ילידי 1974,בנים,5.4,7.2,5.0,82.4\nמין,ילידי 1974,בנות,4.3,5.8,20.7,69.2\nמין,ילידי 1971,בנים,5.4,6.2,4.7,83.7\nמין,ילידי 1971,בנות,4.1,4.9,23.6,67.4\n\n,מגויסים/ות,תלמידי ישיבה שיעסוק בתורה, נשים הפטורות מטעמי דת או נישואין,פטורים מסיבות רפואיות או עקב אי התאמה,שויטלו בחו"ל', type='text')]
# after Api call
# מין,ילידי 1987,בנים,4.1,11.6,9.0,75.3
# מין,ילידי 1987,בנות,4.9,5.1,32.9,58.5
# מין,ילידי 1986,בנים,4.0,11.4,8.5,76.1
# מין,ילידי 1986,בנות,3.5,5.8,31.4,59.3
# מין,ילידי 1984,בנים,4.2,10.2,8.0,77.6
# מין,ילידי 1984,בנות,3.5,6.0,30.8,59.7
# מין,ילידי 1979,בנים,2.9,8.8,6.6,80.7
# מין,ילידי 1979,בנות,3.2,6.3,26.6,63.9
# מין,ילידי 1974,בנים,5.4,7.2,5.0,82.4
# מין,ילידי 1974,בנות,4.3,5.8,20.7,69.2
# מין,ילידי 1971,בנים,5.4,6.2,4.7,83.7
# מין,ילידי 1971,בנות,4.1,4.9,23.6,67.4
#
# ,מגויסים/ות,תלמידי ישיבה שיעסוק בתורה, נשים הפטורות מטעמי דת או נישואין,פטורים מסיבות רפואיות או עקב אי התאמה,שויטלו בחו"ל
# ⚠️ Row 12 in 9_3_2009.png padded with empty strings.
# ⚠️ Row 13 in 9_3_2009.png padded with empty strings.
# ✅ Saved CSV: 9_3_2009.csv
# Processing chapter: 4
# proccesed img
# proccesed img
# proccesed img
# proccesed img
# proccesed img
# proccesed img
# תרשים
# 4א' | ילדים בפנימיות של המנהל לחינוך התיישבותי פנימייתי ועליית הנוער, לפי סוג משפחה (מספרים ואחוזים)
# תשס"ח (2007/08)
# 1_4_2009
# Processing image: 1_4_2009.png (graph: תרשים
# 4א' | ילדים בפנימיות של המנהל לחינוך התיישבותי פנימייתי ועליית הנוער, לפי סוג משפחה (מספרים ואחוזים)
# תשס"ח (2007/08))
# [TextBlock(citations=None, text='מדד,אחוז\nנשואים,66.0%\nגרושים או בתהליך גירושין,25.0%\nיתומים משני ההורים או מהורה אחד,2.0%\nחד הורית,2.0%\n\nסך הכל: 17,323', type='text')]
# after Api call
# מדד,אחוז
# נשואים,66.0%
# גרושים או בתהליך גירושין,25.0%
# יתומים משני ההורים או מהורה אחד,2.0%
# חד הורית,2.0%
#
# סך הכל: 17,323
# ⚠️ Row 5 in 1_4_2009.png padded with empty strings.
# ✅ Saved CSV: 1_4_2009.csv
# תרשים
# 4ב' | ילדים* שהושמו בידי משרד הרווחה בפנימיות לילדים בסיכון** לפי סוג מסגרת  (אחוזים)
# יולי 2003-יולי 2008
# 2_4_2009
# Processing image: 2_4_2009.png (graph: תרשים
# 4ב' | ילדים* שהושמו בידי משרד הרווחה בפנימיות לילדים בסיכון** לפי סוג מסגרת  (אחוזים)
# יולי 2003-יולי 2008)
# [TextBlock(citations=None, text='שנה,סך הכל,חוסכים,שקיפות,סובסידיה,סוגי-אשראות,פיננסיות ויחס\n2003,7632,2047,2852,2073,394,\n2005,6623,1207,2580,1976,322,\n2007,6459,765,2462,2141,337,554\n2008,6557,682,3438,2282,541,614', type='text')]
# after Api call
# שנה,סך הכל,חוסכים,שקיפות,סובסידיה,סוגי-אשראות,פיננסיות ויחס
# 2003,7632,2047,2852,2073,394,
# 2005,6623,1207,2580,1976,322,
# 2007,6459,765,2462,2141,337,554
# 2008,6557,682,3438,2282,541,614
# ✅ Saved CSV: 2_4_2009.csv
# תרשים
# 4ג' | סוג הפנימייה שמשרד הרווחה שם בה ילדים בסיכון
# לפי מאפייני הוריהם (הורה אחד לפחות)
# תשס"ח (2007/08)
# 3_4_2009
# Processing image: 3_4_2009.png (graph: תרשים
# 4ג' | סוג הפנימייה שמשרד הרווחה שם בה ילדים בסיכון
# לפי מאפייני הוריהם (הורה אחד לפחות)
# תשס"ח (2007/08))
# [TextBlock(citations=None, text='נושא,סוציו-מזרחי-אשכנזי,סוציו-מזרחי,סוציו-מזרחי-אשכנזי,סוציו-אשכנזי,שיקומי\nמוטבי שכלית,7.2,6.8,7.2,9.0,8.6\nחולת נפש,14.4,10.6,12.2,13.6,18.1\nמוגבל פיזרית,11.7,8.8,12.0,8.7,9.6\nסיעודי,15.4,14.4,15.8,13.1,17.6\nאחרון,6.8,6.9,5.7,7.2,9.5\nמוגבל,43.8,53.5,53.2,50.3,52.5', type='text')]
# after Api call
# נושא,סוציו-מזרחי-אשכנזי,סוציו-מזרחי,סוציו-מזרחי-אשכנזי,סוציו-אשכנזי,שיקומי
# מוטבי שכלית,7.2,6.8,7.2,9.0,8.6
# חולת נפש,14.4,10.6,12.2,13.6,18.1
# מוגבל פיזרית,11.7,8.8,12.0,8.7,9.6
# סיעודי,15.4,14.4,15.8,13.1,17.6
# אחרון,6.8,6.9,5.7,7.2,9.5
# מוגבל,43.8,53.5,53.2,50.3,52.5
# ✅ Saved CSV: 3_4_2009.csv
# תרשים
# 4ד' | ילדים* שהושמו בידי משרד הרווחה בפנימיות לילדים בסיכון מכוח חוק הנוער**, לפי שנת השמה (מספרים ואחוזים)
# תשס"ה (2004/05) - תשס"ח (2007/08)
# 4_4_2009
# Processing image: 4_4_2009.png (graph: תרשים
# 4ד' | ילדים* שהושמו בידי משרד הרווחה בפנימיות לילדים בסיכון מכוח חוק הנוער**, לפי שנת השמה (מספרים ואחוזים)
# תשס"ה (2004/05) - תשס"ח (2007/08))
# [TextBlock(citations=None, text='שנה,אחוז הילדים המושמים בפנימיות לילדים בסיכון,כמות\nתשס"ה 2004/05,26.8,1772\nתשס"ו 2005/06,29.1,1858\nתשס"ז 2006/07,30.8,1991\nתשס"ח 2007/08,32.4,2126', type='text')]
# after Api call
# שנה,אחוז הילדים המושמים בפנימיות לילדים בסיכון,כמות
# תשס"ה 2004/05,26.8,1772
# תשס"ו 2005/06,29.1,1858
# תשס"ז 2006/07,30.8,1991
# תשס"ח 2007/08,32.4,2126
# ✅ Saved CSV: 4_4_2009.csv
# תרשים
# 4ה' | ילדים* שהושמו בידי משרד הרווחה בפנימיות טיפוליות, שיקומיות ופוסט-אשפוזיות לילדים בסיכון, לפי מצב משפחתי של הוריהם (אחוזים) תשס"ח (2007/08)
# 5_4_2009
# Processing image: 5_4_2009.png (graph: תרשים
# 4ה' | ילדים* שהושמו בידי משרד הרווחה בפנימיות טיפוליות, שיקומיות ופוסט-אשפוזיות לילדים בסיכון, לפי מצב משפחתי של הוריהם (אחוזים) תשס"ח (2007/08))
# [TextBlock(citations=None, text='מצב משפחתי,אחוז\nנשואים,37.5%\nגרושים,39.4%\nפרודים,13.2%\nאלמן/אלמנה,1.1%\nשני ההורים אינם בחיים,8.8%\n\nסך הכל: 5,563', type='text')]
# after Api call
# מצב משפחתי,אחוז
# נשואים,37.5%
# גרושים,39.4%
# פרודים,13.2%
# אלמן/אלמנה,1.1%
# שני ההורים אינם בחיים,8.8%
#
# סך הכל: 5,563
# ⚠️ Row 6 in 5_4_2009.png padded with empty strings.
# ✅ Saved CSV: 5_4_2009.csv
# תרשים 4ו' | ילדים שהושמו בידי שירות האומנה של משרד הרווחה במשפחות אומנה, לפי גילם היום (אחוזים)
# ממוצע 2008
# 6_4_2009
# Processing image: 6_4_2009.png (graph: תרשים 4ו' | ילדים שהושמו בידי שירות האומנה של משרד הרווחה במשפחות אומנה, לפי גילם היום (אחוזים)
# ממוצע 2008)
# [TextBlock(citations=None, text='גיל,אחוז\n0-4,16.0%\n5-12,49.0%\n13-17,32.5%\n18+,2.5%\n\n,\nסך כל הילדים: 1,978', type='text')]
# after Api call
# גיל,אחוז
# 0-4,16.0%
# 5-12,49.0%
# 13-17,32.5%
# 18+,2.5%
#
# ,
# סך כל הילדים: 1,978
# ⚠️ Row 5 in 6_4_2009.png padded with empty strings.
# ✅ Saved CSV: 6_4_2009.csv
# Processing chapter: 5
# proccesed img
# proccesed img
# proccesed img
# proccesed img
# proccesed img
# proccesed img
# proccesed img
# proccesed img
# proccesed img
# proccesed img
# proccesed img
# תלמידים ביסודי ובחטיבות הביניים המדווחים על הסתייעות במורה פרטי בשפת אם, מתמטיקה, מדע וטכנולוגיה ואנגלית
# לפי כיתה (אחוזים)
# תשס"ח (2007/08) | תרשים 5י'
# 10_5_2009
# Processing image: 10_5_2009.png (graph: תלמידים ביסודי ובחטיבות הביניים המדווחים על הסתייעות במורה פרטי בשפת אם, מתמטיקה, מדע וטכנולוגיה ואנגלית
# לפי כיתה (אחוזים)
# תשס"ח (2007/08) | תרשים 5י')
# [TextBlock(citations=None, text='null', type='text')]
# after Api call
# null
# ⚠️ Skipping 10_5_2009.png — Claude returned null (unreadable table).
# דיווח תלמידים על שביעות רצון מבית הספר
# לפי כיתה (אחוזים)
# תשס"ח (2007/08) | תרשים 5יא'
# 11_5_2009
# Processing image: 11_5_2009.png (graph: דיווח תלמידים על שביעות רצון מבית הספר
# לפי כיתה (אחוזים)
# תשס"ח (2007/08) | תרשים 5יא')
# [TextBlock(citations=None, text='קבוצה,תיאור,כיתות ז-ט,כיתות י-יב,סך הכל\n,שביעות רצון כללית של התלמידים מבית הספר,64.0,73.0,68.0\n,אני אוהב להיות בבית הספר,60.0,68.0,63.0\n,טוב לי בבית הספר,66.0,74.0,69.0\n,גם אילו הייתי יכול לא הייתי עובר לבית ספר אחר,68.0,77.0,72.0\n,בבית הספר עושים פעולות רבות כדי שהתלמידים יהיו מעניין לבוא אליי,52.0,76.0,62.0', type='text')]
# after Api call
# קבוצה,תיאור,כיתות ז-ט,כיתות י-יב,סך הכל
# ,שביעות רצון כללית של התלמידים מבית הספר,64.0,73.0,68.0
# ,אני אוהב להיות בבית הספר,60.0,68.0,63.0
# ,טוב לי בבית הספר,66.0,74.0,69.0
# ,גם אילו הייתי יכול לא הייתי עובר לבית ספר אחר,68.0,77.0,72.0
# ,בבית הספר עושים פעולות רבות כדי שהתלמידים יהיו מעניין לבוא אליי,52.0,76.0,62.0
# ✅ Saved CSV: 11_5_2009.csv
# דיווח תלמידים על יחסי קירבה ואכפתיות בין מורים לתלמידים
# לפי כיתה (אחוזים)
# תשס"ח (2007/08) | תרשים 5יב'
# 12_5_2009
# Processing image: 12_5_2009.png (graph: דיווח תלמידים על יחסי קירבה ואכפתיות בין מורים לתלמידים
# לפי כיתה (אחוזים)
# תשס"ח (2007/08) | תרשים 5יב')
# [TextBlock(citations=None, text="I don't see any image attached to your message. The message appears to be empty or the image failed to load. Please try uploading the image again so I can extract the table data as requested.", type='text')]
# after Api call
# I don't see any image attached to your message. The message appears to be empty or the image failed to load. Please try uploading the image again so I can extract the table data as requested.
# ⚠️ Skipping 12_5_2009.png — result is not a valid CSV.
# תרשים 5א' | מספר תלמידים ממוצע בכיתה*
# לפי מגזר
# תש"מ (1979/80)- תשס"ח (2007/08)
# 1_5_2009
# Processing image: 1_5_2009.png (graph: תרשים 5א' | מספר תלמידים ממוצע בכיתה*
# לפי מגזר
# תש"מ (1979/80)- תשס"ח (2007/08))
# [TextBlock(citations=None, text='קבוצה,שנה,מספר תלמידים ממוצע\nסך הכל,תש"מ,27\nסך הכל,תש"ן,28\nסך הכל,תש"נ,28\nסך הכל,תש"ס,27\nסך הכל,תשס"ז,27\nסך הכל,תשס"ח,27\nחינוך עברי,תש"מ,26\nחינוך עברי,תש"ן,27\nחינוך עברי,תש"נ,27\nחינוך עברי,תש"ס,26\nחינוך עברי,תשס"ז,26\nחינוך עברי,תשס"ח,26\nחינוך ערבי,תש"מ,31\nחינוך ערבי,תש"ן,31\nחינוך ערבי,תש"נ,31\nחינוך ערבי,תש"ס,30\nחינוך ערבי,תשס"ז,30\nחינוך ערבי,תשס"ח,30', type='text')]
# after Api call
# קבוצה,שנה,מספר תלמידים ממוצע
# סך הכל,תש"מ,27
# סך הכל,תש"ן,28
# סך הכל,תש"נ,28
# סך הכל,תש"ס,27
# סך הכל,תשס"ז,27
# סך הכל,תשס"ח,27
# חינוך עברי,תש"מ,26
# חינוך עברי,תש"ן,27
# חינוך עברי,תש"נ,27
# חינוך עברי,תש"ס,26
# חינוך עברי,תשס"ז,26
# חינוך עברי,תשס"ח,26
# חינוך ערבי,תש"מ,31
# חינוך ערבי,תש"ן,31
# חינוך ערבי,תש"נ,31
# חינוך ערבי,תש"ס,30
# חינוך ערבי,תשס"ז,30
# חינוך ערבי,תשס"ח,30
# ✅ Saved CSV: 1_5_2009.csv
# תרשים 5ב' | שיעור הלומדים במערכת החינוך*
# לפי גיל ומגזר (אחוז מקבוצת הגיל באוכלוסייה)
# תשס"ח (2007/08)
# 2_5_2009
# Processing image: 2_5_2009.png (graph: תרשים 5ב' | שיעור הלומדים במערכת החינוך*
# לפי גיל ומגזר (אחוז מקבוצת הגיל באוכלוסייה)
# תשס"ח (2007/08))
# [TextBlock(citations=None, text='גיל,ערבים,יהודים ואחרים\n17,82.9,90.9\n16,88.1,96.4\n15,90.5,96.5\n14,96.3,97.3\n13,97.5,96.8\n12,87.4,77.6\n11,97.3,94.4\n10,97.5,96.3\n9,97.4,96.9\n8,97.0,96.8\n7,97.3,96.0\n6,90.5,77.6\n5,94.5,97.1\n4,82.8,92.8\n3,74.9,86.1\n2,13.7,59.6', type='text')]
# after Api call
# גיל,ערבים,יהודים ואחרים
# 17,82.9,90.9
# 16,88.1,96.4
# 15,90.5,96.5
# 14,96.3,97.3
# 13,97.5,96.8
# 12,87.4,77.6
# 11,97.3,94.4
# 10,97.5,96.3
# 9,97.4,96.9
# 8,97.0,96.8
# 7,97.3,96.0
# 6,90.5,77.6
# 5,94.5,97.1
# 4,82.8,92.8
# 3,74.9,86.1
# 2,13.7,59.6
# ✅ Saved CSV: 2_5_2009.csv
# יישובים שבהם 11% ויותר מתלמידי כיתות ט'-יב'
# נשרו ממערכת החינוך
# במעבר מתשס"ח (2007/08) לתשס"ט (2008/09) | תרשים 5ג'
# 3_5_2009
# Processing image: 3_5_2009.png (graph: יישובים שבהם 11% ויותר מתלמידי כיתות ט'-יב'
# נשרו ממערכת החינוך
# במעבר מתשס"ח (2007/08) לתשס"ט (2008/09) | תרשים 5ג')
# [TextBlock(citations=None, text='מיקום,נתון\nטבעת זורעית,\nשגב,\nכפר מנדא,\nירושלים (חינוך ערבי),\nרהט,\nחורה,\nשגב שלום,\n\n,\nשיעור ארצי: 4.3%,\nחינוך עברי: 3.7%,\nחינוך ערבי: 6.6%,', type='text')]
# after Api call
# מיקום,נתון
# טבעת זורעית,
# שגב,
# כפר מנדא,
# ירושלים (חינוך ערבי),
# רהט,
# חורה,
# שגב שלום,
#
# ,
# שיעור ארצי: 4.3%,
# חינוך עברי: 3.7%,
# חינוך ערבי: 6.6%,
# ⚠️ Row 8 in 3_5_2009.png padded with empty strings.
# ✅ Saved CSV: 3_5_2009.csv
# אחוז התלמידים* שלמדו, שניגשו לבחינות ושהיו זכאים**
# לתעודת בגרות מקבוצת הגיל***, לפי שנה
# תשס"א (2000/01)- תשס"ח (2007/08) | תרשים 5ד'
# 4_5_2009
# Processing image: 4_5_2009.png (graph: אחוז התלמידים* שלמדו, שניגשו לבחינות ושהיו זכאים**
# לתעודת בגרות מקבוצת הגיל***, לפי שנה
# תשס"א (2000/01)- תשס"ח (2007/08) | תרשים 5ד')
# [TextBlock(citations=None, text='שנה,לומדים בגי"ב,ניגשים לבגרות,זכאים לתעודת בגרות\nתשס"א 2000/01,75.4,66.1,45.3\nתשס"ב 2001/02,79.8,70.5,48.4\nתשס"ג 2002/03,79.3,70.9,48.3\nתשס"ד 2003/04,82.3,74.2,49.2\nתשס"ה 2004/05,82.0,74.2,46.4\nתשס"ו 2005/06,79.6,72.5,45.9\nתשס"ז 2006/07,81.8,74.4,46.3\nתשס"ח 2007/08,79.2,72.0,44.4', type='text')]
# after Api call
# שנה,לומדים בגי"ב,ניגשים לבגרות,זכאים לתעודת בגרות
# תשס"א 2000/01,75.4,66.1,45.3
# תשס"ב 2001/02,79.8,70.5,48.4
# תשס"ג 2002/03,79.3,70.9,48.3
# תשס"ד 2003/04,82.3,74.2,49.2
# תשס"ה 2004/05,82.0,74.2,46.4
# תשס"ו 2005/06,79.6,72.5,45.9
# תשס"ז 2006/07,81.8,74.4,46.3
# תשס"ח 2007/08,79.2,72.0,44.4
# ✅ Saved CSV: 4_5_2009.csv
# אחוז תלמידי י"ב*, הניגשים לבחינות בגרות והזכאים לתעודת בגרות**  מקבוצת הגיל***  שנה הבאה אפשר להוריד מיותר???
# תשס"ח (2007/08) | תרשים 5ה'
# 5_5_2009
# Processing image: 5_5_2009.png (graph: אחוז תלמידי י"ב*, הניגשים לבחינות בגרות והזכאים לתעודת בגרות**  מקבוצת הגיל***  שנה הבאה אפשר להוריד מיותר???
# תשס"ח (2007/08) | תרשים 5ה')
# [TextBlock(citations=None, text='קבוצה,ערך,אחוזים\nפטור מבצעת בגיל 17,92417,79.2\nניגשים לבחינות בגרות,83866,72.0\nזכאים לתעודת בגרות (לאחר מועד החורף העוקב),51665,44.4\n\nסך הכל תלמידים (בגיל 17) בישראל כולל המגזר החרדי ומזרח ירושלים: 116415', type='text')]
# after Api call
# קבוצה,ערך,אחוזים
# פטור מבצעת בגיל 17,92417,79.2
# ניגשים לבחינות בגרות,83866,72.0
# זכאים לתעודת בגרות (לאחר מועד החורף העוקב),51665,44.4
#
# סך הכל תלמידים (בגיל 17) בישראל כולל המגזר החרדי ומזרח ירושלים: 116415
# ⚠️ Row 4 in 5_5_2009.png padded with empty strings.
# ⚠️ Row 5 in 5_5_2009.png padded with empty strings.
# ✅ Saved CSV: 5_5_2009.csv
# זכאים לתעודת בגרות* (אחוז מקבוצת הגיל**)
# לפי מגזר
# תשס"ב (2000/01)- תשס"ח (2007/08) | תרשים 5ו'
# 6_5_2009
# Processing image: 6_5_2009.png (graph: זכאים לתעודת בגרות* (אחוז מקבוצת הגיל**)
# לפי מגזר
# תשס"ב (2000/01)- תשס"ח (2007/08) | תרשים 5ו')
# [TextBlock(citations=None, text='שנה,סך הכל,מגזר יהודי (כולל חרדים),מגזר ערבי,מגזר דרוזי,בדואים בנגב\n2001/02 תשס"ב,48.6,39.8,38.3,27.6\n2002/03 תשס"ג,48.3,42.3,39.3,27.6\n2003/04 תשס"ד,49.2,42.2,40.5,25.6\n2004/05 תשס"ה,51.1,40.7,36.8,28.8\n2005/06 תשס"ו,50.8,44.4,35.7,27.9\n2006/07 תשס"ז,51.8,43.7,35.6,31.0\n2007/08 תשס"ח,50.5,39.5,32.4,26.6', type='text')]
# after Api call
# שנה,סך הכל,מגזר יהודי (כולל חרדים),מגזר ערבי,מגזר דרוזי,בדואים בנגב
# 2001/02 תשס"ב,48.6,39.8,38.3,27.6
# 2002/03 תשס"ג,48.3,42.3,39.3,27.6
# 2003/04 תשס"ד,49.2,42.2,40.5,25.6
# 2004/05 תשס"ה,51.1,40.7,36.8,28.8
# 2005/06 תשס"ו,50.8,44.4,35.7,27.9
# 2006/07 תשס"ז,51.8,43.7,35.6,31.0
# 2007/08 תשס"ח,50.5,39.5,32.4,26.6
# ⚠️ Row 1 in 6_5_2009.png padded with empty strings.
# ⚠️ Row 2 in 6_5_2009.png padded with empty strings.
# ⚠️ Row 3 in 6_5_2009.png padded with empty strings.
# ⚠️ Row 4 in 6_5_2009.png padded with empty strings.
# ⚠️ Row 5 in 6_5_2009.png padded with empty strings.
# ⚠️ Row 6 in 6_5_2009.png padded with empty strings.
# ⚠️ Row 7 in 6_5_2009.png padded with empty strings.
# ✅ Saved CSV: 6_5_2009.csv
# אחוז הזכאים לתעודת בגרות ואחוז העומדים בדרישות הסף של האוניברסיטאות מתלמידי כיתות יב'
# 1996-2007 | תרשים
# 5ח'
# 8_5_2009
# Processing image: 8_5_2009.png (graph: אחוז הזכאים לתעודת בגרות ואחוז העומדים בדרישות הסף של האוניברסיטאות מתלמידי כיתות יב'
# 1996-2007 | תרשים
# 5ח')
# [TextBlock(citations=None, text='קבוצה,שנה,אחוז הזכאים לתעודת בגרות,אחוז העומדים בדרישות הסף של האוניברסיטאות\nסך הכל,1996,50.4,39.9\nסך הכל,2004,55.1,44.1\nסך הכל,2005,53.8,45.7\nסך הכל,2006,53.4,45.9\nסך הכל,2007,52.5,45.0\nיהודים,1996,51.7,42.4\nיהודים,2004,56.4,46.8\nיהודים,2005,55.1,47.8\nיהודים,2006,54.9,48.3\nיהודים,2007,54.6,47.7\nערבים,1996,41.8,23.7\nערבים,2004,47.8,29.6\nערבים,2005,47.2,35.0\nערבים,2006,46.3,34.4\nערבים,2007,44.0,35.4', type='text')]
# after Api call
# קבוצה,שנה,אחוז הזכאים לתעודת בגרות,אחוז העומדים בדרישות הסף של האוניברסיטאות
# סך הכל,1996,50.4,39.9
# סך הכל,2004,55.1,44.1
# סך הכל,2005,53.8,45.7
# סך הכל,2006,53.4,45.9
# סך הכל,2007,52.5,45.0
# יהודים,1996,51.7,42.4
# יהודים,2004,56.4,46.8
# יהודים,2005,55.1,47.8
# יהודים,2006,54.9,48.3
# יהודים,2007,54.6,47.7
# ערבים,1996,41.8,23.7
# ערבים,2004,47.8,29.6
# ערבים,2005,47.2,35.0
# ערבים,2006,46.3,34.4
# ערבים,2007,44.0,35.4
# ✅ Saved CSV: 8_5_2009.csv
# הגורם המסייע לתלמידים המתקשים בלימודים*
# (אחוז מכלל המתקשים**)
# תשס"ו (2005/06) | תרשים 5ט'
# 9_5_2009
# Processing image: 9_5_2009.png (graph: הגורם המסייע לתלמידים המתקשים בלימודים*
# (אחוז מכלל המתקשים**)
# תשס"ו (2005/06) | תרשים 5ט')
# [TextBlock(citations=None, text='אחוז המתקשים,בתי ספר יסודיים,בתי ספר על יסודיים\nמומחה או מורה מקצועי,67.0,73.0\nמורה טיפולית או מורה חנמ"א או מורה שילוב,55.0,57.0\nסטודנט פר"ח, מורה חיילת, מתנדב או גורם אחר שאינו מורה,21.0,29.0\nמתגבור או פנימיות יום,17.0,21.0\n\nאחוז המתקשים בלימודים ביסודי - 18%,אחוז המתקשים בלימודים בעל-יסודי - 22%', type='text')]
# after Api call
# אחוז המתקשים,בתי ספר יסודיים,בתי ספר על יסודיים
# מומחה או מורה מקצועי,67.0,73.0
# מורה טיפולית או מורה חנמ"א או מורה שילוב,55.0,57.0
# סטודנט פר"ח, מורה חיילת, מתנדב או גורם אחר שאינו מורה,21.0,29.0
# מתגבור או פנימיות יום,17.0,21.0
#
# אחוז המתקשים בלימודים ביסודי - 18%,אחוז המתקשים בלימודים בעל-יסודי - 22%
# ⚠️ Row 0 in 9_5_2009.png padded with empty strings.
# ⚠️ Row 1 in 9_5_2009.png padded with empty strings.
# ⚠️ Row 2 in 9_5_2009.png padded with empty strings.
# ⚠️ Row 4 in 9_5_2009.png padded with empty strings.
# ⚠️ Row 5 in 9_5_2009.png padded with empty strings.
# ⚠️ Row 6 in 9_5_2009.png padded with empty strings.
# ✅ Saved CSV: 9_5_2009.csv
# Processing chapter: 6
# ⚠️ Skipping missing directory: /content/relevant_graphs/2009/06
# Processing chapter: 7
# proccesed img
# proccesed img
# proccesed img
# proccesed img
# proccesed img
# proccesed img
# proccesed img
# proccesed img
# תרשים 7יא' | חלקם של ילדים המקבלים קצבת ילד נכה מכלל הילדים עם מוגבלות חמורה* (אחוזים)
# 1995-2008
# 11_7_2009
# Processing image: 11_7_2009.png (graph: תרשים 7יא' | חלקם של ילדים המקבלים קצבת ילד נכה מכלל הילדים עם מוגבלות חמורה* (אחוזים)
# 1995-2008)
# [TextBlock(citations=None, text='שנה,אחוז מכלל הילדים עם מוגבלות חמורה\n1995,6.2\n2000,8.3\n2005,10.9\n2006,11.4\n2007,11.9\n2008,12.3', type='text')]
# after Api call
# שנה,אחוז מכלל הילדים עם מוגבלות חמורה
# 1995,6.2
# 2000,8.3
# 2005,10.9
# 2006,11.4
# 2007,11.9
# 2008,12.3
# ✅ Saved CSV: 11_7_2009.csv
# תרשים
# 7יד' | בקשות לקבלת מכשירי ניידות ושיקום עבור ילדים (0-17)
# לפי גיל (מספרים)
# 2008
# 13_7_2009
# Processing image: 13_7_2009.png (graph: תרשים
# 7יד' | בקשות לקבלת מכשירי ניידות ושיקום עבור ילדים (0-17)
# לפי גיל (מספרים)
# 2008)
# [TextBlock(citations=None, text='גיל,אחוז\n0-2,2.8%\n3-6,26.0%\n7-12,30.9%\n13-17,40.3%\n,\nסך כל המשפחות: 1,771', type='text')]
# after Api call
# גיל,אחוז
# 0-2,2.8%
# 3-6,26.0%
# 7-12,30.9%
# 13-17,40.3%
# ,
# סך כל המשפחות: 1,771
# ✅ Saved CSV: 13_7_2009.csv
# תרשים 7א' | חלקם של ילדים עם מוגבלויות בכלל אוכלוסיית הילדים
# (אחוזים*)
# אומדן 2008**
# 1_7_2009
# Processing image: 1_7_2009.png (graph: תרשים 7א' | חלקם של ילדים עם מוגבלויות בכלל אוכלוסיית הילדים
# (אחוזים*)
# אומדן 2008**)
# [TextBlock(citations=None, text='קטגוריה,ערך,אחוז\nילדים ללא מוגבלות,2245000,87.2%\nילדים עם מוגבלות לא חמורה,114000,4.5%\nילדים עם מוגבלות חמורה,94000,8.3%\n,סך כל הילדים (דצמבר 2008): 2453000,\n,סך כל הילדים עם צרכים מיוחדים: 208000,', type='text')]
# after Api call
# קטגוריה,ערך,אחוז
# ילדים ללא מוגבלות,2245000,87.2%
# ילדים עם מוגבלות לא חמורה,114000,4.5%
# ילדים עם מוגבלות חמורה,94000,8.3%
# ,סך כל הילדים (דצמבר 2008): 2453000,
# ,סך כל הילדים עם צרכים מיוחדים: 208000,
# ✅ Saved CSV: 1_7_2009.csv
# תרשים 7ב' | התפלגות הילדים עם מוגבלות חמורה
# לפי סוג מוגבלות עיקרי (אחוזים ואלפים)
# אומדן 2008**
# 2_7_2009
# Processing image: 2_7_2009.png (graph: תרשים 7ב' | התפלגות הילדים עם מוגבלות חמורה
# לפי סוג מוגבלות עיקרי (אחוזים ואלפים)
# אומדן 2008**)
# [TextBlock(citations=None, text='קטגוריה,אחוז,ערך מספרי\nלמידה או התנסות,52.5%,109.2\nמתנה,16.0%,33.2\nפיצוי,14.3%,29.7\nחופשית,5.8%,12.1\nשכלית,11.4%,23.8\n\nסך כל הילדים עם מוגבלות חמורה: 208,000', type='text')]
# after Api call
# קטגוריה,אחוז,ערך מספרי
# למידה או התנסות,52.5%,109.2
# מתנה,16.0%,33.2
# פיצוי,14.3%,29.7
# חופשית,5.8%,12.1
# שכלית,11.4%,23.8
#
# סך כל הילדים עם מוגבלות חמורה: 208,000
# ⚠️ Row 6 in 2_7_2009.png padded with empty strings.
# ⚠️ Row 7 in 2_7_2009.png padded with empty strings.
# ✅ Saved CSV: 2_7_2009.csv
# תרשים 7ג' | מוגבלות (עיקרית או/ו משנית) של ילדים עם מוגבלות חמורה (אחוזים*)
# אומדן 2008**
# 3_7_2009
# Processing image: 3_7_2009.png (graph: תרשים 7ג' | מוגבלות (עיקרית או/ו משנית) של ילדים עם מוגבלות חמורה (אחוזים*)
# אומדן 2008**)
# [TextBlock(citations=None, text='אחוזים,סוג מוגבלות\n90.3,למידה או התנהגות\n29.2,מחלה\n17.9,פיזית\n14.1,חושית\n5.6,שכלית\n\n,סך הכל ילדים עם מוגבלות חמורה: 208000', type='text')]
# after Api call
# אחוזים,סוג מוגבלות
# 90.3,למידה או התנהגות
# 29.2,מחלה
# 17.9,פיזית
# 14.1,חושית
# 5.6,שכלית
#
# ,סך הכל ילדים עם מוגבלות חמורה: 208000
# ⚠️ Row 6 in 3_7_2009.png padded with empty strings.
# ✅ Saved CSV: 3_7_2009.csv
# תרשים 7ד' | סוג נכות עיקרית של ילדים יהודים וערבים (נכון ל-1996) ובדווים בנגב (נכון ל-2005) עם צרכים מיוחדים
# (אחוז מהילדים באוכלוסייה המתאימה)
# 4_7_2009
# Processing image: 4_7_2009.png (graph: תרשים 7ד' | סוג נכות עיקרית של ילדים יהודים וערבים (נכון ל-1996) ובדווים בנגב (נכון ל-2005) עם צרכים מיוחדים
# (אחוז מהילדים באוכלוסייה המתאימה))
# [TextBlock(citations=None, text='ערכים,יהודים,ערבים,בדואים\nעד חצי יילדים ושתי זכות אחת לפחות,9.1,8.1,7.6\nבעיות התנהגות, למידה וריכוז,2.8,2.9,4.3\nמחלות כרוניות,3.2,1.2,1.5\nנכות חישית,1.4,1.4,0.7\nנכות פיזית,1.4,2.0,0.9\nפיגור שכלי,0.3,0.6,0.4\nהכנות תיקרות,,,', type='text')]
# after Api call
# ערכים,יהודים,ערבים,בדואים
# עד חצי יילדים ושתי זכות אחת לפחות,9.1,8.1,7.6
# בעיות התנהגות, למידה וריכוז,2.8,2.9,4.3
# מחלות כרוניות,3.2,1.2,1.5
# נכות חישית,1.4,1.4,0.7
# נכות פיזית,1.4,2.0,0.9
# פיגור שכלי,0.3,0.6,0.4
# הכנות תיקרות,,,
# ⚠️ Row 0 in 4_7_2009.png padded with empty strings.
# ⚠️ Row 1 in 4_7_2009.png padded with empty strings.
# ⚠️ Row 3 in 4_7_2009.png padded with empty strings.
# ⚠️ Row 4 in 4_7_2009.png padded with empty strings.
# ⚠️ Row 5 in 4_7_2009.png padded with empty strings.
# ⚠️ Row 6 in 4_7_2009.png padded with empty strings.
# ⚠️ Row 7 in 4_7_2009.png padded with empty strings.
# ✅ Saved CSV: 4_7_2009.csv
# תרשים 7ח' | תלמידים הזכאים לסל שילוב (בטרום חובה עד החטיבה עליונה)
# לפי מגזר (מספרים ואחוזים במגזר)
# תשס"ט 2008/09
# 8_7_2009
# Processing image: 8_7_2009.png (graph: תרשים 7ח' | תלמידים הזכאים לסל שילוב (בטרום חובה עד החטיבה עליונה)
# לפי מגזר (מספרים ואחוזים במגזר)
# תשס"ט 2008/09)
# [TextBlock(citations=None, text='מגזר,אחוז הזכאים במגזר,מספר\nסך הכל,7.2,121613\nבדווי,8.5,7583\nיהודי,7.2,88270\nערבי,7.1,23407\nדרוזי,5.9,2342\n\n,,סך הכל התלמידים: 121,613', type='text')]
# after Api call
# מגזר,אחוז הזכאים במגזר,מספר
# סך הכל,7.2,121613
# בדווי,8.5,7583
# יהודי,7.2,88270
# ערבי,7.1,23407
# דרוזי,5.9,2342
#
# ,,סך הכל התלמידים: 121,613
# ⚠️ Row 0 in 8_7_2009.png padded with empty strings.
# ⚠️ Row 1 in 8_7_2009.png padded with empty strings.
# ⚠️ Row 2 in 8_7_2009.png padded with empty strings.
# ⚠️ Row 3 in 8_7_2009.png padded with empty strings.
# ⚠️ Row 4 in 8_7_2009.png padded with empty strings.
# ⚠️ Row 5 in 8_7_2009.png padded with empty strings.
# ⚠️ Row 6 in 8_7_2009.png padded with empty strings.
# ✅ Saved CSV: 8_7_2009.csv
# תרשים 7ט' | אחוז הנבחנים בבחינות הבגרות* לקויי הלמידה ובעלי ההתאמות בדרכי היבחנות
# קיץ תשנ"ח-תשס"ז (1998/9-2006/07)
# 9_7_2009
# Processing image: 9_7_2009.png (graph: תרשים 7ט' | אחוז הנבחנים בבחינות הבגרות* לקויי הלמידה ובעלי ההתאמות בדרכי היבחנות
# קיץ תשנ"ח-תשס"ז (1998/9-2006/07))
# [TextBlock(citations=None, text='שנה,אחוזים\nתשנ"ח,8.2\nתשנ"ט,10.7\nתש"ס,13.0\nתשס"א,14.0\nתשס"ב,17.3\nתשס"ג,19.0\nתשס"ד,20.3\nתשס"ה,20.2\nתשס"ו,21.1\nתשס"ז,22.3', type='text')]
# after Api call
# שנה,אחוזים
# תשנ"ח,8.2
# תשנ"ט,10.7
# תש"ס,13.0
# תשס"א,14.0
# תשס"ב,17.3
# תשס"ג,19.0
# תשס"ד,20.3
# תשס"ה,20.2
# תשס"ו,21.1
# תשס"ז,22.3
# ✅ Saved CSV: 9_7_2009.csv
# Processing chapter: 8
# proccesed img
# proccesed img
# proccesed img
# proccesed img
# proccesed img
# proccesed img
# proccesed img
# תרשים 8א' | תוחלת חיים בלידה*
# לפי קבוצת אוכלוסייה ומין (ממוצע חמש שנתי)
# 2004/08 - 1985/89
# 1_8_2009
# Processing image: 1_8_2009.png (graph: תרשים 8א' | תוחלת חיים בלידה*
# לפי קבוצת אוכלוסייה ומין (ממוצע חמש שנתי)
# 2004/08 - 1985/89)
# [TextBlock(citations=None, text='שנים,בנות,בנים\nכלל האוכלוסייה,1985-89,77.4,73.8\nכלל האוכלוסייה,1995-99,80.0,76.1\nכלל האוכלוסייה,2000-04,81.6,77.4\nכלל האוכלוסייה,2004-08,82.5,78.6\nיהודים,1985-89,77.8,74.1\nיהודים,1995-99,80.4,76.5\nיהודים,2000-04,82.0,78.1\nיהודים,2004-08,82.9,79.3\nאוכלוסייה ערבית,1985-89,75.5,72.9\nאוכלוסייה ערבית,1995-99,77.8,74.4\nאוכלוסייה ערבית,2000-04,78.3,74.8\nאוכלוסייה ערבית,2004-08,79.0,76.3', type='text')]
# after Api call
# שנים,בנות,בנים
# כלל האוכלוסייה,1985-89,77.4,73.8
# כלל האוכלוסייה,1995-99,80.0,76.1
# כלל האוכלוסייה,2000-04,81.6,77.4
# כלל האוכלוסייה,2004-08,82.5,78.6
# יהודים,1985-89,77.8,74.1
# יהודים,1995-99,80.4,76.5
# יהודים,2000-04,82.0,78.1
# יהודים,2004-08,82.9,79.3
# אוכלוסייה ערבית,1985-89,75.5,72.9
# אוכלוסייה ערבית,1995-99,77.8,74.4
# אוכלוסייה ערבית,2000-04,78.3,74.8
# אוכלוסייה ערבית,2004-08,79.0,76.3
# ⚠️ Row 0 in 1_8_2009.png padded with empty strings.
# ✅ Saved CSV: 1_8_2009.csv
# תרשים
# 8ב' | מספר התיקים של ילדים שעניינם נדון בוועדות פסיכיאטריות מחוזיות לילדים ונוער*
# 1998-2008 | מספר התיקים של ילדים שעניינם נדון בוועדות פסיכיאטריות מחוזיות לילדים ונוער*
# 1998-2008
# 2_8_2009
# Processing image: 2_8_2009.png (graph: תרשים
# 8ב' | מספר התיקים של ילדים שעניינם נדון בוועדות פסיכיאטריות מחוזיות לילדים ונוער*
# 1998-2008 | מספר התיקים של ילדים שעניינם נדון בוועדות פסיכיאטריות מחוזיות לילדים ונוער*
# 1998-2008)
# [TextBlock(citations=None, text="שנה,מס' תיקים\n1998,366\n1999,567\n2000,623\n2001,678\n2002,654\n2003,632\n2004,676\n2005,688\n2006,714\n2007,737\n2008,769", type='text')]
# after Api call
# שנה,מס' תיקים
# 1998,366
# 1999,567
# 2000,623
# 2001,678
# 2002,654
# 2003,632
# 2004,676
# 2005,688
# 2006,714
# 2007,737
# 2008,769
# ✅ Saved CSV: 2_8_2009.csv
# תרשים 8ד' | קבלות של ילדים ונוער לאשפוז* פסיכיאטרי
# לפי סטטוס הקבלה (אחוזים ומספרים)
# 1997-2008
# 4_8_2009
# Processing image: 4_8_2009.png (graph: תרשים 8ד' | קבלות של ילדים ונוער לאשפוז* פסיכיאטרי
# לפי סטטוס הקבלה (אחוזים ומספרים)
# 1997-2008)
# [TextBlock(citations=None, text='שנה,קבלות בהסכמה,קבלות כפויות,אחוזים\n1997,14,86,671\n2000,17,83,993\n2005,23,77,1011\n2006,26,74,926\n2007,22,78,826\n2008,28,72,837', type='text')]
# after Api call
# שנה,קבלות בהסכמה,קבלות כפויות,אחוזים
# 1997,14,86,671
# 2000,17,83,993
# 2005,23,77,1011
# 2006,26,74,926
# 2007,22,78,826
# 2008,28,72,837
# ✅ Saved CSV: 4_8_2009.csv
# תרשים 8ה' | קבלות של ילדים ונוער לאשפוז* פסיכיאטרי
# לפי מספר הקבלה: ראשונה/חוזרת
# דצמבר 2008
# 5_8_2009
# Processing image: 5_8_2009.png (graph: תרשים 8ה' | קבלות של ילדים ונוער לאשפוז* פסיכיאטרי
# לפי מספר הקבלה: ראשונה/חוזרת
# דצמבר 2008)
# [TextBlock(citations=None, text='קבוצה,אחוז\nקבלות ראשונות,57.7%\nקבלות חוזרות,42.3%\n\n,\nמספר הקבלות לאשפוז פסיכיאטרי: 837', type='text')]
# after Api call
# קבוצה,אחוז
# קבלות ראשונות,57.7%
# קבלות חוזרות,42.3%
#
# ,
# מספר הקבלות לאשפוז פסיכיאטרי: 837
# ⚠️ Row 3 in 5_8_2009.png padded with empty strings.
# ⚠️ Row 5 in 5_8_2009.png padded with empty strings.
# ✅ Saved CSV: 5_8_2009.csv
# תרשים 8ו' | משך האשפוז הפסיכיאטרי* של ילדים ונוער
# לפי מין (אחוזים)
# דצמבר 2008
# 6_8_2009
# Processing image: 6_8_2009.png (graph: תרשים 8ו' | משך האשפוז הפסיכיאטרי* של ילדים ונוער
# לפי מין (אחוזים)
# דצמבר 2008)
# [TextBlock(citations=None, text='משך שהייה (מספר ימים),בנים,בנות\nעד 7,11.8,23.5\n8-30,26.5,26.5\n31-180,50.0,47.1\n181-365,2.9,2.9\n+365,8.8,0.0', type='text')]
# after Api call
# משך שהייה (מספר ימים),בנים,בנות
# עד 7,11.8,23.5
# 8-30,26.5,26.5
# 31-180,50.0,47.1
# 181-365,2.9,2.9
# +365,8.8,0.0
# ✅ Saved CSV: 6_8_2009.csv
# תרשים 8ז' | תמותת תינוקות מוסלמים ותינוקות בדווים בנגב
# (שיעור לאלף לידות חי)
# 2001-2007
# 7_8_2009
# Processing image: 7_8_2009.png (graph: תרשים 8ז' | תמותת תינוקות מוסלמים ותינוקות בדווים בנגב
# (שיעור לאלף לידות חי)
# 2001-2007)
# [TextBlock(citations=None, text='שנה,כלל האוכלוסייה,מוסלמים,יהודים בגולה\n2001,5.8,8.8,18.3\n2002,5.2,8.9,17.5\n2003,5.2,8.7,13.6\n2004,5.0,8.8,16.0\n2005,4.6,8.5,15.0\n2006,4.3,8.0,11.9\n2007,3.9,7.2,11.5\n\nשיעור ל-1,000 ליחס זה', type='text')]
# after Api call
# שנה,כלל האוכלוסייה,מוסלמים,יהודים בגולה
# 2001,5.8,8.8,18.3
# 2002,5.2,8.9,17.5
# 2003,5.2,8.7,13.6
# 2004,5.0,8.8,16.0
# 2005,4.6,8.5,15.0
# 2006,4.3,8.0,11.9
# 2007,3.9,7.2,11.5
#
# שיעור ל-1,000 ליחס זה
# ⚠️ Row 8 in 7_8_2009.png padded with empty strings.
# ⚠️ Row 9 in 7_8_2009.png padded with empty strings.
# ✅ Saved CSV: 7_8_2009.csv
# תרשים 8ח' | סיבת המוות של תינוקות לפי קבוצת אוכלוסייה
# (שיעור לאלף לידות חי)
# 2006
# 8_8_2009
# Processing image: 8_8_2009.png (graph: תרשים 8ח' | סיבת המוות של תינוקות לפי קבוצת אוכלוסייה
# (שיעור לאלף לידות חי)
# 2006)
# [TextBlock(citations=None, text='קבוצה,שיעורים לאלף\nסיבות מוצהרות,ערבים,2.7\nסיבות מוצהרות,יהודים ואחרים,0.7\nמוות,ערבים,1.9\nמוות,יהודים ואחרים,1.3\nמוות פתאומי (SIDS),ערבים,0.6\nמוות פתאומי (SIDS),יהודים ואחרים,0.2\nמחלות זיהומיות,ערבים,0.2\nמחלות זיהומיות,יהודים ואחרים,0.1\nמנטלי,ערבים,0.3\nמנטלי,יהודים ואחרים,0.2\nמום חיצוני,ערבים,0.1\nמום חיצוני,יהודים ואחרים,0.1\nסיבה אחרת/לא ידוע/אין מידע,ערבים,1.3\nסיבה אחרת/לא ידוע/אין מידע,יהודים ואחרים,0.4', type='text')]
# after Api call
# קבוצה,שיעורים לאלף
# סיבות מוצהרות,ערבים,2.7
# סיבות מוצהרות,יהודים ואחרים,0.7
# מוות,ערבים,1.9
# מוות,יהודים ואחרים,1.3
# מוות פתאומי (SIDS),ערבים,0.6
# מוות פתאומי (SIDS),יהודים ואחרים,0.2
# מחלות זיהומיות,ערבים,0.2
# מחלות זיהומיות,יהודים ואחרים,0.1
# מנטלי,ערבים,0.3
# מנטלי,יהודים ואחרים,0.2
# מום חיצוני,ערבים,0.1
# מום חיצוני,יהודים ואחרים,0.1
# סיבה אחרת/לא ידוע/אין מידע,ערבים,1.3
# סיבה אחרת/לא ידוע/אין מידע,יהודים ואחרים,0.4
# ⚠️ Row 0 in 8_8_2009.png padded with empty strings.
# ✅ Saved CSV: 8_8_2009.csv
# Processing chapter: 9
# proccesed img
# proccesed img
# proccesed img
# proccesed img
# proccesed img
# proccesed img
# proccesed img
# proccesed img
# proccesed img
# תרשים 9י' | מספר הילדים שבמשך שנת הלימודים נפגעו* בתאונות במערכת החינוך ושיעורם לאלף מכלל התלמידים
# תשס"א (2000/01)- תשס"ח (2007/08)
# 10_9_2009
# Processing image: 10_9_2009.png (graph: תרשים 9י' | מספר הילדים שבמשך שנת הלימודים נפגעו* בתאונות במערכת החינוך ושיעורם לאלף מכלל התלמידים
# תשס"א (2000/01)- תשס"ח (2007/08))
# [TextBlock(citations=None, text='שנה,מספרים (אלפים),שיעור לאלף\n2000/01,10.0,5.7\n2004/05,17.5,12.6\n2005/06,16.9,9.3\n2006/07,16.1,8.8\n2007/08,16.1,8.5', type='text')]
# after Api call
# שנה,מספרים (אלפים),שיעור לאלף
# 2000/01,10.0,5.7
# 2004/05,17.5,12.6
# 2005/06,16.9,9.3
# 2006/07,16.1,8.8
# 2007/08,16.1,8.5
# ✅ Saved CSV: 10_9_2009.csv
# תרשים 9יא' | תאונות של ילדים
# לפי שלב חינוך (אחוזים)
# תשס"ח (2007/08)
# 11_9_2009
# Processing image: 11_9_2009.png (graph: תרשים 9יא' | תאונות של ילדים
# לפי שלב חינוך (אחוזים)
# תשס"ח (2007/08))
# [TextBlock(citations=None, text='קבוצה,שלב חינוך,אחוזים\n,גן ילדים,12.0\n,יסודי,61.0\n,חטיבת-ביניים,18.0\n,תיכוני,9.0\n\n,מספר התאונות במערכת החינוך: 16,163', type='text')]
# after Api call
# קבוצה,שלב חינוך,אחוזים
# ,גן ילדים,12.0
# ,יסודי,61.0
# ,חטיבת-ביניים,18.0
# ,תיכוני,9.0
#
# ,מספר התאונות במערכת החינוך: 16,163
# ⚠️ Row 5 in 11_9_2009.png padded with empty strings.
# ✅ Saved CSV: 11_9_2009.csv
# תרשים 9יב' | תאונות של תלמידים
# לפי סוג פעילות שבה התרחשה התאונה (אחוזים)
# תשס"ח (2007/08)
# 12_9_2009
# Processing image: 12_9_2009.png (graph: תרשים 9יב' | תאונות של תלמידים
# לפי סוג פעילות שבה התרחשה התאונה (אחוזים)
# תשס"ח (2007/08))
# [TextBlock(citations=None, text='קטגוריה,אחוז\nהסעדה,65.0\nשיגור חופשי,1.0\nשיגור עצמי,6.0\nסיור,5.0\nחינוך גופני,23.0\nסוג פעילות,\n\nמספר התאונות במערכת החינוך: 16,163', type='text')]
# after Api call
# קטגוריה,אחוז
# הסעדה,65.0
# שיגור חופשי,1.0
# שיגור עצמי,6.0
# סיור,5.0
# חינוך גופני,23.0
# סוג פעילות,
#
# מספר התאונות במערכת החינוך: 16,163
# ⚠️ Row 7 in 12_9_2009.png padded with empty strings.
# ✅ Saved CSV: 12_9_2009.csv
# תרשים 9יג' | תאונות של תלמידים במערכת החינוך
# לפי גורם התאונה (אחוזים)
# תשס"ח (2007/08)
# 13_9_2009
# Processing image: 13_9_2009.png (graph: תרשים 9יג' | תאונות של תלמידים במערכת החינוך
# לפי גורם התאונה (אחוזים)
# תשס"ח (2007/08))
# [TextBlock(citations=None, text='גורם התאונה,אחוזים\nהתנהגות,7.0\nאלימות,2.0\nמפגע בטיחותי,1.0\nהאצה עצמיתי,89.0\nמעשה קונדס,1.0\n\nמספר התאונות במערכת החינוך: 16,163', type='text')]
# after Api call
# גורם התאונה,אחוזים
# התנהגות,7.0
# אלימות,2.0
# מפגע בטיחותי,1.0
# האצה עצמיתי,89.0
# מעשה קונדס,1.0
#
# מספר התאונות במערכת החינוך: 16,163
# ⚠️ Row 6 in 13_9_2009.png padded with empty strings.
# ✅ Saved CSV: 13_9_2009.csv
# תרשים 9ב' | פניות ילדים לחדרי מיון עקב תאונות בית וחצר* ועקב תאונות דרכים לפי גיל (אחוזים)
# 2008
# 2_9_2009
# Processing image: 2_9_2009.png (graph: תרשים 9ב' | פניות ילדים לחדרי מיון עקב תאונות בית וחצר* ועקב תאונות דרכים לפי גיל (אחוזים)
# 2008)
# [TextBlock(citations=None, text='גיל,תאונות בית וחצר,תאונות דרכים\n0,4.2,3.6\n1-4,32.0,20.5\n5-9,27.0,25.8\n10-14,24.7,23.1\n15-17,12.1,27.2\n\n,סך כל התבניות עקב תאונות בית וחצר: 103,545; סך כל התבניות עקב תאונות דרכים: 18,548; אחוזים', type='text')]
# after Api call
# גיל,תאונות בית וחצר,תאונות דרכים
# 0,4.2,3.6
# 1-4,32.0,20.5
# 5-9,27.0,25.8
# 10-14,24.7,23.1
# 15-17,12.1,27.2
#
# ,סך כל התבניות עקב תאונות בית וחצר: 103,545; סך כל התבניות עקב תאונות דרכים: 18,548; אחוזים
# ⚠️ Row 0 in 2_9_2009.png padded with empty strings.
# ⚠️ Row 1 in 2_9_2009.png padded with empty strings.
# ⚠️ Row 2 in 2_9_2009.png padded with empty strings.
# ⚠️ Row 3 in 2_9_2009.png padded with empty strings.
# ⚠️ Row 4 in 2_9_2009.png padded with empty strings.
# ⚠️ Row 5 in 2_9_2009.png padded with empty strings.
# ⚠️ Row 6 in 2_9_2009.png padded with empty strings.
# ✅ Saved CSV: 2_9_2009.csv
# תרשים 9ה' | ילדים בגיל 0-14 שנהרגו/נפצעו קשה בתאונת דרכים
# לפי גיל וקבוצת אוכלוסייה (שיעור למאה אלף בקבוצה המתאימה)
# 2006
# 5_9_2009
# Processing image: 5_9_2009.png (graph: תרשים 9ה' | ילדים בגיל 0-14 שנהרגו/נפצעו קשה בתאונת דרכים
# לפי גיל וקבוצת אוכלוסייה (שיעור למאה אלף בקבוצה המתאימה)
# 2006)
# [TextBlock(citations=None, text='גיל,יהודים ואחרים,ערבים\n0-4,7.4,33.9\n5-9,16.7,43.8\n10-14,17.0,32.9\nסך הכל 0-14,13.4,37.0', type='text')]
# after Api call
# גיל,יהודים ואחרים,ערבים
# 0-4,7.4,33.9
# 5-9,16.7,43.8
# 10-14,17.0,32.9
# סך הכל 0-14,13.4,37.0
# ✅ Saved CSV: 5_9_2009.csv
# תרשים 9ו' | תמותת בני 0-17 בתאונות
# לפי סיבה (אחוזים)
# 2006
# 6_9_2009
# Processing image: 6_9_2009.png (graph: תרשים 9ו' | תמותת בני 0-17 בתאונות
# לפי סיבה (אחוזים)
# 2006)
# [TextBlock(citations=None, text='סיבה,אחוזים\nרכב מנועי אחר,7.4\nהולך רגל,27.3\nאופניים,2.9\nתאונות יציאה משליטה,2.4\nטביעה,7.7\nחנק,5.3\nתאונות ירי,2.1\nאש/ כוויה,2.9\nנפילה,4.0\nהרעלה,4.0\nאחר,15.9', type='text')]
# after Api call
# סיבה,אחוזים
# רכב מנועי אחר,7.4
# הולך רגל,27.3
# אופניים,2.9
# תאונות יציאה משליטה,2.4
# טביעה,7.7
# חנק,5.3
# תאונות ירי,2.1
# אש/ כוויה,2.9
# נפילה,4.0
# הרעלה,4.0
# אחר,15.9
# ✅ Saved CSV: 6_9_2009.csv
# תרשים 9ז' | תמותת יהודים וערבים בני 0-17 בתאונות
# לפי סיבה* (אחוזים)
# 2006
# 7_9_2009
# Processing image: 7_9_2009.png (graph: תרשים 9ז' | תמותת יהודים וערבים בני 0-17 בתאונות
# לפי סיבה* (אחוזים)
# 2006)
# [TextBlock(citations=None, text='סיבה,ערבים,יהודים ואחרים\nטכנית,8.9,6.6\nכלכלית,5.8,2.2\nאישי/הורית,2.6,2.8\nרקע טעוני,35.6,23.3\nחוסר רצון,21.5,34.1\nאחרת,4.2,1.6\nתירוצים,0.0,0.5\nחוק,3.7,4.9', type='text')]
# after Api call
# סיבה,ערבים,יהודים ואחרים
# טכנית,8.9,6.6
# כלכלית,5.8,2.2
# אישי/הורית,2.6,2.8
# רקע טעוני,35.6,23.3
# חוסר רצון,21.5,34.1
# אחרת,4.2,1.6
# ...
# after Api call
# מדינה,בני 11,בנות 11,בני 13,בנות 13,בני 15,בנות 15
# אוקראינה,20,20,25,26,47,47
# ישראל,19,9,20,8,11,11
# אנגליה,12,7,17,17,41,38
# סלובקיה,9,14,16,16,35,30
# הפדרציה הרוסית,10,15,17,17,27,19
# אוסטריה,2,4,11,12,32,35
# סקוטלנד,7,10,18,18,36,27
# הולנד,3,3,18,11,31,33
# הרפובליקה הצ'כית,8,9,17,12,29,27
# יוון,7,7,16,12,28,31
# דנמרק,1,3,8,6,26,42
# בלגיה הפלמית,3,3,11,11,20,31
# סלובניה,8,3,9,8,32,10
# ספרד,2,3,7,7,25,18
# לוקסמבורג,1,3,6,5,19,25
# שוויץ,2,2,8,5,16,19
# צרפת,2,3,7,6,15,27
# גרמניה,1,2,2,3,25,19
# אירלנד,1,3,3,4,19,16
# קנדה,2,1,7,8,16,16
# פורטוגל,0,1,3,2,19,8
# פולין,1,1,3,2,17,11
# איטליה,0,1,2,3,11,9
# פינלנד,0,2,2,1,12,10
# נורווגיה,1,0,3,1,8,11
# ✅ Saved CSV: 21_15_2009.csv
# תרשים 15כב' | בני נוער שהשתכרו לפחות פעמיים, מדינות נבחרות
# (אחוזים)
# 2006
# 22_15_2009
# Processing image: 22_15_2009.png (graph: תרשים 15כב' | בני נוער שהשתכרו לפחות פעמיים, מדינות נבחרות
# (אחוזים)
# 2006)
# [TextBlock(citations=None, text="בנים 15,בנות 15,בנים 13,בנות 13,בנים 11,בנות 11\nדנמרק,56,,21,,6,\nאנגליה,50,,19,,4,\nפינלנד,47,,18,,3,\nסקוטלנד,44,,17,,4,\nאוסטריה,41,,16,,2,\nקנדה,36,,13,,1,\nסלובקיה,33,,15,,3,\nאוקראינה,32,,12,,1,\nהרפובליקה הצ'כית,28,,11,,4,\nפולין,27,,8,,2,\nאירלנד,26,,10,,1,\nהרפובליקה הצ'כית,22,,10,,1,\nספרד,20,,7,,1,\nרוסיה,20,,6,,1,\nבלגיה הפלמית,33,,11,,0.5,\nנורבגיה,25,,9,,1,\nשבדיה,26,,7,,0.5,\nהולנד,21,,8,,1,\nלוקסמבורג,20,,6,,0.5,\nצרפת,19,,5,,0.5,\nשוויץ,19,,4,,0.5,\nפורטוגל,18,,4,,0.5,\nאיטליה,22,,7,,1,\nארצות הברית,20,,7,,1,\nיוון,17,,4,,0.5,\nישראל,11,22,3,10,3,9\n,,,,,,\n,,,,,,\n,,,,,,", type='text')]
# after Api call
# בנים 15,בנות 15,בנים 13,בנות 13,בנים 11,בנות 11
# דנמרק,56,,21,,6,
# אנגליה,50,,19,,4,
# פינלנד,47,,18,,3,
# סקוטלנד,44,,17,,4,
# אוסטריה,41,,16,,2,
# קנדה,36,,13,,1,
# סלובקיה,33,,15,,3,
# אוקראינה,32,,12,,1,
# הרפובליקה הצ'כית,28,,11,,4,
# פולין,27,,8,,2,
# אירלנד,26,,10,,1,
# הרפובליקה הצ'כית,22,,10,,1,
# ספרד,20,,7,,1,
# רוסיה,20,,6,,1,
# בלגיה הפלמית,33,,11,,0.5,
# נורבגיה,25,,9,,1,
# שבדיה,26,,7,,0.5,
# הולנד,21,,8,,1,
# לוקסמבורג,20,,6,,0.5,
# צרפת,19,,5,,0.5,
# שוויץ,19,,4,,0.5,
# פורטוגל,18,,4,,0.5,
# איטליה,22,,7,,1,
# ארצות הברית,20,,7,,1,
# יוון,17,,4,,0.5,
# ישראל,11,22,3,10,3,9
# ,,,,,,
# ,,,,,,
# ,,,,,,
# ⚠️ Row 0 in 22_15_2009.png padded with empty strings.
# ✅ Saved CSV: 22_15_2009.csv
# תרשים 15ב' | תוחלת חיים ממוצעת בלידה של נשים וגברים (מספר שנות החיים הצפויות) במדינות נבחרות
# 2007
# 2_15_2009
# Processing image: 2_15_2009.png (graph: תרשים 15ב' | תוחלת חיים ממוצעת בלידה של נשים וגברים (מספר שנות החיים הצפויות) במדינות נבחרות
# 2007)
# [TextBlock(citations=None, text='מדינה,ציון\nיפן,83.0\nשוודיה,82.0\nאוסטרליה,81.0\nשוודיה,81.0\nספרד,81.0\nישראל,81.0\nאיטליה,81.0\nצרפת,81.0\nקנדה,81.0\nנורווגיה,80.0\nאוסטריה,80.0\nהולנד,80.0\nגרמניה,79.0\nבריטניה,79.0\nיוון,79.0\nלוקסמבורג,79.0\nפינלנד,79.0\nבלגיה,79.0\nאירלנד,79.0\nקוריאה,79.0\nפורטוגל,78.0\nדנמרק,78.0\nארה"ב,78.0\nצ\'כיה,76.0\nסלובקיה,75.0\nטורקיה,74.0\nר.פלסטינית,73.0\nירדן,72.0\nטורקיה,72.0\nאסטוניה,71.0\nמצרים,71.0\nמד. רוסיה,65.0', type='text')]
# after Api call
# מדינה,ציון
# יפן,83.0
# שוודיה,82.0
# אוסטרליה,81.0
# שוודיה,81.0
# ספרד,81.0
# ישראל,81.0
# איטליה,81.0
# צרפת,81.0
# קנדה,81.0
# נורווגיה,80.0
# אוסטריה,80.0
# הולנד,80.0
# גרמניה,79.0
# בריטניה,79.0
# יוון,79.0
# לוקסמבורג,79.0
# פינלנד,79.0
# בלגיה,79.0
# אירלנד,79.0
# קוריאה,79.0
# פורטוגל,78.0
# דנמרק,78.0
# ארה"ב,78.0
# צ'כיה,76.0
# סלובקיה,75.0
# טורקיה,74.0
# ר.פלסטינית,73.0
# ירדן,72.0
# טורקיה,72.0
# אסטוניה,71.0
# מצרים,71.0
# מד. רוסיה,65.0
# ✅ Saved CSV: 2_15_2009.csv
# תרשים
#  15ג' | מבנה המשפחה שבה חיים ילדים בני 11-15 במדינות נבחרות
# (אחוזים)
# 2006
# 3_15_2009
# Processing image: 3_15_2009.png (graph: תרשים
#  15ג' | מבנה המשפחה שבה חיים ילדים בני 11-15 במדינות נבחרות
# (אחוזים)
# 2006)
# [TextBlock(citations=None, text='מדינה,אחוזים,גרים עם שני ההורים,גרים עם הורה יחיד/ה,משפחה חד הורית,אחר\nארה״ב,57,28,14,\nדנמרק,66,19,13,\nהפדרציה הרוסית,65,22,11,\nסקוטלנד,68,19,12,\nקנדה,69,18,13,\nהרפובליקה הצ׳כית,70,16,13,\nאנגליה,70,16,13,\nפינלנד,71,16,13,\nנורווגיה,72,16,10,\nשבדיה,72,18,12,\nצרפת,73,14,13,\nגרמניה,74,18,7,\nבלגיה הפלמית,74,16,10,\nלוקסמבורג,76,14,3,\nאוסטריה,76,16,3,\nשוויץ,79,12,7,\nהולנד,80,12,7,\nאירלנד,81,13,5,\nפורטוגל,82,10,8,\nפולין,83,12,3,\nסלובניה,84,11,4,\nספרד,84,14,1,\nהונגריה,85,14,0,\nיוון,86,11,2,\nאיטליה,87,9,3,\nישראל,87,9,3,', type='text')]
# after Api call
# מדינה,אחוזים,גרים עם שני ההורים,גרים עם הורה יחיד/ה,משפחה חד הורית,אחר
# ארה״ב,57,28,14,
# דנמרק,66,19,13,
# הפדרציה הרוסית,65,22,11,
# סקוטלנד,68,19,12,
# קנדה,69,18,13,
# הרפובליקה הצ׳כית,70,16,13,
# אנגליה,70,16,13,
# פינלנד,71,16,13,
# נורווגיה,72,16,10,
# שבדיה,72,18,12,
# צרפת,73,14,13,
# גרמניה,74,18,7,
# בלגיה הפלמית,74,16,10,
# לוקסמבורג,76,14,3,
# אוסטריה,76,16,3,
# שוויץ,79,12,7,
# הולנד,80,12,7,
# אירלנד,81,13,5,
# פורטוגל,82,10,8,
# פולין,83,12,3,
# סלובניה,84,11,4,
# ספרד,84,14,1,
# הונגריה,85,14,0,
# יוון,86,11,2,
# איטליה,87,9,3,
# ישראל,87,9,3,
# ⚠️ Row 1 in 3_15_2009.png padded with empty strings.
# ⚠️ Row 2 in 3_15_2009.png padded with empty strings.
# ⚠️ Row 3 in 3_15_2009.png padded with empty strings.
# ⚠️ Row 4 in 3_15_2009.png padded with empty strings.
# ⚠️ Row 5 in 3_15_2009.png padded with empty strings.
# ⚠️ Row 6 in 3_15_2009.png padded with empty strings.
# ⚠️ Row 7 in 3_15_2009.png padded with empty strings.
# ⚠️ Row 8 in 3_15_2009.png padded with empty strings.
# ⚠️ Row 9 in 3_15_2009.png padded with empty strings.
# ⚠️ Row 10 in 3_15_2009.png padded with empty strings.
# ⚠️ Row 11 in 3_15_2009.png padded with empty strings.
# ⚠️ Row 12 in 3_15_2009.png padded with empty strings.
# ⚠️ Row 13 in 3_15_2009.png padded with empty strings.
# ⚠️ Row 14 in 3_15_2009.png padded with empty strings.
# ⚠️ Row 15 in 3_15_2009.png padded with empty strings.
# ⚠️ Row 16 in 3_15_2009.png padded with empty strings.
# ⚠️ Row 17 in 3_15_2009.png padded with empty strings.
# ⚠️ Row 18 in 3_15_2009.png padded with empty strings.
# ⚠️ Row 19 in 3_15_2009.png padded with empty strings.
# ⚠️ Row 20 in 3_15_2009.png padded with empty strings.
# ⚠️ Row 21 in 3_15_2009.png padded with empty strings.
# ⚠️ Row 22 in 3_15_2009.png padded with empty strings.
# ⚠️ Row 23 in 3_15_2009.png padded with empty strings.
# ⚠️ Row 24 in 3_15_2009.png padded with empty strings.
# ⚠️ Row 25 in 3_15_2009.png padded with empty strings.
# ⚠️ Row 26 in 3_15_2009.png padded with empty strings.
# ✅ Saved CSV: 3_15_2009.csv
# תרשים
# 15ד' | הוצאה לאומית לחינוך תלמיד מכיתה א' עד לתואר שלישי
# (דולרים)
# 2007
# 4_15_2009
# Processing image: 4_15_2009.png (graph: תרשים
# 15ד' | הוצאה לאומית לחינוך תלמיד מכיתה א' עד לתואר שלישי
# (דולרים)
# 2007)
# [TextBlock(citations=None, text='ארץ,דולרים (ארה"ב)\nארה"ב,13447\nשוויץ,12667\nנורבגיה,11487\nאוסטריה,10895\nדנמרק,10395\nשבדיה,9523\nהולנד,9330\nבריטניה,9209\nיפן,8872\nבלגיה,8827\nאיסלנד,8823\nאוסטרליה,8678\nצרפת,8428\nאיטליה,8263\nאירלנד,8092\nפינלנד,8048\nגרמניה,7925\nסלובניה,7869\nממוצע ה-OECD,7840\nספרד,7819\nקוריאה,6811\nפורטוגל,6624\nישראל,6293\nניו זילנד,6222\nצ\'כיה,5174\nהונגריה,4588\nאסטוניה,4126\nפולין,3868\nהרפובליקה הסלובקית,3485\nצ\'ילה,2849\nרוסיה,2761\nמקסיקו,2460\nברזיל,1811\nטורקיה,1614', type='text')]
# after Api call
# ארץ,דולרים (ארה"ב)
# ארה"ב,13447
# שוויץ,12667
# נורבגיה,11487
# אוסטריה,10895
# דנמרק,10395
# שבדיה,9523
# הולנד,9330
# בריטניה,9209
# יפן,8872
# בלגיה,8827
# איסלנד,8823
# אוסטרליה,8678
# צרפת,8428
# איטליה,8263
# אירלנד,8092
# פינלנד,8048
# גרמניה,7925
# סלובניה,7869
# ממוצע ה-OECD,7840
# ספרד,7819
# קוריאה,6811
# פורטוגל,6624
# ישראל,6293
# ניו זילנד,6222
# צ'כיה,5174
# הונגריה,4588
# אסטוניה,4126
# פולין,3868
# הרפובליקה הסלובקית,3485
# צ'ילה,2849
# רוסיה,2761
# מקסיקו,2460
# ברזיל,1811
# טורקיה,1614
# ✅ Saved CSV: 4_15_2009.csv
# תרשים
# 15ה' | מספר תלמידים* ממוצע בכיתה בחינוך היסודי ובחטיבות הביניים במוסדות חינוך ציבוריים במדינות נבחרות
# 2007
# 5_15_2009
# Processing image: 5_15_2009.png (graph: תרשים
# 15ה' | מספר תלמידים* ממוצע בכיתה בחינוך היסודי ובחטיבות הביניים במוסדות חינוך ציבוריים במדינות נבחרות
# 2007)
# [TextBlock(citations=None, text="מדינה,חינוך יסודי,חטיבת ביניים\nקוריאה,31.0,35.8\nצ'ילה,30.7,30.3\nיפן,28.1,33.0\nישראל,27.6,32.7\nברזיל,25.9,30.0\nבריטניה,23.7,25.8\nארצות הברית,24.9,23.6\nאוסטרליה,23.3,23.1\nצרפת,22.6,24.1\nגרמניה,22.1,24.6\nממוצע ה-OECD,21.4,23.4\nרפוב׳ הצ׳כית,20.0,22.9\nדנמרק,20.0,20.2\nפולין,19.9,24.6\nאוסטריה,19.9,24.0\nהונגריה,19.9,21.2\nרפוב׳ הסלובקית,19.7,22.6\nמקסיקו,19.7,29.6\nספרד,19.5,23.7\nפורטוגל,19.5,22.2\nשוויץ,19.5,19.0\nאסטוניה,19.1,23.0\nאיטליה,18.4,20.8\nאיסלנד,18.2,19.9\nסלובניה,17.5,19.2\nיוון,16.8,21.5\nלוקסמבורג,15.6,19.8\nהפדרציה הרוסית,15.5,18.1\n\n,,,מספר תלמידים ממוצע בכיתה", type='text')]
# after Api call
# מדינה,חינוך יסודי,חטיבת ביניים
# קוריאה,31.0,35.8
# צ'ילה,30.7,30.3
# יפן,28.1,33.0
# ישראל,27.6,32.7
# ברזיל,25.9,30.0
# בריטניה,23.7,25.8
# ארצות הברית,24.9,23.6
# אוסטרליה,23.3,23.1
# צרפת,22.6,24.1
# גרמניה,22.1,24.6
# ממוצע ה-OECD,21.4,23.4
# רפוב׳ הצ׳כית,20.0,22.9
# דנמרק,20.0,20.2
# פולין,19.9,24.6
# אוסטריה,19.9,24.0
# הונגריה,19.9,21.2
# רפוב׳ הסלובקית,19.7,22.6
# מקסיקו,19.7,29.6
# ספרד,19.5,23.7
# פורטוגל,19.5,22.2
# שוויץ,19.5,19.0
# אסטוניה,19.1,23.0
# איטליה,18.4,20.8
# איסלנד,18.2,19.9
# סלובניה,17.5,19.2
# יוון,16.8,21.5
# לוקסמבורג,15.6,19.8
# הפדרציה הרוסית,15.5,18.1
#
# ,,,מספר תלמידים ממוצע בכיתה
# ⚠️ Row 0 in 5_15_2009.png padded with empty strings.
# ⚠️ Row 1 in 5_15_2009.png padded with empty strings.
# ⚠️ Row 2 in 5_15_2009.png padded with empty strings.
# ⚠️ Row 3 in 5_15_2009.png padded with empty strings.
# ⚠️ Row 4 in 5_15_2009.png padded with empty strings.
# ⚠️ Row 5 in 5_15_2009.png padded with empty strings.
# ⚠️ Row 6 in 5_15_2009.png padded with empty strings.
# ⚠️ Row 7 in 5_15_2009.png padded with empty strings.
# ⚠️ Row 8 in 5_15_2009.png padded with empty strings.
# ⚠️ Row 9 in 5_15_2009.png padded with empty strings.
# ⚠️ Row 10 in 5_15_2009.png padded with empty strings.
# ⚠️ Row 11 in 5_15_2009.png padded with empty strings.
# ⚠️ Row 12 in 5_15_2009.png padded with empty strings.
# ⚠️ Row 13 in 5_15_2009.png padded with empty strings.
# ⚠️ Row 14 in 5_15_2009.png padded with empty strings.
# ⚠️ Row 15 in 5_15_2009.png padded with empty strings.
# ⚠️ Row 16 in 5_15_2009.png padded with empty strings.
# ⚠️ Row 17 in 5_15_2009.png padded with empty strings.
# ⚠️ Row 18 in 5_15_2009.png padded with empty strings.
# ⚠️ Row 19 in 5_15_2009.png padded with empty strings.
# ⚠️ Row 20 in 5_15_2009.png padded with empty strings.
# ⚠️ Row 21 in 5_15_2009.png padded with empty strings.
# ⚠️ Row 22 in 5_15_2009.png padded with empty strings.
# ⚠️ Row 23 in 5_15_2009.png padded with empty strings.
# ⚠️ Row 24 in 5_15_2009.png padded with empty strings.
# ⚠️ Row 25 in 5_15_2009.png padded with empty strings.
# ⚠️ Row 26 in 5_15_2009.png padded with empty strings.
# ⚠️ Row 27 in 5_15_2009.png padded with empty strings.
# ⚠️ Row 28 in 5_15_2009.png padded with empty strings.
# ⚠️ Row 29 in 5_15_2009.png padded with empty strings.
# ✅ Saved CSV: 5_15_2009.csv
# תרשים
# 15ו' | אחוז היילודים שמשקלם בלידה נמוך (פחות מ-2,500 גר') מכלל היילודים, במדינות נבחרות
# 2000-2007*
# 6_15_2009
# Processing image: 6_15_2009.png (graph: תרשים
# 15ו' | אחוז היילודים שמשקלם בלידה נמוך (פחות מ-2,500 גר') מכלל היילודים, במדינות נבחרות
# 2000-2007*)
# [TextBlock(citations=None, text="מדינה,ערך\nסינגפור,16.0\nמצרים,14.0\nירדן,12.0\nסוריה,9.0\nבריטניה,8.0\nארצות הברית,8.0\nבלגיה,8.0\nיפן,8.0\nישראל,8.0\nלוכסמבורג,8.0\nפורטוגל,8.0\nאוסטריה,7.0\nאוסטרליה,7.0\nגרמנייה,7.0\nצ'כיה,7.0\nצרפת,7.0\nסלובקיה,7.0\nר. פלשתינית,7.0\nתפ. חורשית,6.0\nאירלנד,6.0\nאיטליה,6.0\nספרד,6.0\nקנדה,6.0\nשוויץ,6.0\nדנמרק,5.0\nנורבגיה,5.0\nאסטוניה,4.0\nפולנד,4.0\nשוודיה,4.0\nקוריאה,4.0\n\nאחוז היהודים שמוכנים לפגוע ב-2,500 מטכל היהודים", type='text')]
# after Api call
# מדינה,ערך
# סינגפור,16.0
# מצרים,14.0
# ירדן,12.0
# סוריה,9.0
# בריטניה,8.0
# ארצות הברית,8.0
# בלגיה,8.0
# יפן,8.0
# ישראל,8.0
# לוכסמבורג,8.0
# פורטוגל,8.0
# אוסטריה,7.0
# אוסטרליה,7.0
# גרמנייה,7.0
# צ'כיה,7.0
# צרפת,7.0
# סלובקיה,7.0
# ר. פלשתינית,7.0
# תפ. חורשית,6.0
# אירלנד,6.0
# איטליה,6.0
# ספרד,6.0
# קנדה,6.0
# שוויץ,6.0
# דנמרק,5.0
# נורבגיה,5.0
# אסטוניה,4.0
# פולנד,4.0
# שוודיה,4.0
# קוריאה,4.0
#
# אחוז היהודים שמוכנים לפגוע ב-2,500 מטכל היהודים
# ⚠️ Row 31 in 6_15_2009.png padded with empty strings.
# ✅ Saved CSV: 6_15_2009.csv
# תרשים 15ז' | תמותת תינוקות
# במדינות נבחרות (שיעור ל-1,000 לידות חי)
# 2007
# 7_15_2009
# Processing image: 7_15_2009.png (graph: תרשים 15ז' | תמותת תינוקות
# במדינות נבחרות (שיעור ל-1,000 לידות חי)
# 2007)
# [TextBlock(citations=None, text='מדינה,ציון\nמצרים,30.0\nר. פלסטינית,24.0\nטורקיה,21.0\nירדן,21.0\nסוריה,15.0\nמד.רוסיות,13.0\nארה"ב,7.0\nסלובקיה,7.0\nאוסטרליה,5.0\nקנדה,5.0\nבריטניה,5.0\nישראל,4.0\nאוסטריה,4.0\nאירלנד,4.0\nאסטוניה,4.0\nבלגיה,4.0\nגרמניה,4.0\nדנמרק,4.0\nהולנד,4.0\nיוון,4.0\nספרד,4.0\nקוריאה,4.0\nשוויץ,4.0\nאיטליה,3.0\nיפן,3.0\nנורווגיה,3.0\nפורטוגל,3.0\nפינלנד,3.0\nצ\'כיה,3.0\nצרפת,3.0\nשוודיה,3.0\nלוקסמבורג,2.0', type='text')]
# after Api call
# מדינה,ציון
# מצרים,30.0
# ר. פלסטינית,24.0
# טורקיה,21.0
# ירדן,21.0
# סוריה,15.0
# מד.רוסיות,13.0
# ארה"ב,7.0
# סלובקיה,7.0
# אוסטרליה,5.0
# קנדה,5.0
# בריטניה,5.0
# ישראל,4.0
# אוסטריה,4.0
# אירלנד,4.0
# אסטוניה,4.0
# בלגיה,4.0
# גרמניה,4.0
# דנמרק,4.0
# הולנד,4.0
# יוון,4.0
# ספרד,4.0
# קוריאה,4.0
# שוויץ,4.0
# איטליה,3.0
# יפן,3.0
# נורווגיה,3.0
# פורטוגל,3.0
# פינלנד,3.0
# צ'כיה,3.0
# צרפת,3.0
# שוודיה,3.0
# לוקסמבורג,2.0
# ✅ Saved CSV: 7_15_2009.csv
# תרשים 15ח' | תמותת ילדים מתחת לגיל 5
# במדינות נבחרות (שיעור לאלף)
# 2007
# 8_15_2009
# Processing image: 8_15_2009.png (graph: תרשים 15ח' | תמותת ילדים מתחת לגיל 5
# במדינות נבחרות (שיעור לאלף)
# 2007)
# [TextBlock(citations=None, text='מדינה,ערך\nמצרים,36.0\nר. פלסטינית,27.0\nירדן,24.0\nטורקיה,23.0\nסוריה,17.0\nהרפ. חברתית,15.0\nארה"ב,8.0\nסלובקיה,8.0\nאוסטרליה,6.0\nאסטוניה,6.0\nבריטניה,6.0\nקנדה,6.0\nישראל,5.0\nבלגיה,5.0\nהולנד,5.0\nקוריאה,5.0\nשוויץ,5.0\nאוסטריה,4.0\nאיטליה,4.0\nאירלנד,4.0\nגרמניה,4.0\nדנמרק,4.0\nיוון,4.0\nיפן,4.0\nנורווגיה,4.0\nספרד,4.0\nצ\'ילה,4.0\nצרפת,4.0\nפורטוגל,4.0\nפינלנד,4.0\nלוקסמבורג,3.0\nשוודיה,3.0', type='text')]
# after Api call
# מדינה,ערך
# מצרים,36.0
# ר. פלסטינית,27.0
# ירדן,24.0
# טורקיה,23.0
# סוריה,17.0
# הרפ. חברתית,15.0
# ארה"ב,8.0
# סלובקיה,8.0
# אוסטרליה,6.0
# אסטוניה,6.0
# בריטניה,6.0
# קנדה,6.0
# ישראל,5.0
# בלגיה,5.0
# הולנד,5.0
# קוריאה,5.0
# שוויץ,5.0
# אוסטריה,4.0
# איטליה,4.0
# אירלנד,4.0
# גרמניה,4.0
# דנמרק,4.0
# יוון,4.0
# יפן,4.0
# נורווגיה,4.0
# ספרד,4.0
# צ'ילה,4.0
# צרפת,4.0
# פורטוגל,4.0
# פינלנד,4.0
# לוקסמבורג,3.0
# שוודיה,3.0
# ✅ Saved CSV: 8_15_2009.csv
# תרשים 15ט' | בני נוער המצחצחים שיניים פעם ביום ויותר, לפי גיל
# (אחוזים)
# 2006
# 9_15_2009
# Processing image: 9_15_2009.png (graph: תרשים 15ט' | בני נוער המצחצחים שיניים פעם ביום ויותר, לפי גיל
# (אחוזים)
# 2006)
# [TextBlock(citations=None, text='שורון,15 מנדטים,שורון,13 מנדטים,שורון,11 מנדטים\nשבירה,71,שבירה,79,שבירה,89\nנטויה,67,נטויה,65,יחליך,84\nרחליך,71,רחליך,72,נטויה,75\nאסטרונה,66,זעטרף,63,זעטרף,78\nאיסליה,67,נטריזה,62,סוריונה,71\nזעטרף,62,סוריונה,59,אסטריה,77\nאנליה,62,אנליה,63,אנליה,69\nסוריונה,60,איסליה,65,הרטפיסטונ,60\nרחליך,61,אסטריה,78,סקולוטר,73\nהרטפיסטונ,66,סקולוטר,79,לקסטמנטרנ,78\nסקולוטר,63,הרטפיסטונ,78,קזגנ,78\nטלין,67,שרשת,78,איסליה,73\nקזגנ,77,אבגט,75,אבגט,73\nטרטוקל,78,קזגנ,76,טרטוקל,73\nלקסטמנטרנ,59,לקסטמנטרנ,77,ישראל,66\nשרשת,75,ישראל,67,שרשת,68\nאבגט,72,טרטוקל,69,טלין,66\nהסרטגט,73,הסרטגט,69,סבדר,61\nסלקנות,79,סלקנות,65,הסרטגט,61\nאורחלי,82,סבדר,64,טרטוקל,63\nישראל,57,אורחלי,64,סלקנות,67\nסבדר,77,בגמנ הסרטגט,61,בגמנ הסרטגט,65\nבגמנ הסרטגט,67,טלין,68,טלין,67\nטלין,61,יווד,51,יווד,59\nיווד,51,תרמליה,57,תרמליה,53\nתרמליה,51,,,,\n,בנים,בנות,,', type='text')]
# after Api call
# שורון,15 מנדטים,שורון,13 מנדטים,שורון,11 מנדטים
# שבירה,71,שבירה,79,שבירה,89
# נטויה,67,נטויה,65,יחליך,84
# רחליך,71,רחליך,72,נטויה,75
# אסטרונה,66,זעטרף,63,זעטרף,78
# איסליה,67,נטריזה,62,סוריונה,71
# זעטרף,62,סוריונה,59,אסטריה,77
# אנליה,62,אנליה,63,אנליה,69
# סוריונה,60,איסליה,65,הרטפיסטונ,60
# רחליך,61,אסטריה,78,סקולוטר,73
# הרטפיסטונ,66,סקולוטר,79,לקסטמנטרנ,78
# סקולוטר,63,הרטפיסטונ,78,קזגנ,78
# טלין,67,שרשת,78,איסליה,73
# קזגנ,77,אבגט,75,אבגט,73
# טרטוקל,78,קזגנ,76,טרטוקל,73
# לקסטמנטרנ,59,לקסטמנטרנ,77,ישראל,66
# שרשת,75,ישראל,67,שרשת,68
# אבגט,72,טרטוקל,69,טלין,66
# הסרטגט,73,הסרטגט,69,סבדר,61
# סלקנות,79,סלקנות,65,הסרטגט,61
# אורחלי,82,סבדר,64,טרטוקל,63
# ישראל,57,אורחלי,64,סלקנות,67
# סבדר,77,בגמנ הסרטגט,61,בגמנ הסרטגט,65
# בגמנ הסרטגט,67,טלין,68,טלין,67
# טלין,61,יווד,51,יווד,59
# יווד,51,תרמליה,57,תרמליה,53
# תרמליה,51,,,,
# ,בנים,בנות,,
# ⚠️ Row 27 in 9_15_2009.png padded with empty strings.
# ✅ Saved CSV: 9_15_2009.csv

# %%
##checking how many graphs hasnt been extracted ###

import os
import csv

base_dir = "/content/graphs_to_csvs_2001-2016"

for year in range(2003, 2006):
    for chap in range(1, 16):
        dir_path = os.path.join(base_dir, str(year), f"{chap:02d}")
        if not os.path.exists(dir_path):
            continue

        for fname in os.listdir(dir_path):
            if not fname.endswith(".csv"):
                continue
            file_path = os.path.join(dir_path, fname)

            # Read CSV
            with open(file_path, "r", encoding="utf-8") as f:
                reader = csv.reader(f)
                rows = list(reader)

            # Check if any cell contains "null" (case-insensitive)
            contains_null = any("null" in (cell or "").lower() for row in rows for cell in row)

            if contains_null:
                # Overwrite CSV with placeholder
                # with open(file_path, "w", encoding="utf-8", newline="") as f:
                    # writer = csv.writer(f)
                    # writer.writerow([f"⚠️ Graph hasn’t been extracted: {fname}"])
                print(f"⚠️ Replaced CSV with message: {file_path}")
