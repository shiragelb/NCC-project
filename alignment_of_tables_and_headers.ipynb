# %%
##downloads xlsx files from the drive by chapter
##run 1
# tables 2019, 2021-2024

from google.colab import auth
from googleapiclient.discovery import build
from googleapiclient.http import MediaIoBaseDownload
import os
import io

# 1️⃣ Authenticate
auth.authenticate_user()
drive_service = build('drive', 'v3')

# 2️⃣ Folder ID of the specific directory
folder_id = "1xH-6eyhl0XDe0DfS33o0xZAIdTLPkyQj"  # <-- ID of "excel_and_json_2019_2021_2024"

# 3️⃣ Recursive listing of all files in this folder
def list_all_files_in_folder_recursive(parent_id, parent_path=""):
    all_files = []
    query = f"'{parent_id}' in parents and trashed=false"
    page_token = None

    while True:
        response = drive_service.files().list(
            q=query,
            spaces='drive',
            fields='nextPageToken, files(id, name, mimeType)',
            pageToken=page_token
        ).execute()

        for item in response.get('files', []):
            item_path = f"{parent_path}/{item['name']}" if parent_path else item['name']
            if item['mimeType'] == 'application/vnd.google-apps.folder':
                all_files.extend(list_all_files_in_folder_recursive(item['id'], item_path))
            else:
                all_files.append({
                    "file_name": item['name'],
                    "file_path": item_path,
                    "file_id": item['id']
                })

        page_token = response.get('nextPageToken', None)
        if page_token is None:
            break

    return all_files

# 4️⃣ Download all files to local directory
def download_files(files_list, download_dir="/content/excel_and_json_2019_2021_2024-"):
    os.makedirs(download_dir, exist_ok=True)

    for file in files_list:
        local_path = os.path.join(download_dir, file['file_path'].replace("/", os.sep))
        os.makedirs(os.path.dirname(local_path), exist_ok=True)

        request = drive_service.files().get_media(fileId=file['file_id'])
        fh = io.FileIO(local_path, "wb")
        downloader = MediaIoBaseDownload(fh, request)

        done = False
        while not done:
            status, done = downloader.next_chunk()
            if status:
                print(f"⬇️ Downloading {file['file_name']} {int(status.progress() * 100)}%")

        print(f"✅ Saved {file['file_name']} to {local_path}")

# 5️⃣ Run everything
files_list = list_all_files_in_folder_recursive(folder_id)
download_files(files_list)
# Out:
# ⬇️ Downloading 162_1_2024.csv 100%
# ✅ Saved 162_1_2024.csv to /content/excel_and_json_2019_2021_2024-2/2024/1/162_1_2024.csv
# ⬇️ Downloading 172_1_2024.csv 100%
# ✅ Saved 172_1_2024.csv to /content/excel_and_json_2019_2021_2024-2/2024/1/172_1_2024.csv
# ⬇️ Downloading 160_1_2024.csv 100%
# ✅ Saved 160_1_2024.csv to /content/excel_and_json_2019_2021_2024-2/2024/1/160_1_2024.csv
# ⬇️ Downloading 186_1_2024.csv 100%
# ✅ Saved 186_1_2024.csv to /content/excel_and_json_2019_2021_2024-2/2024/1/186_1_2024.csv
# ⬇️ Downloading 161_1_2024.csv 100%
# ✅ Saved 161_1_2024.csv to /content/excel_and_json_2019_2021_2024-2/2024/1/161_1_2024.csv
# ⬇️ Downloading 190_1_2024.csv 100%
# ✅ Saved 190_1_2024.csv to /content/excel_and_json_2019_2021_2024-2/2024/1/190_1_2024.csv
# ⬇️ Downloading 180_1_2024.csv 100%
# ✅ Saved 180_1_2024.csv to /content/excel_and_json_2019_2021_2024-2/2024/1/180_1_2024.csv
# ⬇️ Downloading 191_1_2024.csv 100%
# ✅ Saved 191_1_2024.csv to /content/excel_and_json_2019_2021_2024-2/2024/1/191_1_2024.csv
# ⬇️ Downloading 176_1_2024.csv 100%
# ✅ Saved 176_1_2024.csv to /content/excel_and_json_2019_2021_2024-2/2024/1/176_1_2024.csv
# ⬇️ Downloading 183_1_2024.csv 100%
# ✅ Saved 183_1_2024.csv to /content/excel_and_json_2019_2021_2024-2/2024/1/183_1_2024.csv
# ⬇️ Downloading 189_1_2024.csv 100%
# ✅ Saved 189_1_2024.csv to /content/excel_and_json_2019_2021_2024-2/2024/1/189_1_2024.csv
# ⬇️ Downloading 1_2024.json 100%
# ✅ Saved 1_2024.json to /content/excel_and_json_2019_2021_2024-2/2024/1/1_2024.json
# ⬇️ Downloading 177_1_2024.csv 100%
# ✅ Saved 177_1_2024.csv to /content/excel_and_json_2019_2021_2024-2/2024/1
2019.csv to /content/excel_and_json_2019_2021_2024-2/2019/4/10_4_2019.csv
# ⬇️ Downloading 9_4_2019.csv 100%
# ✅ Saved 9_4_2019.csv to /content/excel_and_json_2019_2021_2024-2/2019/4/9_4_2019.csv
# ⬇️ Downloading 6_4_2019.csv 100%
# ✅ Saved 6_4_2019.csv to /content/excel_and_json_2019_2021_2024-2/2019/4/6_4_2019.csv

# %%
##extracting tables feature names
### run 2
# for tables 2019, 2021-2024

import os
import pandas as pd
import json
import re

def is_hebrew(text):
    """Return True if the text contains Hebrew letters."""
    if not isinstance(text, str):
        return False
    return bool(re.search(r'[\u0590-\u05FF]', text))

def is_year(text, start=1900, end=2024):
    """Return True if the text is a year between start and end (can be float like 2005.0)."""
    try:
        year = float(str(text).strip())
        return start <= year <= end
    except:
        return False

def clean_text_list(text_list):
    """
    Keep Hebrew texts, years (1900-2024), and append 'percentage' to any value containing '%'.
    """
    cleaned = []
    for t in text_list:
        if pd.isna(t):
            continue
        t = str(t).strip()
        if not t or t.lower() in ['nan', 'none']:
            continue

        # Tag percentages
        if '%' in t:
            cleaned.append(f"{t} percentage")
        # Keep Hebrew or year numbers
        elif is_hebrew(t) or is_year(t):
            cleaned.append(t)
    return cleaned

def extract_hebrew_and_years(base_dir, output_dir):
    """
    Extract Hebrew text, years, and tag percentages from CSVs per chapter.
    Saves one JSON per chapter inside output_dir.
    """
    os.makedirs(output_dir, exist_ok=True)

    for year_folder in os.listdir(base_dir):
        year_path = os.path.join(base_dir, year_folder)
        if not os.path.isdir(year_path):
            continue

        for chapter_folder in os.listdir(year_path):
            chapter_path = os.path.join(year_path, chapter_folder)
            if not os.path.isdir(chapter_path):
                continue

            chapter_result = {}

            for file in os.listdir(chapter_path):
                if file.endswith('.csv'):
                    csv_path = os.path.join(chapter_path, file)
                    try:
                        df = pd.read_csv(csv_path, dtype=str)
                    except Exception as e:
                        print(f"Error reading {csv_path}: {e}")
                        continue

                    texts = []

                    # Include all column headers
                    if df.columns is not None:
                        texts.extend(df.columns.astype(str).tolist())

                    # Include all rows and all cells
                    for i in range(len(df)):
                        row_text = df.iloc[i].astype(str).tolist()
                        texts.extend(row_text)

                    # Clean texts
                    cleaned_texts = clean_text_list(texts)

                    # Use filename without .csv as key
                    key = file.replace('.csv', '')
                    chapter_result[key] = cleaned_texts

            # Save JSON per chapter
            chapter_json_path = os.path.join(chapter_path, f"{chapter_folder}_{year_folder}_feature_names.json")
            with open(chapter_json_path, 'w', encoding='utf-8') as f:
                json.dump(chapter_result, f, ensure_ascii=False, indent=2)

            print(f"Saved chapter JSON: {chapter_json_path}")

# Example usage
base_dir = "/content/excel_and_json_2019_2021_2024/"
output_dir = "/content/hebrew_per_chapter_json/"
extract_hebrew_and_years(base_dir, output_dir)
# Out:
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2024/5/5_2024_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2024/8/8_2024_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2024/4/4_2024_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2024/3/3_2024_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2024/7/7_2024_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2024/1/1_2024_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2024/11/11_2024_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2024/2/2_2024_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2024/9/9_2024_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2024/10/10_2024_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2024/14/14_2024_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2024/12/12_2024_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2024/13/13_2024_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2024/6/6_2024_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2022/5/5_2022_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2022/8/8_2022_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2022/4/4_2022_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2022/3/3_2022_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2022/7/7_2022_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2022/1/1_2022_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2022/11/11_2022_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2022/2/2_2022_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2022/9/9_2022_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2022/10/10_2022_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2022/14/14_2022_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2022/12/12_2022_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2022/13/13_2022_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2022/6/6_2022_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2021/5/5_2021_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2021/8/8_2021_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2021/4/4_2021_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2021/3/3_2021_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2021/7/7_2021_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2021/1/1_2021_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2021/11/11_2021_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2021/2/2_2021_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2021/9/9_2021_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2021/10/10_2021_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2021/14/14_2021_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2021/12/12_2021_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2021/13/13_2021_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2021/6/6_2021_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2023/5/5_2023_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2023/8/8_2023_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2023/4/4_2023_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2023/3/3_2023_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2023/7/7_2023_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2023/1/1_2023_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2023/11/11_2023_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2023/2/2_2023_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2023/9/9_2023_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2023/10/10_2023_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2023/14/14_2023_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2023/12/12_2023_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2023/13/13_2023_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2023/6/6_2023_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2019/5/5_2019_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2019/8/8_2019_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2019/4/4_2019_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2019/3/3_2019_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2019/7/7_2019_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2019/1/1_2019_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2019/11/11_2019_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2019/2/2_2019_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2019/9/9_2019_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2019/10/10_2019_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2019/14/14_2019_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2019/12/12_2019_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2019/13/13_2019_feature_names.json
# Saved chapter JSON: /content/excel_and_json_2019_2021_2024/2019/6/6_2019_feature_names.json

# %%
##

# %%writefile real_embeddings.py

# import numpy as np
# import pickle
# import os
# import hashlib

# try:
#     from sentence_transformers import SentenceTransformer
#     TRANSFORMER_AVAILABLE = True
# except:
#     TRANSFORMER_AVAILABLE = False
#     print("Install with: !pip install sentence-transformers")

# class RealEmbeddingGenerator:
#     def __init__(self, model_name="sentence-transformers/LaBSE", cache_dir="cache"):
#         self.cache_dir = cache_dir
#         os.makedirs(cache_dir, exist_ok=True)
#         self.embedding_cache = {}

#         if TRANSFORMER_AVAILABLE:
#             self.model = SentenceTransformer(model_name)
#             self.dimension = self.model.get_sentence_embedding_dimension()
#         else:
#             self.model = None
#             self.dimension = 768

#     def get_text_hash(self, text):
#         return hashlib.md5(text.encode('utf-8')).hexdigest()

#     def generate_embedding(self, text, use_cache=True):
#         text_hash = self.get_text_hash(text)

#         if use_cache and text_hash in self.embedding_cache:
#             return self.embedding_cache[text_hash]

#         if self.model:
#             embedding = self.model.encode(text, convert_to_numpy=True)
#         else:
#             # Fallback to deterministic random
#             np.random.seed(int(text_hash[:8], 16) % 10000)
#             embedding = np.random.randn(self.dimension)

#         if use_cache:
#             self.embedding_cache[text_hash] = embedding

#         return embedding

#     def generate_batch(self, texts, show_progress=True):
#         if self.model:
#             return self.model.encode(texts,
#                                     batch_size=32,
#                                     show_progress_bar=show_progress,
#                                     convert_to_numpy=True)
#         else:
#             return np.array([self.generate_embedding(t) for t in texts])

#     def save_cache(self):
#         cache_file = os.path.join(self.cache_dir, "embedding_cache.pkl")
#         with open(cache_file, 'wb') as f:
#             pickle.dump(self.embedding_cache, f)
# Out:
# Overwriting real_embeddings.py

# %%
# import os
# import json
# import numpy as np
# from real_embeddings import RealEmbeddingGenerator

# def cosine_similarity(a, b):
#     a = np.array(a).flatten()
#     b = np.array(b).flatten()
#     return np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b) + 1e-8)

# def normalize_scores(scores):
#     """Normalize a list of scalar scores to 0-1 range."""
#     scores = [float(s) for s in scores]
#     if not scores:
#         return scores
#     min_s, max_s = min(scores), max(scores)
#     if max_s - min_s < 1e-8:
#         return [1.0] * len(scores)
#     return [(s - min_s) / (max_s - min_s) for s in scores]

# def semantic_alignment_avg_word_header(table_names_json_path, headers_json_path, threshold=0.2):
#     """
#     Align table names to headers (features) using semantic similarity.
#     Each header is represented as the average of embeddings of its words.
#     """
#     # Load JSONs
#     with open(table_names_json_path, 'r', encoding='utf-8') as f:
#         table_names = json.load(f)
#     with open(headers_json_path, 'r', encoding='utf-8') as f:
#         table_headers = json.load(f)

#     embedder = RealEmbeddingGenerator()
#     report = {}

#     table_name_keys = list(table_names.keys())
#     table_name_texts = [table_names[k] for k in table_name_keys]

#     print("Embedding all table names...")
#     table_name_embeddings = embedder.generate_batch(table_name_texts, show_progress=True)
#     print(f"Embedded {len(table_name_embeddings)} table names.\n")

#     for header_key, header_texts in table_headers.items():
#         print(f"\n--- Processing header key: {header_key} ---")
#         print(f"Header texts: {header_texts}")

#         # Step 1: embed each word in each header
#         header_word_embeddings = []
#         for h in header_texts:
#             words = h.split()  # simple tokenization by space
#             if words:
#                 word_embs = embedder.generate_batch(words, show_progress=False)
#                 # Average embeddings for this header
#                 avg_emb = np.mean(np.array(word_embs), axis=0)
#             else:
#                 avg_emb = np.zeros(table_name_embeddings[0].shape)
#             header_word_embeddings.append(avg_emb)

#         matches = []

#         for i, table_emb in enumerate(table_name_embeddings):
#             table_name = table_name_texts[i]
#             table_emb = np.array(table_emb).flatten()
#             print(f"\nComparing to table: {table_name} (key={table_name_keys[i]})")

#             # Compute similarity to each header vector
#             sims = [cosine_similarity(table_emb, h_emb) for h_emb in header_word_embeddings]
#             sims_norm = normalize_scores(sims)
#             avg_sim = float(np.mean(sims_norm))

#             for h_text, s_raw, s_norm in zip(header_texts, sims, sims_norm):
#                 print(f"  Header: '{h_text}' | raw_sim={s_raw:.4f} | norm_sim={s_norm:.4f}")

#             print(f"Average normalized similarity: {avg_sim:.4f}")

#             if avg_sim >= threshold:
#                 matches.append({
#                     "table_name_key": table_name_keys[i],
#                     "table_name": table_name,
#                     "similarity": avg_sim
#                 })

#         matches = sorted(matches, key=lambda x: x['similarity'], reverse=True)
#         print(f"Matches above threshold ({threshold}): {matches}")
#         report[header_key] = matches

#     return report

# # Example usage
# chapter_report = semantic_alignment_avg_word_header(
#     "/content/excel_and_json_2019_2021_2024/2023/5/5_2023.json",
#     "/content/excel_and_json_2019_2021_2024/2023/5/5_2023_headers.json",
#     threshold=0.2
# )

# print(json.dumps(chapter_report, ensure_ascii=False, indent=2))

# %%
# !pip install anthropic
# import os
# import json
# import numpy as np
# from real_embeddings import RealEmbeddingGenerator

# def cosine_similarity(a, b):
#     """Compute cosine similarity between two vectors."""
#     return np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b) + 1e-8)


# def semantic_alignment_report(table_names_json_path, headers_json_path, threshold=0.7):
#     # Load JSONs (same as before)
#      # Load JSONs
#     with open(table_names_json_path, 'r', encoding='utf-8') as f:
#         table_names = json.load(f)

#     with open(headers_json_path, 'r', encoding='utf-8') as f:
#         table_headers = json.load(f)

#     # Initialize embedding generator

#     report = {}


#     # Instead of embedder = RealEmbeddingGenerator()
#     import anthropic
#     client = anthropic.Anthropic(api_key='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')

#     for header_key, header_texts in table_headers.items():
#         # Make one API call per header
#         prompt = f"""Given these table features: {header_texts}

#         Match them to the most relevant table names from this list:
#         {json.dumps(table_names, ensure_ascii=False)}

#         Return JSON with format:
#         {{"matches": [
#             {{"table_key": "...", "table_name": "...", "confidence": 0.0-1.0}}
#         ]}}
#         ⚠️ IMPORTANT: Do not include any explanation, commentary, or extra text.
#         Return strictly valid JSON in the format above.
#         Only include matches with confidence > {threshold}.
#         """

#         response = client.messages.create(
#             model="claude-3-haiku-20240307",
#             max_tokens=1000,
#             messages=[{"role": "user", "content": prompt}]
#         )
#         content_text = response.content[0].text.strip()

#         # Safe parsing
#         try:
#             matches = json.loads(content_text)
#         except json.JSONDecodeError:
#             print(f"⚠️ Could not parse JSON for {header_key}. Raw output:\n{content_text}")
#             matches = {"matches": []}

#         report[header_key] = matches.get("matches", [])

#     return report

# import os
# import json
# import anthropic

# def refine_with_first_round(initial_report, table_names_json_path, headers_json_path, threshold=0.4, api_key='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'):
#     """
#     Second-pass alignment using the first-pass output.
#     Provides the model all headers, table names, and previous matches,
#     asking it to decide which matches are correct or need adjustment.
#     """
#     # Load JSONs
#     with open(table_names_json_path, 'r', encoding='utf-8') as f:
#         table_names = json.load(f)

#     with open(headers_json_path, 'r', encoding='utf-8') as f:
#         table_headers = json.load(f)

#     client = anthropic.Anthropic(api_key='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')
#     refined_report = {}

#     for header_key, header_texts in table_headers.items():
#         previous_matches = initial_report.get(header_key, [])

#         prompt = f"""
#         You are helping to match table headers to table names.

#         Headers: {header_texts}

#         Available table names:
#         {json.dumps(table_names, ensure_ascii=False)}

#         Previous first-round matches with confidence scores:
#         {json.dumps(previous_matches, ensure_ascii=False)}

#         For each header, decide which table(s) it should match.
#         - Keep high-confidence matches.
#         - Correct any matches if needed.
#         - You may update confidence scores (0.0-1.0).
#         - Only include matches with confidence > {threshold}.
#         -there can be "percentage" in the features list - that means that there was
#         numbers in the table that are percentage
#         -if you see a year number feature it might align to header with "שנה"

#         Return strictly valid JSON in this format:
#         {{
#           "matches": [
#             {{"table_key": "...", "table_name": "...", "confidence": 0.0-1.0}}
#           ]
#         }}
#         ⚠️ IMPORTANT: Do not include any explanation, commentary, or extra text.
#                 Return strictly valid JSON in the format above.
#         """

#         # API call
#         response = client.messages.create(
#             model="claude-3-haiku-20240307",
#             max_tokens=1500,
#             messages=[{"role": "user", "content": prompt}]
#         )

#         content_text = response.content[0].text.strip()

#         try:
#             new_matches = json.loads(content_text)
#         except json.JSONDecodeError:
#             print(f"⚠️ Could not parse JSON for {header_key}. Raw output:\n{content_text}")
#             new_matches = {"matches": []}

#         refined_report[header_key] = new_matches.get("matches", [])

#     return refined_report

# # # Example usage:
# chapter_report = semantic_alignment_report(
#     "/content/excel_and_json_2019_2021_2024/2023/5/5_2023.json",
#     "/content/excel_and_json_2019_2021_2024/2023/5/5_2023_headers.json",
#     threshold=0.4
# )
# # Example usage:
# refined_report = refine_with_first_round(chapter_report,
#                                          "/content/excel_and_json_2019_2021_2024/2023/5/5_2023.json",
#                                          "/content/excel_and_json_2019_2021_2024/2023/5/5_2023_headers.json",
#                                          threshold=0.4,
#                                          api_key="")
# print(json.dumps(refined_report, ensure_ascii=False, indent=2))


# # Save uncertain JSON
# with open("/content/7_2022.json", "w", encoding="utf-8") as f:
#     json.dump(refined_report, f, ensure_ascii=False, indent=2)
# Out:
# Requirement already satisfied: anthropic in /usr/local/lib/python3.12/dist-packages (0.67.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (0.10.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (2.11.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.12/dist-packages (from anthropic) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->anthropic) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->anthropic) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.1)
# ⚠️ Could not parse JSON for 5_5_2023. Raw output:
# {
#     "matches": [
#         {
#             "table_key": "4_5_2023",
#             "table_name": "תרשים 5ד': התפלגות הגשת ערעורים של תלמידים שהורחקו לצמיתות מבית הספר, לפי שנה (מספרים ואחוזים מכלל ההרחקות לצמיתות) / תשע\"ב (2011/12) - תשפ\"א (2020/21)",
#             "confidence": 0.8
#         },
#         {
#             "table_key": "5_5_2023",
#             "table_name": "תרשים 5ה': מספר התלמידים שהורחקו לאלתר* מבית הספר, לפי שנה / תשע\"ב (2011/12) - תשפ\"א (2020/21)",
#             "confidence": 0.8
#         },
#         {
#             "table_key": "9_5_2023",
#             "table_name": "תרשים 5ט': שיעור הזכאים לתעודת בגרות מתלמידי י\"ב ומבני ה-17* / תש\"ע (2009/2010) – תשפ\"ב (2021/22)",
#             "confidence": 0.8
#         },
#         {
#             "table_key": "11_5_2023",
#             "table_name": "תרשים 5יב': שיעור הזכאים לתעודת בגרות שנבחנו במתמטיקה ובאנגלית ב-5 יחידות לימוד / תשע\"ג (2012/13) – תשפ\"ב (2021/22)",
#             "confidence": 0.8
#         },
#         {
#             "table_key": "12_5_2023",
#             "table_name": "תרשים 5יג': שיעור הזכאים לתעודת בגרות מצטיינת מתלמידי י\"ב / תשע\"ג (2012/13) – תשפ\"ב (2021/22)",
#             "confidence": 0.8
#         },
#         {
#             "table_key": "14_5_2023",
#             "table_name": "תרשים 5טז': זכאות לבגרות לפי השכלת אם, לפי מגזר / תשפ\"א (2021/22)",
#             "confidence": 0.7
#         },
#         {
#             "table_key": "15_5_2023",
#             "table_name": "תרשים 5יז': התפלגות הנבחנים בבחינת בגרות שמחברת הבחינה שלהם נפסלה* עקב חשד לאי-קיום טוהר הבחינה, (אחוז המחברות הפסולות מכלל הנבחנים) תשע\"ג (2012/13) – תשפ\"ב (2021/22)",
#             "confidence": 0.8
#         },
#         {
#             "table_key": "17_5_2023",
#             "table_name": "תרשים 5יט': שיעור בני הנוער הלומדים לתואר ראשון לפי סוג מוסד לימודים / תשפ\"ג (2022/23)",
#             "confidence": 0.7
#         },
#         {
#             "table_key": "18_5_2023",
#             "table_name": "תרשים 5כ': התפלגות בני נוער הלומדים לת
# ⚠️ Could not parse JSON for 16_5_2023. Raw output:
# {
#     "matches": [
#         {
#             "table_key": "9_5_2023",
#             "table_name": "תרשים 5ט': שיעור הזכאים לתעודת בגרות מתלמידי י\"ב ומבני ה-17* / תש\"ע (2009/2010) – תשפ\"ב (2021/22)",
#             "confidence": 0.9
#         },
#         {
#             "table_key": "11_5_2023",
#             "table_name": "תרשים 5יב': שיעור הזכאים לתעודת בגרות שנבחנו במתמטיקה ובאנגלית ב-5 יחידות לימוד / תשע\"ג (2012/13) – תשפ\"ב (2021/22)",
#             "confidence": 0.9
#         },
#         {
#             "table_key": "12_5_2023",
#             "table_name": "תרשים 5יג': שיעור הזכאים לתעודת בגרות מצטיינת מתלמידי י\"ב / תשע\"ג (2012/13) – תשפ\"ב (2021/22)",
#             "confidence": 0.9
#         },
#         {
#             "table_key": "13_5_2023",
#             "table_name": "תרשים 5יד': שיעור הזכאים לתעודת בגרות ושיעור העומדים בדרישות הסף של האוניברסיטאות מתלמידי כיתות יב' לפי קבוצת אוכלוסייה / 2021-1996",
#             "confidence": 0.9
#         },
#         {
#             "table_key": "17_5_2023",
#             "table_name": "תרשים 5יט': שיעור בני הנוער הלומדים לתואר ראשון לפי סוג מוסד לימודים / תשפ\"ג (2022/23)",
#             "confidence": 0.9
#         },
#         {
#             "table_key": "18_5_2023",
#             "table_name": "תרשים 5כ': התפלגות בני נוער הלומדים לתואר ראשון, לפי גיל / תשפ\"ג (2022/23)",
#             "confidence": 0.9
#         },
#         {
#             "table_key": "19_5_2023",
#             "table_name": "תרשים 5כא': שיעור בני נוער הלומדים לתואר ראשון, לפי מגדר  / תשפ\"ב (2021/22)",
#             "confidence": 0.9
#         },
#         {
#             "table_key": "20_5_2023",
#             "table_name": "תרשים 5כב': שיעור בני נוער הלומדים לתואר ראשון, לפי קבוצת אוכלוסייה /\nתשפ\"ב (2021/22)",
#             "confidence": 0.9
#         },
#         {
#             "table_key": "21_5_2023",
#             "table_name": "תרשים 5כג': שיעור בני נוער הלומדים לתואר ראשון, לפי אשכול חברתי-כלכלי /\nתשפ\"ב (2021/22)",
#             "confidence": 0.9
#         },
#         {
#             "table_key": "22_5_2023",
#             "table_name": "תרשים 5כד
# ⚠️ Could not parse JSON for 27_5_2023. Raw output:
# {
#     "matches": [
#         {
#             "table_key": "1_5_2023",
#             "table_name": "תרשים 5א': שיעור הלומדים במערכת החינוך*, לפי גיל ומגזר (אחוז מקבוצת הגיל באוכלוסייה) / תשפ\"ב (2021/22)",
#             "confidence": 0.8
#         },
#         {
#             "table_key": "2_5_2023",
#             "table_name": "תרשים 5ב': שיעור* התחושות החיוביות כלפי בית הספר, לפי כיתה / תשפ\"ב (2021/22)",
#             "confidence": 0.7
#         },
#         {
#             "table_key": "3_5_2023",
#             "table_name": "תרשים 5ג': שיעור* התלמידים שהעידו על יחסים חיוביים בין חבריהם לכיתה, לפי כיתה /  תשפ\"ב (2021/22)",
#             "confidence": 0.7
#         },
#         {
#             "table_key": "7_5_2023",
#             "table_name": "תרשים 5ז': שיעור (לאלף) של התלמידים שנשרו מבתי הספר בפיקוחו של משרד החינוך* לפי גיל וזרם חינוכי  / במהלך שנת הלימודים תשפ\"ב (2021/22) ובמעבר לשנת הלימודים תשפ\"ג (2022/23)",
#             "confidence": 0.7
#         },
#         {
#             "table_key": "9_5_2023",
#             "table_name": "תרשים 5ט': שיעור הזכאים לתעודת בגרות מתלמידי י\"ב ומבני ה-17* / תש\"ע (2009/2010) – תשפ\"ב (2021/22)",
#             "confidence": 0.8
#         },
#         {
#             "table_key": "11_5_2023",
#             "table_name": "תרשים 5יב': שיעור הזכאים לתעודת בגרות שנבחנו במתמטיקה ובאנגלית ב-5 יחידות לימוד / תשע\"ג (2012/13) – תשפ\"ב (2021/22)",
#             "confidence": 0.8
#         },
#         {
#             "table_key": "12_5_2023",
#             "table_name": "תרשים 5יג': שיעור הזכאים לתעודת בגרות מצטיינת מתלמידי י\"ב / תשע\"ג (2012/13) – תשפ\"ב (2021/22)",
#             "confidence": 0.8
#         },
#         {
#             "table_key": "13_5_2023",
#             "table_name": "תרשים 5יד': שיעור הזכאים לתעודת בגרות ושיעור העומדים בדרישות הסף של האוניברסיטאות מתלמידי כיתות יב' לפי קבוצת אוכלוסייה / 2021-1996",
#             "confidence": 0.8
#         },
#         {
#             "table_key": "17_5_2023",
#             "table_name": "תרשים 5יט': שיעור בני הנוער הל
# ⚠️ Could not parse JSON for 28_5_2023. Raw output:
# {
#     "matches": [
#         {
#             "table_key": "1_5_2023",
#             "table_name": "תרשים 5א': שיעור הלומדים במערכת החינוך*, לפי גיל ומגזר (אחוז מקבוצת הגיל באוכלוסייה) / תשפ\"ב (2021/22)",
#             "confidence": 0.8
#         },
#         {
#             "table_key": "2_5_2023",
#             "table_name": "תרשים 5ב': שיעור* התחושות החיוביות כלפי בית הספר, לפי כיתה / תשפ\"ב (2021/22)",
#             "confidence": 0.7
#         },
#         {
#             "table_key": "3_5_2023",
#             "table_name": "תרשים 5ג': שיעור* התלמידים שהעידו על יחסים חיוביים בין חבריהם לכיתה, לפי כיתה /  תשפ\"ב (2021/22)",
#             "confidence": 0.7
#         },
#         {
#             "table_key": "7_5_2023",
#             "table_name": "תרשים 5ז': שיעור (לאלף) של התלמידים שנשרו מבתי הספר בפיקוחו של משרד החינוך* לפי גיל וזרם חינוכי  / במהלך שנת הלימודים תשפ\"ב (2021/22) ובמעבר לשנת הלימודים תשפ\"ג (2022/23)",
#             "confidence": 0.7
#         },
#         {
#             "table_key": "9_5_2023",
#             "table_name": "תרשים 5ט': שיעור הזכאים לתעודת בגרות מתלמידי י\"ב ומבני ה-17* / תש\"ע (2009/2010) – תשפ\"ב (2021/22)",
#             "confidence": 0.7
#         },
#         {
#             "table_key": "13_5_2023",
#             "table_name": "תרשים 5יד': שיעור הזכאים לתעודת בגרות ושיעור העומדים בדרישות הסף של האוניברסיטאות מתלמידי כיתות יב' לפי קבוצת אוכלוסייה / 2021-1996",
#             "confidence": 0.7
#         },
#         {
#             "table_key": "14_5_2023",
#             "table_name": "תרשים 5טז': זכאות לבגרות לפי השכלת אם, לפי מגזר / תשפ\"א (2021/22)",
#             "confidence": 0.7
#         },
#         {
#             "table_key": "26_5_2023",
#             "table_name": "תרשים 5כח': שיעורי למידה ל-1,000 נפשות בגילאי 13 ו-17 לפי מגזר / תש\"פ (2019\\2020)",
#             "confidence": 0.6
#         },
#         {
#             "table_key": "28_5_2023",
#             "table_name": "תרשים 5כט: שיעורי התלמידים (בכיתות ד') ברמות הביצוע בהבנת הנקרא בעברית, לפי רקע כלכלי, מגדר ו
# ⚠️ Could not parse JSON for 18_5_2023. Raw output:
# {
#   "matches": [
#     {"table_key": "17_5_2023", "table_name": "תרשים 5יט': שיעור בני הנוער הלומדים לתואר ראשון לפי סוג מוסד לימודים / תשפ\"ג (2022/23)", "confidence": 0.9},
#     {"table_key": "18_5_2023", "table_name": "תרשים 5כ': התפלגות בני נוער הלומדים לתואר ראשון, לפי גיל / תשפ\"ג (2022/23)", "confidence": 0.9},
#     {"table_key": "19_5_2023", "table_name": "תרשים 5כא': שיעור בני נוער הלומדים לתואר ראשון, לפי מגדר  / תשפ\"ב (2021/22)", "confidence": 0.9},
#     {"table_key": "20_5_2023", "table_name": "תרשים 5כב': שיעור בני נוער הלומדים לתואר ראשון, לפי קבוצת אוכלוסייה /\nתשפ\"ב (2021/22)", "confidence": 0.9},
#     {"table_key": "21_5_2023", "table_name": "תרשים 5כג': שיעור בני נוער הלומדים לתואר ראשון, לפי אשכול חברתי-כלכלי /\nתשפ\"ב (2021/22)", "confidence": 0.9},
#     {"table_key": "22_5_2023", "table_name": "תרשים 5כד': שיעור בני נוער הלומדים לתואר ראשון, לפי תחום לימוד  / תשפ\"ג (2022/23)", "confidence": 0.9},
#     {"table_key": "13_5_2023", "table_name": "תרשים 5יד': שיעור הזכאים לתעודת בגרות ושיעור העומדים בדרישות הסף של האוניברסיטאות מתלמידי כיתות יב' לפי קבוצת אוכלוסייה / 1996-2021", "confidence": 0.8},
#     {"table_key": "14_5_2023", "table_name": "תרשים 5טז': זכאות לבגרות לפי השכלת אם, לפי מגזר / תשפ\"א (2021/22)", "confidence": 0.8},
#     {"table_key": "9_5_2023", "table_name": "תרשים 5ט': שיעור הזכאים לתעודת בגרות מתלמידי י\"ב ומבני ה-17* / תש\"ע (2009/2010) – תשפ\"ב (2021/22)", "confidence": 0.8},
#     {"table_key": "11_5_2023", "table_name": "תרשים 5יב': שיעור הזכאים לתעודת בגרות שנבחנו במתמטיקה ובאנגלית ב-5 יחידות לימוד / תשע\"ג (2012/13) – תשפ\"ב (2021/22)", "confidence": 0.8},
#     {"table_key": "12_5_2023", "table_name": "תרשים 5יג': שיעור הזכאים לתעודת בגרות מצטיינת מתלמידי י\"ב / תשע\"ג (2012/13) – תשפ\"ב (2021/22)", "confidence": 0.8},
#     {"table_key": "15_5_2023", "table_name": "תרשים 5יז': התפלגות הנבחנים בבחינת בגרות שמחברת הבחינה שלהם נפסלה* עקב חשד לאי-קיום טוהר הבחינה, (אחוז המחברות הפסולות מכלל הנבחנים) תשע\"ג (2012/13) – תשפ\"ב (2021/22)", "confidence": 0.8},
#     {"table_key": "23_5_2023", "table_name": "תרשים 5כה': שיעור השכלה אקדמית של הורים לילדים (17-12), לפי מגזר / תשפ\"ב (2021/22)", "confidence": 0.8},
#     {"table_key": "24_5_2023", "table_name": "תרשים 5כו': שיעור השכלה אקדמית של הורים לילדים (17-12), לפי האשכול החברתי-כלכלי/ תשפ\"ב (2021/22)", "confidence": 0.8},
#     {"table_key": "26_5_2023", "table_name": "תרשים 5כח': שיעורי למידה ל-1,000 נפשות בגילאי 13 ו-17 לפי מגזר / תש\"פ (2019\\2020)", "confidence": 0.6},
#     {"table_key": "28_5_2023", "table_name": "תרשים 5כט:
# ⚠️ Could not parse JSON for 5_5_2023. Raw output:
# {
#   "matches": [
#     {"table_key": "4_5_2023", "table_name": "תרשים 5ד': התפלגות הגשת ערעורים של תלמידים שהורחקו לצמיתות מבית הספר, לפי שנה (מספרים ואחוזים מכלל ההרחקות לצמיתות) / תשע\"ב (2011/12) - תשפ\"א (2020/21)", "confidence": 1.0},
#     {"table_key": "5_5_2023", "table_name": "תרשים 5ה': מספר התלמידים שהורחקו לאלתר* מבית הספר, לפי שנה / תשע\"ב (2011/12) - תשפ\"א (2020/21)", "confidence": 1.0},
#     {"table_key": "9_5_2023", "table_name": "תרשים 5ט': שיעור הזכאים לתעודת בגרות מתלמידי י\"ב ומבני ה-17* / תש\"ע (2009/2010) – תשפ\"ב (2021/22)", "confidence": 1.0},
#     {"table_key": "11_5_2023", "table_name": "תרשים 5יב': שיעור הזכאים לתעודת בגרות שנבחנו במתמטיקה ובאנגלית ב-5 יחידות לימוד / תשע\"ג (2012/13) – תשפ\"ב (2021/22)", "confidence": 1.0},
#     {"table_key": "12_5_2023", "table_name": "תרשים 5יג': שיעור הזכאים לתעודת בגרות מצטיינת מתלמידי י\"ב / תשע\"ג (2012/13) – תשפ\"ב (2021/22)", "confidence": 1.0},
#     {"table_key": "13_5_2023", "table_name": "תרשים 5יד': שיעור הזכאים לתעודת בגרות ושיעור העומדים בדרישות הסף של האוניברסיטאות מתלמידי כיתות יב' לפי קבוצת אוכלוסייה / 2021-1996", "confidence": 1.0},
#     {"table_key": "17_5_2023", "table_name": "תרשים 5יט': שיעור בני הנוער הלומדים לתואר ראשון לפי סוג מוסד לימודים / תשפ\"ג (2022/23)", "confidence": 1.0},
#     {"table_key": "18_5_2023", "table_name": "תרשים 5כ': התפלגות בני נוער הלומדים לתואר ראשון, לפי גיל / תשפ\"ג (2022/23)", "confidence": 1.0},
#     {"table_key": "19_5_2023", "table_name": "תרשים 5כא': שיעור בני נוער הלומדים לתואר ראשון, לפי מגדר  / תשפ\"ב (2021/22)", "confidence": 1.0},
#     {"table_key": "20_5_2023", "table_name": "תרשים 5כב': שיעור בני נוער הלומדים לתואר ראשון, לפי קבוצת אוכלוסייה /\nתשפ\"ב (2021/22)", "confidence": 1.0},
#     {"table_key": "21_5_2023", "table_name": "תרשים 5כג': שיעור בני נוער הלומדים לתואר ראשון, לפי אשכול חברתי-כלכלי /\nתשפ\"ב (2021/22)", "confidence": 1.0},
#     {"table_key": "22_5_2023", "table_name": "תרשים 5כד': שיעור בני נוער הלומדים לתואר ראשון, לפי תחום לימוד  / תשפ\"ג (2022/23)", "confidence": 1.0},
#     {"table_key": "26_5_2023", "table_name": "תרשים 5כח': שיעורי למידה ל-1,000 נפשות בגילאי 13 ו-17 לפי מגזר / תש\"פ (2019\\2020)", "confidence": 1.0},
#     {"table_key": "28_5_2023", "table_name": "תרשים 5כט: שיעורי התלמידים (בכיתות ד') ברמות הביצוע בהבנת הנקרא בעברית, לפי רקע כלכלי, מגדר וסוג הפיקוח הבית ספרי / תשפ\"ב (דצמבר 2021)", "confidence": 1.0},
#     {"table_key": "29_5_2023", "table_name": "תרשים 5לא' שיעורי התלמידים (בכיתות ד') ברמות הביצוע בהבנת הנקרא בערבית,
# ⚠️ Could not parse JSON for 16_5_2023. Raw output:
# {
#   "matches": [
#     {"table_key": "9_5_2023", "table_name": "תרשים 5ט': שיעור הזכאים לתעודת בגרות מתלמידי י\"ב ומבני ה-17* / תש\"ע (2009/2010) – תשפ\"ב (2021/22)", "confidence": 0.8},
#     {"table_key": "11_5_2023", "table_name": "תרשים 5יב': שיעור הזכאים לתעודת בגרות שנבחנו במתמטיקה ובאנגלית ב-5 יחידות לימוד / תשע\"ג (2012/13) – תשפ\"ב (2021/22)", "confidence": 0.8},
#     {"table_key": "12_5_2023", "table_name": "תרשים 5יג': שיעור הזכאים לתעודת בגרות מצטיינת מתלמידי י\"ב / תשע\"ג (2012/13) – תשפ\"ב (2021/22)", "confidence": 0.8},
#     {"table_key": "13_5_2023", "table_name": "תרשים 5יד': שיעור הזכאים לתעודת בגרות ושיעור העומדים בדרישות הסף של האוניברסיטאות מתלמידי כיתות יב' לפי קבוצת אוכלוסייה / 2021-1996", "confidence": 0.8},
#     {"table_key": "14_5_2023", "table_name": "תרשים 5טז': זכאות לבגרות לפי השכלת אם, לפי מגזר / תשפ\"א (2021/22)", "confidence": 0.8},
#     {"table_key": "17_5_2023", "table_name": "תרשים 5יט': שיעור בני הנוער הלומדים לתואר ראשון לפי סוג מוסד לימודים / תשפ\"ג (2022/23)", "confidence": 0.7},
#     {"table_key": "18_5_2023", "table_name": "תרשים 5כ': התפלגות בני נוער הלומדים לתואר ראשון, לפי גיל / תשפ\"ג (2022/23)", "confidence": 0.7},
#     {"table_key": "19_5_2023", "table_name": "תרשים 5כא': שיעור בני נוער הלומדים לתואר ראשון, לפי מגדר  / תשפ\"ב (2021/22)", "confidence": 0.7},
#     {"table_key": "20_5_2023", "table_name": "תרשים 5כב': שיעור בני נוער הלומדים לתואר ראשון, לפי קבוצת אוכלוסייה /\nתשפ\"ב (2021/22)", "confidence": 0.7},
#     {"table_key": "21_5_2023", "table_name": "תרשים 5כג': שיעור בני נוער הלומדים לתואר ראשון, לפי אשכול חברתי-כלכלי /\nתשפ\"ב (2021/22)", "confidence": 0.7},
#     {"table_key": "22_5_2023", "table_name": "תרשים 5כד': שיעור בני נוער הלומדים לתואר ראשון, לפי תחום לימוד  / תשפ\"ג (2022/23)", "confidence": 0.7},
#     {"table_key": "23_5_2023", "table_name": "תרשים 5כה': שיעור השכלה אקדמית של הורים לילדים (17-12), לפי מגזר / תשפ\"ב (2021/22)", "confidence": 0.7},
#     {"table_key": "24_5_2023", "table_name": "תרשים 5כו': שיעור השכלה אקדמית של הורים לילדים (17-12), לפי האשכול החברתי-כלכלי/ תשפ\"ב (2021/22)", "confidence": 0.7},
#     {"table_key": "26_5_2023", "table_name": "תרשים 5כח': שיעורי למידה ל-1,000 נפשות בגילאי 13 ו-17 לפי מגזר / תש\"פ (2019\\2020)", "confidence": 0.6},
#     {"table_key": "28_5_2023", "table_name": "תרשים 5כט: שיעורי התלמידים (בכיתות ד') ברמות הביצוע בהבנת הנקרא בעברית, לפי רקע כלכלי, מגדר וסוג הפיקוח הבית ספרי / תשפ\"ב (דצמבר 2021)", "confidence": 0.6},
#     {"table_key": "29_5_2023", "table_name": "תרשים 5לא' שיעורי התלמידים (בכיתות ד')

# %%
# import json
# import pandas as pd
# from collections import defaultdict

# # Load your JSON
# with open("3_2024.json", "r", encoding="utf-8") as f:
#     data = json.load(f)

# classified = {}
# uncertain = {}

# for csv_name, candidates in data.items():
#     if not candidates:
#         # No candidates → uncertain
#         uncertain[csv_name] = []
#         continue

#     # Sort candidates by confidence descending
#     sorted_cands = sorted(candidates, key=lambda x: x["confidence"], reverse=True)
#     max_conf = sorted_cands[0]["confidence"]

#     # Get all candidates with the max confidence
#     top_candidates = [c for c in sorted_cands if c["confidence"] == max_conf]

#     # Check confidence threshold
#     if max_conf < 0.6:
#         uncertain[csv_name] = sorted_cands
#         continue

#     # Check if all top candidates have the same table_name
#     top_table_names = set(c["table_name"] for c in top_candidates)
#     if len(top_table_names) == 1:
#         # Unique table_name → classify
#         classified[csv_name] = top_candidates[0]["table_key"]
#     else:
#         # Competing different table names → uncertain
#         uncertain[csv_name] = sorted_cands

# # Save classified JSON
# with open("classified.json", "w", encoding="utf-8") as f:
#     json.dump(classified, f, ensure_ascii=False, indent=2)

# # Save uncertain JSON
# with open("uncertain.json", "w", encoding="utf-8") as f:
#     json.dump(uncertain, f, ensure_ascii=False, indent=2)

# # Also make a summary CSV
# rows = []
# for csv_name, table_key in classified.items():
#     rows.append([csv_name, table_key, "classified"])
# for csv_name, candidates in uncertain.items():
#     rows.append([csv_name, "; ".join([c["table_key"] for c in candidates]), "uncertain"])

# df = pd.DataFrame(rows, columns=["csv_name", "table_keys", "status"])
# df.to_csv("classification_summary.csv", index=False, encoding="utf-8-sig")

# print("✅ Saved classified.json, uncertain.json, and classification_summary.csv")
# Out:
# ✅ Saved classified.json, uncertain.json, and classification_summary.csv

# %%
##run 3
## interactive code for aligining the tables to its names.

import os
import json

def interactive_table_to_headers(chapter_headers_json_path, chapter_json_path, save_json_path):
    """
    Interactive alignment where for each table name, user chooses the CSV that corresponds to it.

    Args:
        chapter_headers_json_path (str): JSON path containing extracted headers for CSVs
        chapter_json_path (str): JSON path with table_key -> table_name
        save_json_path (str): Path to save the aligned mapping
    """
    # Load headers JSON
    with open(chapter_headers_json_path, 'r', encoding='utf-8') as f:
        headers_json = json.load(f)

    # Load table names JSON
    with open(chapter_json_path, 'r', encoding='utf-8') as f:
        table_json = json.load(f)

    aligned_mapping = {}

    # Make a copy so we can remove CSVs once assigned (optional)
    remaining_csvs = headers_json.copy()
    remaining_tables = table_json.copy()  # for display purposes

    while remaining_tables:
        # Iterate over a list of table keys to avoid runtime dict size change issues
        for table_key in list(remaining_tables.keys()):
            table_name = remaining_tables[table_key]
            print(f"\n=== Table Name: {table_name} ===")
            print("Candidate CSVs and their headers:")

            # Display all remaining CSVs with headers (first few headers for readability)
            for idx, (csv_file, headers) in enumerate(remaining_csvs.items(), 1):
                headers_preview = " | ".join(headers[:10])  # show first 10 headers max
                print(f"{idx}. {csv_file}: {headers_preview}")

            # Prompt user to choose the correct CSV
            choice = input("\nEnter the number of the CSV that matches this table (or 0 if unsure): ").strip()
            if choice.isdigit():
                choice = int(choice)
                if 1 <= choice <= len(remaining_csvs):
                    selected_csv = list(remaining_csvs.keys())[choice-1]
                    aligned_mapping[table_key] = selected_csv
                    print(f"✅ Mapped {table_name} → {selected_csv}")

                    # Remove the selected CSV to enforce 1:1 mapping
                    remaining_csvs.pop(selected_csv)

                    # Remove the table from the display list (it disappears from screen)
                    remaining_tables.pop(table_key)
                else:
                    print("⚠️ Not mapped (uncertain).")
                    aligned_mapping[table_key] = None
                    remaining_tables.pop(table_key)  # disappear anyway
            else:
                print("⚠️ Invalid input. Skipped.")
                aligned_mapping[table_key] = None
                remaining_tables.pop(table_key)  # disappear anyway

    # Save the aligned mapping JSON
    with open(save_json_path, 'w', encoding='utf-8') as f:
        json.dump(aligned_mapping, f, ensure_ascii=False, indent=2)

    print(f"\n✅ Alignment finished. Saved mapping to: {save_json_path}")
    return aligned_mapping


# # Example usage:
# interactive_table_to_headers(
#     chapter_headers_json_path="/content/excel_and_json_2019_2021_2024/2023/3/3_2023_headers.json",
#     chapter_json_path="/content/excel_and_json_2019_2021_2024/2023/3/3_2023.json",
#     save_json_path="/content/excel_and_json_2019_2021_2024/2023/3/aligned_mapping.json"
# )

for year in range(2022,2023): ##change the year accordingly
      for chapter in range(10,15):
          headers_path = os.path.join(base_dir, str(year), str(chapter), f"{chapter}_{year}_feature_names.json")
          chapter_path = os.path.join(base_dir, str(year), str(chapter), f"{chapter}_{year}.json")
          save_path = os.path.join(base_dir, str(year), str(chapter), "aligned_mapping.json")

          if os.path.exists(headers_path) and os.path.exists(chapter_path):
              print(f"📂 Processing Year {year}, Chapter {chapter}...")
              interactive_table_to_headers(
                  chapter_headers_json_path=headers_path,
                  chapter_json_path=chapter_path,
                  save_json_path=save_path
              )
          else:
              print(f"⚠️ Skipping Year {year}, Chapter {chapter} (files missing)")
# Out:
# 📂 Processing Year 2022, Chapter 10...
#
# === Table Name: תרשים 10א': שיעור אוכלוסיית הילדים בישראל, לפי יישובים בכל אשכול*
# חברתי-כלכלי / 2018 ===
# Candidate CSVs and their headers:
# 1. 1_10_2022: סידרה 1 | נתוני 2017: | 1     הנמוך ביותר | סידרה 1 | 1     הנמוך ביותר | 10     הגבוה ביותר | 10     הגבוה ביותר
# 2. 2_10_2022: סידרה 1 | נתוני 2017: | ילדים עולים | סידרה 1 | סך הכל | ערבים | יהודים | סך הכל
# 3. 13_10_2022: 2019 | 2020 | 2021 | נתוני 2017: | ערבים | סידרה 1 | יהודים | ערבים | סך הכל | יהודים
# 4. 7_10_2022: כלל הילדים | 2005.0 | 2007.0 | 2009.0 | 2010.0 | 2011.0 | 2012.0 | 2013.0 | 2014.0 | 2015.0
# 5. 8_10_2022: סידרה 1 | מתמכרים ושיקום מתמכרים | אמהות לילדים עד גיל שנתיים | משפחות שבראשן הורה עצמאי | דורשי עבודה או מקבלי שכר נמוך
# 6. 10_10_2022: סידרה 1 | 1998.0 | 2000.0 | 2005.0 | 2010.0 | 2011.0 | 2012.0 | 2013.0 | 2014.0 | 2015.0
# 7. 3_10_2022: 2019 | 2020 | 2021 | שכר | פיטורים | זכויות סוציאליות
# 8. 6_10_2022: 2020 | 2021 | כלל הילדים | ילדים יהודים | עוני ילדים | ילדים יהודים לא-חרדים | לפי הכנסה נטו | לפי הכנסה כלכלית | ילדים יהודים חרדים | שנה
# 9. 12_10_2022: עמודה1 | נתוני 2016: | ספרים, מחברות, כלי ומכשירי כתיבה | עמודה1 | גנים בחינוך חובה | משקי בית ללא ילדים | הוצאות אחרות | משקי בית עם ילדים | חטיבות ביניים | בתי ספר תיכוניים
# 10. 5_10_2022: לפני תשלומי העברה ומיסים | לאחר תשלומי העברה ומיסים | 2012 | 2013 | 2014 | 2015 | 2016 | 2017 | 2018 | כדי לשנות את הגודל של טווח נתוני תרשים, גרור את הפינה השמאלית התחתונה של הטווח.
# 11. 4_10_2022: סידרה 1 | נתוני 2017: | 1    הנמוך ביותר | סידרה 1 | ילדים ב 1    יישובים באשכול הנמוך ביותר | 10    הגבוה ביותר | ילדים היישובים באשכול הגבוה ביותר 10
# 12. 9_10_2022: סידרה 1 | 1990.0 | 1995.0 | 2000.0 | 2005.0 | 2010.0 | 2011.0 | 2012.0 | 2013.0 | 2014.0
# 13. 11_10_2022: חוגים ושיעורי עזר | צהרונים | מעונות יום, משפחתונים וגנים פרטים | עשירון תחתון | עשירון 2 | עשירון 3 | עשירון 4 | עשירון 5 | עשירון 6 | עשירון 7
#
# Enter the number of the CSV that matches this table (or 0 if unsure): 1
# ✅ Mapped תרשים 10א': שיעור אוכלוסיית הילדים בישראל, לפי יישובים בכל אשכול*
# חברתי-כלכלי / 2018 → 1_10_2022
#
# === Table Name: תרשים 10ב': שיעור הילדים בעשרת אשכולות היישובים המדורגים חברתית-כלכלית (אחוז מכלל אוכלוסיית האשכול) / 2018 ===
# Candidate CSVs and their headers:
# 1. 2_10_2022: סידרה 1 | נתוני 2017: | ילדים עולים | סידרה 1 | סך הכל | ערבים | יהודים | סך הכל
# 2. 13_10_2022: 2019 | 2020 | 2021 | נתוני 2017: | ערבים | סידרה 1 | יהודים | ערבים | סך הכל | יהודים
# 3. 7_10_2022: כלל הילדים | 2005.0 | 2007.0 | 2009.0 | 2010.0 | 2011.0 | 2012.0 | 2013.0 | 2014.0 | 2015.0
# 4. 8_10_2022: סידרה 1 | מתמכרים ושיקום מתמכרים | אמהות לילדים עד גיל שנתיים | משפחות שבראשן הורה עצמאי | דורשי עבודה או מקבלי שכר נמוך
# 5. 10_10_2022: סידרה 1 | 1998.0 | 2000.0 | 2005.0 | 2010.0 | 2011.0 | 2012.0 | 2013.0 | 2014.0 | 2015.0
# 6. 3_10_2022: 2019 | 2020 | 2021 | שכר | פיטורים | זכויות סוציאליות
# 7. 6_10_2022: 2020 | 2021 | כלל הילדים | ילדים יהודים | עוני ילדים | ילדים יהודים לא-חרדים | לפי הכנסה נטו | לפי הכנסה כלכלית | ילדים יהודים חרדים | שנה
# 8. 12_10_2022: עמודה1 | נתוני 2016: | ספרים, מחברות, כלי ומכשירי כתיבה | עמודה1 | גנים בחינוך חובה | משקי בית ללא ילדים | הוצאות אחרות | משקי בית עם ילדים | חטיבות ביניים | בתי ספר תיכוניים
# 9. 5_10_2022: לפני תשלומי העברה ומיסים | לאחר תשלומי העברה ומיסים | 2012 | 2013 | 2014 | 2015 | 2016 | 2017 | 2018 | כדי לשנות את הגודל של טווח נתוני תרשים, גרור את הפינה השמאלית התחתונה של הטווח.
# 10. 4_10_2022: סידרה 1 | נתוני 2017: | 1    הנמוך ביותר | סידרה 1 | ילדים ב 1    יישובים באשכול הנמוך ביותר | 10    הגבוה ביותר | ילדים היישובים באשכול הגבוה ביותר 10
# 11. 9_10_2022: סידרה 1 | 1990.0 | 1995.0 | 2000.0 | 2005.0 | 2010.0 | 2011.0 | 2012.0 | 2013.0 | 2014.0
# 12. 11_10_2022: חוגים ושיעורי עזר | צהרונים | מעונות יום, משפחתונים וגנים פרטים | עשירון תחתון | עשירון 2 | עשירון 3 | עשירון 4 | עשירון 5 | עשירון 6 | עשירון 7
#
# Enter the number of the CSV that matches this table (or 0 if unsure): 1
# ✅ Mapped תרשים 10ב': שיעור הילדים בעשרת אשכולות היישובים המדורגים חברתית-כלכלית (אחוז מכלל אוכלוסיית האשכול) / 2018 → 2_10_2022
#
# === Table Name: תרשים 10ג': תחולת העוני* בקרב ילדים (אחוזים) / 2021-2012 ===
# Candidate CSVs and their headers:
# 1. 13_10_2022: 2019 | 2020 | 2021 | נתוני 2017: | ערבים | סידרה 1 | יהודים | ערבים | סך הכל | יהודים
# 2. 7_10_2022: כלל הילדים | 2005.0 | 2007.0 | 2009.0 | 2010.0 | 2011.0 | 2012.0 | 2013.0 | 2014.0 | 2015.0
# 3. 8_10_2022: סידרה 1 | מתמכרים ושיקום מתמכרים | אמהות לילדים עד גיל שנתיים | משפחות שבראשן הורה עצמאי | דורשי עבודה או מקבלי שכר נמוך
# 4. 10_10_2022: סידרה 1 | 1998.0 | 2000.0 | 2005.0 | 2010.0 | 2011.0 | 2012.0 | 2013.0 | 2014.0 | 2015.0
# 5. 3_10_2022: 2019 | 2020 | 2021 | שכר | פיטורים | זכויות סוציאליות
# 6. 6_10_2022: 2020 | 2021 | כלל הילדים | ילדים יהודים | עוני ילדים | ילדים יהודים לא-חרדים | לפי הכנסה נטו | לפי הכנסה כלכלית | ילדים יהודים חרדים | שנה
# 7. 12_10_2022: עמודה1 | נתוני 2016: | ספרים, מחברות, כלי ומכשירי כתיבה | עמודה1 | גנים בחינוך חובה | משקי בית ללא ילדים | הוצאות אחרות | משקי בית עם ילדים | חטיבות ביניים | בתי ספר תיכוניים
# 8. 5_10_2022: לפני תשלומי העברה ומיסים | לאחר תשלומי העברה ומיסים | 2012 | 2013 | 2014 | 2015 | 2016 | 2017 | 2018 | כדי לשנות את הגודל של טווח נתוני תרשים, גרור את הפינה השמאלית התחתונה של הטווח.
# 9. 4_10_2022: סידרה 1 | נתוני 2017: | 1    הנמוך ביותר | סידרה 1 | ילדים ב 1    יישובים באשכול הנמוך ביותר | 10    הגבוה ביותר | ילדים היישובים באשכול הגבוה ביותר 10
# 10. 9_10_2022: סידרה 1 | 1990.0 | 1995.0 | 2000.0 | 2005.0 | 2010.0 | 2011.0 | 2012.0 | 2013.0 | 2014.0
# 11. 11_10_2022: חוגים ושיעורי עזר | צהרונים | מעונות יום, משפחתונים וגנים פרטים | עשירון תחתון | עשירון 2 | עשירון 3 | עשירון 4 | עשירון 5 | עשירון 6 | עשירון 7
#
# Enter the number of the CSV that matches this table (or 0 if unsure): 8
# ✅ Mapped תרשים 10ג': תחולת העוני* בקרב ילדים (אחוזים) / 2021-2012 → 5_10_2022
#
# === Table Name: תרשים 10ד': תחולת העוני בקרב ילדים לאחר תשלומי העברה, לפי מגזרים (באחוזים) / 2021-2020 ===
# Candidate CSVs and their headers:
# 1. 13_10_2022: 2019 | 2020 | 2021 | נתוני 2017: | ערבים | סידרה 1 | יהודים | ערבים | סך הכל | יהודים
# 2. 7_10_2022: כלל הילדים | 2005.0 | 2007.0 | 2009.0 | 2010.0 | 2011.0 | 2012.0 | 2013.0 | 2014.0 | 2015.0
# 3. 8_10_2022: סידרה 1 | מתמכרים ושיקום מתמכרים | אמהות לילדים עד גיל שנתיים | משפחות שבראשן הורה עצמאי | דורשי עבודה או מקבלי שכר נמוך
# 4. 10_10_2022: סידרה 1 | 1998.0 | 2000.0 | 2005.0 | 2010.0 | 2011.0 | 2012.0 | 2013.0 | 2014.0 | 2015.0
# 5. 3_10_2022: 2019 | 2020 | 2021 | שכר | פיטורים | זכויות סוציאליות
# 6. 6_10_2022: 2020 | 2021 | כלל הילדים | ילדים יהודים | עוני ילדים | ילדים יהודים לא-חרדים | לפי הכנסה נטו | לפי הכנסה כלכלית | ילדים יהודים חרדים | שנה
# 7. 12_10_2022: עמודה1 | נתוני 2016: | ספרים, מחברות, כלי ומכשירי כתיבה | עמודה1 | גנים בחינוך חובה | משקי בית ללא ילדים | הוצאות אחרות | משקי בית עם ילדים | חטיבות ביניים | בתי ספר תיכוניים
# 8. 4_10_2022: סידרה 1 | נתוני 2017: | 1    הנמוך ביותר | סידרה 1 | ילדים ב 1    יישובים באשכול הנמוך ביותר | 10    הגבוה ביותר | ילדים היישובים באשכול הגבוה ביותר 10
# 9. 9_10_2022: סידרה 1 | 1990.0 | 1995.0 | 2000.0 | 2005.0 | 2010.0 | 2011.0 | 2012.0 | 2013.0 | 2014.0
# 10. 11_10_2022: חוגים ושיעורי עזר | צהרונים | מעונות יום, משפחתונים וגנים פרטים | עשירון תחתון | עשירון 2 | עשירון 3 | עשירון 4 | עשירון 5 | עשירון 6 | עשירון 7
#
# Enter the number of the CSV that matches this table (or 0 if unsure): 6
# ✅ Mapped תרשים 10ד': תחולת העוני בקרב ילדים לאחר תשלומי העברה, לפי מגזרים (באחוזים) / 2021-2020 → 6_10_2022
#
# === Table Name: תרשים 10ה': שיעור הילדים במשפחות המקבלות גמלה להבטחת הכנסה
# מכלל הילדים / 2021-2005* ===
# Candidate CSVs and their headers:
# 1. 13_10_2022: 2019 | 2020 | 2021 | נתוני 2017: | ערבים | סידרה 1 | יהודים | ערבים | סך הכל | יהודים
# 2. 7_10_2022: כלל הילדים | 2005.0 | 2007.0 | 2009.0 | 2010.0 | 2011.0 | 2012.0 | 2013.0 | 2014.0 | 2015.0
# 3. 8_10_2022: סידרה 1 | מתמכרים ושיקום מתמכרים | אמהות לילדים עד גיל שנתיים | משפחות שבראשן הורה עצמאי | דורשי עבודה או מקבלי שכר נמוך
# 4. 10_10_2022: סידרה 1 | 1998.0 | 2000.0 | 2005.0 | 2010.0 | 2011.0 | 2012.0 | 2013.0 | 2014.0 | 2015.0
# 5. 3_10_2022: 2019 | 2020 | 2021 | שכר | פיטורים | זכויות סוציאליות
# 6. 12_10_2022: עמודה1 | נתוני 2016: | ספרים, מחברות, כלי ומכשירי כתיבה | עמודה1 | גנים בחינוך חובה | משקי בית ללא ילדים | הוצאות אחרות | משקי בית עם ילדים | חטיבות ביניים | בתי ספר תיכוניים
# 7. 4_10_2022: סידרה 1 | נתוני 2017: | 1    הנמוך ביותר | סידרה 1 | ילדים ב 1    יישובים באשכול הנמוך ביותר | 10    הגבוה ביותר | ילדים היישובים באשכול הגבוה ביותר 10
# 8. 9_10_2022: סידרה 1 | 1990.0 | 1995.0 | 2000.0 | 2005.0 | 2010.0 | 2011.0 | 2012.0 | 2013.0 | 2014.0
# 9. 11_10_2022: חוגים ושיעורי עזר | צהרונים | מעונות יום, משפחתונים וגנים פרטים | עשירון תחתון | עשירון 2 | עשירון 3 | עשירון 4 | עשירון 5 | עשירון 6 | עשירון 7
#
# Enter the number of the CSV that matches this table (or 0 if unsure): 2
# ✅ Mapped תרשים 10ה': שיעור הילדים במשפחות המקבלות גמלה להבטחת הכנסה
# מכלל הילדים / 2021-2005* → 7_10_2022
#
# === Table Name: תרשים 10ו': שיעור הילדים החיים במשפחות המקבלות גמלה להבטחת הכנסה, לפי עילות נבחרות* / 2021 ===
# Candidate CSVs and their headers:
# 1. 13_10_2022: 2019 | 2020 | 2021 | נתוני 2017: | ערבים | סידרה 1 | יהודים | ערבים | סך הכל | יהודים
# 2. 8_10_2022: סידרה 1 | מתמכרים ושיקום מתמכרים | אמהות לילדים עד גיל שנתיים | משפחות שבראשן הורה עצמאי | דורשי עבודה או מקבלי שכר נמוך
# 3. 10_10_2022: סידרה 1 | 1998.0 | 2000.0 | 2005.0 | 2010.0 | 2011.0 | 2012.0 | 2013.0 | 2014.0 | 2015.0
# 4. 3_10_2022: 2019 | 2020 | 2021 | שכר | פיטורים | זכויות סוציאליות
# 5. 12_10_2022: עמודה1 | נתוני 2016: | ספרים, מחברות, כלי ומכשירי כתיבה | עמודה1 | גנים בחינוך חובה | משקי בית ללא ילדים | הוצאות אחרות | משקי בית עם ילדים | חטיבות ביניים | בתי ספר תיכוניים
# 6. 4_10_2022: סידרה 1 | נתוני 2017: | 1    הנמוך ביותר | סידרה 1 | ילדים ב 1    יישובים באשכול הנמוך ביותר | 10    הגבוה ביותר | ילדים היישובים באשכול הגבוה ביותר 10
# 7. 9_10_2022: סידרה 1 | 1990.0 | 1995.0 | 2000.0 | 2005.0 | 2010.0 | 2011.0 | 2012.0 | 2013.0 | 2014.0
# 8. 11_10_2022: חוגים ושיעורי עזר | צהרונים | מעונות יום, משפחתונים וגנים פרטים | עשירון תחתון | עשירון 2 | עשירון 3 | עשירון 4 | עשירון 5 | עשירון 6 | עשירון 7
#
# Enter the number of the CSV that matches this table (or 0 if unsure): 2
# ✅ Mapped תרשים 10ו': שיעור הילדים החיים במשפחות המקבלות גמלה להבטחת הכנסה, לפי עילות נבחרות* / 2021 → 8_10_2022
#
# === Table Name: תרשים 10ז': שיעור הילדים שחיו במשק בית ללא מועסקים, מכלל הילדים,
# לפי קבוצת אוכלוסיה / 2021-2019 ===
# Candidate CSVs and their headers:
# 1. 13_10_2022: 2019 | 2020 | 2021 | נתוני 2017: | ערבים | סידרה 1 | יהודים | ערבים | סך הכל | יהודים
# 2. 10_10_2022: סידרה 1 | 1998.0 | 2000.0 | 2005.0 | 2010.0 | 2011.0 | 2012.0 | 2013.0 | 2014.0 | 2015.0
# 3. 3_10_2022: 2019 | 2020 | 2021 | שכר | פיטורים | זכויות סוציאליות
# 4. 12_10_2022: עמודה1 | נתוני 2016: | ספרים, מחברות, כלי ומכשירי כתיבה | עמודה1 | גנים בחינוך חובה | משקי בית ללא ילדים | הוצאות אחרות | משקי בית עם ילדים | חטיבות ביניים | בתי ספר תיכוניים
# 5. 4_10_2022: סידרה 1 | נתוני 2017: | 1    הנמוך ביותר | סידרה 1 | ילדים ב 1    יישובים באשכול הנמוך ביותר | 10    הגבוה ביותר | ילדים היישובים באשכול הגבוה ביותר 10
# 6. 9_10_2022: סידרה 1 | 1990.0 | 1995.0 | 2000.0 | 2005.0 | 2010.0 | 2011.0 | 2012.0 | 2013.0 | 2014.0
# 7. 11_10_2022: חוגים ושיעורי עזר | צהרונים | מעונות יום, משפחתונים וגנים פרטים | עשירון תחתון | עשירון 2 | עשירון 3 | עשירון 4 | עשירון 5 | עשירון 6 | עשירון 7
#
# Enter the number of the CSV that matches this table (or 0 if unsure): 1
# ✅ Mapped תרשים 10ז': שיעור הילדים שחיו במשק בית ללא מועסקים, מכלל הילדים,
# לפי קבוצת אוכלוסיה / 2021-2019 → 13_10_2022
#
# === Table Name: תרשים 10ח': שיעור הילדים (וילדים עולים) שחיו במשפחות בהן לפחות הורה אחד מקבל דמי אבטלה / 2021 ===
# Candidate CSVs and their headers:
# 1. 10_10_2022: סידרה 1 | 1998.0 | 2000.0 | 2005.0 | 2010.0 | 2011.0 | 2012.0 | 2013.0 | 2014.0 | 2015.0
# 2. 3_10_2022: 2019 | 2020 | 2021 | שכר | פיטורים | זכויות סוציאליות
# 3. 12_10_2022: עמודה1 | נתוני 2016: | ספרים, מחברות, כלי ומכשירי כתיבה | עמודה1 | גנים בחינוך חובה | משקי בית ללא ילדים | הוצאות אחרות | משקי בית עם ילדים | חטיבות ביניים | בתי ספר תיכוניים
# 4. 4_10_2022: סידרה 1 | נתוני 2017: | 1    הנמוך ביותר | סידרה 1 | ילדים ב 1    יישובים באשכול הנמוך ביותר | 10    הגבוה ביותר | ילדים היישובים באשכול הגבוה ביותר 10
# 5. 9_10_2022: סידרה 1 | 1990.0 | 1995.0 | 2000.0 | 2005.0 | 2010.0 | 2011.0 | 2012.0 | 2013.0 | 2014.0
# 6. 11_10_2022: חוגים ושיעורי עזר | צהרונים | מעונות יום, משפחתונים וגנים פרטים | עשירון תחתון | עשירון 2 | עשירון 3 | עשירון 4 | עשירון 5 | עשירון 6 | עשירון 7
#
# Enter the number of the CSV that matches this table (or 0 if unsure): 4
# ✅ Mapped תרשים 10ח': שיעור הילדים (וילדים עולים) שחיו במשפחות בהן לפחות הורה אחד מקבל דמי אבטלה / 2021 → 4_10_2022
#
# === Table Name: תרשים 10ט': שיעור בני 17-15 שעובדים* מקבוצת בני גילם / 2021-2000 ===
# Candidate CSVs and their headers:
# 1. 10_10_2022: סידרה 1 | 1998.0 | 2000.0 | 2005.0 | 2010.0 | 2011.0 | 2012.0 | 2013.0 | 2014.0 | 2015.0
# 2. 3_10_2022: 2019 | 2020 | 2021 | שכר | פיטורים | זכויות סוציאליות
# 3. 12_10_2022: עמודה1 | נתוני 2016: | ספרים, מחברות, כלי ומכשירי כתיבה | עמודה1 | גנים בחינוך חובה | משקי בית ללא ילדים | הוצאות אחרות | משקי בית עם ילדים | חטיבות ביניים | בתי ספר תיכוניים
# 4. 9_10_2022: סידרה 1 | 1990.0 | 1995.0 | 2000.0 | 2005.0 | 2010.0 | 2011.0 | 2012.0 | 2013.0 | 2014.0
# 5. 11_10_2022: חוגים ושיעורי עזר | צהרונים | מעונות יום, משפחתונים וגנים פרטים | עשירון תחתון | עשירון 2 | עשירון 3 | עשירון 4 | עשירון 5 | עשירון 6 | עשירון 7
#
# Enter the number of the CSV that matches this table (or 0 if unsure): 4
# ✅ Mapped תרשים 10ט': שיעור בני 17-15 שעובדים* מקבוצת בני גילם / 2021-2000 → 9_10_2022
#
# === Table Name: תרשים 10י': פילוח הפניות להסתדרות הנוער העובד והלומד, לפי סעיפי תלונה עיקריים / 2021-2019 ===
# Candidate CSVs and their headers:
# 1. 10_10_2022: סידרה 1 | 1998.0 | 2000.0 | 2005.0 | 2010.0 | 2011.0 | 2012.0 | 2013.0 | 2014.0 | 2015.0
# 2. 3_10_2022: 2019 | 2020 | 2021 | שכר | פיטורים | זכויות סוציאליות
# 3. 12_10_2022: עמודה1 | נתוני 2016: | ספרים, מחברות, כלי ומכשירי כתיבה | עמודה1 | גנים בחינוך חובה | משקי בית ללא ילדים | הוצאות אחרות | משקי בית עם ילדים | חטיבות ביניים | בתי ספר תיכוניים
# 4. 11_10_2022: חוגים ושיעורי עזר | צהרונים | מעונות יום, משפחתונים וגנים פרטים | עשירון תחתון | עשירון 2 | עשירון 3 | עשירון 4 | עשירון 5 | עשירון 6 | עשירון 7
#
# Enter the number of the CSV that matches this table (or 0 if unsure): 2
# ✅ Mapped תרשים 10י': פילוח הפניות להסתדרות הנוער העובד והלומד, לפי סעיפי תלונה עיקריים / 2021-2019 → 3_10_2022
#
# === Table Name: תרשים 10יא': מספר כתבי אישום שהגיש מינהל ההסדרה והאכיפה במשרד העבודה, הרווחה והשירותים החברתיים/ 2021-1998 ===
# Candidate CSVs and their headers:
# 1. 10_10_2022: סידרה 1 | 1998.0 | 2000.0 | 2005.0 | 2010.0 | 2011.0 | 2012.0 | 2013.0 | 2014.0 | 2015.0
# 2. 12_10_2022: עמודה1 | נתוני 2016: | ספרים, מחברות, כלי ומכשירי כתיבה | עמודה1 | גנים בחינוך חובה | משקי בית ללא ילדים | הוצאות אחרות | משקי בית עם ילדים | חטיבות ביניים | בתי ספר תיכוניים
# 3. 11_10_2022: חוגים ושיעורי עזר | צהרונים | מעונות יום, משפחתונים וגנים פרטים | עשירון תחתון | עשירון 2 | עשירון 3 | עשירון 4 | עשירון 5 | עשירון 6 | עשירון 7
#
# Enter the number of the CSV that matches this table (or 0 if unsure): 1
# ✅ Mapped תרשים 10יא': מספר כתבי אישום שהגיש מינהל ההסדרה והאכיפה במשרד העבודה, הרווחה והשירותים החברתיים/ 2021-1998 → 10_10_2022
#
# === Table Name: תרשים 10יב': הוצאה חודשית ממוצעת של משקי בית עם ילדים על סעיפי חינוך נבחרים, לפי עשירוני הכנסה נטו לנפש סטנדרטית / 2018 ===
# Candidate CSVs and their headers:
# 1. 12_10_2022: עמודה1 | נתוני 2016: | ספרים, מחברות, כלי ומכשירי כתיבה | עמודה1 | גנים בחינוך חובה | משקי בית ללא ילדים | הוצאות אחרות | משקי בית עם ילדים | חטיבות ביניים | בתי ספר תיכוניים
# 2. 11_10_2022: חוגים ושיעורי עזר | צהרונים | מעונות יום, משפחתונים וגנים פרטים | עשירון תחתון | עשירון 2 | עשירון 3 | עשירון 4 | עשירון 5 | עשירון 6 | עשירון 7
#
# Enter the number of the CSV that matches this table (or 0 if unsure): 2
# ✅ Mapped תרשים 10יב': הוצאה חודשית ממוצעת של משקי בית עם ילדים על סעיפי חינוך נבחרים, לפי עשירוני הכנסה נטו לנפש סטנדרטית / 2018 → 11_10_2022
#
# === Table Name: תרשים 10יג': ההתפלגות ההוצאה החודשית לחינוך במשקי בית עם ילדים / 2018 ===
# Candidate CSVs and their headers:
# 1. 12_10_2022: עמודה1 | נתוני 2016: | ספרים, מחברות, כלי ומכשירי כתיבה | עמודה1 | גנים בחינוך חובה | משקי בית ללא ילדים | הוצאות אחרות | משקי בית עם ילדים | חטיבות ביניים | בתי ספר תיכוניים
#
# Enter the number of the CSV that matches this table (or 0 if unsure): 1
# ✅ Mapped תרשים 10יג': ההתפלגות ההוצאה החודשית לחינוך במשקי בית עם ילדים / 2018 → 12_10_2022
#
# ✅ Alignment finished. Saved mapping to: /content/excel_and_json_2019_2021_2024/2022/10/aligned_mapping.json
# 📂 Processing Year 2022, Chapter 11...
#
# === Table Name: תרשים 11א': החלטות של בתי משפט שלום לנוער בעניין הכרזת קטין כנזקק* (אחוזים) / 2021 ===
# Candidate CSVs and their headers:
# 1. 2_11_2022: עמודה1 | הקטין נמצא נזקק | דחייה/העברה/מחיקה/אחר
# 2. 1_11_2022: הוגשו | אושרו | 1997 | 2000 | 2005 | 2020 | 2021
#
# Enter the number of the CSV that matches this table (or 0 if unsure): 1
# ✅ Mapped תרשים 11א': החלטות של בתי משפט שלום לנוער בעניין הכרזת קטין כנזקק* (אחוזים) / 2021 → 2_11_2022
#
# === Table Name: תרשים 11ב': מספר הבקשות לאישור נישואי קטינות שהוגשו לבית המשפט לענייני משפחה ומספר הבקשות שאושרו / 2021-1997 ===
# Candidate CSVs and their headers:
# 1. 1_11_2022: הוגשו | אושרו | 1997 | 2000 | 2005 | 2020 | 2021
#
# Enter the number of the CSV that matches this table (or 0 if unsure): 1
# ✅ Mapped תרשים 11ב': מספר הבקשות לאישור נישואי קטינות שהוגשו לבית המשפט לענייני משפחה ומספר הבקשות שאושרו / 2021-1997 → 1_11_2022
#
# ✅ Alignment finished. Saved mapping to: /content/excel_and_json_2019_2021_2024/2022/11/aligned_mapping.json
# 📂 Processing Year 2022, Chapter 12...
#
# === Table Name: תרשים 12א': התפלגות קטינים חשודים ונילונים* / 2021-2010 ===
# Candidate CSVs and their headers:
# 1. 11_12_2022: סידרה 1 | 2010 | 2011 | 2012 | 2013 | 2014 | 2015 | 2016 | 2017 | 2018
# 2. 3_12_2022: פלילי | ט.מ. | סה"כ | 2005 | 2010 | 2011 | 2012 | 2013 | 2014 | 2015
# 3. 14_12_2022: עד 14 | קליטת אסירים קטינים תושבי ישראל לפי גיל | גיל | 2018.0 | עד גיל 14 | מ-14 עד 16 | מ-16 עד - 18 | סה"כ
# 4. 15_12_2022: סה"כ | עצורים | שפוטים | עד 14 | נתונים ל-2019 | עצורים | שפוטים | סה"כ | עצורים | שפוטים
# 5. 10_12_2022: גיל 12 | גיל 13 | גיל 14 | גיל 15 | גיל 16 | גיל 17 | סך הכל | עמודה1 | 2010 | 2011
# 6. 2_12_2022: שנה | אחוז הקטינים | 2005 | 2010 | 2011 | 2012 | 2013 | 2014 | 2015 | 2016
# 7. 12_12_2022: בימ"ש שלום לנוער | בימ"ש מחוזי לנוער | בימ"ש עליון | תעבורה | הליכים ללא בימ"ש | ירושלים | דרום** | מרכז | תל אביב | 1946.0
# 8. 1_12_2022: שנה | נילונים | חשודים | סך הכל | 2011.0 | 2012.0 | 2013.0 | נילונים | חשודים | נילונים
# 9. 5_12_2022: עמודה1 | נתונים | רישוי | חיי אדם | אחר** | כלכליות | תנועה | מרמה | מין | ביטחון
# 10. 13_12_2022: הרשעה | אי-הרשעה | ערבים (שאינם תושבי ישראל) | ערבים (תושבי ישראל) | יהודים
# 11. 4_12_2022: תיקי ט.מ. | תיקים פליליים | סידרה 3 | 2006.0 | 2007.0 | 2008.0 | 2009.0 | 2010.0 | 2011.0 | 2012.0
# 12. 6_12_2022: נשיאת סכין/אגרופן | גרימת נזק לרכוש בזדון | איומים | 2010.0 | 2011.0 | 2012.0 | 2013.0 | 2014.0 | 2015.0 | 2016.0
# 13. 7_12_2022: שנה | גיל 12 | גיל 13 | גיל 14 | גיל 15 | גיל 16 | גיל 17 | סך כל | סה"כ | סך הכל
# 14. 9_12_2022: תיקי ט.מ. | תיקים פליליים | סך הכל | שיעור לאלף בקבוצת הגיל | 2010.0 | 2011.0 | 2012.0 | 2013.0 | 2014.0 | 2015.0
# 15. 8_12_2022: עמודה1 | גיל 12 | גיל 13 | גיל 14 | גיל 15 | גיל 16 | גיל 17
# 16. 16_12_2022: עמודה2 | עמודה1 | עד 14
#
# Enter the number of the CSV that matches this table (or 0 if unsure): 8
# ✅ Mapped תרשים 12א': התפלגות קטינים חשודים ונילונים* / 2021-2010 → 1_12_2022
#
# === Table Name: תרשים 12ב': שיעור הקטינים החשודים* עם תיקים פליליים** מכלל החשודים*** / 2021-2005 ===
# Candidate CSVs and their headers:
# 1. 11_12_2022: סידרה 1 | 2010 | 2011 | 2012 | 2013 | 2014 | 2015 | 2016 | 2017 | 2018
# 2. 3_12_2022: פלילי | ט.מ. | סה"כ | 2005 | 2010 | 2011 | 2012 | 2013 | 2014 | 2015
# 3. 14_12_2022: עד 14 | קליטת אסירים קטינים תושבי ישראל לפי גיל | גיל | 2018.0 | עד גיל 14 | מ-14 עד 16 | מ-16 עד - 18 | סה"כ
# 4. 15_12_2022: סה"כ | עצורים | שפוטים | עד 14 | נתונים ל-2019 | עצורים | שפוטים | סה"כ | עצורים | שפוטים
# 5. 10_12_2022: גיל 12 | גיל 13 | גיל 14 | גיל 15 | גיל 16 | גיל 17 | סך הכל | עמודה1 | 2010 | 2011
# 6. 2_12_2022: שנה | אחוז הקטינים | 2005 | 2010 | 2011 | 2012 | 2013 | 2014 | 2015 | 2016
# 7. 12_12_2022: בימ"ש שלום לנוער | בימ"ש מחוזי לנוער | בימ"ש עליון | תעבורה | הליכים ללא בימ"ש | ירושלים | דרום** | מרכז | תל אביב | 1946.0
# 8. 5_12_2022: עמודה1 | נתונים | רישוי | חיי אדם | אחר** | כלכליות | תנועה | מרמה | מין | ביטחון
# 9. 13_12_2022: הרשעה | אי-הרשעה | ערבים (שאינם תושבי ישראל) | ערבים (תושבי ישראל) | יהודים
# 10. 4_12_2022: תיקי ט.מ. | תיקים פליליים | סידרה 3 | 2006.0 | 2007.0 | 2008.0 | 2009.0 | 2010.0 | 2011.0 | 2012.0
# 11. 6_12_2022: נשיאת סכין/אגרופן | גרימת נזק לרכוש בזדון | איומים | 2010.0 | 2011.0 | 2012.0 | 2013.0 | 2014.0 | 2015.0 | 2016.0
# 12. 7_12_2022: שנה | גיל 12 | גיל 13 | גיל 14 | גיל 15 | גיל 16 | גיל 17 | סך כל | סה"כ | סך הכל
# 13. 9_12_2022: תיקי ט.מ. | תיקים פליליים | סך הכל | שיעור לאלף בקבוצת הגיל | 2010.0 | 2011.0 | 2012.0 | 2013.0 | 2014.0 | 2015.0
# 14. 8_12_2022: עמודה1 | גיל 12 | גיל 13 | גיל 14 | גיל 15 | גיל 16 | גיל 17
# 15. 16_12_2022: עמודה2 | עמודה1 | עד 14
#
# Enter the number of the CSV that matches this table (or 0 if unsure): 6
# ✅ Mapped תרשים 12ב': שיעור הקטינים החשודים* עם תיקים פליליים** מכלל החשודים*** / 2021-2005 → 2_12_2022
#
# === Table Name: תרשים 12ג': התפלגות תיקים פליליים ותיקי ט.מ. בעבירות שמעורבים בהם קטינים חשודים*, לפי סוג תיק / 2021-2005 ===
# Candidate CSVs and their headers:
# 1. 11_12_2022: סידרה 1 | 2010 | 2011 | 2012 | 2013 | 2014 | 2015 | 2016 | 2017 | 2018
# 2. 3_12_2022: פלילי | ט.מ. | סה"כ | 2005 | 2010 | 2011 | 2012 | 2013 | 2014 | 2015
# 3. 14_12_2022: עד 14 | קליטת אסירים קטינים תושבי ישראל לפי גיל | גיל | 2018.0 | עד גיל 14 | מ-14 עד 16 | מ-16 עד - 18 | סה"כ
# 4. 15_12_2022: סה"כ | עצורים | שפוטים | עד 14 | נתונים ל-2019 | עצורים | שפוטים | סה"כ | עצורים | שפוטים
# 5. 10_12_2022: גיל 12 | גיל 13 | גיל 14 | גיל 15 | גיל 16 | גיל 17 | סך הכל | עמודה1 | 2010 | 2011
# 6. 12_12_2022: בימ"ש שלום לנוער | בימ"ש מחוזי לנוער | בימ"ש עליון | תעבורה | הליכים ללא בימ"ש | ירושלים | דרום** | מרכז | תל אביב | 1946.0
# 7. 5_12_2022: עמודה1 | נתונים | רישוי | חיי אדם | אחר** | כלכליות | תנועה | מרמה | מין | ביטחון
# 8. 13_12_2022: הרשעה | אי-הרשעה | ערבים (שאינם תושבי ישראל) | ערבים (תושבי ישראל) | יהודים
# 9. 4_12_2022: תיקי ט.מ. | תיקים פליליים | סידרה 3 | 2006.0 | 2007.0 | 2008.0 | 2009.0 | 2010.0 | 2011.0 | 2012.0
# 10. 6_12_2022: נשיאת סכין/אגרופן | גרימת נזק לרכוש בזדון | איומים | 2010.0 | 2011.0 | 2012.0 | 2013.0 | 2014.0 | 2015.0 | 2016.0
# 11. 7_12_2022: שנה | גיל 12 | גיל 13 | גיל 14 | גיל 15 | גיל 16 | גיל 17 | סך כל | סה"כ | סך הכל
# 12. 9_12_2022: תיקי ט.מ. | תיקים פליליים | סך הכל | שיעור לאלף בקבוצת הגיל | 2010.0 | 2011.0 | 2012.0 | 2013.0 | 2014.0 | 2015.0
# 13. 8_12_2022: עמודה1 | גיל 12 | גיל 13 | גיל 14 | גיל 15 | גיל 16 | גיל 17
# 14. 16_12_2022: עמודה2 | עמודה1 | עד 14
#
# Enter the number of the CSV that matches this table (or 0 if unsure): 2
# ✅ Mapped תרשים 12ג': התפלגות תיקים פליליים ותיקי ט.מ. בעבירות שמעורבים בהם קטינים חשודים*, לפי סוג תיק / 2021-2005 → 3_12_2022
#
# === Table Name: תרשים 12ד': התפלגות תיקים שנפתחו לקטינים* החשודים בביצוע עבירות נגד קטינים, לפי שנה / 2021-2006 ===
# Candidate CSVs and their headers:
# 1. 11_12_2022: סידרה 1 | 2010 | 2011 | 2012 | 2013 | 2014 | 2015 | 2016 | 2017 | 2018
# 2. 14_12_2022: עד 14 | קליטת אסירים קטינים תושבי ישראל לפי גיל | גיל | 2018.0 | עד גיל 14 | מ-14 עד 16 | מ-16 עד - 18 | סה"כ
# 3. 15_12_2022: סה"כ | עצורים | שפוטים | עד 14 | נתונים ל-2019 | עצורים | שפוטים | סה"כ | עצורים | שפוטים
# 4. 10_12_2022: גיל 12 | גיל 13 | גיל 14 | גיל 15 | גיל 16 | גיל 17 | סך הכל | עמודה1 | 2010 | 2011
# 5. 12_12_2022: בימ"ש שלום לנוער | בימ"ש מחוזי לנוער | בימ"ש עליון | תעבורה | הליכים ללא בימ"ש | ירושלים | דרום** | מרכז | תל אביב | 1946.0
# 6. 5_12_2022: עמודה1 | נתונים | רישוי | חיי אדם | אחר** | כלכליות | תנועה | מרמה | מין | ביטחון
# 7. 13_12_2022: הרשעה | אי-הרשעה | ערבים (שאינם תושבי ישראל) | ערבים (תושבי ישראל) | יהודים
# 8. 4_12_2022: תיקי ט.מ. | תיקים פליליים | סידרה 3 | 2006.0 | 2007.0 | 2008.0 | 2009.0 | 2010.0 | 2011.0 | 2012.0
# 9. 6_12_2022: נשיאת סכין/אגרופן | גרימת נזק לרכוש בזדון | איומים | 2010.0 | 2011.0 | 2012.0 | 2013.0 | 2014.0 | 2015.0 | 2016.0
# 10. 7_12_2022: שנה | גיל 12 | גיל 13 | גיל 14 | גיל 15 | גיל 16 | גיל 17 | סך כל | סה"כ | סך הכל
# 11. 9_12_2022: תיקי ט.מ. | תיקים פליליים | סך הכל | שיעור לאלף בקבוצת הגיל | 2010.0 | 2011.0 | 2012.0 | 2013.0 | 2014.0 | 2015.0
# 12. 8_12_2022: עמודה1 | גיל 12 | גיל 13 | גיל 14 | גיל 15 | גיל 16 | גיל 17
# 13. 16_12_2022: עמודה2 | עמודה1 | עד 14
#
# Enter the number of the CSV that matches this table (or 0 if unsure): 8
# ✅ Mapped תרשים 12ד': התפלגות תיקים שנפתחו לקטינים* החשודים בביצוע עבירות נגד קטינים, לפי שנה / 2021-2006 → 4_12_2022
#
# === Table Name: תרשים 12ה': שיעור הקטינים החשודים עם תיקים פליליים*, לפי סוג עבירה / 2021 ===
# Candidate CSVs and their headers:
# 1. 11_12_2022: סידרה 1 | 2010 | 2011 | 2012 | 2013 | 2014 | 2015 | 2016 | 2017 | 2018
# 2. 14_12_2022: עד 14 | קליטת אסירים קטינים תושבי ישראל לפי גיל | גיל | 2018.0 | עד גיל 14 | מ-14 עד 16 | מ-16 עד - 18 | סה"כ
# 3. 15_12_2022: סה"כ | עצורים | שפוטים | עד 14 | נתונים ל-2019 | עצורים | שפוטים | סה"כ | עצורים | שפוטים
# 4. 10_12_2022: גיל 12 | גיל 13 | גיל 14 | גיל 15 | גיל 16 | גיל 17 | סך הכל | עמודה1 | 2010 | 2011
# 5. 12_12_2022: בימ"ש שלום לנוער | בימ"ש מחוזי לנוער | בימ"ש עליון | תעבורה | הליכים ללא בימ"ש | ירושלים | דרום** | מרכז | תל אביב | 1946.0
# 6. 5_12_2022: עמודה1 | נתונים | רישוי | חיי אדם | אחר** | כלכליות | תנועה | מרמה | מין | ביטחון
# 7. 13_12_2022: הרשעה | אי-הרשעה | ערבים (שאינם תושבי ישראל) | ערבים (תושבי ישראל) | יהודים
# 8. 6_12_2022: נשיאת סכין/אגרופן | גרימת נזק לרכוש בזדון | איומים | 2010.0 | 2011.0 | 2012.0 | 2013.0 | 2014.0 | 2015.0 | 2016.0
# 9. 7_12_2022: שנה | גיל 12 | גיל 13 | גיל 14 | גיל 15 | גיל 16 | גיל 17 | סך כל | סה"כ | סך הכל
# 10. 9_12_2022: תיקי ט.מ. | תיקים פליליים | סך הכל | שיעור לאלף בקבוצת הגיל | 2010.0 | 2011.0 | 2012.0 | 2013.0 | 2014.0 | 2015.0
# 11. 8_12_2022: עמודה1 | גיל 12 | גיל 13 | גיל 14 | גיל 15 | גיל 16 | גיל 17
# 12. 16_12_2022: עמודה2 | עמודה1 | עד 14
#
# Enter the number of the CSV that matches this table (or 0 if unsure): 6
# ✅ Mapped תרשים 12ה': שיעור הקטינים החשודים עם תיקים פליליים*, לפי סוג עבירה / 2021 → 5_12_2022
#
# === Table Name: תרשים 12ו': שיעור התיקים שנפתחו לקטינים שנחשדו בביצוע עבירות אלימות נבחרות במוסדות חינוך (שיעור ל-10,000 בקבוצת הגיל) / 2020-2010 ===
# Candidate CSVs and their headers:
# 1. 11_12_2022: סידרה 1 | 2010 | 2011 | 2012 | 2013 | 2014 | 2015 | 2016 | 2017 | 2018
# 2. 14_12_2022: עד 14 | קליטת אסירים קטינים תושבי ישראל לפי גיל | גיל | 2018.0 | עד גיל 14 | מ-14 עד 16 | מ-16 עד - 18 | סה"כ
# 3. 15_12_2022: סה"כ | עצורים | שפוטים | עד 14 | נתונים ל-2019 | עצורים | שפוטים | סה"כ | עצורים | שפוטים
# 4. 10_12_2022: גיל 12 | גיל 13 | גיל 14 | גיל 15 | גיל 16 | גיל 17 | סך הכל | עמודה1 | 2010 | 2011
# 5. 12_12_2022: בימ"ש שלום לנוער | בימ"ש מחוזי לנוער | בימ"ש עליון | תעבורה | הליכים ללא בימ"ש | ירושלים | דרום** | מרכז | תל אביב | 1946.0
# 6. 13_12_2022: הרשעה | אי-הרשעה | ערבים (שאינם תושבי ישראל) | ערבים (תושבי ישראל) | יהודים
# 7. 6_12_2022: נשיאת סכין/אגרופן | גרימת נזק לרכוש בזדון | איומים | 2010.0 | 2011.0 | 2012.0 | 2013.0 | 2014.0 | 2015.0 | 2016.0
# 8. 7_12_2022: שנה | גיל 12 | גיל 13 | גיל 14 | גיל 15 | גיל 16 | גיל 17 | סך כל | סה"כ | סך הכל
# 9. 9_12_2022: תיקי ט.מ. | תיקים פליליים | סך הכל | שיעור לאלף בקבוצת הגיל | 2010.0 | 2011.0 | 2012.0 | 2013.0 | 2014.0 | 2015.0
# 10. 8_12_2022: עמודה1 | גיל 12 | גיל 13 | גיל 14 | גיל 15 | גיל 16 | גיל 17
# 11. 16_12_2022: עמודה2 | עמודה1 | עד 14
#
# Enter the number of the CSV that matches this table (or 0 if unsure): 7
# ✅ Mapped תרשים 12ו': שיעור התיקים שנפתחו לקטינים שנחשדו בביצוע עבירות אלימות נבחרות במוסדות חינוך (שיעור ל-10,000 בקבוצת הגיל) / 2020-2010 → 6_12_2022
#
# === Table Name: תרשים 12ז': מספר הקטינים העצורים, לפי שנה וגיל / 2021-2011 ===
# Candidate CSVs and their headers:
# 1. 11_12_2022: סידרה 1 | 2010 | 2011 | 2012 | 2013 | 2014 | 2015 | 2016 | 2017 | 2018
# 2. 14_12_2022: עד 14 | קליטת אסירים קטינים תושבי ישראל לפי גיל | גיל | 2018.0 | עד גיל 14 | מ-14 עד 16 | מ-16 עד - 18 | סה"כ
# 3. 15_12_2022: סה"כ | עצורים | שפוטים | עד 14 | נתונים ל-2019 | עצורים | שפוטים | סה"כ | עצורים | שפוטים
# 4. 10_12_2022: גיל 12 | גיל 13 | גיל 14 | גיל 15 | גיל 16 | גיל 17 | סך הכל | עמודה1 | 2010 | 2011
# 5. 12_12_2022: בימ"ש שלום לנוער | בימ"ש מחוזי לנוער | בימ"ש עליון | תעבורה | הליכים ללא בימ"ש | ירושלים | דרום** | מרכז | תל אביב | 1946.0
# 6. 13_12_2022: הרשעה | אי-הרשעה | ערבים (שאינם תושבי ישראל) | ערבים (תושבי ישראל) | יהודים
# 7. 7_12_2022: שנה | גיל 12 | גיל 13 | גיל 14 | גיל 15 | גיל 16 | גיל 17 | סך כל | סה"כ | סך הכל
# 8. 9_12_2022: תיקי ט.מ. | תיקים פליליים | סך הכל | שיעור לאלף בקבוצת הגיל | 2010.0 | 2011.0 | 2012.0 | 2013.0 | 2014.0 | 2015.0
# 9. 8_12_2022: עמודה1 | גיל 12 | גיל 13 | גיל 14 | גיל 15 | גיל 16 | גיל 17
# 10. 16_12_2022: עמודה2 | עמודה1 | עד 14
#
# Enter the number of the CSV that matches this table (or 0 if unsure): 7
# ✅ Mapped תרשים 12ז': מספר הקטינים העצורים, לפי שנה וגיל / 2021-2011 → 7_12_2022
#
# === Table Name: תרשים 12ח': התפלגות גילאי הקטינים העצורים  / 2021 ===
# Candidate CSVs and their headers:
# 1. 11_12_2022: סידרה 1 | 2010 | 2011 | 2012 | 2013 | 2014 | 2015 | 2016 | 2017 | 2018
# 2. 14_12_2022: עד 14 | קליטת אסירים קטינים תושבי ישראל לפי גיל | גיל | 2018.0 | עד גיל 14 | מ-14 עד 16 | מ-16 עד - 18 | סה"כ
# 3. 15_12_2022: סה"כ | עצורים | שפוטים | עד 14 | נתונים ל-2019 | עצורים | שפוטים | סה"כ | עצורים | שפוטים
# 4. 10_12_2022: גיל 12 | גיל 13 | גיל 14 | גיל 15 | גיל 16 | גיל 17 | סך הכל | עמודה1 | 2010 | 2011
# 5. 12_12_2022: בימ"ש שלום לנוער | בימ"ש מחוזי לנוער | בימ"ש עליון | תעבורה | הליכים ללא בימ"ש | ירושלים | דרום** | מרכז | תל אביב | 1946.0
# 6. 13_12_2022: הרשעה | אי-הרשעה | ערבים (שאינם תושבי ישראל) | ערבים (תושבי ישראל) | יהודים
# 7. 9_12_2022: תיקי ט.מ. | תיקים פליליים | סך הכל | שיעור לאלף בקבוצת הגיל | 2010.0 | 2011.0 | 2012.0 | 2013.0 | 2014.0 | 2015.0
# 8. 8_12_2022: עמודה1 | גיל 12 | גיל 13 | גיל 14 | גיל 15 | גיל 16 | גיל 17
# 9. 16_12_2022: עמודה2 | עמודה1 | עד 14
#
# Enter the number of the CSV that matches this table (or 0 if unsure): 8
# ✅ Mapped תרשים 12ח': התפלגות גילאי הקטינים העצורים  / 2021 → 8_12_2022
#
# === Table Name: תרשים 12ט': התפלגות קטינים המופנים בידי המשטרה לטיפול שירות המבחן לנוער
# לפי סוג תיק (מספרים ושיעור לאלף בקבוצת הגיל 17-12) / 2021-2010
#
#
#                                לדלל את הסקאלה ===
# Candidate CSVs and their headers:
# 1. 11_12_2022: סידרה 1 | 2010 | 2011 | 2012 | 2013 | 2014 | 2015 | 2016 | 2017 | 2018
# 2. 14_12_2022: עד 14 | קליטת אסירים קטינים תושבי ישראל לפי גיל | גיל | 2018.0 | עד גיל 14 | מ-14 עד 16 | מ-16 עד - 18 | סה"כ
# 3. 15_12_2022: סה"כ | עצורים | שפוטים | עד 14 | נתונים ל-2019 | עצורים | שפוטים | סה"כ | עצורים | שפוטים
# 4. 10_12_2022: גיל 12 | גיל 13 | גיל 14 | גיל 15 | גיל 16 | גיל 17 | סך הכל | עמודה1 | 2010 | 2011
# 5. 12_12_2022: בימ"ש שלום לנוער | בימ"ש מחוזי לנוער | בימ"ש עליון | תעבורה | הליכים ללא בימ"ש | ירושלים | דרום** | מרכז | תל אביב | 1946.0
# 6. 13_12_2022: הרשעה | אי-הרשעה | ערבים (שאינם תושבי ישראל) | ערבים (תושבי ישראל) | יהודים
# 7. 9_12_2022: תיקי ט.מ. | תיקים פליליים | סך הכל | שיעור לאלף בקבוצת הגיל | 2010.0 | 2011.0 | 2012.0 | 2013.0 | 2014.0 | 2015.0
# 8. 16_12_2022: עמודה2 | עמודה1 | עד 14
#
# Enter the number of the CSV that matches this table (or 0 if unsure): 7
# ✅ Mapped תרשים 12ט': התפלגות קטינים המופנים בידי המשטרה לטיפול שירות המבחן לנוער
# לפי סוג תיק (מספרים ושיעור לאלף בקבוצת הגיל 17-12) / 2021-2010
#
#
#                                לדלל את הסקאלה → 9_12_2022
#
# === Table Name: תרשים 12י': שיעור הקטינים בטיפול שירות המבחן לנוער, לפי גילם בעת ביצוע העבירה (אחוז מכלל הקטינים המופנים) / 2021-2010 ===
# Candidate CSVs and their headers:
# 1. 11_12_2022: סידרה 1 | 2010 | 2011 | 2012 | 2013 | 2014 | 2015 | 2016 | 2017 | 2018
# 2. 14_12_2022: עד 14 | קליטת אסירים קטינים תושבי ישראל לפי גיל | גיל | 2018.0 | עד גיל 14 | מ-14 עד 16 | מ-16 עד - 18 | סה"כ
# 3. 15_12_2022: סה"כ | עצורים | שפוטים | עד 14 | נתונים ל-2019 | עצורים | שפוטים | סה"כ | עצורים | שפוטים
# 4. 10_12_2022: גיל 12 | גיל 13 | גיל 14 | גיל 15 | גיל 16 | גיל 17 | סך הכל | עמודה1 | 2010 | 2011
# 5. 12_12_2022: בימ"ש שלום לנוער | בימ"ש מחוזי לנוער | בימ"ש עליון | תעבורה | הליכים ללא בימ"ש | ירושלים | דרום** | מרכז | תל אביב | 1946.0
# 6. 13_12_2022: הרשעה | אי-הרשעה | ערבים (שאינם תושבי ישראל) | ערבים (תושבי ישראל) | יהודים
# 7. 16_12_2022: עמודה2 | עמודה1 | עד 14
#
# Enter the number of the CSV that matches this table (or 0 if unsure): 4
# ✅ Mapped תרשים 12י': שיעור הקטינים בטיפול שירות המבחן לנוער, לפי גילם בעת ביצוע העבירה (אחוז מכלל הקטינים המופנים) / 2021-2010 → 10_12_2022
#
# === Table Name: תרשים 12יא': מספר ההליכים הפליליים שבהם קטינים יוצגו בידי הסניגוריה הציבורית*, לפי שנה** / 2021-2010 ===
# Candidate CSVs and their headers:
# 1. 11_12_2022: סידרה 1 | 2010 | 2011 | 2012 | 2013 | 2014 | 2015 | 2016 | 2017 | 2018
# 2. 14_12_2022: עד 14 | קליטת אסירים קטינים תושבי ישראל לפי גיל | גיל | 2018.0 | עד גיל 14 | מ-14 עד 16 | מ-16 עד - 18 | סה"כ
# 3. 15_12_2022: סה"כ | עצורים | שפוטים | עד 14 | נתונים ל-2019 | עצורים | שפוטים | סה"כ | עצורים | שפוטים
# 4. 12_12_2022: בימ"ש שלום לנוער | בימ"ש מחוזי לנוער | בימ"ש עליון | תעבורה | הליכים ללא בימ"ש | ירושלים | דרום** | מרכז | תל אביב | 1946.0
# 5. 13_12_2022: הרשעה | אי-הרשעה | ערבים (שאינם תושבי ישראל) | ערבים (תושבי ישראל) | יהודים
# 6. 16_12_2022: עמודה2 | עמודה1 | עד 14
#
# Enter the number of the CSV that matches this table (or 0 if unsure): 1
# ✅ Mapped תרשים 12יא': מספר ההליכים הפליליים שבהם קטינים יוצגו בידי הסניגוריה הציבורית*, לפי שנה** / 2021-2010 → 11_12_2022
#
# === Table Name: תרשים 12יב': מספר ההליכים הפליליים שבהם קטינים יוצגו בידי הסניגוריה הציבורית*, לפי מחוז / 2021 ===
# Candidate CSVs and their headers:
# 1. 14_12_2022: עד 14 | קליטת אסירים קטינים תושבי ישראל לפי גיל | גיל | 2018.0 | עד גיל 14 | מ-14 עד 16 | מ-16 עד - 18 | סה"כ
# 2. 15_12_2022: סה"כ | עצורים | שפוטים | עד 14 | נתונים ל-2019 | עצורים | שפוטים | סה"כ | עצורים | שפוטים
# 3. 12_12_2022: בימ"ש שלום לנוער | בימ"ש מחוזי לנוער | בימ"ש עליון | תעבורה | הליכים ללא בימ"ש | ירושלים | דרום** | מרכז | תל אביב | 1946.0
# 4. 13_12_2022: הרשעה | אי-הרשעה | ערבים (שאינם תושבי ישראל) | ערבים (תושבי ישראל) | יהודים
# 5. 16_12_2022: עמודה2 | עמודה1 | עד 14
#
# Enter the number of the CSV that matches this table (or 0 if unsure): 3
# ✅ Mapped תרשים 12יב': מספר ההליכים הפליליים שבהם קטינים יוצגו בידי הסניגוריה הציבורית*, לפי מחוז / 2021 → 12_12_2022
#
# === Table Name: תרשים 12יג': יחס הרשעה/אי הרשעה* בקרב קטינים לפי קבוצת אוכלוסייה (אחוזים)/ 2020 ===
# Candidate CSVs and their headers:
# 1. 14_12_2022: עד 14 | קליטת אסירים קטינים תושבי ישראל לפי גיל | גיל | 2018.0 | עד גיל 14 | מ-14 עד 16 | מ-16 עד - 18 | סה"כ
# 2. 15_12_2022: סה"כ | עצורים | שפוטים | עד 14 | נתונים ל-2019 | עצורים | שפוטים | סה"כ | עצורים | שפוטים
# 3. 13_12_2022: הרשעה | אי-הרשעה | ערבים (שאינם תושבי ישראל) | ערבים (תושבי ישראל) | יהודים
# 4. 16_12_2022: עמודה2 | עמודה1 | עד 14
#
# Enter the number of the CSV that matches this table (or 0 if unsure): 3
# ✅ Mapped תרשים 12יג': יחס הרשעה/אי הרשעה* בקרב קטינים לפי קבוצת אוכלוסייה (אחוזים)/ 2020 → 13_12_2022
#
# === Table Name: תרשים 12יד': התפלגות מעצרים* של קטינים תושבי ישראל שנקלטו במהלך שנת 2120** במתקני השב"ס, לפי גיל (באחוזים) / 2120 ===
# Candidate CSVs and their headers:
# 1. 14_12_2022: עד 14 | קליטת אסירים קטינים תושבי ישראל לפי גיל | גיל | 2018.0 | עד גיל 14 | מ-14 עד 16 | מ-16 עד - 18 | סה"כ
# 2. 15_12_2022: סה"כ | עצורים | שפוטים | עד 14 | נתונים ל-2019 | עצורים | שפוטים | סה"כ | עצורים | שפוטים
# 3. 16_12_2022: עמודה2 | עמודה1 | עד 14
#
# Enter the number of the CSV that matches this table (or 0 if unsure): 1
# ✅ Mapped תרשים 12יד': התפלגות מעצרים* של קטינים תושבי ישראל שנקלטו במהלך שנת 2120** במתקני השב"ס, לפי גיל (באחוזים) / 2120 → 14_12_2022
#
# === Table Name: תרשים 12טו': התפלגות הקליטות* של קטינים תושבי ישראל במתקני השב"ס במהלך שנת 2021**, לפי סוג אסיר (באחוזים) / 2021 ===
# Candidate CSVs and their headers:
# 1. 15_12_2022: סה"כ | עצורים | שפוטים | עד 14 | נתונים ל-2019 | עצורים | שפוטים | סה"כ | עצורים | שפוטים
# 2. 16_12_2022: עמודה2 | עמודה1 | עד 14
#
# Enter the number of the CSV that matches this table (or 0 if unsure): 1
# ✅ Mapped תרשים 12טו': התפלגות הקליטות* של קטינים תושבי ישראל במתקני השב"ס במהלך שנת 2021**, לפי סוג אסיר (באחוזים) / 2021 → 15_12_2022
#
# === Table Name: תרשים 12טז': התפלגות קליטת אסירים/עצירים בטחוניים קטינים, לפי גיל / 2021 ===
# Candidate CSVs and their headers:
# 1. 16_12_2022: עמודה2 | עמודה1 | עד 14
#
# Enter the number of the CSV that matches this table (or 0 if unsure): 1
# ✅ Mapped תרשים 12טז': התפלגות קליטת אסירים/עצירים בטחוניים קטינים, לפי גיל / 2021 → 16_12_2022
#
# ✅ Alignment finished. Saved mapping to: /content/excel_and_json_2019_2021_2024/2022/12/aligned_mapping.json
# 📂 Processing Year 2022, Chapter 13...
#
# === Table Name: תרשים 13א': מספר התיקים הפליליים ותיקי טיפול מותנה (ט.מ.) שנפתחו בגין עבירות כנגד ילדים במשפחה ומחוץ למשפחה / 2021-2011 ===
# Candidate CSVs and their headers:
# 1. 5_13_2022: סידרה 1 | אילת | טובא זנגרייה | שדרות | בית דגן | אריאל - 32.5 | ג'סר א-זרקא | בת ים | כפר ורדים | טירה - 32.6
# 2. 19_13_2022: עמודה1 | בדואים | דרוזים | מוסלמים | נוצרים
# 3. 2_13_2022: הסתיים בהרשעה (מכלל התיקים שנדונו) | סגור נדון | סגור בלא שנדון | פתוח בפרקליטות | פתוח במשטרה | 2015 | 2016 | 2017 | 2018 | 2019
# 4. 12_13_2022: תיקים פליליים | כתבי אישום | 2005 | 2006 | 2007 | 2008 | 2009 | 2010 | 2011 | 2012
# 5. 14_13_2022: מספר התיקים | 2018 | 2019 | 2020 | 2021
# 6. 7_13_2022: סידרה 1 | יעי | לא ידוע/ללא סיווג | עד שנה | לוח חדש: ילדים שנרצחו בתוך המשפחה, לפי גיל (מספרים ואחוזים)/ 2004-2019* | גיל | מספרים | אחוזים | סך הכל | עד שנה
# 7. 17_13_2022: עמודה1 | אלימות/ישע | מין | אלימות בין הורים | מין+ישע | מין ברשת | רצח/הריגה | אחר
# 8. 15_13_2022: יהודי | לא יהודי | סך הכל* | יהודי.1 | לא יהודי.1 | ללא סיווג | סך הכל | 2000.0 | 1986.0 | 2005.0
# 9. 18_13_2022: עמודה1 | חילונים | חרדים | מסורתיים/דתיים
# 10. 9_13_2022: תיקים פליליים | כתבי אישום | 2012.0 | 2013.0 | שנה כללי | כמות תיקים | כתבי אישום | 2014.0 | 2012 | 2012
# 11. 13_13_2022: סך הקטינים | גילאי 3-0 | גילאי 6-3 | 2008 | 2009 | 2010 | 2011 | 2012 | 2013 | 2014
# 12. 3_13_2022: הסתיים בהרשעה (מכלל התיקים שנדונו) | סגור נדון | סגור בלא שנדון | פתוח בפרקליטות | פתוח במשטרה | לא | לא.1 | לא.2 | לא.3 | לא.4
# 13. 10_13_2022: בנים | בנות | סהכ | 2008 | 2009 | 2010 | 2011 | 2012 | 2013 | 2014
# 14. 8_13_2022: עמודה1 | נתוני טבלה 2018: | אב | עמודה1 | אם | אב | אח/אחות | אם | קרוב משפחה אחר | אח/אחות
# 15. 11_13_2022: סידרה 1 | נתונים לא מעודכנים | 2011.0 | 2005 | 2012.0 | 2006 | 2013.0 | 2007 | 2014.0 | 2008
# 16. 1_13_2022: תיקי ט.מ. | תיקים פליליים | סידרה 3 | 2011 | 2012 | 2013 | 2014 | 2015 | 2016 | 2017
# 17. 6_13_2022: עמודה1 | 2004 | 2005 | 2006 | 2007 | 2008 | 2009 | 2010 | 2011 | 2012
# 18. 16_13_2022: עמודה1 | נפגע עבירה | עד | חשוד | נפגע עבירה + עד | עד לאלימות בין הורים | עד לרצח
# 19. 4_13_2022: תיקים פליליים | שיעורים | 2008.0 | 2009.0 | 2010.0 | 2011.0 | 2012.0 | 2013.0 | 2014.0 | 2015.0
#
# Enter the number of the CSV that matches this table (or 0 if unsure): 16
# ✅ Mapped תרשים 13א': מספר התיקים הפליליים ותיקי טיפול מותנה (ט.מ.) שנפתחו בגין עבירות כנגד ילדים במשפחה ומחוץ למשפחה / 2021-2011 → 1_13_2022
#
# === Table Name: תרשים 13ב': אחוז* התיקים הפליליים ותיקי ט.מ. שנפתחו בגין עבירות כנגד ילדים במשפחה , לפי מצב התיק / 2021-2015 ===
# Candidate CSVs and their headers:
# 1. 5_13_2022: סידרה 1 | אילת | טובא זנגרייה | שדרות | בית דגן | אריאל - 32.5 | ג'סר א-זרקא | בת ים | כפר ורדים | טירה - 32.6
# 2. 19_13_2022: עמודה1 | בדואים | דרוזים | מוסלמים | נוצרים
# 3. 2_13_2022: הסתיים בהרשעה (מכלל התיקים שנדונו) | סגור נדון | סגור בלא שנדון | פתוח בפרקליטות | פתוח במשטרה | 2015 | 2016 | 2017 | 2018 | 2019
# 4. 12_13_2022: תיקים פליליים | כתבי אישום | 2005 | 2006 | 2007 | 2008 | 2009 | 2010 | 2011 | 2012
# 5. 14_13_2022: מספר התיקים | 2018 | 2019 | 2020 | 2021
# 6. 7_13_2022: סידרה 1 | יעי | לא ידוע/ללא סיווג | עד שנה | לוח חדש: ילדים שנרצחו בתוך המשפחה, לפי גיל (מספרים ואחוזים)/ 2004-2019* | גיל | מספרים | אחוזים | סך הכל | עד שנה
# 7. 17_13_2022: עמודה1 | אלימות/ישע | מין | אלימות בין הורים | מין+ישע | מין ברשת | רצח/הריגה | אחר
# 8. 15_13_2022: יהודי | לא יהודי | סך הכל* | יהודי.1 | לא יהודי.1 | ללא סיווג | סך הכל | 2000.0 | 1986.0 | 2005.0
# 9. 18_13_2022: עמודה1 | חילונים | חרדים | מסורתיים/דתיים
# 10. 9_13_2022: תיקים פליליים | כתבי אישום | 2012.0 | 2013.0 | שנה כללי | כמות תיקים | כתבי אישום | 2014.0 | 2012 | 2012
# 11. 13_13_2022: סך הקטינים | גילאי 3-0 | גילאי 6-3 | 2008 | 2009 | 2010 | 2011 | 2012 | 2013 | 2014
# 12. 3_13_2022: הסתיים בהרשעה (מכלל התיקים שנדונו) | סגור נדון | סגור בלא שנדון | פתוח בפרקליטות | פתוח במשטרה | לא | לא.1 | לא.2 | לא.3 | לא.4
# 13. 10_13_2022: בנים | בנות | סהכ | 2008 | 2009 | 2010 | 2011 | 2012 | 2013 | 2014
# 14. 8_13_2022: עמודה1 | נתוני טבלה 2018: | אב | עמודה1 | אם | אב | אח/אחות | אם | קרוב משפחה אחר | אח/אחות
# 15. 11_13_2022: סידרה 1 | נתונים לא מעודכנים | 2011.0 | 2005 | 2012.0 | 2006 | 2013.0 | 2007 | 2014.0 | 2008
# 16. 6_13_2022: עמודה1 | 2004 | 2005 | 2006 | 2007 | 2008 | 2009 | 2010 | 2011 | 2012
# 17. 16_13_2022: עמודה1 | נפגע עבירה | עד | חשוד | נפגע עבירה + עד | עד לאלימות בין הורים | עד לרצח
# 18. 4_13_2022: תיקים פליליים | שיעורים | 2008.0 | 2009.0 | 2010.0 | 2011.0 | 2012.0 | 2013.0 | 2014.0 | 2015.0
#
# Enter the number of the CSV that matches this table (or 0 if unsure): 3
# ✅ Mapped תרשים 13ב': אחוז* התיקים הפליליים ותיקי ט.מ. שנפתחו בגין עבירות כנגד ילדים במשפחה , לפי מצב התיק / 2021-2015 → 2_13_2022
#
# === Table Name: תרשים 13ג': שיעור התיקים הפליליים ותיקי ט.מ. שנפתחו בגין עבירות כנגד ילדים מחוץ למשפחה, לפי מצב התיק / 2021-2015 ===
# Candidate CSVs and their headers:
# 1. 5_13_2022: סידרה 1 | אילת | טובא זנגרייה | שדרות | בית דגן | אריאל - 32.5 | ג'סר א-זרקא | בת ים | כפר ורדים | טירה - 32.6
# 2. 19_13_2022: עמודה1 | בדואים | דרוזים | מוסלמים | נוצרים
# 3. 12_13_2022: תיקים פליליים | כתבי אישום | 2005 | 2006 | 2007 | 2008 | 2009 | 2010 | 2011 | 2012
# 4. 14_13_2022: מספר התיקים | 2018 | 2019 | 2020 | 2021
# 5. 7_13_2022: סידרה 1 | יעי | לא ידוע/ללא סיווג | עד שנה | לוח חדש: ילדים שנרצחו בתוך המשפחה, לפי גיל (מספרים ואחוזים)/ 2004-2019* | גיל | מספרים | אחוזים | סך הכל | עד שנה
# 6. 17_13_2022: עמודה1 | אלימות/ישע | מין | אלימות בין הורים | מין+ישע | מין ברשת | רצח/הריגה | אחר
# 7. 15_13_2022: יהודי | לא יהודי | סך הכל* | יהודי.1 | לא יהודי.1 | ללא סיווג | סך הכל | 2000.0 | 1986.0 | 2005.0
# 8. 18_13_2022: עמודה1 | חילונים | חרדים | מסורתיים/דתיים
# 9. 9_13_2022: תיקים פליליים | כתבי אישום | 2012.0 | 2013.0 | שנה כללי | כמות תיקים | כתבי אישום | 2014.0 | 2012 | 2012
# 10. 13_13_2022: סך הקטינים | גילאי 3-0 | גילאי 6-3 | 2008 | 2009 | 2010 | 2011 | 2012 | 2013 | 2014
# 11. 3_13_2022: הסתיים בהרשעה (מכלל התיקים שנדונו) | סגור נדון | סגור בלא שנדון | פתוח בפרקליטות | פתוח במשטרה | לא | לא.1 | לא.2 | לא.3 | לא.4
# 12. 10_13_2022: בנים | בנות | סהכ | 2008 | 2009 | 2010 | 2011 | 2012 | 2013 | 2014
# 13. 8_13_2022: עמודה1 | נתוני טבלה 2018: | אב | עמודה1 | אם | אב | אח/אחות | אם | קרוב משפחה אחר | אח/אחות
# 14. 11_13_2022: סידרה 1 | נתונים לא מעודכנים | 2011.0 | 2005 | 2012.0 | 2006 | 2013.0 | 2007 | 2014.0 | 2008
# 15. 6_13_2022: עמודה1 | 2004 | 2005 | 2006 | 2007 | 2008 | 2009 | 2010 | 2011 | 2012
# 16. 16_13_2022: עמודה1 | נפגע עבירה | עד | חשוד | נפגע עבירה + עד | עד לאלימות בין הורים | עד לרצח
# 17. 4_13_2022: תיקים פליליים | שיעורים | 2008.0 | 2009.0 | 2010.0 | 2011.0 | 2012.0 | 2013.0 | 2014.0 | 2015.0
#
# Enter the number of the CSV that matches this table (or 0 if unsure): 11
# ✅ Mapped תרשים 13ג': שיעור התיקים הפליליים ותיקי ט.מ. שנפתחו בגין עבירות כנגד ילדים מחוץ למשפחה, לפי מצב התיק / 2021-2015 → 3_13_2022
#
# === Table Name: תרשים 13ד': התפלגות התיקים שנפתחו בגין עבירות אלימות גופנית* של בגירים כנגד קטינים, לפי שנה (מספרים ושיעור ל-10,000 בקרב בגירים) / 2021-2008 ===
# Candidate CSVs and their headers:
# 1. 5_13_2022: סידרה 1 | אילת | טובא זנגרייה | שדרות | בית דגן | אריאל - 32.5 | ג'סר א-זרקא | בת ים | כפר ורדים | טירה - 32.6
# 2. 19_13_2022: עמודה1 | בדואים | דרוזים | מוסלמים | נוצרים
# 3. 12_13_2022: תיקים פליליים | כתבי אישום | 2005 | 2006 | 2007 | 2008 | 2009 | 2010 | 2011 | 2012
# 4. 14_13_2022: מספר התיקים | 2018 | 2019 | 2020 | 2021
# 5. 7_13_2022: סידרה 1 | יעי | לא ידוע/ללא סיווג | עד שנה | לוח חדש: ילדים שנרצחו בתוך המשפחה, לפי גיל (מספרים ואחוזים)/ 2004-2019* | גיל | מספרים | אחוזים | סך הכל | עד שנה
# 6. 17_13_2022: עמודה1 | אלימות/ישע | מין | אלימות בין הורים | מין+ישע | מין ברשת | רצח/הריגה | אחר
# 7. 15_13_2022: יהודי | לא יהודי | סך הכל* | יהודי.1 | לא יהודי.1 | ללא סיווג | סך הכל | 2000.0 | 1986.0 | 2005.0
# 8. 18_13_2022: עמודה1 | חילונים | חרדים | מסורתיים/דתיים
# 9. 9_13_2022: תיקים פליליים | כתבי אישום | 2012.0 | 2013.0 | שנה כללי | כמות תיקים | כתבי אישום | 2014.0 | 2012 | 2012
# 10. 13_13_2022: סך הקטינים | גילאי 3-0 | גילאי 6-3 | 2008 | 2009 | 2010 | 2011 | 2012 | 2013 | 2014
# 11. 10_13_2022: בנים | בנות | סהכ | 2008 | 2009 | 2010 | 2011 | 2012 | 2013 | 2014
# 12. 8_13_2022: עמודה1 | נתוני טבלה 2018: | אב | עמודה1 | אם | אב | אח/אחות | אם | קרוב משפחה אחר | אח/אחות
# 13. 11_13_2022: סידרה 1 | נתונים לא מעודכנים | 2011.0 | 2005 | 2012.0 | 2006 | 2013.0 | 2007 | 2014.0 | 2008
# 14. 6_13_2022: עמודה1 | 2004 | 2005 | 2006 | 2007 | 2008 | 2009 | 2010 | 2011 | 2012
# 15. 16_13_2022: עמודה1 | נפגע עבירה | עד | חשוד | נפגע עבירה + עד | עד לאלימות בין הורים | עד לרצח
# 16. 4_13_2022: תיקים פליליים | שיעורים | 2008.0 | 2009.0 | 2010.0 | 2011.0 | 2012.0 | 2013.0 | 2014.0 | 2015.0
#
# Enter the number of the CSV that matches this table (or 0 if unsure): 16
# ✅ Mapped תרשים 13ד': התפלגות התיקים שנפתחו בגין עבירות אלימות גופנית* של בגירים כנגד קטינים, לפי שנה (מספרים ושיעור ל-10,000 בקרב בגירים) / 2021-2008 → 4_13_2022
#
# === Table Name: תרשים 13ה': יישובים* שבהם שיעור התיקים הפליליים שנפתחו בגין עבירות אלימות** של בגירים כנגד קטינים היה כפול מהשיעור הארצי / 2021 ===
# Candidate CSVs and their headers:
# 1. 5_13_2022: סידרה 1 | אילת | טובא זנגרייה | שדרות | בית דגן | אריאל - 32.5 | ג'סר א-זרקא | בת ים | כפר ורדים | טירה - 32.6
# 2. 19_13_2022: עמודה1 | בדואים | דרוזים | מוסלמים | נוצרים
# 3. 12_13_2022: תיקים פליליים | כתבי אישום | 2005 | 2006 | 2007 | 2008 | 2009 | 2010 | 2011 | 2012
# 4. 14_13_2022: מספר התיקים | 2018 | 2019 | 2020 | 2021
# 5. 7_13_2022: סידרה 1 | יעי | לא ידוע/ללא סיווג | עד שנה | לוח חדש: ילדים שנרצחו בתוך המשפחה, לפי גיל (מספרים ואחוזים)/ 2004-2019* | גיל | מספרים | אחוזים | סך הכל | עד שנה
# 6. 17_13_2022: עמודה1 | אלימות/ישע | מין | אלימות בין הורים | מין+ישע | מין ברשת | רצח/הריגה | אחר
# 7. 15_13_2022: יהודי | לא יהודי | סך הכל* | יהודי.1 | לא יהודי.1 | ללא סיווג | סך הכל | 2000.0 | 1986.0 | 2005.0
# 8. 18_13_2022: עמודה1 | חילונים | חרדים | מסורתיים/דתיים
# 9. 9_13_2022: תיקים פליליים | כתבי אישום | 2012.0 | 2013.0 | שנה כללי | כמות תיקים | כתבי אישום | 2014.0 | 2012 | 2012
# 10. 13_13_2022: סך הקטינים | גילאי 3-0 | גילאי 6-3 | 2008 | 2009 | 2010 | 2011 | 2012 | 2013 | 2014
# 11. 10_13_2022: בנים | בנות | סהכ | 2008 | 2009 | 2010 | 2011 | 2012 | 2013 | 2014
# 12. 8_13_2022: עמודה1 | נתוני טבלה 2018: | אב | עמודה1 | אם | אב | אח/אחות | אם | קרוב משפחה אחר | אח/אחות
# 13. 11_13_2022: סידרה 1 | נתונים לא מעודכנים | 2011.0 | 2005 | 2012.0 | 2006 | 2013.0 | 2007 | 2014.0 | 2008
# 14. 6_13_2022: עמודה1 | 2004 | 2005 | 2006 | 2007 | 2008 | 2009 | 2010 | 2011 | 2012
# 15. 16_13_2022: עמודה1 | נפגע עבירה | עד | חשוד | נפגע עבירה + עד | עד לאלימות בין הורים | עד לרצח
#
# Enter the number of the CSV that matches this table (or 0 if unsure): 1
# ✅ Mapped תרשים 13ה': יישובים* שבהם שיעור התיקים הפליליים שנפתחו בגין עבירות אלימות** של בגירים כנגד קטינים היה כפול מהשיעור הארצי / 2021 → 5_13_2022
#
# === Table Name: תרשים 13ו': מספר הילדים שנרצחו בתוך המשפחה / 2021-2004 ===
# Candidate CSVs and their headers:
# 1. 19_13_2022: עמודה1 | בדואים | דרוזים | מוסלמים | נוצרים
# 2. 12_13_2022: תיקים פליליים | כתבי אישום | 2005 | 2006 | 2007 | 2008 | 2009 | 2010 | 2011 | 2012
# 3. 14_13_2022: מספר התיקים | 2018 | 2019 | 2020 | 2021
# 4. 7_13_2022: סידרה 1 | יעי | לא ידוע/ללא סיווג | עד שנה | לוח חדש: ילדים שנרצחו בתוך המשפחה, לפי גיל (מספרים ואחוזים)/ 2004-2019* | גיל | מספרים | אחוזים | סך הכל | עד שנה
# 5. 17_13_2022: עמודה1 | אלימות/ישע | מין | אלימות בין הורים | מין+ישע | מין ברשת | רצח/הריגה | אחר
# 6. 15_13_2022: יהודי | לא יהודי | סך הכל* | יהודי.1 | לא יהודי.1 | ללא סיווג | סך הכל | 2000.0 | 1986.0 | 2005.0
# 7. 18_13_2022: עמודה1 | חילונים | חרדים | מסורתיים/דתיים
# ...
# 4. 2_14_2022: עמודה1 | זכר | נקבה | איום בהתאבדות | לא בנושא התעניינות | מסירת מידע מודיעיני | הטרדה  - לא מינית | הפצת תמונות ו/או סרטונים מיניים | מצוקה | ייעוץ טכנולוגי
# 5. 13_14_2022: עד 9 | 2006 | 2007 | בנים | בנות | 2008 | סך הכל | עד 9 | סך הכל | עד 9
# 6. 7_14_2022: סידרה 1 | 1993.0 | 1996.0 | 1999.0 | 2002.0 | 2005.0 | 2008.0 | 2011.0 | 2012.0 | 2013.0
# 7. 6_14_2022: סידרה 1 | 2000.0 | 2001.0 | 2002.0 | 2003.0 | 2004.0 | 2005.0 | 2006.0 | 2007.0 | 2008.0
# 8. 1_14_2022: עמודה1 | עבירות מין | הפצת תמונות/סרטונים מביכים | איום בהתאבדות | לא בנושא התעניינות - לא קטין | הטרדה לא מינית | פריצה למחשב/ חומר מחשב | הפצת תמונות/סרטונים מיניים | לא בנושא התעניינות - לא ברשת | איום וסחיטה - לא על רקע מיני
# 9. 4_14_2022: 2019 | 2020 | 2021 | מטופלים | נפגעים מינית | 2010.0 | פוגעים מינית\התנהגות מינית לא מותאמת | הליך פלילי לצד הטיפול
# 10. 8_14_2022: אחוז | עמודה1 | בנים | בנות
# 11. 3_14_2022: 2021 | 2020 | 2019 | 2018 | ילדים מטופלים | קבוצות טיפוליות | מרכזים
# 12. 5_14_2022: עמודה1 | הורה | הנפגע | עד | אנשי חינוך | קרוב משפחה | חבר | אגודות/פורומים | אחר | אחר
# 13. 9_14_2022: פניות | בני 22+ | 2019 | 2020 | 2021 | אפריל 2021 | אלימות פיזית\מילולית\מינית | בדידות | פגיעות עצמיות
#
# Enter the number of the CSV that matches this table (or 0 if unsure): 5
# ✅ Mapped תרשים 14יז': שיעור ניסיונות התאבדות של ילדים ובני נוער שהתקבלו בחדרי מיון,
# לפי גיל ושנה / 2021-2006 → 13_14_2022
#
# === Table Name: תרשים 14יח': מספר הילדים בגיל 17-12 שניסו להתאבד באמצעות רעלים*/
# 2020-1993 ===
# Candidate CSVs and their headers:
# 1. 10_14_2022: אחוז | מתחת לגיל 14 | גיל 15-17 | יהודים ואחרים | ערבים
# 2. 12_14_2022: 2020 | 2021 | הערכות סיכון | טיפול פסיכולוגי בסיכון אובדני | התערבויות מערכתיות פסיכולוגיות במעטפת הבית ספרית
# 3. 11_14_2022: 2019 | 2020 | 2021 | חשד לאלימות | חשד להזנחה | חשד לפגיעה מינית | נתוני פניות של פגיעה בילדים- מרץ עד אוקטובר | אלימות כלפי ילדים | אלימות כלפי ילדים 2019 | אלימות כלפי ילדים 2020
# 4. 2_14_2022: עמודה1 | זכר | נקבה | איום בהתאבדות | לא בנושא התעניינות | מסירת מידע מודיעיני | הטרדה  - לא מינית | הפצת תמונות ו/או סרטונים מיניים | מצוקה | ייעוץ טכנולוגי
# 5. 7_14_2022: סידרה 1 | 1993.0 | 1996.0 | 1999.0 | 2002.0 | 2005.0 | 2008.0 | 2011.0 | 2012.0 | 2013.0
# 6. 6_14_2022: סידרה 1 | 2000.0 | 2001.0 | 2002.0 | 2003.0 | 2004.0 | 2005.0 | 2006.0 | 2007.0 | 2008.0
# 7. 1_14_2022: עמודה1 | עבירות מין | הפצת תמונות/סרטונים מביכים | איום בהתאבדות | לא בנושא התעניינות - לא קטין | הטרדה לא מינית | פריצה למחשב/ חומר מחשב | הפצת תמונות/סרטונים מיניים | לא בנושא התעניינות - לא ברשת | איום וסחיטה - לא על רקע מיני
# 8. 4_14_2022: 2019 | 2020 | 2021 | מטופלים | נפגעים מינית | 2010.0 | פוגעים מינית\התנהגות מינית לא מותאמת | הליך פלילי לצד הטיפול
# 9. 8_14_2022: אחוז | עמודה1 | בנים | בנות
# 10. 3_14_2022: 2021 | 2020 | 2019 | 2018 | ילדים מטופלים | קבוצות טיפוליות | מרכזים
# 11. 5_14_2022: עמודה1 | הורה | הנפגע | עד | אנשי חינוך | קרוב משפחה | חבר | אגודות/פורומים | אחר | אחר
# 12. 9_14_2022: פניות | בני 22+ | 2019 | 2020 | 2021 | אפריל 2021 | אלימות פיזית\מילולית\מינית | בדידות | פגיעות עצמיות
#
# Enter the number of the CSV that matches this table (or 0 if unsure): 5
# ✅ Mapped תרשים 14יח': מספר הילדים בגיל 17-12 שניסו להתאבד באמצעות רעלים*/
# 2020-1993 → 7_14_2022
#
# === Table Name: תרשים 14יט': מספר ההתאבדויות של ילדים ובני נוער עד גיל 17, לפי שנה /
# 2018-1990 ===
# Candidate CSVs and their headers:
# 1. 10_14_2022: אחוז | מתחת לגיל 14 | גיל 15-17 | יהודים ואחרים | ערבים
# 2. 12_14_2022: 2020 | 2021 | הערכות סיכון | טיפול פסיכולוגי בסיכון אובדני | התערבויות מערכתיות פסיכולוגיות במעטפת הבית ספרית
# 3. 11_14_2022: 2019 | 2020 | 2021 | חשד לאלימות | חשד להזנחה | חשד לפגיעה מינית | נתוני פניות של פגיעה בילדים- מרץ עד אוקטובר | אלימות כלפי ילדים | אלימות כלפי ילדים 2019 | אלימות כלפי ילדים 2020
# 4. 2_14_2022: עמודה1 | זכר | נקבה | איום בהתאבדות | לא בנושא התעניינות | מסירת מידע מודיעיני | הטרדה  - לא מינית | הפצת תמונות ו/או סרטונים מיניים | מצוקה | ייעוץ טכנולוגי
# 5. 6_14_2022: סידרה 1 | 2000.0 | 2001.0 | 2002.0 | 2003.0 | 2004.0 | 2005.0 | 2006.0 | 2007.0 | 2008.0
# 6. 1_14_2022: עמודה1 | עבירות מין | הפצת תמונות/סרטונים מביכים | איום בהתאבדות | לא בנושא התעניינות - לא קטין | הטרדה לא מינית | פריצה למחשב/ חומר מחשב | הפצת תמונות/סרטונים מיניים | לא בנושא התעניינות - לא ברשת | איום וסחיטה - לא על רקע מיני
# 7. 4_14_2022: 2019 | 2020 | 2021 | מטופלים | נפגעים מינית | 2010.0 | פוגעים מינית\התנהגות מינית לא מותאמת | הליך פלילי לצד הטיפול
# 8. 8_14_2022: אחוז | עמודה1 | בנים | בנות
# 9. 3_14_2022: 2021 | 2020 | 2019 | 2018 | ילדים מטופלים | קבוצות טיפוליות | מרכזים
# 10. 5_14_2022: עמודה1 | הורה | הנפגע | עד | אנשי חינוך | קרוב משפחה | חבר | אגודות/פורומים | אחר | אחר
# 11. 9_14_2022: פניות | בני 22+ | 2019 | 2020 | 2021 | אפריל 2021 | אלימות פיזית\מילולית\מינית | בדידות | פגיעות עצמיות
#
# Enter the number of the CSV that matches this table (or 0 if unsure): 5
# ✅ Mapped תרשים 14יט': מספר ההתאבדויות של ילדים ובני נוער עד גיל 17, לפי שנה /
# 2018-1990 → 6_14_2022
#
# === Table Name: תרשים 14כ': שיעור ההתאבדויות של ילדים ובני נוער עד גיל 17, לפי מגדר/
# 2018-2010 ===
# Candidate CSVs and their headers:
# 1. 10_14_2022: אחוז | מתחת לגיל 14 | גיל 15-17 | יהודים ואחרים | ערבים
# 2. 12_14_2022: 2020 | 2021 | הערכות סיכון | טיפול פסיכולוגי בסיכון אובדני | התערבויות מערכתיות פסיכולוגיות במעטפת הבית ספרית
# 3. 11_14_2022: 2019 | 2020 | 2021 | חשד לאלימות | חשד להזנחה | חשד לפגיעה מינית | נתוני פניות של פגיעה בילדים- מרץ עד אוקטובר | אלימות כלפי ילדים | אלימות כלפי ילדים 2019 | אלימות כלפי ילדים 2020
# 4. 2_14_2022: עמודה1 | זכר | נקבה | איום בהתאבדות | לא בנושא התעניינות | מסירת מידע מודיעיני | הטרדה  - לא מינית | הפצת תמונות ו/או סרטונים מיניים | מצוקה | ייעוץ טכנולוגי
# 5. 1_14_2022: עמודה1 | עבירות מין | הפצת תמונות/סרטונים מביכים | איום בהתאבדות | לא בנושא התעניינות - לא קטין | הטרדה לא מינית | פריצה למחשב/ חומר מחשב | הפצת תמונות/סרטונים מיניים | לא בנושא התעניינות - לא ברשת | איום וסחיטה - לא על רקע מיני
# 6. 4_14_2022: 2019 | 2020 | 2021 | מטופלים | נפגעים מינית | 2010.0 | פוגעים מינית\התנהגות מינית לא מותאמת | הליך פלילי לצד הטיפול
# 7. 8_14_2022: אחוז | עמודה1 | בנים | בנות
# 8. 3_14_2022: 2021 | 2020 | 2019 | 2018 | ילדים מטופלים | קבוצות טיפוליות | מרכזים
# 9. 5_14_2022: עמודה1 | הורה | הנפגע | עד | אנשי חינוך | קרוב משפחה | חבר | אגודות/פורומים | אחר | אחר
# 10. 9_14_2022: פניות | בני 22+ | 2019 | 2020 | 2021 | אפריל 2021 | אלימות פיזית\מילולית\מינית | בדידות | פגיעות עצמיות
#
# Enter the number of the CSV that matches this table (or 0 if unsure): 7
# ✅ Mapped תרשים 14כ': שיעור ההתאבדויות של ילדים ובני נוער עד גיל 17, לפי מגדר/
# 2018-2010 → 8_14_2022
#
# === Table Name: תרשים 14כא': שיעור ההתאבדויות של ילדים ובני נוער עד גיל 17, לפי גיל/2010-2018 ===
# Candidate CSVs and their headers:
# 1. 10_14_2022: אחוז | מתחת לגיל 14 | גיל 15-17 | יהודים ואחרים | ערבים
# 2. 12_14_2022: 2020 | 2021 | הערכות סיכון | טיפול פסיכולוגי בסיכון אובדני | התערבויות מערכתיות פסיכולוגיות במעטפת הבית ספרית
# 3. 11_14_2022: 2019 | 2020 | 2021 | חשד לאלימות | חשד להזנחה | חשד לפגיעה מינית | נתוני פניות של פגיעה בילדים- מרץ עד אוקטובר | אלימות כלפי ילדים | אלימות כלפי ילדים 2019 | אלימות כלפי ילדים 2020
# 4. 2_14_2022: עמודה1 | זכר | נקבה | איום בהתאבדות | לא בנושא התעניינות | מסירת מידע מודיעיני | הטרדה  - לא מינית | הפצת תמונות ו/או סרטונים מיניים | מצוקה | ייעוץ טכנולוגי
# 5. 1_14_2022: עמודה1 | עבירות מין | הפצת תמונות/סרטונים מביכים | איום בהתאבדות | לא בנושא התעניינות - לא קטין | הטרדה לא מינית | פריצה למחשב/ חומר מחשב | הפצת תמונות/סרטונים מיניים | לא בנושא התעניינות - לא ברשת | איום וסחיטה - לא על רקע מיני
# 6. 4_14_2022: 2019 | 2020 | 2021 | מטופלים | נפגעים מינית | 2010.0 | פוגעים מינית\התנהגות מינית לא מותאמת | הליך פלילי לצד הטיפול
# 7. 3_14_2022: 2021 | 2020 | 2019 | 2018 | ילדים מטופלים | קבוצות טיפוליות | מרכזים
# 8. 5_14_2022: עמודה1 | הורה | הנפגע | עד | אנשי חינוך | קרוב משפחה | חבר | אגודות/פורומים | אחר | אחר
# 9. 9_14_2022: פניות | בני 22+ | 2019 | 2020 | 2021 | אפריל 2021 | אלימות פיזית\מילולית\מינית | בדידות | פגיעות עצמיות
#
# Enter the number of the CSV that matches this table (or 0 if unsure): 1
# ✅ Mapped תרשים 14כא': שיעור ההתאבדויות של ילדים ובני נוער עד גיל 17, לפי גיל/2010-2018 → 10_14_2022
#
# === Table Name: תרשים 14כב': מספר הפניות למוקד 105 (המטה הלאומי להגנה על ילדים ברשת) \ 2021-2019 ===
# Candidate CSVs and their headers:
# 1. 12_14_2022: 2020 | 2021 | הערכות סיכון | טיפול פסיכולוגי בסיכון אובדני | התערבויות מערכתיות פסיכולוגיות במעטפת הבית ספרית
# 2. 11_14_2022: 2019 | 2020 | 2021 | חשד לאלימות | חשד להזנחה | חשד לפגיעה מינית | נתוני פניות של פגיעה בילדים- מרץ עד אוקטובר | אלימות כלפי ילדים | אלימות כלפי ילדים 2019 | אלימות כלפי ילדים 2020
# 3. 2_14_2022: עמודה1 | זכר | נקבה | איום בהתאבדות | לא בנושא התעניינות | מסירת מידע מודיעיני | הטרדה  - לא מינית | הפצת תמונות ו/או סרטונים מיניים | מצוקה | ייעוץ טכנולוגי
# 4. 1_14_2022: עמודה1 | עבירות מין | הפצת תמונות/סרטונים מביכים | איום בהתאבדות | לא בנושא התעניינות - לא קטין | הטרדה לא מינית | פריצה למחשב/ חומר מחשב | הפצת תמונות/סרטונים מיניים | לא בנושא התעניינות - לא ברשת | איום וסחיטה - לא על רקע מיני
# 5. 4_14_2022: 2019 | 2020 | 2021 | מטופלים | נפגעים מינית | 2010.0 | פוגעים מינית\התנהגות מינית לא מותאמת | הליך פלילי לצד הטיפול
# 6. 3_14_2022: 2021 | 2020 | 2019 | 2018 | ילדים מטופלים | קבוצות טיפוליות | מרכזים
# 7. 5_14_2022: עמודה1 | הורה | הנפגע | עד | אנשי חינוך | קרוב משפחה | חבר | אגודות/פורומים | אחר | אחר
# 8. 9_14_2022: פניות | בני 22+ | 2019 | 2020 | 2021 | אפריל 2021 | אלימות פיזית\מילולית\מינית | בדידות | פגיעות עצמיות
#
# Enter the number of the CSV that matches this table (or 0 if unsure): 8
# ✅ Mapped תרשים 14כב': מספר הפניות למוקד 105 (המטה הלאומי להגנה על ילדים ברשת) \ 2021-2019 → 9_14_2022
#
# === Table Name: תרשים 14כג': דיווחים למוקד 105, לפי מדווח (באחוזים) / 2021 ===
# Candidate CSVs and their headers:
# 1. 12_14_2022: 2020 | 2021 | הערכות סיכון | טיפול פסיכולוגי בסיכון אובדני | התערבויות מערכתיות פסיכולוגיות במעטפת הבית ספרית
# 2. 11_14_2022: 2019 | 2020 | 2021 | חשד לאלימות | חשד להזנחה | חשד לפגיעה מינית | נתוני פניות של פגיעה בילדים- מרץ עד אוקטובר | אלימות כלפי ילדים | אלימות כלפי ילדים 2019 | אלימות כלפי ילדים 2020
# 3. 2_14_2022: עמודה1 | זכר | נקבה | איום בהתאבדות | לא בנושא התעניינות | מסירת מידע מודיעיני | הטרדה  - לא מינית | הפצת תמונות ו/או סרטונים מיניים | מצוקה | ייעוץ טכנולוגי
# 4. 1_14_2022: עמודה1 | עבירות מין | הפצת תמונות/סרטונים מביכים | איום בהתאבדות | לא בנושא התעניינות - לא קטין | הטרדה לא מינית | פריצה למחשב/ חומר מחשב | הפצת תמונות/סרטונים מיניים | לא בנושא התעניינות - לא ברשת | איום וסחיטה - לא על רקע מיני
# 5. 4_14_2022: 2019 | 2020 | 2021 | מטופלים | נפגעים מינית | 2010.0 | פוגעים מינית\התנהגות מינית לא מותאמת | הליך פלילי לצד הטיפול
# 6. 3_14_2022: 2021 | 2020 | 2019 | 2018 | ילדים מטופלים | קבוצות טיפוליות | מרכזים
# 7. 5_14_2022: עמודה1 | הורה | הנפגע | עד | אנשי חינוך | קרוב משפחה | חבר | אגודות/פורומים | אחר | אחר
#
# Enter the number of the CSV that matches this table (or 0 if unsure): 7
# ✅ Mapped תרשים 14כג': דיווחים למוקד 105, לפי מדווח (באחוזים) / 2021 → 5_14_2022
#
# === Table Name: תרשים 14כד': דיווחים למוקד 105, לפי סוג אירוע (באחוזים) / 2021 ===
# Candidate CSVs and their headers:
# 1. 12_14_2022: 2020 | 2021 | הערכות סיכון | טיפול פסיכולוגי בסיכון אובדני | התערבויות מערכתיות פסיכולוגיות במעטפת הבית ספרית
# 2. 11_14_2022: 2019 | 2020 | 2021 | חשד לאלימות | חשד להזנחה | חשד לפגיעה מינית | נתוני פניות של פגיעה בילדים- מרץ עד אוקטובר | אלימות כלפי ילדים | אלימות כלפי ילדים 2019 | אלימות כלפי ילדים 2020
# 3. 2_14_2022: עמודה1 | זכר | נקבה | איום בהתאבדות | לא בנושא התעניינות | מסירת מידע מודיעיני | הטרדה  - לא מינית | הפצת תמונות ו/או סרטונים מיניים | מצוקה | ייעוץ טכנולוגי
# 4. 1_14_2022: עמודה1 | עבירות מין | הפצת תמונות/סרטונים מביכים | איום בהתאבדות | לא בנושא התעניינות - לא קטין | הטרדה לא מינית | פריצה למחשב/ חומר מחשב | הפצת תמונות/סרטונים מיניים | לא בנושא התעניינות - לא ברשת | איום וסחיטה - לא על רקע מיני
# 5. 4_14_2022: 2019 | 2020 | 2021 | מטופלים | נפגעים מינית | 2010.0 | פוגעים מינית\התנהגות מינית לא מותאמת | הליך פלילי לצד הטיפול
# 6. 3_14_2022: 2021 | 2020 | 2019 | 2018 | ילדים מטופלים | קבוצות טיפוליות | מרכזים
#
# Enter the number of the CSV that matches this table (or 0 if unsure): 4
# ✅ Mapped תרשים 14כד': דיווחים למוקד 105, לפי סוג אירוע (באחוזים) / 2021 → 1_14_2022
#
# === Table Name: תרשים 14כה': קטינים נפגעים באירועים שדווחו למוקד 105, לפי מגדר (באחוזים) / 2021 ===
# Candidate CSVs and their headers:
# 1. 12_14_2022: 2020 | 2021 | הערכות סיכון | טיפול פסיכולוגי בסיכון אובדני | התערבויות מערכתיות פסיכולוגיות במעטפת הבית ספרית
# 2. 11_14_2022: 2019 | 2020 | 2021 | חשד לאלימות | חשד להזנחה | חשד לפגיעה מינית | נתוני פניות של פגיעה בילדים- מרץ עד אוקטובר | אלימות כלפי ילדים | אלימות כלפי ילדים 2019 | אלימות כלפי ילדים 2020
# 3. 2_14_2022: עמודה1 | זכר | נקבה | איום בהתאבדות | לא בנושא התעניינות | מסירת מידע מודיעיני | הטרדה  - לא מינית | הפצת תמונות ו/או סרטונים מיניים | מצוקה | ייעוץ טכנולוגי
# 4. 4_14_2022: 2019 | 2020 | 2021 | מטופלים | נפגעים מינית | 2010.0 | פוגעים מינית\התנהגות מינית לא מותאמת | הליך פלילי לצד הטיפול
# 5. 3_14_2022: 2021 | 2020 | 2019 | 2018 | ילדים מטופלים | קבוצות טיפוליות | מרכזים
#
# Enter the number of the CSV that matches this table (or 0 if unsure): 3
# ✅ Mapped תרשים 14כה': קטינים נפגעים באירועים שדווחו למוקד 105, לפי מגדר (באחוזים) / 2021 → 2_14_2022
#
# === Table Name: תרשים 14כו': מטופלים במרכזים האזוריים לטיפול בפגיעות מיניות בילדים ובני נוער* / 2021-2019 ===
# Candidate CSVs and their headers:
# 1. 12_14_2022: 2020 | 2021 | הערכות סיכון | טיפול פסיכולוגי בסיכון אובדני | התערבויות מערכתיות פסיכולוגיות במעטפת הבית ספרית
# 2. 11_14_2022: 2019 | 2020 | 2021 | חשד לאלימות | חשד להזנחה | חשד לפגיעה מינית | נתוני פניות של פגיעה בילדים- מרץ עד אוקטובר | אלימות כלפי ילדים | אלימות כלפי ילדים 2019 | אלימות כלפי ילדים 2020
# 3. 4_14_2022: 2019 | 2020 | 2021 | מטופלים | נפגעים מינית | 2010.0 | פוגעים מינית\התנהגות מינית לא מותאמת | הליך פלילי לצד הטיפול
# 4. 3_14_2022: 2021 | 2020 | 2019 | 2018 | ילדים מטופלים | קבוצות טיפוליות | מרכזים
#
# Enter the number of the CSV that matches this table (or 0 if unsure): 3
# ✅ Mapped תרשים 14כו': מטופלים במרכזים האזוריים לטיפול בפגיעות מיניות בילדים ובני נוער* / 2021-2019 → 4_14_2022
#
# === Table Name: תרשים 14כז': ילדים חשופים לאלימות בין הוריהם שטופלו במסגרת מרכזים למניעת אלימות במשפחה / 2021-2018 ===
# Candidate CSVs and their headers:
# 1. 12_14_2022: 2020 | 2021 | הערכות סיכון | טיפול פסיכולוגי בסיכון אובדני | התערבויות מערכתיות פסיכולוגיות במעטפת הבית ספרית
# 2. 11_14_2022: 2019 | 2020 | 2021 | חשד לאלימות | חשד להזנחה | חשד לפגיעה מינית | נתוני פניות של פגיעה בילדים- מרץ עד אוקטובר | אלימות כלפי ילדים | אלימות כלפי ילדים 2019 | אלימות כלפי ילדים 2020
# 3. 3_14_2022: 2021 | 2020 | 2019 | 2018 | ילדים מטופלים | קבוצות טיפוליות | מרכזים
#
# Enter the number of the CSV that matches this table (or 0 if unsure): 3
# ✅ Mapped תרשים 14כז': ילדים חשופים לאלימות בין הוריהם שטופלו במסגרת מרכזים למניעת אלימות במשפחה / 2021-2018 → 3_14_2022
#
# === Table Name: תרשים 14כח': פניות למוקד 118 של משרד הרווחה בשל חשד לפגיעה בקטינים / 2021-2019 ===
# Candidate CSVs and their headers:
# 1. 12_14_2022: 2020 | 2021 | הערכות סיכון | טיפול פסיכולוגי בסיכון אובדני | התערבויות מערכתיות פסיכולוגיות במעטפת הבית ספרית
# 2. 11_14_2022: 2019 | 2020 | 2021 | חשד לאלימות | חשד להזנחה | חשד לפגיעה מינית | נתוני פניות של פגיעה בילדים- מרץ עד אוקטובר | אלימות כלפי ילדים | אלימות כלפי ילדים 2019 | אלימות כלפי ילדים 2020
#
# Enter the number of the CSV that matches this table (or 0 if unsure): 2
# ✅ Mapped תרשים 14כח': פניות למוקד 118 של משרד הרווחה בשל חשד לפגיעה בקטינים / 2021-2019 → 11_14_2022
#
# === Table Name: תרשים 14כט': הערכות סיכון וטיפול בשירותים הפסיכולוגיים במסגרת התוכנית הלאומית למניעת אובדנות / 2021-2020 ===
# Candidate CSVs and their headers:
# 1. 12_14_2022: 2020 | 2021 | הערכות סיכון | טיפול פסיכולוגי בסיכון אובדני | התערבויות מערכתיות פסיכולוגיות במעטפת הבית ספרית
#
# Enter the number of the CSV that matches this table (or 0 if unsure): 1
# ✅ Mapped תרשים 14כט': הערכות סיכון וטיפול בשירותים הפסיכולוגיים במסגרת התוכנית הלאומית למניעת אובדנות / 2021-2020 → 12_14_2022
#
# ✅ Alignment finished. Saved mapping to: /content/excel_and_json_2019_2021_2024/2022/14/aligned_mapping.json

# %%
import pandas as pd
import os

# Data from the table in the screenshot
data = {
    "סוג לקות": [
        "לא כולל ילדים עם לקות למידה או הפרעת קשב וריכוז",
        "כולל ילדים עם לקות למידה או הפרעת קשב וריכוז ברמה מתונה",
        "כולל ילדים עם לקות למידה או הפרעת קשב וריכוז בכל הרמות"
    ],
    "יהודים שאינם חרדים - מספרי מ": [164, 192, 283],
    "יהודים שאינם חרדים - אחוזים": ["10.3%", "12.1%", "17.8%"],
    "יהודים חרדים - מספרי מ": [41, 46, 66],
    "יהודים חרדים - אחוזים": ["7.2%", "8.2%", "11.6%"],
    "ערבים - מספרי מ": [65, 72, 85],
    "ערבים - אחוזים": ["9.2%", "10.2%", "12.0%"]
}

# Create DataFrame
df = pd.DataFrame(data)

# Target directory
output_dir = "/content/excel_and_json_2019_2021_2024/2022/7"
os.makedirs(output_dir, exist_ok=True)

# Save CSV
output_path = os.path.join(output_dir, "6_7_2022.csv")
df.to_csv(output_path, index=False, encoding="utf-8-sig")

print(f"✅ Saved CSV at: {output_path}")
print(df)
# Out:
# ✅ Saved CSV at: /content/excel_and_json_2019_2021_2024/2022/7/6_7_2022.csv
#                                             סוג לקות  \
# 0    לא כולל ילדים עם לקות למידה או הפרעת קשב וריכוז
# 1  כולל ילדים עם לקות למידה או הפרעת קשב וריכוז ב...
# 2  כולל ילדים עם לקות למידה או הפרעת קשב וריכוז ב...
#
#    יהודים שאינם חרדים - מספרי מ יהודים שאינם חרדים - אחוזים  \
# 0                           164                       10.3%
# 1                           192                       12.1%
# 2                           283                       17.8%
#
#    יהודים חרדים - מספרי מ יהודים חרדים - אחוזים  ערבים - מספרי מ  \
# 0                      41                  7.2%               65
# 1                      46                  8.2%               72
# 2                      66                 11.6%               85
#
#   ערבים - אחוזים
# 0           9.2%
# 1          10.2%
# 2          12.0%

# %%
# !pip install anthropic
# import json
# import anthropic
# import os
# import numpy as np

# # ------------------------------
# # --- Semantic Alignment API ---
# # ------------------------------
# def semantic_alignment_report(table_names_json_path, headers_json_path, threshold=0.9, api_key=""):
#     """
#     First-pass semantic alignment using Claude API, keeping only high-confidence matches.
#     """
#     with open(table_names_json_path, 'r', encoding='utf-8') as f:
#         table_names = json.load(f)
#     with open(headers_json_path, 'r', encoding='utf-8') as f:
#         table_headers = json.load(f)

#     client = anthropic.Anthropic(api_key=api_key)
#     report = {}

#     for header_key, header_texts in table_headers.items():
#         prompt = f"""
#         You are matching table headers to table names.

#         Headers: {header_texts}

#         Available table names: {json.dumps(table_names, ensure_ascii=False)}

#         Only include matches you are very certain about (confidence ≥ {threshold}).
#         If unsure, return an empty "matches": [] list.

#         Return strictly valid JSON:
#         {{
#           "matches": [
#             {{"table_key": "...", "table_name": "...", "confidence": 0.0-1.0}}
#           ]
#         }}
#         ⚠️ No explanations, no extra text.
#         """

#         response = client.messages.create(
#             model="claude-3-haiku-20240307",
#             max_tokens=1500,
#             messages=[{"role": "user", "content": prompt}]
#         )
#         content_text = response.content[0].text.strip()

#         try:
#             matches = json.loads(content_text)
#         except json.JSONDecodeError:
#             print(f"⚠️ Could not parse JSON for {header_key}. Raw output:\n{content_text}")
#             matches = {"matches": []}

#         # Keep only matches above threshold
#         filtered = [m for m in matches.get("matches", []) if m.get("confidence", 0) >= threshold]
#         report[header_key] = filtered

#     return report

# # ------------------------------
# # --- Refinement with API ---
# # ------------------------------
# def refine_with_first_round(initial_report, table_names_json_path, headers_json_path, threshold=0.9, api_key=""):
#     """
#     Refines matches using first-pass output, keeping only high-confidence matches.
#     """
#     with open(table_names_json_path, 'r', encoding='utf-8') as f:
#         table_names = json.load(f)
#     with open(headers_json_path, 'r', encoding='utf-8') as f:
#         table_headers = json.load(f)

#     client = anthropic.Anthropic(api_key=api_key)
#     refined_report = {}

#     for header_key, header_texts in table_headers.items():
#         previous_matches = initial_report.get(header_key, [])

#         prompt = f"""
#         Refine table header matches to table names.

#         Headers: {header_texts}

#         Available table names: {json.dumps(table_names, ensure_ascii=False)}

#         Previous matches: {json.dumps(previous_matches, ensure_ascii=False)}

#         Only include matches with confidence ≥ {threshold}.
#         If unsure, return empty list.

#         Return strictly valid JSON:
#         {{
#           "matches": [
#             {{"table_key": "...", "table_name": "...", "confidence": 0.0-1.0}}
#           ]
#         }}
#         ⚠️ No explanations, no extra text.
#         """

#         response = client.messages.create(
#             model="claude-3-haiku-20240307",
#             max_tokens=1500,
#             messages=[{"role": "user", "content": prompt}]
#         )
#         content_text = response.content[0].text.strip()

#         try:
#             matches = json.loads(content_text)
#         except json.JSONDecodeError:
#             print(f"⚠️ Could not parse JSON for {header_key}. Raw output:\n{content_text}")
#             matches = {"matches": []}

#         filtered = [m for m in matches.get("matches", []) if m.get("confidence", 0) >= threshold]
#         refined_report[header_key] = filtered

#     return refined_report

# # ------------------------------
# # --- Interactive Mapping ---
# # ------------------------------
# def interactive_table_to_headers(headers_json_path, table_json_path, preassigned_report=None, save_json_path=None):
#     """
#     Interactive alignment for remaining unassigned tables.
#     """
#     with open(headers_json_path, 'r', encoding='utf-8') as f:
#         headers_json = json.load(f)
#     with open(table_json_path, 'r', encoding='utf-8') as f:
#         table_json = json.load(f)

#     aligned_mapping = {}

#     # Apply preassigned high-confidence matches
#     remaining_csvs = headers_json.copy()
#     remaining_tables = table_json.copy()
#     if preassigned_report:
#         for header_key, matches in preassigned_report.items():
#             if matches:
#                 # Take the first match (already filtered by confidence)
#                 match = matches[0]
#                 aligned_mapping[match['table_key']] = header_key
#                 if header_key in remaining_csvs:
#                     remaining_csvs.pop(header_key)
#                 if match['table_key'] in remaining_tables:
#                     remaining_tables.pop(match['table_key'])

#     # Interactive alignment for remaining tables
#     while remaining_tables:
#         for table_key in list(remaining_tables.keys()):
#             table_name = remaining_tables[table_key]
#             print(f"\n=== Table Name: {table_name} ===")
#             print("Candidate CSVs and their headers:")
#             for idx, (csv_file, headers) in enumerate(remaining_csvs.items(), 1):
#                 headers_preview = " | ".join(headers[:10])
#                 print(f"{idx}. {csv_file}: {headers_preview}")

#             choice = input("\nEnter the number of the CSV that matches this table (or 0 if unsure): ").strip()
#             if choice.isdigit():
#                 choice = int(choice)
#                 if 1 <= choice <= len(remaining_csvs):
#                     selected_csv = list(remaining_csvs.keys())[choice-1]
#                     aligned_mapping[table_key] = selected_csv
#                     remaining_csvs.pop(selected_csv)
#                     remaining_tables.pop(table_key)
#                     print(f"✅ Mapped {table_name} → {selected_csv}")
#                 else:
#                     aligned_mapping[table_key] = None
#                     remaining_tables.pop(table_key)
#                     print("⚠️ Not mapped (uncertain).")
#             else:
#                 aligned_mapping[table_key] = None
#                 remaining_tables.pop(table_key)
#                 print("⚠️ Invalid input. Skipped.")

#     # Save mapping
#     if save_json_path:
#         with open(save_json_path, 'w', encoding='utf-8') as f:
#             json.dump(aligned_mapping, f, ensure_ascii=False, indent=2)
#         print(f"\n✅ Saved mapping to: {save_json_path}")

#     return aligned_mapping

# # ------------------------------
# # --- Full Pipeline Example ---
# # ------------------------------
# api_key = "YOUR_API_KEY_HERE"
# chapter_json = "/content/excel_and_json_2019_2021_2024/2023/5/5_2023.json"
# headers_json = "/content/excel_and_json_2019_2021_2024/2023/5/5_2023_headers.json"
# save_json = "/content/excel_and_json_2019_2021_2024/2023/5/aligned_mapping.json"

# # Step 1: Automatic high-confidence matching
# chapter_report = semantic_alignment_report(chapter_json, headers_json, threshold=0.9, api_key=api_key)
# refined_report = refine_with_first_round(chapter_report, chapter_json, headers_json, threshold=0.9, api_key=api_key)

# # Step 2: Interactive review for remaining tables
# final_mapping = interactive_table_to_headers(headers_json, chapter_json, preassigned_report=refined_report, save_json_path=save_json)
# Out:
# Collecting anthropic
#   Downloading anthropic-0.67.0-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (0.10.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (2.11.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.12/dist-packages (from anthropic) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->anthropic) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->anthropic) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.1)
# Downloading anthropic-0.67.0-py3-none-any.whl (317 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 kB 6.4 MB/s eta 0:00:00
# Installing collected packages: anthropic
# Successfully installed anthropic-0.67.0
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# /tmp/ipython-input-4191105939.py in <cell line: 0>()
#     189
#     190 # Step 1: Automatic high-confidence matching
# --> 191 chapter_report = semantic_alignment_report(chapter_json, headers_json, threshold=0.9, api_key=api_key)
#     192 refined_report = refine_with_first_round(chapter_report, chapter_json, headers_json, threshold=0.9, api_key=api_key)
#     193
#
# /tmp/ipython-input-4191105939.py in semantic_alignment_report(table_names_json_path, headers_json_path, threshold, api_key)
#      40         """
#      41
# ---> 42         response = client.messages.create(
#      43             model="claude-3-haiku-20240307",
#      44             max_tokens=1500,
#
# /usr/local/lib/python3.12/dist-packages/anthropic/_utils/_utils.py in wrapper(*args, **kwargs)
#     280                         msg = f"Missing required argument: {quote(missing[0])}"
#     281                 raise TypeError(msg)
# --> 282             return func(*args, **kwargs)
#     283
#     284         return wrapper  # type: ignore
#
# /usr/local/lib/python3.12/dist-packages/anthropic/resources/messages/messages.py in create(self, max_tokens, messages, model, metadata, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#     928             )
#     929
# --> 930         return self._post(
#     931             "/v1/messages",
#     932             body=maybe_transform(
#
# /usr/local/lib/python3.12/dist-packages/anthropic/_base_client.py in post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1322             method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1323         )
# -> 1324         return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#    1325
#    1326     def patch(
#
# /usr/local/lib/python3.12/dist-packages/anthropic/_base_client.py in request(self, cast_to, options, stream, stream_cls)
#    1110
#    1111                 log.debug("Re-raising status error")
# -> 1112                 raise self._make_status_error_from_response(err.response) from None
#    1113
#    1114             break
#
# AuthenticationError: Error code: 401 - {'type': 'error', 'error': {'type': 'authentication_error', 'message': 'invalid x-api-key'}, 'request_id': 'req_011CTBoWSikSgEsEwdLsoGTA'}

# %%
## running the final summary json creation and mapping the csv files to its real names
#run 4
# years 2019,2021, 2022, 2023

import os
import json

# Base directories
mapped_dir = "/content/mapped"
chapters_base = "/content/excel_and_json_2019_2021_2024"   # contains year/chapter/chapter_year.json
summary_json_path = "/content/graphs_summary.json"

# Load existing summary if it exists, otherwise start empty
if os.path.exists(summary_json_path):
    with open(summary_json_path, "r", encoding="utf-8") as f:
        graphs_summary = json.load(f)
else:
    graphs_summary = {}

# Iterate through all mapping files
for fname in os.listdir(mapped_dir):
    if not fname.endswith("_aligned_mapping.json"):
        continue

    # Parse chapter and year from filename (e.g. "3_2022_aligned_mapping.json")
    chapter, year, *_ = fname.replace("_aligned_mapping.json", "").split("_")
    chapter, year = int(chapter), int(year)

    mapping_path = os.path.join(mapped_dir, fname)

    # Load mapping
    with open(mapping_path, "r", encoding="utf-8") as f:
        mapping = json.load(f)

    # Path to chapter json (contains "real" names)
    chapter_json_path = os.path.join(chapters_base, str(year), str(chapter), f"{chapter}_{year}.json")
    if not os.path.exists(chapter_json_path):
        print(f"⚠️ Missing chapter json: {chapter_json_path}")
        continue

    with open(chapter_json_path, "r", encoding="utf-8") as f:
        chapter_json = json.load(f)

    # Iterate over mapping pairs
    for csv_id, real_id in mapping.items():
      if real_id is None:
          continue

      # Handle the case where real_id is a list
      if isinstance(real_id, list):
          for rid in real_id:
              if rid not in chapter_json:
                  print(f"⚠️ {rid} not found in {chapter_json_path}")
                  continue
              table_name = chapter_json[rid]
              graphs_summary[csv_id] = table_name
              print(f"✅ {csv_id} → {table_name[:40]}...")
      else:
          if real_id not in chapter_json:
              print(f"⚠️ {real_id} not found in {chapter_json_path}")
              continue
          table_name = chapter_json[real_id]
          graphs_summary[csv_id] = table_name
          print(f"✅ {csv_id} → {table_name[:40]}...")


# Save the updated summary JSON
with open(summary_json_path, "w", encoding="utf-8") as f:
    json.dump(graphs_summary, f, ensure_ascii=False, indent=2)

print(f"\n🎉 Done! Updated summary saved to {summary_json_path}")
# Out:
# ✅ 1_3_2022 → תרשים 3ו': נישואי קטינים לפי גיל* ושנה (...
# ✅ 2_3_2022 → תרשים 3ב': שיעור המשפחות שבראשן הורה עצמ...
# ✅ 3_3_2022 → תרשים 3ה': התפלגות הילדים שאומצו בידי אז...
# ✅ 4_3_2022 → תרשים 3ד': התפלגות ילדים יתומים החיים במ...
# ✅ 5_3_2022 → תרשים 3ג': מספר הילדים החיים במשפחות המק...
# ✅ 6_3_2022 → תרשים 3א': התפלגות הילדים החיים במשפחות ...
# ✅ 1_8_2022 → תרשים 8ב': סיבת הפנייה של ילדים לחדר מיו...
# ✅ 2_8_2022 → תרשים 8ג': התפלגות הבקשות שאושרו לסייעות...
# ✅ 3_8_2022 → תרשים 8ד': מספר תיקי הילדים שעניינם נדון...
# ✅ 4_8_2022 → תרשים 8א': ממוצע חמש שנתי של תוחלת החיים...
# ✅ 5_8_2022 → תרשים 8ה': ילדים (17-0) מאושפזים בסוף הש...
# ✅ 6_8_2022 → תרשים 8ו': שיעור תמותת תינוקות מוסלמים ו...
# ✅ 7_8_2022 → תרשים 8ז': סימפטומים של חרדה בקרב ילדים,...
# ✅ 8_8_2022 → תרשים 8ח': שיעורי התנהגויות קיצון של ילד...
# ✅ 1_5_2022 → תרשים 5ב': שיעור* התחושות החיוביות כלפי ...
# ✅ 2_5_2022 → תרשים 5א': שיעור הלומדים במערכת החינוך*,...
# ✅ 3_5_2022 → תרשים 5ד': התפלגות הגשת ערעורים של תלמיד...
# ✅ 4_5_2022 → תרשים 5ה': מספר התלמידים שהורחקו לאלתר* ...
# ✅ 5_5_2022 → תרשים 5ו': התפלגות התלמידים בטיפול קציני...
# ✅ 6_5_2022 → תרשים 5ז': שיעור (לאלף) של התלמידים שנשר...
# ✅ 7_5_2022 → תרשים 5ח': היישובים בהם אחוז הנשירה מבתי...
# ✅ 8_5_2022 → תרשים 5ט': שיעור הזכאים לתעודת בגרות מתל...
# ✅ 9_5_2022 → תרשים 5ג': שיעור* התלמידים שהעידו על יחס...
# ✅ 10_5_2022 → תרשים 5יב': שיעור הזכאים לתעודת בגרות שנ...
# ✅ 11_5_2022 → תרשים 5יג': שיעור הזכאים לתעודת בגרות מצ...
# ✅ 12_5_2022 → תרשים 5יד': שיעור הזכאים לתעודת בגרות וש...
# ✅ 13_5_2022 → תרשים 5טו': יישובים בהם הפער בין אחוז הז...
# ✅ 14_5_2022 → תרשים 5טז': זכאות לבגרות לפי השכלת אם, ל...
# ✅ 15_5_2022 → תרשים 5טז': התפלגות הנבחנים בבחינת בגרות...
# ✅ 16_5_2022 → תרשים 5יח': התפלגות הבקשות שהוגשו לפטור ...
# ✅ 17_5_2022 → תרשים 5יט': שיעור בני הנוער הלומדים לתוא...
# ✅ 18_5_2022 → תרשים 5כ': התפלגות בני נוער הלומדים לתוא...
# ✅ 19_5_2022 → תרשים 5כא': שיעור בני נוער הלומדים לתואר...
# ✅ 20_5_2022 → תרשים 5כב': שיעור בני נוער הלומדים לתואר...
# ⚠️ 32_5_2022 not found in /content/excel_and_json_2019_2021_2024/2022/5/5_2022.json
# ✅ 22_5_2022 → תרשים 5כג': שיעור בני נוער הלומדים לתואר...
# ✅ 23_5_2022 → תרשים 5כד': תחומי הלימוד אותם לומדים בני...
# ✅ 24_5_2022 → תרשים 5כה': שיעור השכלה אקדמית של הורים ...
# ✅ 25_5_2022 → תרשים 5כו': שיעור השכלה אקדמית של הורים ...
# ✅ 26_5_2022 → תרשים 5כז': ילדים בדואים בגילי 3 עד 5 מח...
# ✅ 27_5_2022 → תרשים 5כח': שיעורי למידה ל-1,000 נפשות ב...
# ✅ 28_5_2022 → תרשים 5כט: התראות* שהתקבלו באמצעות מנגנו...
# ✅ 29_5_2022 → תרשים 5כט: שיעורי התלמידים (בכיתות ד') ב...
# ✅ 30_5_2022 → תרשים 5לא' שיעורי התלמידים (בכיתות ד') ב...
# ✅ 31_5_2022 → תרשים 5לב': התפלגות נושאים עיקריים בדיוו...
# ✅ 1_7_2022 → תרשים 7א': אומדן מספר ילדים עם מוגבלויות...
# ✅ 3_7_2022 → תרשים 7ב': אומדן מספר ילדים עם מוגבלויות...
# ✅ 4_7_2022 → תרשים 7ג': התפלגות תלמידים הזכאים לשירות...
# ✅ 5_7_2022 → תרשים 7ד': התפלגות תלמידי החינוך המיוחד ...
# ✅ 6_7_2022 → תרשים 7ה': התפלגות ילדים המקבלים קצבת יל...
# ✅ 1_2_2023 → תרשים 2יב': שיעור התינוקות והפעוטות של מ...
# ✅ 2_2_2023 → תרשים 2ג': שיעור הילדים העולים, יליד חו"...
# ✅ 3_2_2023 → תרשים 2טו': מספר ילדי מהגרי עבודה ילדי ז...
# ✅ 4_2_2023 → תרשים 2טז': גיל ילדי מהגרי עבודה וילדי ז...
# ✅ 5_2_2023 → תרשים 2ח': שיעור ילדי עולים*, לפי מספר ה...
# ✅ 6_2_2023 → תרשים 2ב': שיעור הילדים העולים (ילידי חו...
# ✅ 7_2_2023 → תרשים 2ה': התפלגות ילדים עולים שעלו ב-20...
# ✅ 8_2_2023 → תרשים 2יג': שיעור התינוקות והפעוטות של מ...
# ✅ 9_2_2023 → תרשים 2יא': שיעור הילדים העולים* מכלל או...
# ✅ 10_2_2023 → תרשים 2ט': מספר ילדים* ממוצע במשפחות עול...
# ✅ 11_2_2023 → תרשים 2י': התפלגות ילדי עולים* לפי גיל ו...
# ✅ 12_2_2023 → תרשים 2יד': מספר התינוקות והפעוטות של מה...
# ✅ 13_2_2023 → תרשים 2ד': מספר הילדים העולים, לפי שנת ע...
# ✅ 14_2_2023 → תרשים 2ז': התפלגות ילדי העולים* (17-0) ו...
# ✅ 15_2_2023 → תרשים 2ו': ילדים אזרחים עולים* (17-0), ל...
# ✅ 16_2_2023 → תרשים 2א': מספר הילדים העולים* וילדי עול...
# ✅ 1_8_2023 → תרשים 8ב': סיבת הפנייה של ילדים לחדר מיו...
# ✅ 2_8_2023 → תרשים 8ג': התפלגות הבקשות שאושרו לסייעות...
# ✅ 3_8_2023 → תרשים 8ד': מספר תיקי הילדים שעניינם נדון...
# ✅ 4_8_2023 → תרשים 8ה': ילדים (17-0) מאושפזים בסוף הש...
# ✅ 5_8_2023 → תרשים 8ו': שיעור תמותת תינוקות מוסלמים ו...
# ✅ 6_8_2023 → תרשים 8א': ממוצע חמש שנתי של תוחלת החיים...
# ✅ 1_1_2022 → תרשים 1ב': יישובים* בהם ילדים מנו כ-25% ...
# ⚠️ 5_1_2022 not found in /content/excel_and_json_2019_2021_2024/2022/1/1_2022.json
# ✅ 2_1_2022 → תרשים 1ד': שיעור הילדים (0- 17) הזרים שק...
# ✅ 3_1_2022 → תרשים 1ג': מספר הילדים (17-0) שקיבלו במה...
# ✅ 4_1_2022 → תרשים 1א': התפלגות הילדים בישראל, לפי דת...
# ✅ 1_12_2023 → תרשים 12א': התפלגות קטינים חשודים ונילונ...
# ✅ 2_12_2023 → תרשים 12ב': שיעור הקטינים החשודים* עם תי...
# ✅ 3_12_2023 → תרשים 12ג': התפלגות תיקים פליליים ותיקי ...
# ✅ 4_12_2023 → תרשים 12ד': התפלגות תיקים שנפתחו לקטינים...
# ✅ 5_12_2023 → תרשים 12ה': שיעור הקטינים החשודים עם תיק...
# ✅ 6_12_2023 → תרשים 12ו': שיעור התיקים שנפתחו לקטינים ...
# ✅ 7_12_2023 → תרשים 12ז': מספר הקטינים העצורים, לפי שנ...
# ✅ 8_12_2023 → תרשים 12ח': התפלגות גילאי הקטינים העצורי...
# ✅ 9_12_2023 → תרשים 12ט': התפלגות קטינים המופנים בידי ...
# ✅ 10_12_2023 → תרשים 12י': שיעור הקטינים בטיפול שירות ה...
# ✅ 11_12_2023 → תרשים 12יא': מספר ההליכים הפליליים שבהם ...
# ✅ 12_12_2023 → תרשים 12יב': מספר ההליכים הפליליים שבהם ...
# ✅ 13_12_2023 → תרשים 12יג': יחס הרשעה/אי הרשעה* בקרב קט...
# ✅ 14_12_2023 → תרשים 12יד': התפלגות מעצרים* של קטינים ת...
# ✅ 15_12_2023 → תרשים 12טו': התפלגות הקליטות* של קטינים ...
# ✅ 16_12_2023 → תרשים 12טז': התפלגות קליטת אסירים/עצירים...
# ✅ 1_1_2023 → תרשים 1ג': מספר הילדים (17-0) שקיבלו במה...
# ✅ 2_1_2023 → תרשים 1ד': שיעור הילדים (17-0) הזרים שקי...
# ⚠️ 5_1_2023 not found in /content/excel_and_json_2019_2021_2024/2023/1/1_2023.json
# ✅ 4_1_2023 → תרשים 1א': התפלגות הילדים בישראל, לפי דת...
# ✅ 1_9_2022 → תרשים 9א': שיעור פניות ילדים לחדרי מיון ...
# ✅ 2_9_2022 → תרשים 9ב': שיעור פניות ילדים לחדרי מיון ...
# ✅ 3_9_2022 → תרשים 9ג': שיעור פניות ילדים לחדרי מיון ...
# ✅ 4_9_2022 → תרשים 9ד': אחוז האשפוזים וימי אשפוז של י...
# ✅ 5_9_2022 → תרשים 9ה': התפלגות הסיבה החיצונית (תאונה...
# ✅ 6_9_2022 → תרשים 9ו': שיעור למאה אלף של תמותת ילדים...
# ✅ 7_9_2022 → תרשים 9ז': התפלגות מקרי תמותה עקב היפגעו...
# ✅ 8_9_2022 → תרשים 9ח': מספר הילדים (14-0) שנפגעו בתא...
# ✅ 9_9_2022 → תרשים 9ט': חלקם של ילדים (14-0) שנפגעו ב...
# ✅ 10_9_2022 → תרשים 9י': מספר הילדים (14-0) שנפצעו קשה...
# ✅ 11_9_2022 → תרשים 9יג': שיעור רוכבי אופניים / קורקינ...
# ✅ 12_9_2022 → תרשים 9יד': מספר רוכבי האופניים והקורקינ...
# ✅ 13_9_2022 → תרשים 9טז': התפלגות ילדים שהושארו או נלכ...
# ✅ 14_9_2022 → תרשים 9טז': מספר הילדים שנהרגו במהלך חופ...
# ✅ 15_9_2022 → תרשים 9יז': התפלגות הילדים שנהרגו בטביעה...
# ✅ 16_9_2022 → תרשים 9יח': מספר פניות ילדים עד גיל 17 ל...
# ✅ 17_9_2022 → תרשים 9יט': פניות ילדים עד גיל 17 למכון ...
# ✅ 18_9_2022 → תרשים 9כ: ליקויי בטיחות בסביבת בתי ספר י...
# ✅ 19_9_2022 → תרשים 9כא: ליקויי בטיחות בסביבת בתי ספר ...
# ✅ 20_9_2022 → תרשים 9כב: ליקויי בטיחות בסביבת בתי ספר ...
# ⚠️ 22_9_2022 not found in /content/excel_and_json_2019_2021_2024/2022/9/9_2022.json
# ✅ 1_6_2023 → תרשים 6א: פעילות של בני נוער (17-13) ברש...
# ✅ 2_6_2023 → תרשים 6ב: שיעור הילדים (12-8) ובני נוער ...
# ✅ 3_6_2023 → תרשים 6ג: התפלגות פעילות הורים בהגנה על ...
# ✅ 4_6_2023 → תרשים 6ד': רצון בני נוער (17-13) להגביל ...
# ✅ 5_6_2023 → תרשים 6ה: שימוש בני נוער (17-13) ברשתות ...
# ✅ 6_6_2023 → תרשים 6ו: זמן שהייה ברשתות חברתיות נבחרו...
# ✅ 7_6_2023 → תרשים 6ז': תחושות בני נוער (17-13) בעקבו...
# ✅ 8_6_2023 → תרשים 6ז':  שיעור הילדים ובני הנוער (17-...
# ✅ 9_6_2023 → תרשים 6ח':  שיעור הילדים ובני הנוער (17-...
# ✅ 10_6_2023 → תרשים 6ט': שיעור הנהגים עד גיל 18* מכלל ...
# ✅ 1_13_2022 → תרשים 13א': מספר התיקים הפליליים ותיקי ט...
# ✅ 2_13_2022 → תרשים 13ב': אחוז* התיקים הפליליים ותיקי ...
# ✅ 3_13_2022 → תרשים 13ג': שיעור התיקים הפליליים ותיקי ...
# ✅ 4_13_2022 → תרשים 13ד': התפלגות התיקים שנפתחו בגין ע...
# ✅ 5_13_2022 → תרשים 13ה': יישובים* שבהם שיעור התיקים ה...
# ✅ 6_13_2022 → תרשים 13ו': מספר הילדים שנרצחו בתוך המשפ...
# ✅ 7_13_2022 → תרשים 13ז':התפלגות הילדים שנרצחו בתוך המ...
# ✅ 8_13_2022 → תרשים 13ח': התפלגות התיקים שנפתחו בגין ר...
# ✅ 9_13_2022 → תרשים 13ט': מספר התיקים והגשת כתבי אישום...
# ✅ 10_13_2022 → תרשים 13י': שיעור התיקים שנפתחו בגין עבי...
# ✅ 11_13_2022 → תרשים 13יא': מספר התיקים שנפתחו לבגירים ...
# ✅ 12_13_2022 → תרשים 13יב': מספר התיקים שנפתחו לבגירים ...
# ✅ 13_13_2022 → תרשים 13יג': מספר התיקים שנפתחו לבגירים ...
# ✅ 14_13_2022 → תרשים 13יד': מספר התיקים שנפתחו בגין עבי...
# ✅ 15_13_2022 → תרשים 13טו': מספר הילדים עד גיל 14 שנחקר...
# ✅ 16_13_2022 → תרשים 13טז': התפלגות מעמד הילדים עד גיל ...
# ✅ 17_13_2022 → תרשים 13יז': התפלגות סוג העבירה עליה נחק...
# ✅ 18_13_2022 → תרשים 13יח': התפלגות הילדים היהודים עד ג...
# ✅ 19_13_2022 → תרשים 13יט': התפלגות הילדים הלא-יהודים ע...
# ✅ 1_14_2023 → תרשים 14א': התפלגות הילדים המוכרים למחלק...
# ✅ 2_14_2023 → תרשים 14ב':מספר הדיווחים* לעובדים סוציאל...
# ✅ 3_14_2023 → תרשים 14ג': זיקת הפוגע לילד שדווח עליו ל...
# ✅ 4_14_2023 → תרשים 14ד': דיווחים לעובדים סוציאליים לח...
# ✅ 5_14_2023 → תרשים 14ה': דיווחים לעובדים סוציאליים לח...
# ✅ 6_14_2023 → תרשים 14ו': שיעור דיווחי שווא*/ שלא נדרש...
# ✅ 7_14_2023 → תרשים 14ז': דיווחים על קטינים שבעניינם ה...
# ✅ 8_14_2023 → תרשים 14ח': התפלגות הגורם המפנה ומדווח ל...
# ✅ 9_14_2023 → תרשים 14ט': שיעור הילדים בסיכון שהיו בטי...
# ✅ 10_14_2023 → תרשים 14י': התפלגות* הילדים בסיכון שהיו ...
# ✅ 11_14_2023 → תרשים 14יא': מספר הילדים השוהים במקלטים ...
# ✅ 12_14_2023 → תרשים 14כג': מספר הפניות למוקד 105 (המטה...
# ✅ 13_14_2023 → תרשים 14יג': התפלגות משך השהות של ילדים ...
# ✅ 14_14_2023 → תרשים 14יד': מספר בני הנוער והצעירים בטי...
# ✅ 15_14_2023 → תרשים 14טו': התפלגות גילם של בני נוער וצ...
# ✅ 16_14_2023 → תרשים 14טז': התפלגות בני נוער וצעירים בט...
# ✅ 17_14_2023 → תרשים 14יז': מספר הקטינים הנעדרים, לפי מ...
# ✅ 18_14_2023 → תרשים 14יח': שיעור ניסיונות התאבדות של י...
# ✅ 19_14_2023 → תרשים 14יט': מספר הילדים בגיל 17-12 שניס...
# ✅ 20_14_2023 → תרשים 14כ': מספר ההתאבדויות של ילדים ובנ...
# ✅ 21_14_2023 → תרשים 14כא': שיעור ההתאבדויות של ילדים ו...
# ✅ 22_14_2023 → תרשים 14כב': שיעור ההתאבדויות של ילדים ו...
# ✅ 23_14_2023 → תרשים 14כג': מספר הפניות למוקד 105 (המטה...
# ✅ 24_14_2023 → תרשים 14כד': דיווחים למוקד 105, לפי מדוו...
# ✅ 25_14_2023 → תרשים 14כה': דיווחים למוקד 105, לפי סוג ...
# ✅ 26_14_2023 → תרשים 14כו': קטינים נפגעים באירועים שדוו...
# ✅ 27_14_2023 → תרשים 14כז': מטופלים במרכזים האזוריים לט...
# ✅ 28_14_2023 → תרשים 14כח': ילדים חשופים לאלימות בין הו...
# ✅ 29_14_2023 → תרשים 14כט': פניות למוקד 118 של משרד הרו...
# ✅ 30_14_2023 → תרשים 14ל': הערכות סיכון וטיפול בשירותים...
# ✅ 1_4_2022 → תרשים 4ב': מספר הילדים שהושמו בידי משרד ...
# ✅ 2_4_2022 → תרשים 4ג':  התפלגות הילדים שהושמו בידי מ...
# ✅ 3_4_2022 → תרשים 4א': התפלגות סוג משפחה* של ילדים ב...
# ✅ 4_4_2022 → תרשים 4ד': התפלגות הילדים* שהושמו בידי ש...
# ✅ 5_4_2022 → תרשים 4ה': התפלגות הסמנים* של ילדים שהוש...
# ✅ 6_4_2022 → תרשים 4ו': התפלגות הילדים שהושמו באומנה ...
# ✅ 7_4_2022 → תרשים 4ז': התפלגות גיל הילדים שהושמו באו...
# ✅ 8_4_2022 → תרשים 4ח': התפלגות האשפוזים של ילדים בגי...
# ✅ 1_6_2022 → תרשים 6ו': שיעור הנהגים עד גיל 18* מכלל ...
# ✅ 2_6_2022 → תרשים 6ב: פריצות סייבר לסמארטפון אישי, ל...
# ✅ 3_6_2022 → תרשים 6ג: זמן שהייה ברשתות חברתיות נבחרו...
# ✅ 4_6_2022 → תרשים 6ה':  שיעור הילדים ובני הנוער (17-...
# ✅ 5_6_2022 → תרשים 6ד':  שיעור הילדים ובני הנוער (17-...
# ✅ 6_6_2022 → תרשים 6א: פעילות של בני נוער (17-13) ברש...
# ✅ 1_13_2023 → תרשים 13א': מספר התיקים הפליליים ותיקי ט...
# ✅ 2_13_2023 → תרשים 13ג': שיעור התיקים הפליליים ותיקי ...
# ✅ 3_13_2023 → תרשים 13ב': אחוז* התיקים הפליליים ותיקי ...
# ✅ 4_13_2023 → תרשים 13ד': התפלגות התיקים שנפתחו בגין ע...
# ✅ 5_13_2023 → תרשים 13ה': יישובים* שבהם שיעור התיקים ה...
# ✅ 6_13_2023 → תרשים 13ו': מספר הילדים שנרצחו בתוך המשפ...
# ✅ 7_13_2023 → תרשים 13ז':התפלגות הילדים שנרצחו בתוך המ...
# ✅ 8_13_2023 → תרשים 13ח': התפלגות התיקים שנפתחו בגין ר...
# ✅ 9_13_2023 → תרשים 13ט': מספר התיקים והגשת כתבי אישום...
# ✅ 10_13_2023 → תרשים 13י': שיעור התיקים שנפתחו בגין עבי...
# ✅ 11_13_2023 → תרשים 13יא': מספר התיקים שנפתחו לבגירים ...
# ✅ 12_13_2023 → תרשים 13יב': מספר התיקים שנפתחו לבגירים ...
# ✅ 13_13_2023 → תרשים 13יג': מספר התיקים שנפתחו לבגירים ...
# ✅ 14_13_2023 → תרשים 13יד': מספר התיקים שנפתחו בגין עבי...
# ✅ 15_13_2023 → תרשים 13טו': מספר הילדים עד גיל 14 שנחקר...
# ✅ 16_13_2023 → תרשים 13טז': התפלגות מעמד הילדים עד גיל ...
# ✅ 17_13_2023 → תרשים 13יז': התפלגות סוג העבירה עליה נחק...
# ✅ 18_13_2023 → תרשים 13יח': התפלגות הילדים היהודים עד ג...
# ✅ 19_13_2023 → תרשים 13יט': התפלגות הילדים הלא-יהודים ע...
# ✅ 1_7_2023 → תרשים 7א': אומדן מספר ילדים עם מוגבלויות...
# ✅ 2_7_2023 → תרשים 7ח': התפלגות ילדים המקבלים קצבת יל...
# ✅ 3_7_2023 → תרשים 7ב': אומדן מספר ילדים עם מוגבלויות...
# ✅ 4_7_2023 → תרשים 7ג: התפלגות ילדים ובני נוער בני 17...
# ✅ 5_7_2023 → תרשים 7ד: התפלגות ילדים ובני נוער בני 17...
# ✅ 6_7_2023 → תרשים 7ו': התפלגות תלמידים הזכאים לשירות...
# ✅ 7_7_2023 → תרשים 7ז': התפלגות תלמידי החינוך המיוחד ...
# ✅ 1_5_2023 → תרשים 5א': שיעור הלומדים במערכת החינוך*,...
# ✅ 2_5_2023 → תרשים 5ב': שיעור* התחושות החיוביות כלפי ...
# ✅ 3_5_2023 → תרשים 5ג': שיעור* התלמידים שהעידו על יחס...
# ✅ 4_5_2023 → תרשים 5ד': התפלגות הגשת ערעורים של תלמיד...
# ✅ 5_5_2023 → תרשים 5ה': מספר התלמידים שהורחקו לאלתר* ...
# ✅ 6_5_2023 → תרשים 5ו': התפלגות התלמידים בטיפול קציני...
# ✅ 7_5_2023 → תרשים 5ז': שיעור (לאלף) של התלמידים שנשר...
# ✅ 8_5_2023 → תרשים 5ח': היישובים בהם אחוז הנשירה מבתי...
# ✅ 9_5_2023 → תרשים 5ט': שיעור הזכאים לתעודת בגרות מתל...
# ✅ 10_5_2023 → תרשים 5יב': שיעור הזכאים לתעודת בגרות שנ...
# ✅ 11_5_2023 → תרשים 5יג': שיעור הזכאים לתעודת בגרות מצ...
# ✅ 12_5_2023 → תרשים 5יד': שיעור הזכאים לתעודת בגרות וש...
# ✅ 13_5_2023 → תרשים 5טז': זכאות לבגרות לפי השכלת אם, ל...
# ✅ 14_5_2023 → תרשים 5יז': התפלגות הנבחנים בבחינת בגרות...
# ✅ 15_5_2023 → תרשים 5יח': התפלגות הבקשות שהוגשו לפטור ...
# ✅ 16_5_2023 → תרשים 5יט': שיעור בני הנוער הלומדים לתוא...
# ✅ 17_5_2023 → תרשים 5כ': התפלגות בני נוער הלומדים לתוא...
# ✅ 18_5_2023 → תרשים 5כא': שיעור בני נוער הלומדים לתואר...
# ⚠️ 30_5_2023 not found in /content/excel_and_json_2019_2021_2024/2023/5/5_2023.json
# ✅ 20_5_2023 → תרשים 5לא' שיעורי התלמידים (בכיתות ד') ב...
# ✅ 21_5_2023 → תרשים 5כב': שיעור בני נוער הלומדים לתואר...
# ✅ 22_5_2023 → תרשים 5כג': שיעור בני נוער הלומדים לתואר...
# ✅ 23_5_2023 → תרשים 5כד': שיעור בני נוער הלומדים לתואר...
# ✅ 24_5_2023 → תרשים 5כה': שיעור השכלה אקדמית של הורים ...
# ✅ 25_5_2023 → תרשים 5כו': שיעור השכלה אקדמית של הורים ...
# ✅ 26_5_2023 → תרשים 5כז': ילדים בדואים בגילי 3 עד 5 מח...
# ✅ 27_5_2023 → תרשים 5כח': שיעורי למידה ל-1,000 נפשות ב...
# ✅ 28_5_2023 → תרשים 5כט: התראות* שהתקבלו באמצעות מנגנו...
# ✅ 29_5_2023 → תרשים 5כט: שיעורי התלמידים (בכיתות ד') ב...
# ✅ 1_4_2023 → תרשים 4ב': מספר הילדים שהושמו בידי משרד ...
# ✅ 2_4_2023 → תרשים 4ג':  התפלגות הילדים שהושמו בידי מ...
# ✅ 3_4_2023 → תרשים 4א': התפלגות סוג משפחה* של ילדים ב...
# ✅ 4_4_2023 → תרשים 4ד': התפלגות הילדים* שהושמו בידי ש...
# ✅ 5_4_2023 → תרשים 4ה': התפלגות הסמנים* של ילדים שהוש...
# ✅ 6_4_2023 → תרשים 4ו': התפלגות הילדים שהושמו באומנה ...
# ✅ 7_4_2023 → תרשים 4ז': התפלגות גיל הילדים שהושמו באו...
# ✅ 8_4_2023 → תרשים 4ח': התפלגות האשפוזים של ילדים בגי...
# ✅ 1_14_2022 → תרשים 14יט': מספר ההתאבדויות של ילדים וב...
# ✅ 2_14_2022 → תרשים 14יח': מספר הילדים בגיל 17-12 שניס...
# ✅ 3_14_2022 → תרשים 14יז': שיעור ניסיונות התאבדות של י...
# ✅ 4_14_2022 → תרשים 14טז': התפלגות הקטינים הנעדרים*, ל...
# ✅ 5_14_2022 → תרשים 14יג': מספר בני הנוער והצעירים בטי...
# ✅ 6_14_2022 → תרשים 14יד': התפלגות גילם של בני נוער וצ...
# ✅ 7_14_2022 → תרשים 14טו': התפלגות בני נוער וצעירים בט...
# ✅ 8_14_2022 → תרשים 14כ': שיעור ההתאבדויות של ילדים וב...
# ✅ 9_14_2022 → תרשים 14כז': ילדים חשופים לאלימות בין הו...
# ✅ 10_14_2022 → תרשים 14כו': מטופלים במרכזים האזוריים לט...
# ✅ 11_14_2022 → תרשים 14כח': פניות למוקד 118 של משרד הרו...
# ✅ 12_14_2022 → תרשים 14כט': הערכות סיכון וטיפול בשירותי...
# ✅ 13_14_2022 → תרשים 14כה': קטינים נפגעים באירועים שדוו...
# ✅ 14_14_2022 → תרשים 14כד': דיווחים למוקד 105, לפי סוג ...
# ✅ 15_14_2022 → תרשים 14כא': שיעור ההתאבדויות של ילדים ו...
# ✅ 16_14_2022 → תרשים 14כב': מספר הפניות למוקד 105 (המטה...
# ✅ 17_14_2022 → תרשים 14כג': דיווחים למוקד 105, לפי מדוו...
# ✅ 18_14_2022 → תרשים 14יב': התפלגות משך השהות של ילדים ...
# ✅ 19_14_2022 → תרשים 14ז': דיווחים על קטינים שבעניינם ה...
# ✅ 20_14_2022 → תרשים 14ו': שיעור דיווחי שווא*/ שלא נדרש...
# ✅ 21_14_2022 → תרשים 14ח': התפלגות הגורם המפנה ומדווח ל...
# ✅ 22_14_2022 → תרשים 14ט': התפלגות* הילדים בסיכון שהיו ...
# ✅ 23_14_2022 → תרשים 14ח': שיעור הילדים בסיכון שהיו בטי...
# ✅ 24_14_2022 → תרשים 14ה': דיווחים לעובדים סוציאליים לח...
# ✅ 25_14_2022 → תרשים 14א': התפלגות הילדים המוכרים למחלק...
# ✅ 26_14_2022 → תרשים 14ב':מספר הדיווחים* לעובדים סוציאל...
# ✅ 27_14_2022 → תרשים 14ד': דיווחים לעובדים סוציאליים לח...
# ✅ 28_14_2022 → תרשים 14ג': זיקת הפוגע לילד שדווח עליו ל...
# ✅ 29_14_2022 → תרשים 14י': מספר הילדים השוהים במקלטים ל...
# ✅ 30_14_2022 → תרשים 14יא': התפלגות הגילים של ילדים השו...
# ✅ 1_9_2023 → תרשים 9א': שיעור פניות ילדים לחדרי מיון ...
# ✅ 2_9_2023 → תרשים 9ב': שיעור פניות ילדים לחדרי מיון ...
# ✅ 3_9_2023 → תרשים 9ג': שיעור פניות ילדים לחדרי מיון ...
# ✅ 4_9_2023 → תרשים 9ד': אחוז האשפוזים וימי אשפוז של י...
# ✅ 5_9_2023 → תרשים 9ה': התפלגות הסיבה החיצונית (תאונה...
# ✅ 6_9_2023 → תרשים 9ו': שיעור למאה אלף של תמותת ילדים...
# ✅ 7_9_2023 → תרשים 9ז': התפלגות מקרי תמותה עקב היפגעו...
# ✅ 8_9_2023 → תרשים 9ח': מספר הילדים (14-0) שנפגעו בתא...
# ✅ 9_9_2023 → תרשים 9ט': חלקם של ילדים (14-0) שנפגעו ב...
# ✅ 10_9_2023 → תרשים 9י': מספר הילדים (14-0) שנפצעו קשה...
# ✅ 11_9_2023 → תרשים 9יג': שיעור רוכבי אופניים / קורקינ...
# ✅ 12_9_2023 → תרשים 9יד': מספר רוכבי האופניים והקורקינ...
# ✅ 13_9_2023 → תרשים 9טו': התפלגות ילדים שהושארו או נלכ...
# ✅ 14_9_2023 → תרשים 9טז': מספר הילדים שנהרגו במהלך חופ...
# ✅ 15_9_2023 → תרשים 9יז': התפלגות הילדים שנהרגו בטביעה...
# ✅ 16_9_2023 → תרשים 9יח': מספר פניות ילדים בגילאים 17-...
# ✅ 17_9_2023 → תרשים 9יט;: חלוקה בין ילדים ובני נוער לב...
# ✅ 18_9_2023 → תרשים 9יא': מספר רוכבי אופניים חשמליים ו...
# ✅ 19_9_2023 → תרשים 9יב': שיעור רוכבי אופניים/קורקינט ...
# ⚠️ 22_9_2023 not found in /content/excel_and_json_2019_2021_2024/2023/9/9_2023.json
# ✅ 21_9_2023 → תרשים 9כב: ליקויי בטיחות בסביבת בתי ספר ...
# ✅ 1_2_2022 → תרשים 2א': מספר הילדים העולים* וילדי עול...
# ✅ 2_2_2022 → תרשים 2ב': שיעור הילדים העולים (ילידי חו...
# ✅ 3_2_2022 → תרשים 2ג': שיעור הילדים העולים, יליד חו"...
# ✅ 4_2_2022 → תרשים 2ד': מספר הילדים העולים, לפי שנת ע...
# ✅ 5_2_2022 → תרשים 2ה': התפלגות ילדים עולים שעלו ב-20...
# ✅ 6_2_2022 → תרשים 2ו': ילדים אזרחים עולים* (17-0), ל...
# ✅ 7_2_2022 → תרשים 2ז': התפלגות ילדי העולים* (17-0) ו...
# ✅ 8_2_2022 → תרשים 2ח': שיעור ילדי עולים*, לפי מספר ה...
# ✅ 9_2_2022 → תרשים 2ט': מספר ילדים* ממוצע במשפחות עול...
# ✅ 10_2_2022 → תרשים 2י': התפלגות ילדי עולים* לפי גיל ו...
# ✅ 11_2_2022 → תרשים 2יא': שיעור הילדים העולים* מכלל או...
# ✅ 12_2_2022 → תרשים 2יב': שיעור התינוקות והפעוטות של מ...
# ✅ 13_2_2022 → תרשים 2יג': שיעור התינוקות והפעוטות של מ...
# ✅ 14_2_2022 → תרשים 2יד': מספר התינוקות והפעוטות של מה...
# ✅ 15_2_2022 → תרשים 2טו': מספר ילדי מהגרי עבודה ילדי ז...
# ✅ 16_2_2022 → תרשים 2טז': גיל ילדי מהגרי עבודה וילדי ז...
# ✅ 1_12_2022 → תרשים 12א': התפלגות קטינים חשודים ונילונ...
# ✅ 2_12_2022 → תרשים 12ב': שיעור הקטינים החשודים* עם תי...
# ✅ 3_12_2022 → תרשים 12ג': התפלגות תיקים פליליים ותיקי ...
# ✅ 4_12_2022 → תרשים 12ד': התפלגות תיקים שנפתחו לקטינים...
# ✅ 5_12_2022 → תרשים 12ה': שיעור הקטינים החשודים עם תיק...
# ✅ 6_12_2022 → תרשים 12ו': שיעור התיקים שנפתחו לקטינים ...
# ✅ 7_12_2022 → תרשים 12ז': מספר הקטינים העצורים, לפי שנ...
# ✅ 8_12_2022 → תרשים 12ח': התפלגות גילאי הקטינים העצורי...
# ✅ 9_12_2022 → תרשים 12ט': התפלגות קטינים המופנים בידי ...
# ✅ 10_12_2022 → תרשים 12י': שיעור הקטינים בטיפול שירות ה...
# ✅ 11_12_2022 → תרשים 12יא': מספר ההליכים הפליליים שבהם ...
# ✅ 12_12_2022 → תרשים 12יב': מספר ההליכים הפליליים שבהם ...
# ✅ 13_12_2022 → תרשים 12יג': יחס הרשעה/אי הרשעה* בקרב קט...
# ✅ 14_12_2022 → תרשים 12יד': התפלגות מעצרים* של קטינים ת...
# ✅ 15_12_2022 → תרשים 12טו': התפלגות הקליטות* של קטינים ...
# ✅ 16_12_2022 → תרשים 12טז': התפלגות קליטת אסירים/עצירים...
# ✅ 1_11_2023 → תרשים 11א': החלטות של בתי משפט שלום לנוע...
# ✅ 1_10_2022 → תרשים 10א': שיעור אוכלוסיית הילדים בישרא...
# ✅ 2_10_2022 → תרשים 10ד': תחולת העוני בקרב ילדים לאחר ...
# ✅ 3_10_2022 → תרשים 10ה': שיעור הילדים במשפחות המקבלות...
# ✅ 4_10_2022 → תרשים 10ו': שיעור הילדים החיים במשפחות ה...
# ✅ 5_10_2022 → תרשים 10ז': שיעור הילדים שחיו במשק בית ל...
# ✅ 6_10_2022 → תרשים 10ח': שיעור הילדים (וילדים עולים) ...
# ✅ 7_10_2022 → תרשים 10יג': ההתפלגות ההוצאה החודשית לחי...
# ✅ 8_10_2022 → תרשים 10ב': שיעור הילדים בעשרת אשכולות ה...
# ✅ 9_10_2022 → תרשים 10ט': שיעור בני 17-15 שעובדים* מקב...
# ✅ 10_10_2022 → תרשים 10ג': תחולת העוני* בקרב ילדים (אחו...
# ✅ 11_10_2022 → תרשים 10י': פילוח הפניות להסתדרות הנוער ...
# ✅ 12_10_2022 → תרשים 10יא': מספר כתבי אישום שהגיש מינהל...
# ✅ 13_10_2022 → תרשים 10יב': הוצאה חודשית ממוצעת של משקי...
# ✅ 1_11_2022 → תרשים 11ב': מספר הבקשות לאישור נישואי קט...
# ✅ 2_11_2022 → תרשים 11א': החלטות של בתי משפט שלום לנוע...
# ✅ 1_3_2023 → תרשים 3ב': שיעור המשפחות שבראשן הורה עצמ...
# ✅ 2_3_2023 → תרשים 3ג': מספר הילדים החיים במשפחות המק...
# ✅ 3_3_2023 → תרשים 3ד': התפלגות ילדים יתומים החיים במ...
# ✅ 4_3_2023 → תרשים 3ה': התפלגות הילדים שאומצו בידי אז...
# ✅ 5_3_2023 → תרשים 3ו': נישואי קטינים לפי גיל* ושנה (...
# ✅ 6_3_2023 → תרשים 3א': התפלגות הילדים החיים במשפחות ...
# ✅ 1_10_2023 → תרשים 10א': שיעור אוכלוסיית הילדים בישרא...
# ✅ 2_10_2023 → תרשים 10ב': שיעור הילדים בעשרת אשכולות ה...
# ✅ 4_10_2023 → תרשים 10ג': תחולת העוני* בקרב ילדים (אחו...
# ✅ 5_10_2023 → תרשים 10ד': תחולת העוני בקרב ילדים לאחר ...
# ✅ 6_10_2023 → תרשים 10ה': שיעור הילדים במשפחות המקבלות...
# ✅ 7_10_2023 → תרשים 10ו': שיעור הילדים החיים במשפחות ה...
# ✅ 8_10_2023 → תרשים 10ז': שיעור הילדים שחיו במשק בית ל...
# ✅ 9_10_2023 → תרשים 10ח': שיעור הילדים (וילדים עולים) ...
# ✅ 10_10_2023 → תרשים 10ט': שיעור בני 17-15 שעובדים* מקב...
# ✅ 11_10_2023 → תרשים 10י': פילוח הפניות להסתדרות הנוער ...
# ✅ 12_10_2023 → תרשים 10יא': כתבי אישום (בגין הפרת חוק ה...
#
# 🎉 Done! Updated summary saved to /content/graphs_summary.json
