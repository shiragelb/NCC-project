# %%
# %%writefile real_embeddings.py

import numpy as np
import pickle
import os
import hashlib

try:
    from sentence_transformers import SentenceTransformer
    TRANSFORMER_AVAILABLE = True
except:
    TRANSFORMER_AVAILABLE = False
    print("Install with: !pip install sentence-transformers")


class RealEmbeddingGenerator:
    def __init__(self, model_name="onlplab/alephbert-base", cache_dir="cache"):
        self.cache_dir = cache_dir
        os.makedirs(cache_dir, exist_ok=True)
        self.embedding_cache = {}


        if TRANSFORMER_AVAILABLE:
            self.model = SentenceTransformer(model_name)
            self.dimension = self.model.get_sentence_embedding_dimension()
        else:
            self.model = None
            self.dimension = 768

    def get_text_hash(self, text):
        return hashlib.md5(text.encode('utf-8')).hexdigest()

    def generate_embedding(self, text, use_cache=True):
        text_hash = self.get_text_hash(text)
        print("Fallback to random embeddings.")
        if use_cache and text_hash in self.embedding_cache:
            return self.embedding_cache[text_hash]

        if self.model:
            embedding = self.model.encode(text, convert_to_numpy=True)
        else:
            # Fallback to deterministic random
            np.random.seed(int(text_hash[:8], 16) % 10000)
            embedding = np.random.randn(self.dimension)

        if use_cache:
            self.embedding_cache[text_hash] = embedding



        return embedding

    def generate_batch(self, texts, show_progress=True):
        if self.model:
            return self.model.encode(texts,
                                    batch_size=32,
                                    show_progress_bar=show_progress,
                                    convert_to_numpy=True)
        else:
            return np.array([self.generate_embedding(t) for t in texts])

    def save_cache(self):
        cache_file = os.path.join(self.cache_dir, "embedding_cache.pkl")
        with open(cache_file, 'wb') as f:
            pickle.dump(self.embedding_cache, f)
# Out:
# Writing real_embeddings.py

# %%
# cosin similiarity for each photo with all chapter tables.
# and an API call to see if redundent photo with the max similarity.
# output 2 json files - 1. YES/NO (redundent or not) 2. YES/NO + explanation (reasoning)
# cost of about 7$ total  ###

# !pip install sentence-transformers
# !pip install anthropic

import os
import sys
sys.path.append("/content")
import json
import numpy as np
from real_embeddings import RealEmbeddingGenerator
import anthropic



# ---------- Utils ----------
def cosine_similarity(a, b):
    """Compute cosine similarity between two vectors."""
    a, b = np.array(a).flatten(), np.array(b).flatten()
    return np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b) + 1e-8)

def normalize_scores(scores):
    """Normalize a list of scalar scores to 0-1 range."""
    scores = [float(s) for s in scores]
    if not scores:
        return scores
    min_s, max_s = min(scores), max(scores)
    if max_s - min_s < 1e-8:
        return [1.0] * len(scores)
    return [(s - min_s) / (max_s - min_s) for s in scores]

json_file_id = "redundant_graphs.json"
json_file_info = "redundant_graphs_info.json"

def analyze_graph_redundancy(year, chapter_id, table_json_url, graph_json_url, threshold=0.25, api_threshold=0.55):
    """
    Match tables and graphs for a single chapter and decide if graph is just analysis.
    """

    # Load JSONs
    with open(table_json_url, "r", encoding="utf-8") as f:
        tables = json.load(f)
    with open(graph_json_url, "r", encoding="utf-8") as f:
        graphs = json.load(f)

    # Filter for one chapter
    tables = {k: v for k, v in tables.items()
              if int(k.split("_")[2]) == int(year) and int(k.split("_")[1]) == int(chapter_id)}
    graphs = {k: v for k, v in graphs.items()
              if int(k.split("_")[2]) == int(year) and int(k.split("_")[1]) == int(chapter_id)}

    print(f"✅ Loaded {len(tables)} tables and {len(graphs)} graphs for chapter {chapter_id}\n")

    embedder = RealEmbeddingGenerator()
    table_keys, table_texts = list(tables.keys()), list(tables.values())
    graph_keys, graph_texts = list(graphs.keys()), list(graphs.values())

    # Embed all at once
    table_embs = embedder.generate_batch(table_texts, show_progress=True)
    graph_embs = embedder.generate_batch(graph_texts, show_progress=True)

    # Cloud API client
    client = anthropic.Anthropic(
        api_key= "" # replace with your actual API key
    )

    results = []
    efficiency = {"checked": 0, "sent_to_api": 0, "high_sim": 0}

    for gi, g_emb in enumerate(graph_embs):
        g_text, g_key = graph_texts[gi], graph_keys[gi]

        sims = [cosine_similarity(g_emb, t_emb) for t_emb in table_embs]
        sims_norm = normalize_scores(sims)

        avg_sim = float(np.mean(sims_norm))
        best_idx = int(np.argmax(sims))
        best_sim, best_table = sims[best_idx], table_texts[best_idx]
        efficiency["checked"] += 1

        print(best_sim, best_table)

        if best_sim >= threshold:
            efficiency["high_sim"] += 1

            prompt = f"""
            You are an expert in data analysis and visualization.

            Task:
            Decide if the graph is a redundant visualization of the table — meaning that all the information in the graph
            can be derived or regenerated directly from the table data (possibly with filtering, aggregation, or converting counts to percentages).

            Rules:
            - Answer "YES" if:
              * The graph uses only a subset of the variables, time ranges, or measures already present in the table.
              * The graph is a simpler or filtered view of the table (e.g., table has numbers and the graph shows percentages, or the table has multiple breakdowns and the graph shows just one).
            - Answer "NO" if:
              * The graph introduces any variable, breakdown, or dimension not included in the table (e.g., family size, gender, region, etc.).
              * The graph includes years or time periods not covered by the table.
              * The graph uses measures not derivable from the table.

            Important:
            We want to mark graphs as "YES" whenever they are redundant and can be safely removed without losing unique information.

            Return !STRICTLY! a JSON object:
            {{
                "is_analysis": "YES" or "NO",
                "explanation": "<short reasoning>"
            }}

            Table header (heb): "{best_table}"
            Graph header/title (heb): "{g_text}"
            """
            print("starting the API call")
            response = client.messages.create(
                # model="claude-3-haiku-20240307",
                model = "claude-3-7-sonnet-20250219",
                max_tokens=500,
                messages=[{"role": "user", "content": prompt}]
            )
            efficiency["sent_to_api"] += 1

            print("got answer")
            try:
                import re
                import ast

                raw_text = response.content[0].text.strip()
                print(raw_text)

                # Extract JSON-like substring that contains "is_analysis"
                match = re.search(r'(\{.*?"is_analysis".*?\})', raw_text, re.DOTALL)
                if match:
                    json_str = match.group(1)
                    try:
                        api_json = json.loads(json_str)
                    except Exception:
                        try:
                            api_json = ast.literal_eval(json_str)
                        except Exception:
                            api_json = {"is_analysis": "NO", "explanation": "Fallback parse failed."}
                else:
                    api_json = {"is_analysis": "NO", "explanation": "No JSON found in response."}
                    print("fallback")


                is_analysis = api_json.get("is_analysis", "NO")
                explanation = api_json.get("explanation", "")
            except Exception:
                is_analysis = "NO"
                explanation = "Could not parse API output safely."
                print("fallback")

        else:
            is_analysis = "NO"
            explanation = f"Similarity {best_sim:.2f} below threshold."

        # --- Save ID → YES/NO ---
        if os.path.exists(json_file_id):
            with open(json_file_id, "r", encoding="utf-8") as f:
                id_data = json.load(f)
        else:
            id_data = {}
        id_data[g_key] = is_analysis

        with open(json_file_id, "w", encoding="utf-8") as f:
            json.dump(id_data, f, ensure_ascii=False, indent=2)

        # --- Save full info object ---
        info_obj = {
        "table": best_table,
        "graph": g_text,
        "similarity": float(best_sim),  # ensure JSON serializable
        "is_analysis": is_analysis,
        "explanation": explanation
        }

        # Load existing data safely, or start with empty dict
        if os.path.exists(json_file_info):
            with open(json_file_info, "r", encoding="utf-8") as f:
                try:
                    info_data = json.load(f)
                    if not isinstance(info_data, dict):
                        info_data = {}  # fallback if JSON is a list or corrupted
                        print("fallback")
                except Exception:
                    info_data = {}
        else:
            info_data = {}

        # Save/update entry
        info_data[g_key] = info_obj

        # Write back to JSON
        with open(json_file_info, "w", encoding="utf-8") as f:
            json.dump(info_data, f, ensure_ascii=False, indent=2)

        print(f"Saved graph {g_key}: {is_analysis}")

    print("✅ All graphs processed and saved.")


## Run
for year in range(2016,2017):
  for chap in range(1,15):
    analyze_graph_redundancy(
          year=str(year),
          chapter_id=f"{chap:02d}",
          # chapter_id= "3",
          table_json_url="/content/tables_summary_all_cleaned.json",
          graph_json_url="/content/graphs_summary.json",
          threshold=0.7
      )
# Out:
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.12/dist-packages (5.1.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (4.56.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (2.8.0+cu126)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (1.16.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (0.34.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (11.3.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.4)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.1.9)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.4.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.22.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sentence-transformers) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2025.8.3)
# Requirement already satisfied: anthropic in /usr/local/lib/python3.12/dist-packages (0.68.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /usr/local/lib/python3.12/dist-packages (from anthropic) (0.17.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (0.10.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (2.11.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.12/dist-packages (from anthropic) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->anthropic) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->anthropic) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.1)
# WARNING:sentence_transformers.SentenceTransformer:No sentence-transformers model found with name onlplab/alephbert-base. Creating a new one with mean pooling.
# ✅ Loaded 0 tables and 0 graphs for chapter 01
# Some weights of BertModel were not initialized from the model checkpoint at onlplab/alephbert-base and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Batches: 0it [00:00, ?it/s]
# Batches: 0it [00:00, ?it/s]
# WARNING:sentence_transformers.SentenceTransformer:No sentence-transformers model found with name onlplab/alephbert-base. Creating a new one with mean pooling.
# ✅ All graphs processed and saved.
# ✅ Loaded 16 tables and 11 graphs for chapter 02
# Some weights of BertModel were not initialized from the model checkpoint at onlplab/alephbert-base and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 0.8565646 לוח 2.7 גילם של ילדי עולים^ (0-17) (מספרים ואחוזים) 2005-2015
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "NO",
#     "explanation": "The graph includes 'ילדים עולים' (immigrant children) as a separate category, which appears to be distinct from 'ילדי עולים' (children of immigrants) that the table focuses on. The graph also starts from 2006 while the table starts from 2005, suggesting they may contain different time periods or data points."
# }
# ```
# Saved graph 1_2_2016: NO
# 0.8774385 לוח  2.8 חלקם של ילדי עולים^ בכלל ילדי היישוב (יישובים בני 5,000 נפש ויותר)  (מספרים ואחוזים)  דצמבר 2015
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "NO",
#     "explanation": "The graph shows data from 2006-2015, but the table only includes data from December 2015. The graph includes historical data over a 10-year period that is not present in the table, making it non-redundant."
# }
# ```
# Saved graph 2_2_2016: NO
# 0.8483849 לוח 2.2 ילדים עולים^ לפי תקופת העלייה לישראל, ארץ מוצא וגילם היום (מספרים) דצמבר 2015
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "YES",
#     "explanation": "The graph shows percentages of immigrant children by country of origin in December 2015, which can be directly calculated from the table that contains the raw numbers of immigrant children by period of immigration, country of origin, and current age as of December 2015. The graph simply presents the country of origin data as percentages instead of absolute numbers."
# }
# ```
# Saved graph 3_2_2016: YES
# 0.924978 לוח 2.7 גילם של ילדי עולים^ (0-17) (מספרים ואחוזים) 2005-2015
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "NO",
#     "explanation": "The graph covers a much wider time period (1990-2015) than the table (2005-2015). The graph shows data from 1990-2004 that is not present in the table, making it contain unique information that would be lost if removed."
# }
# ```
# Saved graph 4_2_2016: NO
# 0.8785998 לוח 2.7 גילם של ילדי עולים^ (0-17) (מספרים ואחוזים) 2005-2015
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "NO",
#     "explanation": "The graph shows a breakdown by number of children per family, which is a dimension not present in the table. The table only shows ages of immigrant children, while the graph introduces family size as a new variable that cannot be derived from the age distribution data."
# }
# ```
# Saved graph 5_2_2016: NO
# 0.8321951 לוח  2.8 חלקם של ילדי עולים^ בכלל ילדי היישוב (יישובים בני 5,000 נפש ויותר)  (מספרים ואחוזים)  דצמבר 2015
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "YES",
#     "explanation": "The graph shows locations where immigrant children make up 20% or more of the child population as of December 2015, which is a filtered subset of the table data. The table contains percentage data of immigrant children across all localities (with 5,000+ residents) as of December 2015, so the graph simply highlights specific localities meeting the 20%+ threshold using the same underlying data."
# }
# ```
# Saved graph 6_2_2016: YES
# 0.87470996 לוח 2.9 מין הילדים* העולים   לפי תקופת עלייה (מספרים ואחוז מכלל העולים בקבוצה המתאימה) 1948-2015
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "YES",
#     "explanation": "The graph shows the percentage of immigrant children within the total immigrant population across different time periods from 1948-2015, which can be derived directly from the table data. The table contains both numbers and percentages of immigrant children by period, and the graph is simply visualizing the percentage information already present in the table, making it redundant."
# }
# ```
# Saved graph 7_2_2016: YES
# 0.8868706 לוח 2.10 ילדים (0-17) שמעמדם שונה מתייר לעולה חדש לפי ארץ מוצא* ושנת עלייה (מספרים ואחוזים)     2010-2016
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "YES",
#     "explanation": "The graph shows percentages of children (0-17) whose status changed from tourist to new immigrant as a portion of all immigrants with changed status for 2010-2016. This is directly derivable from the table which contains both numbers and percentages of these children by country of origin and year of immigration for the same time period (2010-2016). The graph is simply presenting a visualization of percentage data already contained in the table."
# }
# ```
# Saved graph 8_2_2016: YES
# 0.9555635 לוח 2.11 תינוקות ופעוטות של מהגרי עבודה, מבקשי מקלט ומסתננים שטופלו בתחנות לבריאות המשפחה (טיפות חלב) לפי מחוז וגיל (מספרים)  2010-2015
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "YES",
#     "explanation": "The graph shows percentages of infants and toddlers of migrant workers and asylum seekers treated at family health stations (well-baby clinics) by age for 2015, which is derived from the table data that contains numbers for the same population by district and age for 2010-2015. The graph is simply presenting the age breakdown as percentages for the year 2015, which can be calculated directly from the table's numerical data."
# }
# ```
# Saved graph 9_2_2016: YES
# 0.89750063 לוח 2.11 תינוקות ופעוטות של מהגרי עבודה, מבקשי מקלט ומסתננים שטופלו בתחנות לבריאות המשפחה (טיפות חלב) לפי מחוז וגיל (מספרים)  2010-2015
# starting the API call
# got answer
# {
#     "is_analysis": "NO",
#     "explanation": "The graph covers data from 1996-2015, while the table only contains data from 2010-2015. The graph specifically focuses on Tel Aviv-Yafo city, while the table appears to be organized by broader districts. Since the graph includes years (1996-2009) not covered in the table, it contains unique information that would be lost if removed."
# }
# Saved graph 10_2_2016: NO
# 0.8598674 לוח 2.11 תינוקות ופעוטות של מהגרי עבודה, מבקשי מקלט ומסתננים שטופלו בתחנות לבריאות המשפחה (טיפות חלב) לפי מחוז וגיל (מספרים)  2010-2015
# starting the API call
# WARNING:sentence_transformers.SentenceTransformer:No sentence-transformers model found with name onlplab/alephbert-base. Creating a new one with mean pooling.
# got answer
# ```json
# {
#     "is_analysis": "NO",
#     "explanation": "The graph shows data specifically from 'קופת חולים מאוחדת' (Meuhedet Health Fund), which is not mentioned in the table. The table shows data from 'תחנות לבריאות המשפחה' (family health stations/Tipat Halav). These are different healthcare services, so the graph contains information not derivable from the table."
# }
# ```
# Saved graph 11_2_2016: NO
# ✅ All graphs processed and saved.
# ✅ Loaded 14 tables and 9 graphs for chapter 03
# Some weights of BertModel were not initialized from the model checkpoint at onlplab/alephbert-base and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 0.89893866 לוח 3.2 ילדים (0-17) במשפחות שבראשן הורה עצמאי^  לפי מצבו המשפחתי של ההורה (מספרים ואחוזים) 2015*
# starting the API call
# got answer
# {
#     "is_analysis": "NO",
#     "explanation": "The graph shows a time series from 1995-2015, while the table only contains data for 2015. The graph provides historical data across multiple years that is not present in the table, so it contains unique information not derivable from the table."
# }
# Saved graph 1_3_2016: NO
# 0.8473906 לוח 3.3 ילדים במשפחות שבראשן הורה עצמאי^ וחלקם בכלל ילדי היישוב (יישובים בני 5,000 נפש ויותר) (מספרים ואחוזים) 2000-2015*
# starting the API call
# got answer
# {
#     "is_analysis": "NO",
#     "explanation": "The graph shows a breakdown of children in single-parent families by immigrant status (new immigrants vs. established residents), which is not a variable present in the table. The table shows data about single-parent families across different localities, but does not segment this data by immigrant status. Therefore, the graph introduces a new dimension not included in the table data."
# }
# Saved graph 2_3_2016: NO
# 0.85474044 לוח 3.3 ילדים במשפחות שבראשן הורה עצמאי^ וחלקם בכלל ילדי היישוב (יישובים בני 5,000 נפש ויותר) (מספרים ואחוזים) 2000-2015*
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "NO",
#     "explanation": "The graph shows specific localities where children in single-parent families comprise 15% or more of all children in that locality, which is a filtered subset with a specific threshold. While the table contains data about single-parent families by locality, the graph applies a specific filter criterion (15%+) to highlight particular localities meeting this threshold. The graph represents a derived analytical view that adds meaningful interpretation beyond the raw data in the table."
# }
# ```
# Saved graph 3_3_2016: NO
# 0.86727846 לוח 3.7 ילדים יתומים החיים במשפחות שמקבלות גמלה מהמוסד לביטוח לאומי, לפי גיל וסוג גמלה (מספרים ושיעור ל-100,000 בקבוצת הגיל*)  דצמבר 2010-2015
# starting the API call
# got answer
# ```json
# {
#   "is_analysis": "NO",
#   "explanation": "The graph covers a longer time period (1995-2015) than the table (2010-2015). Additionally, the graph focuses specifically on children living in families receiving alimony payments, while the table appears to cover orphaned children receiving various types of benefits. The graph also shows the proportion of these children among all children in Israel, which may not be directly derivable from the table data."
# }
# ```
# Saved graph 4_3_2016: NO
# 0.89530116 לוח 3.7 ילדים יתומים החיים במשפחות שמקבלות גמלה מהמוסד לביטוח לאומי, לפי גיל וסוג גמלה (מספרים ושיעור ל-100,000 בקבוצת הגיל*)  דצמבר 2010-2015
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "YES",
#     "explanation": "The graph shows the percentage distribution of orphaned children living in families receiving benefits by type of benefit for December 2015. This information can be derived directly from the table data, which contains the numbers and rates of orphaned children by age and benefit type for December 2010-2015. The graph simply presents the percentage breakdown for one specific time point (December 2015) that is covered in the table, making it redundant."
# }
# ```
# Saved graph 5_3_2016: YES
# 0.7569624 לוח 3.9 מספר הילדים הישראלים שנמסרו לאימוץ בידי השירות  למען הילד* במשרד הרווחה 1995-2015
# starting the API call
# got answer
# {
#     "is_analysis": "YES",
#     "explanation": "The graph is showing percentages of children adopted by Israeli citizens in 2015, which is a subset of the data from the table. The table covers Israeli children placed for adoption from 1995-2015, so the graph only represents the final year of data from the table, presented as percentages instead of raw counts. Since the time period and subjects in the graph are fully contained within the table's data range, the graph is redundant."
# }
# Saved graph 6_3_2016: YES
# 0.89147377 לוח 3.13 נישואי קטינים*   לפי מין, גיל ודת (מספרים) 2005-2014**
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "NO",
#     "explanation": "The graph covers years 1991-2014 while the table only includes data from 2005-2014. Since the graph contains temporal data (1991-2004) that is not present in the table, it provides unique information not derivable from the table data."
# }
# ```
# Saved graph 7_3_2016: NO
# 0.8194391 לוח 3.8 מספר הילדים היתומים (בגיל 0-17) של חללי צה"ל לפי שנה, מין* וגיל 1991-2015
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "NO",
#     "explanation": "The graph shows recruitment rates to the IDF by recruitment year and birth year, while the table contains data about orphans of IDF casualties by year, gender, and age. These are completely different datasets measuring different phenomena."
# }
# ```
# Saved graph 8_3_2016: NO
# 0.82609355 לוח 3.8 מספר הילדים היתומים (בגיל 0-17) של חללי צה"ל לפי שנה, מין* וגיל 1991-2015
# starting the API call
# WARNING:sentence_transformers.SentenceTransformer:No sentence-transformers model found with name onlplab/alephbert-base. Creating a new one with mean pooling.
# got answer
# ```json
# {
#     "is_analysis": "NO",
#     "explanation": "The graph shows recruitment rates to the IDF and reasons for non-recruitment by birth year and gender, while the table shows data about orphaned children of IDF casualties. These are completely different datasets measuring different phenomena."
# }
# ```
# Saved graph 9_3_2016: NO
# ✅ All graphs processed and saved.
# ✅ Loaded 10 tables and 6 graphs for chapter 04
# Some weights of BertModel were not initialized from the model checkpoint at onlplab/alephbert-base and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 0.9321071 לוח 4.1 גיל, מין וארץ מוצא של ילדים בפנימיות של המינהל לחינוך התיישבותי ועליית הנוער (מספרים ואחוזים) תש"ע (2009/10) - תשע"ה (2014/15)
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "NO",
#     "explanation": "The graph is about 'family type' (סוג משפחה) of children, while the table contains data about age, gender, and country of origin. The graph introduces a new variable (family type) not present in the table data, making it non-redundant."
# }
# ```
# Saved graph 1_4_2016: NO
# 0.94673395 לוח 4.5 ילדים שהושמו בפנימיות לילדים בסיכון,  לפי מגזר חינוכי וסוג פנימייה (מספרים ואחוזים) תשע"ו (2015/16)
# starting the API call
# got answer
# {
#     "is_analysis": "YES",
#     "explanation": "The graph shows children placed in residential facilities by welfare services, broken down by facility type. All of this information appears to be directly derivable from the table, which contains data on children in residential care facilities by educational sector and type of facility for the same time period (2015/16). The graph simply presents a subset or reorganization of the table data, focusing on the facility type breakdown."
# }
# Saved graph 2_4_2016: YES
# 0.8976079 לוח 4.2 ארץ מוצא/סוג קליטה* ושנת עלייה של ילדים בפנימיות של המינהל לחינוך התיישבותי ועליית הנוער (מספרים ואחוזים) תש"ע (2009/10) - תשע"ה (2014/15)
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "NO",
#     "explanation": "The graph shows children placed in dormitories by the Ministry of Welfare under the Youth Law (Care and Supervision) from 2004/05-2015/16, while the table shows country of origin/type of absorption and year of immigration for children in dormitories of the Administration for Settlement Education from 2009/10-2014/15. These are different populations, different time periods, and different variables being measured."
# }
# ```
# Saved graph 3_4_2016: NO
# 0.9275988 לוח  4.6 ארץ מוצא של ילדי עולים* שהושמו בידי משרד הרווחה בפנימיות לילדים בסיכון, לפי מגזר חינוכי של הפנימייה (אחוזים) תשע"ו (2015/16)
# starting the API call
# got answer
# ```json
# {
#   "is_analysis": "NO",
#   "explanation": "The graph shows data about children placed in boarding schools by welfare services according to parents' characteristics, while the table shows data specifically about children of immigrants categorized by country of origin and educational sector of the boarding school. The graph introduces a different dimension (parents' characteristics) not covered in the table."
# }
# ```
# Saved graph 4_4_2016: NO
# 0.922341 לוח 4.3 ילדים שהושמו בידי משרד הרווחה במסגרות חוץ-ביתיות, לפי סוג מסגרת (אחוזים)                                     תשע"ד (2013/14)
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "NO",
#     "explanation": "The graph shows data from 2015/16 while the table is from 2013/14. Additionally, the graph includes a breakdown by parents' marital status which is not present in the table. These represent different time periods and different variables/dimensions that cannot be derived from the table data."
# }
# ```
# Saved graph 5_4_2016: NO
# 0.9354917 לוח 4.8 גיל הילדים שהושמו באומנה בידי משרד הרווחה  לפי סוג אומנה* (אחוזים)  2015
# starting the API call
# WARNING:sentence_transformers.SentenceTransformer:No sentence-transformers model found with name onlplab/alephbert-base. Creating a new one with mean pooling.
# got answer
# ```json
# {
#     "is_analysis": "YES",
#     "explanation": "The graph appears to be visualizing the same data as the table - specifically showing children placed in foster care by the Ministry of Welfare by type of foster care (percentages) for 2015. Both the table and graph cover the same subject, same time period (2015), and use the same metric (percentages). The graph is simply a visual representation of the tabular data."
# }
# ```
# Saved graph 6_4_2016: YES
# ✅ All graphs processed and saved.
# ✅ Loaded 46 tables and 17 graphs for chapter 05
# Some weights of BertModel were not initialized from the model checkpoint at onlplab/alephbert-base and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 0.888209 לוח 5.6 מספר התלמידים לפי יישוב מגורים ושלב חינוך   (יישובים בני 10,000 נפש ויותר)  תשע"ה (2014/15)
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "NO",
#     "explanation": "The graph shows percentages of students by age group and sector (as a percentage of population in that age group), while the table shows absolute numbers of students by locality and education level. The graph introduces different variables (age groups and sectors/demographics) not present in the table, and presents data as percentages of population rather than raw counts."
# }
# ```
# Saved graph 1_5_2016: NO
# 0.89513665 לוח  5.16 הסביבה הפיזית בבית הספר לפי מגזר וכיתה*** (אחוזים*) תשע"ו (2015/16)
# starting the API call
# got answer
# ```json
# {
#   "is_analysis": "NO",
#   "explanation": "The graph appears to be showing 'positive feelings toward school' while the table shows data about 'physical environment in school'. These are different measures/variables. The table breaks down physical environment by sector and class, while the graph focuses on positive feelings by class. These represent distinct concepts that are not derivable from each other."
# }
# ```
# Saved graph 2_5_2016: NO
# 0.89382935 לוח  5.15 התנהגות נאותה של תלמידים בכיתה לפי מגזר וכיתה*** (אחוזים*) תשס"ח (2007/08) - תשע"ו (2015/16)
# starting the API call
# got answer
# {
#   "is_analysis": "NO",
#   "explanation": "The graph shows 'positive relationships between students and classmates' which is not one of the variables presented in the table. The table focuses on 'proper behavior of students in class by sector and class' which is a different measure. The graph appears to be examining student relationships rather than classroom behavior, so it introduces a variable not included in the table."
# }
# Saved graph 3_5_2016: NO
# 0.9513882 לוח 5.29 נסיבות ההרחקה של תלמידים שהורחקו לצמיתות מבית הספר לפי שנה (מספרים ואחוזים*)  תשע"ד (2013/14) - תשע"ה (2014/15)
# starting the API call
# got answer
# {
#     "is_analysis": "NO",
#     "explanation": "The graph shows data about student appeals after permanent expulsion from school, spanning years 2011/12-2014/15, while the table only covers circumstances of expulsion for 2013/14-2014/15. The graph includes earlier years (2011/12-2012/13) not present in the table, and focuses on appeals information which appears to be a different metric than the 'circumstances of expulsion' shown in the table."
# }
# Saved graph 4_5_2016: NO
# 0.9395435 לוח 5.29 נסיבות ההרחקה של תלמידים שהורחקו לצמיתות מבית הספר לפי שנה (מספרים ואחוזים*)  תשע"ד (2013/14) - תשע"ה (2014/15)
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "NO",
#     "explanation": "The graph covers years from 2011/12 to 2014/15, while the table only covers years 2013/14 to 2014/15. The graph includes data from two additional years (תשע"ב 2011/12 and תשע"ג 2012/13) that are not present in the table, making the graph provide unique information not found in the table."
# }
# ```
# Saved graph 5_5_2016: NO
# 0.9090988 לוח 5.30 מצב התלמידים שהורחקו לצמיתות מבית הספר (מספרים ואחוזים)  תשע"ה (2014/15)
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "YES",
#     "explanation": "The graph shows adaptation rates of students expelled from schools, which appears to be visualizing a subset of the data from Table 5.30 about permanently expelled students. Both refer to the same time period (2014/15) and use the same measurements (numbers and percentages). The graph is presenting a specific aspect of the expelled students' status that is already contained in the table."
# }
# ```
# Saved graph 6_5_2016: YES
# 0.95018864 לוח 5.31 תלמידים המטופלים בידי קציני ביקור סדיר (קב"סים) לפי כיתה ודת (מספרים ואחוזים)  תשע"ה (2014/15)-תשע"ו (2015/16)
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "NO",
#     "explanation": "The graph includes data from years 2004/05 to 2015/16, while the table only covers 2014/15-2015/16. The graph spans a much longer time period (12 years) than what's available in the table (2 years), so it contains information not derivable from the table."
# }
# ```
# Saved graph 7_5_2016: NO
# 0.9706502 לוח 5.32 אחוז תלמידי כיתות ו', ח' ו-י' שהסתלקו (ברחו) משיעורים או מלימודים שלושה ימים ויותר במהלך שנת הלימודים, לפי מין ומגזר 1998-2014
# starting the API call
# got answer
# {
#     "is_analysis": "YES",
#     "explanation": "The graph shows the percentage of 6th, 8th and 10th grade students who skipped/ran away from classes for three or more days during the school year, broken down by grade, gender and sector from 1998-2014. All of this information is already contained in the table with the same title, covering the same time period, and using the same breakdowns (grade, gender, sector). The graph is simply a visual representation of the tabular data."
# }
# Saved graph 8_5_2016: YES
# 0.9529675 לוח 5.33 נשירת תלמידים* בכיתות א'-יב' בחינוך העברי והערבי  לפי פיקוח, מין וותק בארץ במהלך שנת הלימודים תשע"ה (2014/15) ובמעבר לשנת הלימודים תשע"ו (2015/16) (מספרים ואחוזים)
# starting the API call
# got answer
# {
#     "is_analysis": "YES",
#     "explanation": "The graph appears to be displaying dropout rates for students in grades 1-12 in Hebrew and Arab education during the 2014/15 school year and transition to 2015/16, which is exactly the same data covered in the table. The table includes this information broken down by supervision, gender, and seniority in the country, and the graph is likely just visualizing this same data without adding any new variables or time periods."
# }
# Saved graph 9_5_2016: YES
# 0.8837161 לוח 5.35 תלמידי ז'-יב' שנשרו ממערכת החינוך במהלך שנת הלימודים תשע"ה (2014/15) ובמעבר לשנת הלימודים תשע"ו (2015/16), לפי מסגרת הלימוד החלופית* (מספרים ואחוז מהתלמידים**)
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "NO",
#     "explanation": "The table shows dropout data from 2014/15 to 2015/16, while the graph shows matriculation exam data (students who took exams and were eligible for certificates) from 2000/01 to 2014/15. The graph covers different metrics (exam participation and eligibility) and a much longer time period than the table, making it non-redundant."
# }
# ```
# Saved graph 10_5_2016: NO
# 0.84964085 לוח  5.43 חשיבות תעודת הבגרות לתלמידי כיתות י'-יא' לפי מגזר* (אחוזים**) תשע"ו (2015/16)
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "NO",
#     "explanation": "The graph shows data from 2014/15 (תשע\"ה) about students who took 4-5 units of math and English, while the table is from 2015/16 (תשע\"ו) and focuses on the importance of matriculation certificates. These represent different metrics from different time periods."
# }
# ```
# Saved graph 11_5_2016: NO
# 0.8964004 לוח 5.39 נשירת תלמידים* מכיתות ז'-יב' בחינוך הערבי  לפי כיתה (אחוזים) תש"ע (2009/10) - תשע"ו (2015/16)
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "NO",
#     "explanation": "The table shows dropout rates in Arab education for grades 7-12 from 2009/10-2015/16, while the graph shows data about excellent matriculation certificates among 12th grade students from 2012/13-2014/15. These are different metrics (dropout rates vs. excellent matriculation certificates) that measure different educational outcomes, so the graph is not a redundant visualization of the table."
# }
# ```
# Saved graph 12_5_2016: NO
# 0.8773936 לוח 5.42 אחוז הזכאים לתעודת בגרות שעמדו בדרישות הסף* של האוניברסיטאות מתלמידי כיתות י"ב, לפי יישוב מגורים (יישובים ומועצות מקומיות בני יותר מ-10,000 נפש)  תשע"ד (2013/14)
# starting the API call
# got answer
# {
#     "is_analysis": "NO",
#     "explanation": "The graph shows data across 1996-2014, while the table only shows data for 2013/14. The graph also includes a time series analysis that's not present in the table. Additionally, the graph breaks down data by population group ('קבוצת אוכלוסייה'), which does not appear to be included in the table that focuses on localities ('יישוב מגורים'). These are different dimensions of analysis not derivable from the table data."
# }
# Saved graph 13_5_2016: NO
# 0.83315164 לוח 5.42 אחוז הזכאים לתעודת בגרות שעמדו בדרישות הסף* של האוניברסיטאות מתלמידי כיתות י"ב, לפי יישוב מגורים (יישובים ומועצות מקומיות בני יותר מ-10,000 נפש)  תשע"ד (2013/14)
# starting the API call
# got answer
# {
#     "is_analysis": "NO",
#     "explanation": "The graph shows data about students with learning disabilities who received accommodations from 2010-2014, while the table focuses on eligibility for university matriculation certificates by location in 2013/14. These are different data points - the graph tracks learning disability accommodations over time, which is not present in the table data."
# }
# Saved graph 14_5_2016: NO
# 0.8107474 לוח   5.13 הערכות של תלמידים על בית ספרם  לפי מין ומגזר (אחוז מכלל התלמידים בקבוצה המתאימה)  2014
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "NO",
#     "explanation": "The graph shows data about students with learning disabilities who were approved for accommodations, broken down by population groups, which is not information contained in the table. The table shows student evaluations of their schools by gender and sector, which is completely different data. These are separate datasets addressing different aspects of the education system."
# }
# ```
# Saved graph 15_5_2016: NO
# 0.89255595 לוח 5.29 נסיבות ההרחקה של תלמידים שהורחקו לצמיתות מבית הספר לפי שנה (מספרים ואחוזים*)  תשע"ד (2013/14) - תשע"ה (2014/15)
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "NO",
#     "explanation": "The graph shows data about invalidated exams due to suspected cheating for years 2012/13-2014/15, while the table contains information about permanent student expulsions and their circumstances for 2013/14-2014/15. These are different metrics (exam invalidation vs. expulsion) and the graph includes a year (2012/13) not covered by the table."
# }
# ```
# Saved graph 16_5_2016: NO
# 0.8194955 לוח 5.45 דירוג פסיכוטכני של המתגייסים לצה"ל  (אחוזים) 1995-2015*
# starting the API call
# WARNING:sentence_transformers.SentenceTransformer:No sentence-transformers model found with name onlplab/alephbert-base. Creating a new one with mean pooling.
# got answer
# ```json
# {
#     "is_analysis": "NO",
#     "explanation": "The graph shows 'years of education' of military recruits by gender, which is not included in the table. The table only shows psychotechnical ratings of recruits, not education levels. These are different variables, and the gender breakdown is also not present in the table data."
# }
# ```
# Saved graph 17_5_2016: NO
# ✅ All graphs processed and saved.
# ✅ Loaded 16 tables and 20 graphs for chapter 06
# Some weights of BertModel were not initialized from the model checkpoint at onlplab/alephbert-base and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 0.9384608 לוח 6.3 אחוז התלמידים שבדרך כלל צופים בטלויזיה* ארבע שעות ביום או יותר, בזמנם הפנוי בימי השבוע לפי כיתה, מגזר ומין  2014
# starting the API call
# got answer
# {
#     "is_analysis": "NO",
#     "explanation": "The graph shows data by year from 2002-2014, while the table only includes data for 2014. The graph includes historical time series information that is not available in the table, making it a non-redundant visualization."
# }
# Saved graph 1_6_2016: NO
# 0.90268844 לוח 6.5 השפעת השימוש באמצעים דיגיטליים* על בני נוער (12-17) והוריהם (אחוזים) יולי 2015
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "NO",
#     "explanation": "The graph shows data about digital communication usage for interpersonal purposes, while the table appears to focus on the effects of digital media usage. While they share the same demographic groups (12-17 year olds and their parents) and time period (July/Summer 2015), they measure different aspects of digital usage - effects versus interpersonal communication purposes. The graph introduces a specific dimension (interpersonal communication) not explicitly covered in the table."
# }
# ```
# Saved graph 2_6_2016: NO
# 0.8971975 לוח 6.5 השפעת השימוש באמצעים דיגיטליים* על בני נוער (12-17) והוריהם (אחוזים) יולי 2015
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "NO",
#     "explanation": "The graph shows 'purpose of use of digital communication by teenagers' which is not derivable from the table that focuses on 'effects of digital media use on teenagers and their parents'. These are different measures - the effects versus the purpose of use, representing distinct information not contained in the same dataset."
# }
# ```
# Saved graph 3_6_2016: NO
# 0.8960663 לוח 6.5 השפעת השימוש באמצעים דיגיטליים* על בני נוער (12-17) והוריהם (אחוזים) יולי 2015
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "YES",
#     "explanation": "Both the table and graph show data about digital media usage by teenagers (12-17) and parental supervision from the same time period (July/Summer 2015). The graph appears to be presenting a subset of the data from the table, specifically focusing on parental supervision of teenagers' digital communication usage, which is information already contained in the table. The graph is simply visualizing specific percentages that can be derived from the table data."
# }
# ```
# Saved graph 4_6_2016: YES
# 0.9105339 לוח 6.5 השפעת השימוש באמצעים דיגיטליים* על בני נוער (12-17) והוריהם (אחוזים) יולי 2015
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "YES",
#     "explanation": "Both the table and graph show data about teenagers (12-17) and their parents' relationship with digital media usage from July/Summer 2015. The graph specifically focuses on parents' awareness of their children's digital media usage, which is a subset of the information contained in the table about the effects of digital media use on teenagers and their parents. The time period matches (2015) and no additional variables are introduced in the graph that aren't available in the table data."
# }
# ```
# Saved graph 5_6_2016: YES
# 0.8659226 לוח 6.7 משך השימוש היומי של ילדים (8-15) בטלפון החכם (סמארטפון)  לפי מין וגיל (אחוזים) ינואר 2015
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "NO",
#     "explanation": "The graph is about 'children who own a smartphone' (ownership rates) while the table describes 'daily usage time of smartphones by children'. These are different measures - ownership versus usage duration. The table data cannot be used to derive ownership percentages."
# }
# ```
# Saved graph 6_6_2016: NO
# 0.90656483 לוח 6.7 משך השימוש היומי של ילדים (8-15) בטלפון החכם (סמארטפון)  לפי מין וגיל (אחוזים) ינואר 2015
# starting the API call
# got answer
# ```json
# {
#   "is_analysis": "NO",
#   "explanation": "While both the table and graph appear to cover smartphone usage by children (8-15) from January 2015, the graph title indicates it shows 'usage' more generally, while the table specifically shows 'daily usage duration'. The table breaks down data by gender and age, but without seeing the actual graph content, I cannot confirm it shows exactly the same information. The asterisk (*) in the graph title suggests there may be additional information or a specific type of usage not specified in the table."
# }
# ```
# Saved graph 7_6_2016: NO
# 0.89840686 לוח 6.5 השפעת השימוש באמצעים דיגיטליים* על בני נוער (12-17) והוריהם (אחוזים) יולי 2015
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "NO",
#     "explanation": "The graph shows data comparing social media usage between teens (12-17) and adults (18+), while the table focuses on the effects of digital media usage on teens and their parents. The graph introduces a new comparison (teens vs adults 18+) not present in the table which only addresses teens and their parents specifically. The different focus makes the graph non-redundant."
# }
# ```
# Saved graph 8_6_2016: NO
# 0.8316621 לוח 6.5 השפעת השימוש באמצעים דיגיטליים* על בני נוער (12-17) והוריהם (אחוזים) יולי 2015
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "NO",
#     "explanation": "The graph specifically shows Instagram app usage among teenagers (12-17), but the table header only mentions 'digital means' in general without specifying Instagram. The graph appears to focus on a specific digital platform that may not be explicitly broken down in the table data."
# }
# ```
# Saved graph 9_6_2016: NO
# 0.80664545 לוח 6.5 השפעת השימוש באמצעים דיגיטליים* על בני נוער (12-17) והוריהם (אחוזים) יולי 2015
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "NO",
#     "explanation": "The graph appears to show data specifically about Instagram private accounts among teenagers (12-17), while the table focuses more broadly on the impact of digital media use on teenagers and their parents. The table header doesn't indicate that it contains specific information about Instagram accounts, suggesting the graph presents information not directly derivable from the table."
# }
# ```
# Saved graph 10_6_2016: NO
# 0.82610166 לוח 6.5 השפעת השימוש באמצעים דיגיטליים* על בני נוער (12-17) והוריהם (אחוזים) יולי 2015
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "NO",
#     "explanation": "The graph shows the distribution of Instagram followers among teenagers (12-17), but the table only mentions digital means usage impact. The graph introduces a new variable (number of Instagram followers) that is not present in the table data, so it provides unique information that cannot be derived from the table."
# }
# ```
# Saved graph 11_6_2016: NO
# 0.84131914 לוח 6.5 השפעת השימוש באמצעים דיגיטליים* על בני נוער (12-17) והוריהם (אחוזים) יולי 2015
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "NO",
#     "explanation": "The graph specifically shows Instagram app usage patterns by teenagers (12-17) broken down by viewing content types, which is not provided in the table. The table appears to focus on the general impact of digital media on teenagers and their parents, but does not contain specific data about Instagram content viewing preferences. This represents unique information not derivable from the table."
# }
# ```
# Saved graph 12_6_2016: NO
# 0.8346024 לוח 6.5 השפעת השימוש באמצעים דיגיטליים* על בני נוער (12-17) והוריהם (אחוזים) יולי 2015
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "NO",
#     "explanation": "While both the table and graph relate to digital media use by teenagers, the graph specifically focuses on Instagram application usage patterns, which is not clearly presented in the table. The table header mentions 'digital means' broadly but doesn't specify Instagram data. The graph appears to contain specific information about Instagram usage that is not derivable from the general digital media impact data in the table."
# }
# ```
# Saved graph 13_6_2016: NO
# 0.6979213 לוח 6.7 משך השימוש היומי של ילדים (8-15) בטלפון החכם (סמארטפון)  לפי מין וגיל (אחוזים) ינואר 2015
# Saved graph 14_6_2016: NO
# 0.86351633 לוח 6.9 סוג הפעילות ההתנדבותית של תלמידים  לפי מגזר ומין (אחוזים) 2014
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "NO",
#     "explanation": "The graph shows time series data from 2004-2014, while the table only shows data for 2014. The graph tracks volunteer participation over multiple years which is not present in the table that only shows types of volunteer activities for a single year."
# }
# ```
# Saved graph 15_6_2016: NO
# 0.7987764 לוח 6.9 סוג הפעילות ההתנדבותית של תלמידים  לפי מגזר ומין (אחוזים) 2014
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "NO",
#     "explanation": "The graph presents data from 2015 about youth movement members by gender (numbers and percentages), while the table shows volunteer activities of students by sector and gender from 2014. The graph presents different data (youth movement membership vs. volunteer activities) from a different year (2015 vs. 2014)."
# }
# ```
# Saved graph 16_6_2016: NO
# 0.8372043 לוח 6.9 סוג הפעילות ההתנדבותית של תלמידים  לפי מגזר ומין (אחוזים) 2014
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "NO",
#     "explanation": "The table shows volunteer activities of students by sector and gender in 2014, while the graph shows youth movement members by sector across years up to 2015. The graph includes data for 2015 not covered in the table, and focuses on youth movements specifically rather than general volunteering activities. These are different metrics and timeframes."
# }
# ```
# Saved graph 17_6_2016: NO
# 0.8068768 לוח 6.9 סוג הפעילות ההתנדבותית של תלמידים  לפי מגזר ומין (אחוזים) 2014
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "NO",
#     "explanation": "The graph shows data about youth movement participants by grade (2015), while the table contains data about volunteer activities of students by sector and gender (2014). These are different data sets with different variables, different years, and different measures."
# }
# ```
# Saved graph 18_6_2016: NO
# 0.8098908 לוח 6.9 סוג הפעילות ההתנדבותית של תלמידים  לפי מגזר ומין (אחוזים) 2014
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "NO",
# ...
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "NO",
#     "explanation": "The graph shows data for 2015 only, while the table covers the period 2005-2015. The graph is showing a specific slice of the table data (just 2015) rather than redundantly representing the entire table. Additionally, the graph appears to be focusing on the status of children investigated ('מעמד הנחקר'), which is one specific aspect of the table data about immigrant children."
# }
# ```
# Saved graph 10_13_2016: NO
# 0.92568034 לוח 13.1 מספר תיקים פליליים* ותיקי טיפול מותנה (ט.מ.) שנפתחו בגין עבירות כנגד קטינים במשפחה ומחוץ למשפחה, לפי סוג תיק  2006-2015
# starting the API call
# WARNING:sentence_transformers.SentenceTransformer:No sentence-transformers model found with name onlplab/alephbert-base. Creating a new one with mean pooling.
# got answer
# ```json
# {
#   "is_analysis": "NO",
#   "explanation": "The graph shows data about crimes related to marriage age laws, which is not mentioned in the table. The table focuses on criminal cases against minors inside and outside families, while the graph specifically analyzes marriage age law violations. The graph also covers a wider time range (2000-2015) than the table (2006-2015)."
# }
# ```
# Saved graph 11_13_2016: NO
# ✅ All graphs processed and saved.
# ✅ Loaded 41 tables and 25 graphs for chapter 14
# Some weights of BertModel were not initialized from the model checkpoint at onlplab/alephbert-base and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 0.79503995 לוח 14.4 יישוב המגורים של ילדים המוכרים למחלקות לשירותים חברתיים,   גילם וחלקם בכלל ילדי היישוב (מספרים ואחוזים) 2005-2016*
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "YES",
#     "explanation": "The graph shows localities where 30% or more of children are known to social services departments in January 2016, which is a subset/filtered view of the table data. The table contains information about children known to social services across different localities from 2005-2016, including their percentages in each locality, so the graph simply highlights localities meeting the 30% threshold from the 2016 data in the table."
# }
# ```
# Saved graph 1_14_2016: YES
# 0.7733742 לוח 14.6 מספר הבקשות* לפטור מחובת דיווח** אודות פגיעה בילדים שטופלו, הוגשו ואושרו, לפי מחוז    1995-2015
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "NO",
#     "explanation": "The table focuses on exemption requests from reporting child abuse across districts from 1995-2015, while the graph shows the relationship of the abuser to the reported child (e.g., family member, non-family) for 2015. The graph introduces a new variable (abuser's relationship to child) that is not included in the table data."
# }
# ```
# Saved graph 2_14_2016: NO
# 0.8892429 לוח 14.5 דיווחים* לעובדים סוציאליים לחוק הנוער, לפי שנה, מין, גיל וסיבת הדיווח (מספרים ואחוזים)  2015
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "NO",
#     "explanation": "The graph focuses specifically on reports about minors with disabilities categorized by type of disability, which appears to be a breakdown not explicitly shown in the table. While the table includes reports by year, gender, age and reason for reporting, it doesn't appear to have the specific disability type breakdown featured in the graph."
# }
# ```
# Saved graph 3_14_2016: NO
# 0.8222598 לוח 14.15 גילם של בני נוער וצעירים בטיפולה של רשות חסות הנוער  (מספרים ואחוזים)   2005-2015
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "NO",
#     "explanation": "The graph focuses on reports to social workers regarding immigrant minors, while the table shows the age distribution of youth in the care of the Youth Protection Authority. These appear to be different datasets covering different measures - one about reports to social workers specifically about immigrant minors, and the other about age demographics of youth in protective custody."
# }
# ```
# Saved graph 4_14_2016: NO
# 0.79754937 לוח 14.5 דיווחים* לעובדים סוציאליים לחוק הנוער, לפי שנה, מין, גיל וסיבת הדיווח (מספרים ואחוזים)  2015
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "YES",
#     "explanation": "The graph shows percentages of true and false reports to social workers, which can be derived from the table data. The table contains information about reports to social workers by year, gender, age, and reason for reporting (both numbers and percentages) for 2015, which encompasses all the information presented in the graph. The graph is simply showing a specific view or aggregation of this data."
# }
# ```
# Saved graph 5_14_2016: YES
# 0.8718896 לוח 14.11 גיל הילדים בסיכון שהיו בטיפול במרכזי חירום  לפי סוג מסגרת (ממוצע)  2015
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "YES",
#     "explanation": "The graph shows children at risk placed in emergency frameworks by type of framework as percentages for 2015, which can be derived from the table data that shows average ages of children at risk in emergency centers by type of framework for the same year 2015. The graph is simply representing the same data as percentages rather than showing the ages."
# }
# ```
# Saved graph 6_14_2016: YES
# 0.8582016 לוח 14.24 מין וסיבת הפנייה של ילדים לחדר מיון עקב שימוש בסמים  (מספרים, אחוזים ושיעור למאה אלף בכלל הילדים)  2010-2015
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "NO",
#     "explanation": "The table shows emergency room visits for drug use (2010-2015), while the graph shows at-risk children in internal emergency center treatment (2000-2015). These represent different populations, different facilities, different causes, and different time periods, making them distinct data sources."
# }
# ```
# Saved graph 7_14_2016: NO
# 0.85156184 לוח 14.11 גיל הילדים בסיכון שהיו בטיפול במרכזי חירום  לפי סוג מסגרת (ממוצע)  2015
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "NO",
#     "explanation": "The table shows age distribution of children at risk in emergency centers by type of facility (average for 2015), while the graph shows gender distribution of children removed to emergency facilities (percentages for 2015). The gender breakdown is a new variable not present in the table, which only focuses on age."
# }
# ```
# Saved graph 8_14_2016: NO
# 0.9131603 לוח 14.12 תקופת השהות של ילדים בסיכון שהיו בטיפול במרכזי חירום  לפי סוג מסגרת (ממוצע בחודשים)  2015
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "NO",
#     "explanation": "The table shows average duration of stay in months, while the graph shows percentages of children. The graph represents a distribution that cannot be derived directly from the average values in the table. The table provides mean duration in months, but the graph shows a percentage breakdown that would require the original count data to generate."
# }
# ```
# Saved graph 9_14_2016: NO
# 0.8360513 לוח 14.2 ילדים נטושים המוכרים למחלקות לשירותים חברתיים  לפי גיל ומוצא (מספרים) 2010-2016*
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "NO",
#     "explanation": "The graph shows data about children staying in shelters for women victims of violence from 2001-2015, while the table is about abandoned children known to social services departments by age and origin from 2010-2016. These are different metrics and different time periods. The graph presents information not derivable from the table data."
# }
# ```
# Saved graph 10_14_2016: NO
# 0.811183 לוח 14.11 גיל הילדים בסיכון שהיו בטיפול במרכזי חירום  לפי סוג מסגרת (ממוצע)  2015
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "NO",
#     "explanation": "The graph shows data about children staying in shelters for women affected by violence, while the table is about at-risk children treated in emergency centers. These are different populations and facilities, so the graph contains unique information not derivable from the table."
# }
# ```
# Saved graph 11_14_2016: NO
# 0.8214545 לוח 14.12 תקופת השהות של ילדים בסיכון שהיו בטיפול במרכזי חירום  לפי סוג מסגרת (ממוצע בחודשים)  2015
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "NO",
#     "explanation": "The graph shows data about length of stay for children in shelters for women victims of violence, while the table shows length of stay for at-risk children in emergency centers. These are different types of facilities and populations, so the graph presents information not contained in the table."
# }
# ```
# Saved graph 12_14_2016: NO
# 0.91228354 לוח 14.15 גילם של בני נוער וצעירים בטיפולה של רשות חסות הנוער  (מספרים ואחוזים)   2005-2015
# starting the API call
# got answer
# {
#     "is_analysis": "NO",
#     "explanation": "The graph covers years 2002-2015 while the table only covers 2005-2015. The graph includes 3 additional years (2002-2004) not present in the table, making it not redundant as it provides unique information not available in the table data."
# }
# Saved graph 13_14_2016: NO
# 0.92908096 לוח 14.19 עיסוקם של בני נוער (13-17) במצוקה לאחר שטופלו בידי השרות למתבגרים וצעירים במשרד הרווחה (מספרים ואחוזים) 2015
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "NO",
#     "explanation": "The graph appears to show gender breakdown (מין הנערים והנערות) of youth in distress, while the table focuses on their occupations (עיסוקם) after treatment. The graph specifically highlights gender distribution which doesn't seem to be included as a variable in the table that focuses on occupations."
# }
# ```
# Saved graph 14_14_2016: NO
# 0.8692854 לוח  14.25 תדירות שתיית אלכוהול בקרב תלמידי כיתות ו', ח', י', יא' ו-יב'  לפי מגזר ומין (אחוז בקבוצה המתאימה) 2014
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "NO",
#     "explanation": "The table is about alcohol consumption frequency among students in grades 6, 8, 10, 11, and 12 by sector and gender (2014), while the graph shows daily cigarette/tobacco product usage among students in grades 6, 8, and 10 from 1998-2014. These are different substances (alcohol vs. tobacco) and the graph covers multiple years (1998-2014) not present in the table data."
# }
# ```
# Saved graph 15_14_2016: NO
# 0.8852316 לוח  14.25 תדירות שתיית אלכוהול בקרב תלמידי כיתות ו', ח', י', יא' ו-יב'  לפי מגזר ומין (אחוז בקבוצה המתאימה) 2014
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "NO",
#     "explanation": "The graph shows a time series from 1998-2014, while the table only contains data for 2014. The graph includes historical data not present in the table, making it provide unique information that cannot be derived from the table alone."
# }
# ```
# Saved graph 16_14_2016: NO
# 0.87909937 לוח  14.25 תדירות שתיית אלכוהול בקרב תלמידי כיתות ו', ח', י', יא' ו-יב'  לפי מגזר ומין (אחוז בקבוצה המתאימה) 2014
# starting the API call
# got answer
# {
#     "is_analysis": "NO",
#     "explanation": "The graph shows data from 2015/16, while the table is from 2014. The graph covers a different time period than the table, making it non-redundant as it provides unique information not available in the table."
# }
# Saved graph 17_14_2016: NO
# 0.8531412 לוח 14.29 קטינים שהוכרזו כנעדרים* ואותרו  לפי מין, גיל ומוצא (מספרים) 2002-2015
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "NO",
#     "explanation": "The graph shows data breakdown by 'מחוז' (district/region) which is not included in the table. The table only breaks down the data by gender (מין), age (גיל), and origin (מוצא), but does not include regional/district information."
# }
# ```
# Saved graph 18_14_2016: NO
# 0.76968414 לוח 14.32 תלמידים בכיתות י' שחשבו על התאבדות, הכינו תכנית או ניסו להתאבד ב-12 החודשים האחרונים (אחוזים) 2004-2014
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "NO",
#     "explanation": "The graph shows suicide attempts by poisoning for ages 12-17 from 1993-2015, while the table only covers suicidal thoughts/plans/attempts for 10th graders from 2004-2014. The graph has a different age range, covers more years (including years not in the table), focuses specifically on poisoning method, and presents absolute numbers rather than percentages."
# }
# ```
# Saved graph 19_14_2016: NO
# 0.82433283 לוח 14.31 נסיונות התאבדות של ילדים ובני נוער שהתקבלו בחדרי מיון  לפי מין וגיל* (מספרים) 2004-2015
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "NO",
#     "explanation": "The graph shows suicide deaths (התאבדויות) from 1990-2014, while the table shows suicide attempts (נסיונות התאבדות) from 2004-2015. These are different measures covering different time periods, so the graph is not redundant."
# }
# ```
# Saved graph 20_14_2016: NO
# 0.9418491 לוח 14.35 תחומי פנייה לנציב קבילות ילדים ובני נוער (אומבודסמן)  במועצה לשלום הילד (מספרים ואחוזים)  1990-2015
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "YES",
#     "explanation": "The graph shows the number of requests to the Children's Ombudsman at the National Council for the Child for 1990-2015, which is directly available in the table. The table includes both numbers and percentages by area of request for the same time period (1990-2015), so the graph is simply plotting one of the metrics already present in the table without adding any new information."
# }
# ```
# Saved graph 21_14_2016: YES
# 0.86343485 לוח 14.14 ילדים ובני נוער בסיכון שטופלו בידי מחלקות אגף א' - חינוך ילדים ונוער בסיכון* במשרד החינוך, לפי מחלקות האגף (מספרים ואחוזים) 2003-2015
# starting the API call
# got answer
# {
#     "is_analysis": "NO",
#     "explanation": "The graph shows data about children supported by a program for victims of crimes at the National Council for the Child from 2006-2016, while the table focuses on at-risk children treated by departments of the Ministry of Education from 2003-2015. The graph covers a different program, different organization, and includes the year 2016 which is not in the table. These are separate datasets tracking different populations."
# }
# Saved graph 22_14_2016: NO
# 0.8323943 לוח 14.14 ילדים ובני נוער בסיכון שטופלו בידי מחלקות אגף א' - חינוך ילדים ונוער בסיכון* במשרד החינוך, לפי מחלקות האגף (מספרים ואחוזים) 2003-2015
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "NO",
#     "explanation": "The graph shows data from 2016 for a specific program (child victims of crime) with age and gender breakdowns, while the table covers different services from 2003-2015. The graph presents newer data (2016) not included in the table, and focuses on variables (gender breakdown and child victims of crime) that aren't mentioned in the table."
# }
# ```
# Saved graph 23_14_2016: NO
# 0.8384609 לוח 14.14 ילדים ובני נוער בסיכון שטופלו בידי מחלקות אגף א' - חינוך ילדים ונוער בסיכון* במשרד החינוך, לפי מחלקות האגף (מספרים ואחוזים) 2003-2015
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "NO",
#     "explanation": "The graph shows data about child victims of crimes treated through a specific program at the National Council for the Child, broken down by type of offense. The table discusses children and youth at risk treated by departments of Division A in the Ministry of Education. These are completely different data sources and populations, with the graph showing information not present in the table."
# }
# ```
# Saved graph 24_14_2016: NO
# 0.8598288 לוח 14.38 פניית קטינים למרכזי הסיוע* לנפגעי תקיפה מינית לפי סוג תקיפה                          (מספרים ואחוזים)   2013-2014
# starting the API call
# got answer
# ```json
# {
#     "is_analysis": "NO",
#     "explanation": "The table shows data about types of sexual assault involving minors who contacted help centers in 2013-2014. The graph focuses on percentage of sexual assault reports by age and time elapsed between the assault and reporting in 2014. The graph introduces two variables not in the table: age breakdown and time elapsed between assault and reporting, making it non-redundant."
# }
# ```
# Saved graph 25_14_2016: NO
# ✅ All graphs processed and saved.

# %%
##cleaning up the table_summmaries.json from the tables first and second row +
# one row table name without /n or hebrew and english format mistakes
## localy running about 1s. ####
# (much needed for the redundancy check)

import os
import csv
import json

def update_summary_headers_second_row_multiple_louch(year_dir, summary_json_path):
    """
    Update summary_table.json headers using the second row of each CSV:
    - Keep all cells containing 'לוח' aside (in order)
    - Check duplicates among other cells (ignoring empty strings)
    - Skip if more than one distinct non-empty text exists outside 'לוח'
    - Build header: all 'לוח' cells concatenated + duplicate text
    - Remove newlines so header is a single line
    """
    # Load the JSON
    with open(summary_json_path, "r", encoding="utf-8") as f:
        summary_data = json.load(f)

    # Walk through all CSVs
    for root, _, files in os.walk(year_dir):
        for file in files:
            if not file.endswith(".csv"):
                continue
            csv_path = os.path.join(root, file)

            # Extract JSON key from filename (remove .csv)
            json_key = file[:-4]
            if json_key not in summary_data:
                print(f"JSON key not found for {file}, skipping.")
                continue

            # Read the second row
            with open(csv_path, "r", encoding="utf-8-sig") as f:
                reader = csv.reader(f)
                try:
                    next(reader)  # Skip first row
                    second_row = next(reader)  # Read second row
                except StopIteration:
                    print(f"CSV has less than 2 rows: {file}, skipping.")
                    continue

            # Separate 'לוח' cells and other cells (ignore empty strings)
            louch_cells = [cell for cell in second_row if "לוח" in cell]
            other_cells = [cell for cell in second_row if cell not in louch_cells and cell != ""]

            if not louch_cells:
                print(f"No 'לוח' cell found in second row, skipping: {file}")
                continue

            # Check duplicates among other_cells
            unique_texts = set(other_cells)
            if len(unique_texts) > 1:
                print(f"More than one distinct non-empty text in second row (excluding 'לוח'), skipping: {file}")
                continue

            # Determine duplicate text (empty if nothing else)
            duplicate_text = other_cells[0] if other_cells else ""
            louch_cell = louch_cells[0]  if louch_cells else ""

            # Build cleaned header: concatenate 'לוח' + duplicate, remove newlines
            cleaned_header = " ".join([louch_cell] + ([duplicate_text] if duplicate_text else []))
            cleaned_header = cleaned_header.replace("\n", " ").replace("\r", " ").strip()

            # Update JSON
            summary_data[json_key] = cleaned_header

    # Save updated JSON
    with open(summary_json_path, "w", encoding="utf-8") as f:
        json.dump(summary_data, f, ensure_ascii=False, indent=4)

    print("Summary JSON updated successfully.")


# # Example usage
for year in range(2001,2017):
   update_summary_headers_second_row_multiple_louch(f"/content/tables_2001-2016/{year}", "/content/tables_summary_all_cleaned.json")

# %%
## extracting releavant graphs into a new directory - convertion prep ###

import os
import json
import shutil

# Paths
graphs_dir = "/content/graphs"
redundant_json_path = "/content/redundant_graphs.json"
graphs_summary_path = "/content/graphs_summary.json"
relevant_dir = "/content/relevant_graphs"
relevant_summary_path = "/content/relevant_graphs_summary.json"

# Load JSONs
with open(redundant_json_path, "r", encoding="utf-8") as f:
    redundant_map = json.load(f)

with open(graphs_summary_path, "r", encoding="utf-8") as f:
    graphs_summary = json.load(f)

# Ensure relevant directory exists
os.makedirs(relevant_dir, exist_ok=True)

# ---------- Helper ----------
def filename_to_key(fname):
    """
    Convert filename '2023_03__04.png' -> '4_3_2023' to match JSON keys.
    Handles double underscores before the serial number and strips leading zeros.
    """
    base = os.path.splitext(fname)[0]
    parts = [p for p in base.split("_") if p != ""]  # remove empty strings
    if len(parts) >= 3:
        year, chapter, serial = parts[:3]
        chapter = str(int(chapter))  # remove leading zeros
        serial = str(int(serial))    # remove leading zeros
        return f"{serial}_{chapter}_{year}"
    return base  # fallback

# ---------- Filter relevant graphs ----------
relevant_summary = {}

for year in os.listdir(graphs_dir):
    year_path = os.path.join(graphs_dir, year)
    if not os.path.isdir(year_path):
        continue

    for chapter in os.listdir(year_path):
        chapter_path = os.path.join(year_path, chapter)
        if not os.path.isdir(chapter_path):
            continue

        for fname in os.listdir(chapter_path):
            if not fname.lower().endswith((".png", ".jpg", ".jpeg", ".pdf")):
                continue

            key = filename_to_key(fname)

            if redundant_map.get(key, "NO") == "NO":  # only keep relevant
                # Copy to relevant directory
                new_year_dir = os.path.join(relevant_dir, year)
                new_chap_dir = os.path.join(new_year_dir, chapter)
                os.makedirs(new_chap_dir, exist_ok=True)
                shutil.copy2(os.path.join(chapter_path, fname), os.path.join(new_chap_dir, fname))

                # Add to relevant summary if exists
                if key in graphs_summary:
                    relevant_summary[key] = graphs_summary[key]

# Save relevant summary JSON
with open(relevant_summary_path, "w", encoding="utf-8") as f:
    json.dump(relevant_summary, f, ensure_ascii=False, indent=2)

print("✅ Filtering complete")
print(f"Relevant graphs saved under: {relevant_dir}")
print(f"Relevant summary saved as: {relevant_summary_path}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1330987801.py in <cell line: 0>()
#      11
#      12 # Load JSONs
# ---> 13 with open(redundant_json_path, "r", encoding="utf-8") as f:
#      14     redundant_map = json.load(f)
#      15
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/redundant_graphs.json'

# %%
##validation to decesion - randomlly chosing cases (default 40) to check by hand ###

import json
import random

def sample_yes_cases(json_path, out_path="/content/yes_samples_validation.txt", n=40, seed=42):
    # Load JSON
    with open(json_path, "r") as f:
        data = json.load(f)

    # Collect only "YES" cases
    yes_items = [(k, v) for k, v in data.items() if v.get("is_analysis") == "YES"]

    # Sample randomly (uniform)
    random.seed(seed)  # reproducibility
    sample = random.sample(yes_items, min(n, len(yes_items)))

    # Write to file in readable format
    with open(out_path, "w", encoding="utf-8") as f:
        for key, entry in sample:
            f.write(f"Key: {key}\n")
            f.write(f"Table: {entry.get('table','')}\n")
            f.write(f"Graph: {entry.get('graph','')}\n")
            f.write(f"Similarity: {entry.get('similarity','')}\n")
            f.write(f"Explanation: {entry.get('explanation','')}\n")
            f.write("="*80 + "\n")

    print(f"✅ Saved {len(sample)} YES cases to {out_path}")

# Example usage
sample_yes_cases("/content/redundant_graphs.json")

# %%
## validation of extraction
## ran locally in my computer ###

#!/usr/bin/env python3
# generate_checks.py
import json
import random
from pathlib import Path
from collections import OrderedDict
import csv

# External libs
from docx import Document
from reportlab.lib.pagesizes import A4
from reportlab.pdfgen import canvas
from reportlab.lib.units import mm

# ---------- CONFIG ----------
JSON_FILENAME = "graphs_summary.json"   # file expected in same folder
OUT_DIR = Path("checks_output")
OUT_DIR.mkdir(parents=True, exist_ok=True)
PERSONS = ["shira", "suf", "elisheva", "shaul"]
TABLES_PER_PERSON = 10
PAGES_PER_PERSON = 10
TOTAL_CHECKS_PER_PERSON = TABLES_PER_PERSON + PAGES_PER_PERSON
YEARS_ALLOWED = list(range(2001, 2017)) + [2019, 2021, 2022, 2023]
SEED = 42  # set to None for nondeterministic sampling
# ----------------------------

random.seed(SEED)

# ---------- load JSON ----------
json_path = Path(JSON_FILENAME)
if not json_path.exists():
    raise FileNotFoundError(f"JSON file not found: {json_path.resolve()}\nPut your graphs_summary.json next to this script")

with json_path.open("r", encoding="utf-8") as f:
    data = json.load(f)

# Normalize items -> list of (key, description)
all_items = []
for k, v in data.items():
    if isinstance(v, str):
        desc = v.replace("\n", " ").strip()  # <--- preprocessing here
    elif isinstance(v, dict):
        desc = (
            v.get("table")
            or v.get("graph")
            or v.get("explanation")
            or json.dumps(v, ensure_ascii=False)
        )
        desc = desc.replace("\n", " ").strip()  # <--- preprocessing here too
    else:
        desc = str(v).replace("\n", " ").strip()  # <--- also here
    all_items.append((k, desc))

if not all_items:
    raise RuntimeError("No items found in JSON file.")

# ---------- helper ----------
def parse_key(key):
    parts = key.split("_")
    try:
        serial = int(parts[0]); chapter = int(parts[1]); year = int(parts[2])
        return serial, chapter, year
    except Exception:
        return None, None, None

def sample_unique(n, pool):
    """Uniform sample without replacement if possible else with replacement."""
    if n <= len(pool):
        return random.sample(pool, n)
    else:
        # not enough unique items: sample all then fill with random choices
        out = pool.copy()
        while len(out) < n:
            out.append(random.choice(pool))
        return out

# ---------- sampling per person ----------
persons_data = {}
for person in PERSONS:
    tables = sample_unique(TABLES_PER_PERSON, all_items)
    page_checks = []
    for _ in range(PAGES_PER_PERSON):
        page = random.randint(5, 30)
        chapter = random.randint(1, 15)
        year = random.choice(YEARS_ALLOWED)
        page_checks.append({"page": page, "chapter": chapter, "year": year})
    persons_data[person] = {"tables": tables, "page_checks": page_checks}

# ---------- save CSV of sampled keys ----------
csv_path = OUT_DIR / "sampled_keys.csv"
with csv_path.open("w", encoding="utf-8", newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["person", "kind", "index", "key", "chapter", "year", "short_description"])
    for person, pdata in persons_data.items():
        for i, (key, desc) in enumerate(pdata["tables"], start=1):
            _, chapter, year = parse_key(key)
            short = desc.replace("\n", " ")[:250]
            writer.writerow([person, "table", i, key, chapter, year, short])
        for i, chk in enumerate(pdata["page_checks"], start=1):
            writer.writerow([person, "page_check", i, "", chk["chapter"], chk["year"], f"page {chk['page']}"])

print(f"Saved CSV of sampled keys to {csv_path}")

# ---------- create DOCX per person ----------
for person, pdata in persons_data.items():
    doc = Document()
    doc.add_heading(f"Checks for {person.capitalize()}", level=1)
    doc.add_paragraph(f"Total checks: {TOTAL_CHECKS_PER_PERSON} (10 table checks + 10 page checks)")
    doc.add_paragraph("Instructions: For each table entry, go to the indicated chapter/year and confirm whether the table exists. Mark Found / Not Found and add notes.\n")
    doc.add_heading("Part A — Table entries (from our summary)", level=2)
    for i, (key, desc) in enumerate(pdata["tables"], start=1):
        serial, chapter, year = parse_key(key)
        doc.add_paragraph(f"{i}. Key: {key}  (Chapter: {chapter}, Year: {year})")
        short_desc = desc if len(desc) < 600 else desc[:600] + " ..."
        doc.add_paragraph(short_desc)
        doc.add_paragraph("[ ] Found   [ ] Not Found\n")
    doc.add_heading("Part B — Page checks", level=2)
    for i, chk in enumerate(pdata["page_checks"], start=1):
        doc.add_paragraph(f"{i}. Page: {chk['page']}   Chapter: {chk['chapter']}   Year: {chk['year']}")
        doc.add_paragraph("Was there a table on this page? [ ] Yes  [ ] No    If yes: which table key? ______   Exists in our data? [ ] Yes [ ] No \n")
    doc_path = OUT_DIR / f"{person}_checks.docx"
    doc.save(doc_path)
    print(f"Wrote {doc_path}")

# ---------- create combined PDF ----------
pdf_path = OUT_DIR / "checks_all_people.pdf"
c = canvas.Canvas(str(pdf_path), pagesize=A4)
width, height = A4
margin = 18 * mm
x = margin
y_start = height - margin
line_h = 12
font_name = "Helvetica"

for person, pdata in persons_data.items():
    y = y_start
    c.setFont(font_name, 14)
    c.drawString(x, y, f"Checks for {person.capitalize()}")
    y -= 18
    c.setFont(font_name, 10)
    c.drawString(x, y, f"Total checks: {TOTAL_CHECKS_PER_PERSON} (10 table checks + 10 page checks)")
    y -= 14
    c.drawString(x, y, "Part A — Table entries (tick Found / Not Found).")
    y -= 14

    for i, (key, desc) in enumerate(pdata["tables"], start=1):
        serial, chapter, year = parse_key(key)
        c.setFont(font_name, 9)
        c.drawString(x, y, f"{i}. Key: {key}  (Ch {chapter}, Yr {year})")
        # checkboxes
        bx = width - margin - 120
        c.rect(bx, y-4, 8, 8)
        c.drawString(bx+12, y, "Found")
        c.rect(bx+56, y-4, 8, 8)
        c.drawString(bx+68, y, "Not Found")
        y -= line_h
        # wrapped description
        desc_short = desc.replace("\n", " ")
        max_chars = 120
        words = desc_short.split()
        cur = ""
        for w in words:
            if len(cur) + len(w) + 1 <= max_chars:
                cur += (" " + w) if cur else w
            else:
                c.drawString(x+6, y, cur)
                y -= 10
                cur = w
                if y < margin + 60:
                    c.showPage()
                    y = y_start
        if cur:
            c.drawString(x+6, y, cur)
            y -= 14
        if y < margin + 80:
            c.showPage()
            y = y_start

    c.setFont(font_name, 11)
    c.drawString(x, y, "Part B — Page checks")
    y -= 14
    c.setFont(font_name, 10)
    for i, chk in enumerate(pdata["page_checks"], start=1):
        c.drawString(x, y, f"{i}. Page {chk['page']}   Chapter {chk['chapter']}   Year {chk['year']}")
        bx = width - margin - 170
        c.rect(bx, y-4, 8, 8)
        c.drawString(bx+12, y, "Table present?")
        c.rect(bx+90, y-4, 8, 8)
        c.drawString(bx+102, y, "Exists in data?")
        y -= line_h
        c.drawString(x+10, y, "If yes: which table key? ___________ ")
        y -= 18
        if y < margin + 80:
            c.showPage()
            y = y_start

    c.showPage()

c.save()
print(f"Wrote combined PDF: {pdf_path}")

print("\nAll outputs written to:", OUT_DIR.resolve())

# %%
# statistics of extracted YES/NO (arround 20% redundent) ###

import json
from collections import defaultdict
import pandas as pd

def analyze_redundant_graphs(json_path="/content/redundant_graphs.json"):
    # Load JSON
    with open(json_path, "r") as f:
        data = json.load(f)

    # Counting structures
    yearly_counts = defaultdict(lambda: {"YES": 0, "NO": 0})
    chapter_counts = defaultdict(lambda: {"YES": 0, "NO": 0})
    overall_counts = {"YES": 0, "NO": 0}

    # Parse keys
    for key, value in data.items():
        try:
            serial, chapter, year = map(int, key.split("_"))
        except ValueError:
            continue  # skip malformed keys

        # Update counts
        yearly_counts[year][value] += 1
        chapter_counts[(year, chapter)][value] += 1
        overall_counts[value] += 1

    # Yearly stats
    year_df = pd.DataFrame.from_dict(yearly_counts, orient="index").sort_index()
    year_df["Total"] = year_df["YES"] + year_df["NO"]
    year_df["%YES"] = (year_df["YES"] / year_df["Total"] * 100).round(2)
    year_df["%NO"] = (year_df["NO"] / year_df["Total"] * 100).round(2)

    # Chapter stats
    chapter_df = pd.DataFrame.from_dict(chapter_counts, orient="index")
    chapter_df.index = pd.MultiIndex.from_tuples(chapter_df.index, names=["Year", "Chapter"])
    chapter_df = chapter_df.sort_index()
    chapter_df["Total"] = chapter_df["YES"] + chapter_df["NO"]
    chapter_df["%YES"] = (chapter_df["YES"] / chapter_df["Total"] * 100).round(2)
    chapter_df["%NO"] = (chapter_df["NO"] / chapter_df["Total"] * 100).round(2)

    # Overall stats with % too
    overall_total = overall_counts["YES"] + overall_counts["NO"]
    overall_percent = {
        "YES": round(overall_counts["YES"] / overall_total * 100, 2),
        "NO": round(overall_counts["NO"] / overall_total * 100, 2),
    }

    # Print summaries
    print("=== Overall Counts ===")
    print(overall_counts)
    print("=== Overall % ===")
    print(overall_percent)
    print("\n=== Yearly Stats ===")
    display(year_df)
    print("\n=== Chapter Stats (per year, per chapter) ===")
    display(chapter_df)

    return overall_counts, year_df, chapter_df

analyze_redundant_graphs()
# Out:
# === Overall Counts ===
# {'YES': 369, 'NO': 1421}
# === Overall % ===
# {'YES': 20.61, 'NO': 79.39}
#
# === Yearly Stats ===
#       YES   NO  Total   %YES    %NO
# 2001   24   73     97  24.74  75.26
# 2002   25   87    112  22.32  77.68
# 2003   29   78    107  27.10  72.90
# 2004   30   75    105  28.57  71.43
# 2005   21   72     93  22.58  77.42
# 2006   20   89    109  18.35  81.65
# 2007   18   92    110  16.36  83.64
# 2008   19   90    109  17.43  82.57
# 2009   19  116    135  14.07  85.93
# 2010   30  115    145  20.69  79.31
# 2011   26  120    146  17.81  82.19
# 2012   21   97    118  17.80  82.20
# 2013   18   96    114  15.79  84.21
# 2014   31  101    132  23.48  76.52
# 2015   38  120    158  24.05  75.95
# === Chapter Stats (per year, per chapter) ===
#               YES  NO  Total    %YES     %NO
# Year Chapter
# 2001 1          0   2      2    0.00  100.00
#      2          3   3      6   50.00   50.00
#      3          1  11     12    8.33   91.67
#      4          1   0      1  100.00    0.00
#      5          3   6      9   33.33   66.67
# ...           ...  ..    ...     ...     ...
# 2015 10         2  15     17   11.76   88.24
#      11         0   2      2    0.00  100.00
#      12         1   9     10   10.00   90.00
#      13         1  15     16    6.25   93.75
#      14         4  21     25   16.00   84.00
#
# [199 rows x 5 columns]
# ({'YES': 369, 'NO': 1421},
#        YES   NO  Total   %YES    %NO
#  2001   24   73     97  24.74  75.26
#  2002   25   87    112  22.32  77.68
#  2003   29   78    107  27.10  72.90
#  2004   30   75    105  28.57  71.43
#  2005   21   72     93  22.58  77.42
#  2006   20   89    109  18.35  81.65
#  2007   18   92    110  16.36  83.64
#  2008   19   90    109  17.43  82.57
#  2009   19  116    135  14.07  85.93
#  2010   30  115    145  20.69  79.31
#  2011   26  120    146  17.81  82.19
#  2012   21   97    118  17.80  82.20
#  2013   18   96    114  15.79  84.21
#  2014   31  101    132  23.48  76.52
#  2015   38  120    158  24.05  75.95,
#                YES  NO  Total    %YES     %NO
#  Year Chapter
#  2001 1          0   2      2    0.00  100.00
#       2          3   3      6   50.00   50.00
#       3          1  11     12    8.33   91.67
#       4          1   0      1  100.00    0.00
#       5          3   6      9   33.33   66.67
#  ...           ...  ..    ...     ...     ...
#  2015 10         2  15     17   11.76   88.24
#       11         0   2      2    0.00  100.00
#       12         1   9     10   10.00   90.00
#       13         1  15     16    6.25   93.75
#       14         4  21     25   16.00   84.00
#
#  [199 rows x 5 columns])
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['YES'].plot(kind='hist', bins=20, title='YES')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['NO'].plot(kind='hist', bins=20, title='NO')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['Total'].plot(kind='hist', bins=20, title='Total')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='index', y='YES', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='YES', y='NO', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='NO', y='Total', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='Total', y='%YES', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['YES']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_8.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('YES')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['NO']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_9.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('NO')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['Total']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_10.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('Total')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['%YES']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_11.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('%YES')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_12['index'].plot(kind='line', figsize=(8, 4), title='index')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_13['YES'].plot(kind='line', figsize=(8, 4), title='YES')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_14['NO'].plot(kind='line', figsize=(8, 4), title='NO')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_15['Total'].plot(kind='line', figsize=(8, 4), title='Total')
# plt.gca().spines[['top', 'right']].set_visible(False)
